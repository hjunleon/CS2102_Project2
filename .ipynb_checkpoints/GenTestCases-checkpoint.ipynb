# %%
# !pip install psycopg2
# Out:
# /bin/bash: /home/randell-crapy/miniconda3/envs/base_py39/lib/libtinfo.so.6: no version information available (required by /bin/bash)
# Requirement already satisfied: psycopg2 in /home/randell-crapy/miniconda3/envs/finance/lib/python3.10/site-packages (2.9.3)

# %%
import psycopg2 
import random
import string
# from datetime import time
from datetime import datetime, timedelta
import time
from enum import Enum
import math

# %%
def connect__to_database():
    conn = None
    try:
        conn = psycopg2.connect(database="cs2102_project2",
                        host="localhost",
                        user="postgres",
                        password="burnoutx123",
                        port="5432")
        return conn 
    except (Exception, psycopg2.DatabaseError) as error:
        print(error)
    return False

# %%
conn = connect__to_database()

# %%
cursor = conn.cursor()

# %%
cursor.execute("SELECT * FROM accepted_requests")

# %%
cursor.execute("SELECT datname FROM pg_database")
for table in cursor.fetchall():
    print(table)
# Out:
# ('postgres',)
# ('template1',)
# ('template0',)
# ('golang_gin_db',)
# ('nus_mods',)
# ('cs2102_project2',)
# ('uv3_autocompound',)
# ('cs2102_as_01',)
# ('wonderland',)

# %%
cursor.close()
conn.close()

# %%
# random_seed = 20
# random.seed(random_seed)

# %%
def get_random_string(length):
    # choose from all lowercase letter
    letters = string.ascii_letters
    return ''.join(random.choice(letters) for i in range(length))

def get_random_number(length):
    choices = [str(x) for x in range(10)]
    return ''.join(random.choice(choices) for i in range(length))

def get_random_int_to(start = 2, upto = 9):
    return random.randint(start, upto)

def get_random_float_from_to(start = 1, mul = 9):
    return round(random.random() * mul, 2) + start

def random_plus_minus(num, mag = 5):
    return num + random.random() * 5 - random.random() * 5 

def get_random_price():
    return round(random.random() * 100, 2)

def random_date():
    d = random.randint(1, int(time.time()))
    return datetime.fromtimestamp(d).strftime('%Y-%m-%d')
def random_timestamp():
    d = random.randint(1, int(time.time()))
    return datetime.fromtimestamp(d)#.strftime('%Y-%m-%d')

# %%
def is_cancelled(status):
    return status == 'cancelled'

def is_unsuccessful(status):
    return status == 'unsuccessful'

# %%
NUM_EMPLOYEES = 50
NUM_FACILITIES = 10
NUM_CUSTOMERS = 1000
NUM_DEL_REQ = NUM_CUSTOMERS * 2
NUM_PACKAGES = math.floor(NUM_DEL_REQ * 1.5)
NUM_LEGS = NUM_DEL_REQ * 3
NUM_UNSUCCESSFUL_PICKUP = NUM_DEL_REQ // 100 + 5
# class delivery_status(Enum):
#     submitted = 1
#     evaluated = 2
#     withdrawn = 3
#     accepted = 4
#     completed = 5
#     cancelled = 6
#     unsuccessful = 7
    
all_d_status = ['submitted', 'evaluated', 'withdrawn', 'accepted', 'completed', 'cancelled', 'unsuccessful']
accepted_statuses = set(['accepted', 'completed', 'cancelled', 'unsuccessful'])

# %%
employee = {}
delivery_staff_id = set()
for i in range(NUM_EMPLOYEES):
    this_id = i + 1
    to_add = {}
    to_add['gender'] = random.choice( ['male', 'female'] )
    to_add['name'] = get_random_string(16)
    to_add["dob"] = random_date()
    to_add["title"] = random.choice(['Mr', 'Ser']) if to_add['gender'] == 'male' else random.choice(['Mrs', 'Miss', "Mdm"])
    to_add["salary"] = round(random.random() * 15000, 2)
    to_add["is_delivery"] = False
    employee[this_id] = to_add
for i in range(min(NUM_EMPLOYEES,10)):
    this_id = i + 1
    employee[this_id]["is_delivery"] = True
    delivery_staff_id.add(this_id)
employee
# Out:
# {1: {'gender': 'male',
#   'name': 'eOOYKNUMTrZLOubA',
#   'dob': '2003-08-20',
#   'title': 'Mr',
#   'salary': 5138.68,
#   'is_delivery': True},
#  2: {'gender': 'male',
#   'name': 'MKzZRSgJUXpbKpXf',
#   'dob': '2021-08-26',
#   'title': 'Ser',
#   'salary': 9.11,
#   'is_delivery': True},
#  3: {'gender': 'male',
#   'name': 'VjsEaBgfjJQsofRu',
#   'dob': '1999-03-04',
#   'title': 'Mr',
#   'salary': 5472.37,
#   'is_delivery': True},
#  4: {'gender': 'male',
#   'name': 'lnvgCnFCzgrtWjrU',
#   'dob': '1978-08-09',
#   'title': 'Ser',
#   'salary': 11303.86,
#   'is_delivery': True},
#  5: {'gender': 'male',
#   'name': 'ViiXttJHRnOBJqtH',
#   'dob': '1999-05-17',
#   'title': 'Mr',
#   'salary': 5333.98,
#   'is_delivery': True},
#  6: {'gender': 'male',
#   'name': 'udwZOZOWyQytWdhy',
#   'dob': '1984-01-25',
#   'title': 'Mr',
#   'salary': 823.66,
#   'is_delivery': True},
#  7: {'gender': 'female',
#   'name': 'YrhqVrnmYYtNPrGa',
#   'dob': '2007-01-08',
#   'title': 'Mrs',
#   'salary': 1603.07,
#   'is_delivery': True},
#  8: {'gender': 'female',
#   'name': 'XBbxeFOrVdkxdtsv',
#   'dob': '1976-06-11',
#   'title': 'Mdm',
#   'salary': 801.17,
#   'is_delivery': True},
#  9: {'gender': 'female',
#   'name': 'tLSeIikEVWQbluCq',
#   'dob': '1986-02-20',
#   'title': 'Miss',
#   'salary': 5955.27,
#   'is_delivery': True},
#  10: {'gender': 'male',
#   'name': 'NevNcXzAlGDYgHZP',
#   'dob': '2005-05-20',
#   'title': 'Ser',
#   'salary': 3629.8,
#   'is_delivery': True},
#  11: {'gender': 'female',
#   'name': 'AymGNuRGfLRYeaKd',
#   'dob': '2019-07-08',
#   'title': 'Miss',
#   'salary': 10545.75,
#   'is_delivery': False},
#  12: {'gender': 'female',
#   'name': 'LXpiXXLrGLGVqqlx',
#   'dob': '1970-06-10',
#   'title': 'Mrs',
#   'salary': 1969.57,
#   'is_delivery': False},
#  13: {'gender': 'male',
#   'name': 'FCzgGglRtJrVmItv',
#   'dob': '2013-02-15',
#   'title': 'Mr',
#   'salary': 1117.8,
#   'is_delivery': False},
#  14: {'gender': 'male',
#   'name': 'ZLuiBhTcnUYkvqCP',
#   'dob': '2005-10-17',
#   'title': 'Ser',
#   'salary': 1065.37,
#   'is_delivery': False},
#  15: {'gender': 'male',
#   'name': 'psEePcOwmoNZHLZf',
#   'dob': '1983-03-18',
#   'title': 'Mr',
#   'salary': 6286.17,
#   'is_delivery': False},
#  16: {'gender': 'male',
#   'name': 'NrzxDYVecJPNZrkU',
#   'dob': '2009-07-07',
#   'title': 'Ser',
#   'salary': 7483.65,
#   'is_delivery': False},
#  17: {'gender': 'female',
#   'name': 'BRgSxeHHSNIQkwDK',
#   'dob': '1992-10-10',
#   'title': 'Miss',
#   'salary': 11362.68,
#   'is_delivery': False},
#  18: {'gender': 'female',
#   'name': 'noNnbvliDWNcbwkx',
#   'dob': '2017-08-23',
#   'title': 'Mrs',
#   'salary': 10312.22,
#   'is_delivery': False},
#  19: {'gender': 'male',
#   'name': 'sokaCtUWvPKWivRY',
#   'dob': '1980-08-23',
#   'title': 'Ser',
#   'salary': 8166.99,
#   'is_delivery': False},
#  20: {'gender': 'male',
#   'name': 'TJYmuidxVwjaVptW',
#   'dob': '1989-08-29',
#   'title': 'Ser',
#   'salary': 12122.74,
#   'is_delivery': False},
#  21: {'gender': 'female',
#   'name': 'ZlKtISBmMRANZreE',
#   'dob': '2008-08-17',
#   'title': 'Mrs',
#   'salary': 8588.28,
#   'is_delivery': False},
#  22: {'gender': 'female',
#   'name': 'LPXxKEyYVJjlmqMo',
#   'dob': '2018-09-20',
#   'title': 'Mrs',
#   'salary': 11015.15,
#   'is_delivery': False},
#  23: {'gender': 'female',
#   'name': 'WsmxkSlAxjkaekmh',
#   'dob': '2020-12-20',
#   'title': 'Mdm',
#   'salary': 10112.56,
#   'is_delivery': False},
#  24: {'gender': 'female',
#   'name': 'MpHgnMpCbNFIKDjC',
#   'dob': '1978-05-21',
#   'title': 'Mrs',
#   'salary': 12633.74,
#   'is_delivery': False},
#  25: {'gender': 'male',
#   'name': 'hqUFgZJFGQtRobvd',
#   'dob': '1980-02-23',
#   'title': 'Mr',
#   'salary': 3892.29,
#   'is_delivery': False},
#  26: {'gender': 'male',
#   'name': 'UqIMihcDUtTllZQW',
#   'dob': '1989-02-18',
#   'title': 'Ser',
#   'salary': 14562.73,
#   'is_delivery': False},
#  27: {'gender': 'female',
#   'name': 'rXLzTqNFhuoKUXFf',
#   'dob': '1984-01-15',
#   'title': 'Mdm',
#   'salary': 2058.13,
#   'is_delivery': False},
#  28: {'gender': 'female',
#   'name': 'YgsHILPajoTJTibs',
#   'dob': '1982-10-15',
#   'title': 'Mdm',
#   'salary': 12772.32,
#   'is_delivery': False},
#  29: {'gender': 'female',
#   'name': 'rOVHAEjGBYstRefh',
#   'dob': '1999-07-22',
#   'title': 'Mdm',
#   'salary': 1159.24,
#   'is_delivery': False},
#  30: {'gender': 'male',
#   'name': 'CvShLbGxbRwVgMEI',
#   'dob': '1976-10-24',
#   'title': 'Mr',
#   'salary': 5256.95,
#   'is_delivery': False},
#  31: {'gender': 'female',
#   'name': 'wXkkfUmHvBiiQSbm',
#   'dob': '1975-10-14',
#   'title': 'Miss',
#   'salary': 11482.18,
#   'is_delivery': False},
#  32: {'gender': 'male',
#   'name': 'hDeXgZyEeByPsGyF',
#   'dob': '2003-06-05',
#   'title': 'Mr',
#   'salary': 5458.68,
#   'is_delivery': False},
#  33: {'gender': 'male',
#   'name': 'aUWCFkswHJObOmpK',
#   'dob': '2003-06-02',
#   'title': 'Mr',
#   'salary': 3821.12,
#   'is_delivery': False},
#  34: {'gender': 'female',
#   'name': 'FCYFaySvXjZIfVQL',
#   'dob': '1970-12-11',
#   'title': 'Miss',
#   'salary': 12592.53,
#   'is_delivery': False},
#  35: {'gender': 'female',
#   'name': 'rnrkukwhelaCVmju',
#   'dob': '2022-02-05',
#   'title': 'Mrs',
#   'salary': 11568.5,
#   'is_delivery': False},
#  36: {'gender': 'male',
#   'name': 'UxpQkaSpsKjAPGfW',
#   'dob': '2000-03-15',
#   'title': 'Mr',
#   'salary': 14757.96,
#   'is_delivery': False},
#  37: {'gender': 'male',
#   'name': 'pvuXqAoUCapjVFra',
#   'dob': '1988-10-03',
#   'title': 'Mr',
#   'salary': 1183.99,
#   'is_delivery': False},
#  38: {'gender': 'male',
#   'name': 'WxYWrwrsgikoFxXo',
#   'dob': '1971-02-16',
#   'title': 'Mr',
#   'salary': 14325.69,
#   'is_delivery': False},
#  39: {'gender': 'female',
#   'name': 'LgrEGHgRXrmQcTZq',
#   'dob': '1986-10-12',
#   'title': 'Mrs',
#   'salary': 188.28,
#   'is_delivery': False},
#  40: {'gender': 'male',
#   'name': 'UuzLUzojoauYdfTj',
#   'dob': '1975-03-18',
#   'title': 'Mr',
#   'salary': 2117.44,
#   'is_delivery': False},
#  41: {'gender': 'female',
#   'name': 'JeNNFpcAQpymZewQ',
#   'dob': '1991-02-15',
#   'title': 'Mdm',
#   'salary': 387.12,
#   'is_delivery': False},
#  42: {'gender': 'female',
#   'name': 'HMPNIVPyItjceBzT',
#   'dob': '2016-05-27',
#   'title': 'Mdm',
#   'salary': 13390.68,
#   'is_delivery': False},
#  43: {'gender': 'female',
#   'name': 'QkqtYnrUEYDXkuPq',
#   'dob': '1997-10-20',
#   'title': 'Mrs',
#   'salary': 1624.16,
#   'is_delivery': False},
#  44: {'gender': 'male',
#   'name': 'VzJijguRsYtzUgvK',
#   'dob': '1974-03-04',
#   'title': 'Mr',
#   'salary': 4936.25,
#   'is_delivery': False},
#  45: {'gender': 'female',
#   'name': 'spnlOlFoPrYTxrYF',
#   'dob': '1984-05-27',
#   'title': 'Mdm',
#   'salary': 12802.72,
#   'is_delivery': False},
#  46: {'gender': 'male',
#   'name': 'wqDaRJgoGPCLYrMr',
#   'dob': '1989-06-03',
#   'title': 'Ser',
#   'salary': 12420.76,
#   'is_delivery': False},
#  47: {'gender': 'male',
#   'name': 'VqksCQPOxFNowNcU',
#   'dob': '1973-01-09',
#   'title': 'Ser',
#   'salary': 719.94,
#   'is_delivery': False},
#  48: {'gender': 'female',
#   'name': 'tLcDieZblWOeXrds',
#   'dob': '1999-09-12',
#   'title': 'Mdm',
#   'salary': 1586.62,
#   'is_delivery': False},
#  49: {'gender': 'male',
#   'name': 'fvgwUTDRgeQAyIGv',
#   'dob': '2007-08-05',
#   'title': 'Mr',
#   'salary': 13831.33,
#   'is_delivery': False},
#  50: {'gender': 'female',
#   'name': 'yIfgkGkkgawdSywj',
#   'dob': '2021-05-14',
#   'title': 'Miss',
#   'salary': 8327.13,
#   'is_delivery': False}}

# %%
customers = {}
for i in range(NUM_CUSTOMERS):
    this_id = i + 1
    to_add = {}
cancelled_or_unsuccessful_requests_id = set()
for i in range(NUM_DEL_REQ):
    this_id = i + 1
    to_add = {}
    to_add['recipient_name'] = get_random_string(16)
    to_add['recipient_addr'] = get_random_string(32)
    to_add['recipient_postal'] = get_random_number(6)
    to_add['pickup_addr'] = get_random_string(32)
    to_add['pickup_postal'] = get_random_number(6)
    to_add['pickup_date'] = random_date()
    current_timestamp = random_timestamp()
    to_add['submission_time'] = current_timestamp
    to_add['num_days_needed'] = get_random_int_to(2, 16)
    to_add['price'] = get_random_price()
    
    to_add['customer_id'] = random.choice(list(customers.keys()))
    to_add['evaluater_id'] = random.choice(list(employee.keys()))
    to_add['status'] = random.choice(all_d_status)
    
    if (to_add['status'] in accepted_statuses):
        to_add['card_number'] = get_random_number(12)
        to_add['payment_time'] = random_timestamp()
        to_add['monitor_id'] = random.choice(list(employee.keys()))
        accepted_req_id.add(this_id)
        
    if (is_cancelled(to_add['status'])):
        current_timestamp += timedelta(hours=get_random_int_to(1,12))
        to_add['cancel_time'] = current_timestamp
        cancelled_or_unsuccessful_requests_id.add(this_id)
    
    if (is_unsuccessful(to_add['status'])):
        cancelled_or_unsuccessful_requests_id.add(this_id)
    
    delivery_requests[this_id] = to_add
    
delivery_requests
# Out:
# {1: {'recipient_name': 'KgtqsTFDBrokzFDt',
#   'recipient_addr': 'uJmwMrUOQFzjUlkIKVSLHKcUQTsuOPcl',
#   'recipient_postal': '418832',
#   'pickup_addr': 'oABuOYgRowypvqeXzAoTAOxLJJvweXlv',
#   'pickup_postal': '092991',
#   'pickup_date': '2009-03-27',
#   'submission_time': datetime.datetime(1972, 2, 16, 16, 16, 28),
#   'num_days_needed': 16,
#   'price': 59.65,
#   'customer_id': 593,
#   'evaluater_id': 30,
#   'status': 'withdrawn'},
#  2: {'recipient_name': 'dBTIRWcHLQaIpJXr',
#   'recipient_addr': 'BKAgOAwojjorZvdRwDFXDIqwkfoHjpOg',
#   'recipient_postal': '470823',
#   'pickup_addr': 'duADBhCiyaBMxyALLofxbVjtTWILMkQE',
#   'pickup_postal': '067525',
#   'pickup_date': '2001-01-13',
#   'submission_time': datetime.datetime(1972, 11, 9, 9, 41, 16),
#   'num_days_needed': 9,
#   'price': 15.28,
#   'customer_id': 407,
#   'evaluater_id': 49,
#   'status': 'withdrawn'},
#  3: {'recipient_name': 'CmUeAyKoZmonzlTZ',
#   'recipient_addr': 'hDWGoecjOyXZcHPoOxuPxfjUZxaurlbh',
#   'recipient_postal': '523549',
#   'pickup_addr': 'aXpgmVdDkfORgYAZoGxpTqhioEyKvnJF',
#   'pickup_postal': '447345',
#   'pickup_date': '1996-08-18',
#   'submission_time': datetime.datetime(1984, 4, 17, 14, 6, 46),
#   'num_days_needed': 7,
#   'price': 75.15,
#   'customer_id': 432,
#   'evaluater_id': 38,
#   'status': 'submitted'},
#  4: {'recipient_name': 'NJjblzquSORjaPPA',
#   'recipient_addr': 'nEznGiloUYtSbeJDFfGzvVkkldzkkcEv',
#   'recipient_postal': '812138',
#   'pickup_addr': 'htmCrisupaYqkRYPlZGklzcjQeEAlfuG',
#   'pickup_postal': '522905',
#   'pickup_date': '2000-02-19',
#   'submission_time': datetime.datetime(1998, 9, 25, 23, 2, 14),
#   'num_days_needed': 5,
#   'price': 91.44,
#   'customer_id': 250,
#   'evaluater_id': 36,
#   'status': 'submitted'},
#  5: {'recipient_name': 'qgFIQLWoNIrlLqtM',
#   'recipient_addr': 'CQyrzcFpoMqsRTwGfDQxRigsJQZvcTvc',
#   'recipient_postal': '294058',
#   'pickup_addr': 'jytWBdJwQIkSgGQIvcxedMkQAjDCxSiY',
#   'pickup_postal': '782986',
#   'pickup_date': '1987-10-06',
#   'submission_time': datetime.datetime(1989, 3, 24, 12, 27, 21),
#   'num_days_needed': 9,
#   'price': 81.49,
#   'customer_id': 719,
#   'evaluater_id': 2,
#   'status': 'evaluated'},
#  6: {'recipient_name': 'SZrTfPRfJAcwCpDw',
#   'recipient_addr': 'VbATUINyhhygPnZtmRcbyYaZUUIJsLHZ',
#   'recipient_postal': '051023',
#   'pickup_addr': 'ruveuZVluZtFYSSYRqfMcDDLsibvgome',
#   'pickup_postal': '750900',
#   'pickup_date': '2007-06-28',
#   'submission_time': datetime.datetime(2021, 5, 9, 11, 49, 57),
#   'num_days_needed': 10,
#   'price': 23.87,
#   'customer_id': 538,
#   'evaluater_id': 28,
#   'status': 'evaluated'},
#  7: {'recipient_name': 'TWyEKKfnHSkwZKer',
#   'recipient_addr': 'qjAJJjgmzNntUExCPEPBPUhOwzScyzHQ',
#   'recipient_postal': '120881',
#   'pickup_addr': 'EhvDkxsOuxclGKJEvcsteAGRHBYqWEJV',
#   'pickup_postal': '125520',
#   'pickup_date': '2021-01-11',
#   'submission_time': datetime.datetime(1997, 7, 10, 15, 57, 9),
#   'num_days_needed': 14,
#   'price': 57.67,
#   'customer_id': 459,
#   'evaluater_id': 40,
#   'status': 'submitted'},
#  8: {'recipient_name': 'DgHkPGDurdQtmvNp',
#   'recipient_addr': 'TvQXBfqiKtABinjPzUkKiatWgMLCgUpx',
#   'recipient_postal': '122961',
#   'pickup_addr': 'cAUMUlcRCPgQaobMUYyxNRhFBhCGGaGJ',
#   'pickup_postal': '200084',
#   'pickup_date': '1991-05-16',
#   'submission_time': datetime.datetime(1986, 11, 17, 8, 32, 10),
#   'num_days_needed': 2,
#   'price': 52.15,
#   'customer_id': 426,
#   'evaluater_id': 7,
#   'status': 'submitted'},
#  9: {'recipient_name': 'xGwZuZYWiqazdVab',
#   'recipient_addr': 'uIKZWqntegtTeIoisoxFNzEUUZqpCwnL',
#   'recipient_postal': '288976',
#   'pickup_addr': 'hClbAkPjbZGckTunXxAMSUsYDRyUbmOz',
#   'pickup_postal': '627230',
#   'pickup_date': '1988-02-12',
#   'submission_time': datetime.datetime(1970, 6, 21, 8, 31, 56),
#   'num_days_needed': 8,
#   'price': 60.09,
#   'customer_id': 212,
#   'evaluater_id': 26,
#   'status': 'completed',
#   'card_number': '447606076036',
#   'payment_time': datetime.datetime(2014, 9, 30, 7, 14, 13),
#   'monitor_id': 16},
#  10: {'recipient_name': 'GQqOMQyVkgIAyjJU',
#   'recipient_addr': 'GvXDJIGZDNAFjxgKaaYerULJrGFxVejn',
#   'recipient_postal': '720200',
#   'pickup_addr': 'VQarFwvOcVPJbzkBXNoNwNXmVXzTPYqd',
#   'pickup_postal': '600992',
#   'pickup_date': '1988-10-15',
#   'submission_time': datetime.datetime(2012, 11, 19, 19, 19, 32),
#   'num_days_needed': 9,
#   'price': 14.71,
#   'customer_id': 356,
#   'evaluater_id': 42,
#   'status': 'evaluated'},
#  11: {'recipient_name': 'SRDcREVmRLSGdvuF',
#   'recipient_addr': 'pAVICchesVSrgwwYlqcUQaleGLpNrqFH',
#   'recipient_postal': '704842',
#   'pickup_addr': 'BHcbbjmeIoCfOFKQXTXSMSJbcHBQvDVT',
#   'pickup_postal': '538581',
#   'pickup_date': '2017-09-05',
#   'submission_time': datetime.datetime(1982, 8, 28, 11, 1, 49),
#   'num_days_needed': 16,
#   'price': 70.44,
#   'customer_id': 592,
#   'evaluater_id': 8,
#   'status': 'completed',
#   'card_number': '324273804347',
#   'payment_time': datetime.datetime(1972, 10, 20, 21, 10, 50),
#   'monitor_id': 47},
#  12: {'recipient_name': 'BmCrTOfXxirTjXdJ',
#   'recipient_addr': 'dvGMWKAMXIzrGiRmiadMNdWJdPDDCJsG',
#   'recipient_postal': '592337',
#   'pickup_addr': 'cRcGqEMukaTDFgooINYrmKawAIElYbsj',
#   'pickup_postal': '390807',
#   'pickup_date': '2005-04-07',
#   'submission_time': datetime.datetime(1988, 11, 6, 20, 41, 5),
#   'num_days_needed': 6,
#   'price': 9.63,
#   'customer_id': 599,
#   'evaluater_id': 16,
#   'status': 'accepted',
#   'card_number': '606147156778',
#   'payment_time': datetime.datetime(2003, 7, 31, 14, 14, 35),
#   'monitor_id': 32},
#  13: {'recipient_name': 'GhRXLADQqnLvycjS',
#   'recipient_addr': 'KMXsNhZxxsDdnofsNlCBdrLlkkCSgwyH',
#   'recipient_postal': '359530',
#   'pickup_addr': 'tNTtSgPHWvFVvDijSabymREVvaQZQwom',
#   'pickup_postal': '109706',
#   'pickup_date': '1976-01-02',
#   'submission_time': datetime.datetime(1995, 4, 20, 5, 58, 24),
#   'num_days_needed': 13,
#   'price': 18.68,
#   'customer_id': 28,
#   'evaluater_id': 8,
#   'status': 'cancelled',
#   'card_number': '384846497632',
#   'payment_time': datetime.datetime(2013, 5, 1, 22, 18, 24),
#   'monitor_id': 25,
#   'cancel_time': datetime.datetime(1995, 4, 20, 10, 58, 24)},
#  14: {'recipient_name': 'KnWefWuHPdbSQKGK',
#   'recipient_addr': 'aYlNjQciBUaIcHUfQWIrvWqZmjHmDozP',
#   'recipient_postal': '846284',
#   'pickup_addr': 'AlvSvavILztZLoRfyyJQRaRZaHFIYLaO',
#   'pickup_postal': '729855',
#   'pickup_date': '1971-01-02',
#   'submission_time': datetime.datetime(2000, 4, 27, 2, 40, 28),
#   'num_days_needed': 12,
#   'price': 33.73,
#   'customer_id': 954,
#   'evaluater_id': 6,
#   'status': 'withdrawn'},
#  15: {'recipient_name': 'lfgwpncPICOpZTDA',
#   'recipient_addr': 'GkLLSsMpQsVrQlcHriKiBmDwOUZCFDqR',
#   'recipient_postal': '739543',
#   'pickup_addr': 'qBOoGlpzvBjLQFKQESWucXgEtHIWvjlp',
#   'pickup_postal': '978042',
#   'pickup_date': '1992-01-17',
#   'submission_time': datetime.datetime(1970, 9, 12, 10, 3, 3),
#   'num_days_needed': 6,
#   'price': 28.55,
#   'customer_id': 862,
#   'evaluater_id': 10,
#   'status': 'cancelled',
#   'card_number': '830904245600',
#   'payment_time': datetime.datetime(2007, 4, 26, 3, 55, 25),
#   'monitor_id': 14,
#   'cancel_time': datetime.datetime(1970, 9, 12, 18, 3, 3)},
#  16: {'recipient_name': 'mPioujmayoHPcBeN',
#   'recipient_addr': 'bGjBqoCiEIWRWbhNQZrdMTwCRpNpgMkY',
#   'recipient_postal': '819737',
#   'pickup_addr': 'aynuMyRaKtgjKQOuWGajYzkGfLjnKSjS',
#   'pickup_postal': '624439',
#   'pickup_date': '1997-07-03',
#   'submission_time': datetime.datetime(1972, 6, 28, 7, 51, 40),
#   'num_days_needed': 16,
#   'price': 59.08,
#   'customer_id': 290,
#   'evaluater_id': 22,
#   'status': 'submitted'},
#  17: {'recipient_name': 'WBTmfBRuWTQIfwRF',
#   'recipient_addr': 'TmQiAfWIavleTBzvNEPZBfFgzZiHSeJh',
#   'recipient_postal': '656127',
#   'pickup_addr': 'QciZuXeKDHJYeUejooIlncJTIgsLXWZW',
#   'pickup_postal': '322611',
#   'pickup_date': '2017-08-12',
#   'submission_time': datetime.datetime(2019, 2, 5, 17, 8, 4),
#   'num_days_needed': 12,
#   'price': 19.8,
#   'customer_id': 837,
#   'evaluater_id': 47,
#   'status': 'evaluated'},
#  18: {'recipient_name': 'AbdXECJRRfXlcIZU',
#   'recipient_addr': 'zVdGJojiyXOsIhzEHLTdpsJaaNzIdviW',
#   'recipient_postal': '618677',
#   'pickup_addr': 'DIpLMfAyhRuvlddEckweoylwTisHKroQ',
#   'pickup_postal': '097836',
#   'pickup_date': '1971-07-26',
#   'submission_time': datetime.datetime(2022, 2, 28, 20, 49, 31),
#   'num_days_needed': 2,
#   'price': 42.02,
#   'customer_id': 473,
#   'evaluater_id': 23,
#   'status': 'submitted'},
#  19: {'recipient_name': 'MsBwDyxGnNcDpaqv',
#   'recipient_addr': 'CUYNggFRDSqDztMZOCmTbBDTgOFmtFgf',
#   'recipient_postal': '417913',
#   'pickup_addr': 'ZoyCtUdpVjXdHOWqMiWRJjODwyOAaVSD',
#   'pickup_postal': '248901',
#   'pickup_date': '1991-08-20',
#   'submission_time': datetime.datetime(1997, 3, 11, 11, 12, 5),
#   'num_days_needed': 6,
#   'price': 46.02,
#   'customer_id': 882,
#   'evaluater_id': 2,
#   'status': 'cancelled',
#   'card_number': '784817016294',
#   'payment_time': datetime.datetime(2015, 11, 6, 14, 31, 30),
#   'monitor_id': 17,
#   'cancel_time': datetime.datetime(1997, 3, 11, 23, 12, 5)},
#  20: {'recipient_name': 'xXYcQJWIJgwjqLRt',
#   'recipient_addr': 'IjlUxIfirpLIdwWKPKQvLrGvUXmyKrDh',
#   'recipient_postal': '346972',
#   'pickup_addr': 'ePekvNmRbwyhEDtbNgHaBsSEGvkEMnQA',
#   'pickup_postal': '945940',
#   'pickup_date': '2009-05-03',
#   'submission_time': datetime.datetime(2010, 2, 22, 9, 55, 46),
#   'num_days_needed': 16,
#   'price': 51.25,
#   'customer_id': 120,
#   'evaluater_id': 9,
#   'status': 'withdrawn'},
#  21: {'recipient_name': 'usdrvHkQUgfVbCaH',
#   'recipient_addr': 'YfqeoLLCtZpIzNhaMxWjgbdkkwUKDGRR',
#   'recipient_postal': '136961',
#   'pickup_addr': 'UoBTvGEYrtQnXZhSpkFpBHJenkeKgfJy',
#   'pickup_postal': '230533',
#   'pickup_date': '1997-09-24',
#   'submission_time': datetime.datetime(2021, 3, 5, 9, 35, 19),
#   'num_days_needed': 3,
#   'price': 54.53,
#   'customer_id': 533,
#   'evaluater_id': 39,
#   'status': 'withdrawn'},
#  22: {'recipient_name': 'NTJtlrJHPWlxXnBW',
#   'recipient_addr': 'gBmaOxplssVIEBUwQKSyfvGimzCKUikz',
#   'recipient_postal': '223306',
#   'pickup_addr': 'auhzxuoYbqitDWIdOmULOvsymgfXfsWR',
#   'pickup_postal': '637368',
#   'pickup_date': '2017-01-19',
#   'submission_time': datetime.datetime(2008, 4, 10, 14, 25, 53),
#   'num_days_needed': 6,
#   'price': 12.68,
#   'customer_id': 383,
#   'evaluater_id': 43,
#   'status': 'withdrawn'},
#  23: {'recipient_name': 'bkRVZTOkHFDaWagb',
#   'recipient_addr': 'kKoNNAzbrwjasXpVYQmhGAsARNVtHgve',
#   'recipient_postal': '225894',
#   'pickup_addr': 'SotRtTiNHnVaqiHpASZQpJlUkEBkaQfF',
#   'pickup_postal': '013814',
#   'pickup_date': '2001-11-03',
#   'submission_time': datetime.datetime(1991, 5, 11, 23, 31, 53),
#   'num_days_needed': 9,
#   'price': 56.73,
#   'customer_id': 895,
#   'evaluater_id': 23,
#   'status': 'completed',
#   'card_number': '809719370006',
#   'payment_time': datetime.datetime(2018, 1, 11, 7, 50, 58),
#   'monitor_id': 20},
#  24: {'recipient_name': 'SuCvmYulfQWvWdbh',
#   'recipient_addr': 'sCIbIiDazAseKZFlQDaIfqNMqIypKtSz',
#   'recipient_postal': '042697',
#   'pickup_addr': 'WzNZPhVHUPtHdHqmbSnKCwsvXiJompgT',
#   'pickup_postal': '958899',
#   'pickup_date': '2023-02-20',
#   'submission_time': datetime.datetime(1983, 1, 27, 3, 10, 9),
#   'num_days_needed': 15,
#   'price': 93.53,
#   'customer_id': 369,
#   'evaluater_id': 40,
#   'status': 'unsuccessful',
#   'card_number': '999027286079',
#   'payment_time': datetime.datetime(1982, 10, 9, 10, 21, 28),
#   'monitor_id': 24},
#  25: {'recipient_name': 'DZkaidCTRubTtGug',
#   'recipient_addr': 'lJRbTZFJxSKCalLBSaXtuBaRphfWwsQj',
#   'recipient_postal': '694600',
#   'pickup_addr': 'kHMeAxpXvsFYCxHiiniWMplBEIeaRRig',
#   'pickup_postal': '399157',
#   'pickup_date': '2000-02-04',
#   'submission_time': datetime.datetime(2008, 12, 31, 14, 2, 34),
#   'num_days_needed': 16,
#   'price': 6.33,
#   'customer_id': 771,
#   'evaluater_id': 20,
#   'status': 'evaluated'},
#  26: {'recipient_name': 'jUVdvDyMUkqXzBwO',
#   'recipient_addr': 'lVPbHTbbMUXjYyutbSStasBFgJyaLMpe',
#   'recipient_postal': '408208',
#   'pickup_addr': 'aGpeQrbaUQVcYrzUqmJCgMlZZUnurOiq',
#   'pickup_postal': '551233',
#   'pickup_date': '2001-05-14',
#   'submission_time': datetime.datetime(1972, 10, 6, 14, 54, 15),
#   'num_days_needed': 8,
#   'price': 35.31,
#   'customer_id': 419,
#   'evaluater_id': 32,
#   'status': 'withdrawn'},
#  27: {'recipient_name': 'fFkZmJXOTyvvvAWT',
#   'recipient_addr': 'jPtsKNelHkLqgRZfGlQLZffXiedGdfBb',
#   'recipient_postal': '158943',
#   'pickup_addr': 'tJnJzdKabflFITpYNnZnkhZrpNFuzJfd',
#   'pickup_postal': '301841',
#   'pickup_date': '2014-11-04',
#   'submission_time': datetime.datetime(1982, 2, 13, 17, 14, 29),
#   'num_days_needed': 3,
#   'price': 8.84,
#   'customer_id': 789,
#   'evaluater_id': 16,
#   'status': 'accepted',
#   'card_number': '864343060218',
#   'payment_time': datetime.datetime(2021, 9, 22, 14, 32, 13),
#   'monitor_id': 30},
#  28: {'recipient_name': 'zvvMyunyYOhETHpy',
#   'recipient_addr': 'xirMcKQWdzxAFxoIpPzqBjEpeJbZnhgC',
#   'recipient_postal': '065688',
#   'pickup_addr': 'QpWBzjdiujQtDVrbVGPFlcDzoVbpBqmG',
#   'pickup_postal': '494686',
#   'pickup_date': '2016-05-19',
#   'submission_time': datetime.datetime(2007, 6, 17, 8, 49, 1),
#   'num_days_needed': 8,
#   'price': 37.32,
#   'customer_id': 82,
#   'evaluater_id': 30,
#   'status': 'completed',
#   'card_number': '479444344012',
#   'payment_time': datetime.datetime(1974, 12, 28, 13, 56, 35),
#   'monitor_id': 26},
#  29: {'recipient_name': 'dBNbSorucKniEPdL',
#   'recipient_addr': 'nAGaDgVCYNpuBZjYEUYJCclGgUcxxyIt',
#   'recipient_postal': '898842',
#   'pickup_addr': 'KXJSsEAKlnHDozwJGLHtrDixoNrmVGhL',
#   'pickup_postal': '719876',
#   'pickup_date': '2021-04-13',
#   'submission_time': datetime.datetime(1971, 7, 3, 10, 45, 43),
#   'num_days_needed': 2,
#   'price': 63.81,
#   'customer_id': 753,
#   'evaluater_id': 20,
#   'status': 'completed',
#   'card_number': '890019003824',
#   'payment_time': datetime.datetime(1984, 5, 28, 18, 46, 3),
#   'monitor_id': 7},
#  30: {'recipient_name': 'KbxnfEIEpKSJeSYd',
#   'recipient_addr': 'njnHWZeGVDrwyOPVSbXGToRJTuESXHfD',
#   'recipient_postal': '773012',
#   'pickup_addr': 'jUSxaUHCwDzxGRGdjpucdGwVwXmErugX',
#   'pickup_postal': '474584',
#   'pickup_date': '2000-10-05',
#   'submission_time': datetime.datetime(1977, 3, 9, 9, 5, 33),
#   'num_days_needed': 8,
#   'price': 12.94,
#   'customer_id': 989,
#   'evaluater_id': 32,
#   'status': 'cancelled',
#   'card_number': '319305900632',
#   'payment_time': datetime.datetime(2007, 3, 14, 13, 41, 25),
#   'monitor_id': 10,
#   'cancel_time': datetime.datetime(1977, 3, 9, 10, 5, 33)},
#  31: {'recipient_name': 'NdjtQwbfFJiNKdfW',
#   'recipient_addr': 'QJZJuIvVlrlfeNPmkuZuHdluHegWlRFa',
#   'recipient_postal': '584917',
#   'pickup_addr': 'URfrxDFKrKmRgSaJVYzdDgiAxcNQnFLe',
#   'pickup_postal': '957858',
#   'pickup_date': '1990-12-10',
#   'submission_time': datetime.datetime(2016, 3, 31, 4, 22, 33),
#   'num_days_needed': 3,
#   'price': 23.5,
#   'customer_id': 237,
#   'evaluater_id': 35,
#   'status': 'cancelled',
#   'card_number': '138102700292',
#   'payment_time': datetime.datetime(1972, 5, 22, 10, 48, 17),
#   'monitor_id': 2,
#   'cancel_time': datetime.datetime(2016, 3, 31, 14, 22, 33)},
#  32: {'recipient_name': 'xSvmQavtvVrxmItq',
#   'recipient_addr': 'QssVWyOHWDTpmwSqLybBwcRZBNugYsbH',
#   'recipient_postal': '232184',
#   'pickup_addr': 'ZBdloVErbfCOlwppisaZZYZicxeZnEDj',
#   'pickup_postal': '898949',
#   'pickup_date': '2021-08-19',
#   'submission_time': datetime.datetime(1975, 6, 5, 5, 5, 33),
#   'num_days_needed': 11,
#   'price': 29.87,
#   'customer_id': 572,
#   'evaluater_id': 26,
#   'status': 'unsuccessful',
#   'card_number': '122778980553',
#   'payment_time': datetime.datetime(1978, 6, 8, 21, 46, 11),
#   'monitor_id': 15},
#  33: {'recipient_name': 'XTjKmmESIujHWOvi',
#   'recipient_addr': 'CDjhqWanYrWYsTGGWePCrSXaaAXQCtoN',
#   'recipient_postal': '479549',
#   'pickup_addr': 'ZzbagClzWTmAayHruoraKwrdwnQSTFhj',
#   'pickup_postal': '879153',
#   'pickup_date': '1991-08-17',
#   'submission_time': datetime.datetime(2019, 5, 11, 4, 18, 13),
#   'num_days_needed': 5,
#   'price': 97.63,
#   'customer_id': 352,
#   'evaluater_id': 31,
#   'status': 'withdrawn'},
#  34: {'recipient_name': 'yKFhlmtFvlsYeiOS',
#   'recipient_addr': 'iboEqiPlqobRTCCyqfaYrtPgjbdAbPPt',
#   'recipient_postal': '057536',
#   'pickup_addr': 'lHKZtFnLqXFxWfCpxZbuUDNNYuMuMIEw',
#   'pickup_postal': '313590',
#   'pickup_date': '2011-07-25',
#   'submission_time': datetime.datetime(1978, 5, 19, 6, 20, 23),
#   'num_days_needed': 7,
#   'price': 79.1,
#   'customer_id': 212,
#   'evaluater_id': 6,
#   'status': 'submitted'},
#  35: {'recipient_name': 'sKzRwuffMZbqEiSA',
#   'recipient_addr': 'YOJJcWNorrmGhlINDvxAuEgDDkVVKJXx',
#   'recipient_postal': '606403',
#   'pickup_addr': 'NaKtoEHhEUkDBRsnZHCwZezMOAwNKGlW',
#   'pickup_postal': '373100',
#   'pickup_date': '1980-04-14',
#   'submission_time': datetime.datetime(2003, 4, 29, 19, 47, 21),
#   'num_days_needed': 2,
#   'price': 1.8,
#   'customer_id': 86,
#   'evaluater_id': 9,
#   'status': 'accepted',
#   'card_number': '470186661304',
#   'payment_time': datetime.datetime(2010, 10, 11, 22, 4, 33),
#   'monitor_id': 26},
#  36: {'recipient_name': 'HbsHPbfRCgwrnHki',
#   'recipient_addr': 'bituxSTXOIdwBgyAvbjGzhXRrvEIIaBc',
#   'recipient_postal': '510410',
#   'pickup_addr': 'IlrrpoXOyTsCVlLewrWOsXrCymcdWqdJ',
#   'pickup_postal': '182582',
#   'pickup_date': '1975-10-12',
#   'submission_time': datetime.datetime(1977, 5, 11, 12, 32, 5),
#   'num_days_needed': 7,
#   'price': 15.79,
#   'customer_id': 401,
#   'evaluater_id': 3,
#   'status': 'cancelled',
#   'card_number': '620279268952',
#   'payment_time': datetime.datetime(2016, 12, 14, 5, 35, 5),
#   'monitor_id': 29,
#   'cancel_time': datetime.datetime(1977, 5, 11, 23, 32, 5)},
#  37: {'recipient_name': 'dgfpaDUCYYKKYwib',
#   'recipient_addr': 'eejLEEcrCkrWtBqzzJkujfxldEMEudvn',
#   'recipient_postal': '913183',
#   'pickup_addr': 'OnGARwlKGsEbneoFnaLZchlssMPAscIu',
#   'pickup_postal': '710556',
#   'pickup_date': '2019-01-13',
#   'submission_time': datetime.datetime(1978, 9, 1, 4, 52, 23),
#   'num_days_needed': 4,
#   'price': 14.39,
#   'customer_id': 955,
#   'evaluater_id': 45,
#   'status': 'submitted'},
#  38: {'recipient_name': 'SiMoabGsAfoqwdcL',
#   'recipient_addr': 'gepjHTnEItiAcrpeFlgYHeZWbWPCnSHr',
#   'recipient_postal': '959524',
#   'pickup_addr': 'mZmxfUgocPMoISxRLpyMQUUBfDXDJBAJ',
#   'pickup_postal': '587582',
#   'pickup_date': '2010-03-05',
#   'submission_time': datetime.datetime(2005, 8, 23, 18, 57, 8),
#   'num_days_needed': 12,
#   'price': 71.74,
#   'customer_id': 203,
#   'evaluater_id': 45,
#   'status': 'evaluated'},
#  39: {'recipient_name': 'WSedtiggqwirbcXY',
#   'recipient_addr': 'fACZTSPgzPMlIgVPTYccmTyNhLecSUCj',
#   'recipient_postal': '328743',
#   'pickup_addr': 'GDqNVkXjtAJQkMdkIXhmHLnbFCXISNCm',
#   'pickup_postal': '225434',
#   'pickup_date': '2014-04-10',
#   'submission_time': datetime.datetime(1985, 10, 15, 0, 59, 25),
#   'num_days_needed': 7,
#   'price': 96.74,
#   'customer_id': 977,
#   'evaluater_id': 22,
#   'status': 'withdrawn'},
#  40: {'recipient_name': 'EgjpQIjoefAdrfHW',
#   'recipient_addr': 'uiPnlFNIQNUnWLSXGFrxzFoEQpYonOrd',
#   'recipient_postal': '270468',
#   'pickup_addr': 'jVaebMDVevlsWZeHxwfrCKaXrRmjMWDk',
#   'pickup_postal': '562165',
#   'pickup_date': '2006-01-22',
#   'submission_time': datetime.datetime(1986, 1, 11, 19, 56, 45),
#   'num_days_needed': 14,
#   'price': 29.73,
#   'customer_id': 62,
#   'evaluater_id': 6,
#   'status': 'withdrawn'},
#  41: {'recipient_name': 'uNqWIaaWTFatHrBb',
#   'recipient_addr': 'PuSBmTvvqXqSplYsMnotrmfXRdxizYaj',
#   'recipient_postal': '280127',
#   'pickup_addr': 'nOXgjKoZVfmocTXIbxLsDNxvDAgIXlNn',
#   'pickup_postal': '594512',
#   'pickup_date': '2017-06-01',
#   'submission_time': datetime.datetime(2016, 11, 2, 5, 52, 51),
#   'num_days_needed': 11,
#   'price': 52.05,
#   'customer_id': 948,
#   'evaluater_id': 16,
#   'status': 'evaluated'},
#  42: {'recipient_name': 'dVEYEevrnJrBHpbu',
#   'recipient_addr': 'vARleuniXemtaNjEuTXcgwtsCeGkFCzd',
#   'recipient_postal': '495480',
#   'pickup_addr': 'cpbsJzKQgTdsXXNVPvONeluWzsizAFZW',
#   'pickup_postal': '945643',
#   'pickup_date': '1983-05-25',
#   'submission_time': datetime.datetime(1997, 11, 18, 13, 20, 37),
#   'num_days_needed': 7,
#   'price': 58.44,
#   'customer_id': 770,
#   'evaluater_id': 50,
#   'status': 'evaluated'},
#  43: {'recipient_name': 'kkJeLaGcTanGZwPv',
#   'recipient_addr': 'hbeFahzIBcRWepjaZNLTQgfQUEMBeWtE',
#   'recipient_postal': '053572',
#   'pickup_addr': 'GqGMtwZqLmjboATFkbKOkKRASwdUFsAk',
#   'pickup_postal': '056089',
#   'pickup_date': '2021-05-11',
#   'submission_time': datetime.datetime(1975, 7, 29, 0, 47, 44),
#   'num_days_needed': 3,
#   'price': 39.37,
#   'customer_id': 608,
#   'evaluater_id': 27,
#   'status': 'evaluated'},
#  44: {'recipient_name': 'ztAFKVIwrHbJKNwH',
#   'recipient_addr': 'QhbNTVwCoyLMdOcMgZdPqLhGMwdETSyB',
#   'recipient_postal': '598698',
#   'pickup_addr': 'dlonmSiLDTXKzyJrlElRPrPuKTwWZKPF',
#   'pickup_postal': '931547',
#   'pickup_date': '1975-04-24',
#   'submission_time': datetime.datetime(1980, 11, 5, 9, 44, 21),
#   'num_days_needed': 9,
#   'price': 6.26,
#   'customer_id': 535,
#   'evaluater_id': 14,
#   'status': 'submitted'},
#  45: {'recipient_name': 'dcgEXnanRiSHmtfk',
#   'recipient_addr': 'xaCyiJBVgZDqrKHvyKZdgGwvURFyzktm',
#   'recipient_postal': '434370',
#   'pickup_addr': 'xOKuxuaiCJFSguBLsZEWFWBoeQrYlooL',
#   'pickup_postal': '710142',
#   'pickup_date': '2001-01-18',
#   'submission_time': datetime.datetime(1983, 2, 4, 8, 45, 48),
#   'num_days_needed': 4,
#   'price': 66.34,
#   'customer_id': 473,
#   'evaluater_id': 37,
#   'status': 'evaluated'},
#  46: {'recipient_name': 'YXegKajsoDfaYWwX',
#   'recipient_addr': 'vnRUgNQFVmkOjbKzykLquDDrJOQZjCci',
#   'recipient_postal': '943149',
#   'pickup_addr': 'iSNzxTSTmeVqQggUvAmQqweuIxPNAzSz',
#   'pickup_postal': '233791',
#   'pickup_date': '1984-04-11',
#   'submission_time': datetime.datetime(2001, 10, 6, 10, 46, 42),
#   'num_days_needed': 10,
#   'price': 33.02,
#   'customer_id': 724,
#   'evaluater_id': 7,
#   'status': 'unsuccessful',
#   'card_number': '443388224354',
#   'payment_time': datetime.datetime(2019, 4, 30, 22, 54, 33),
#   'monitor_id': 10},
#  47: {'recipient_name': 'fLGczjIOxBOzVRrW',
#   'recipient_addr': 'UiwnfwbJvTPgsvaBWoXiQRWMAOBXYgJv',
#   'recipient_postal': '934560',
#   'pickup_addr': 'zApzDtDNkKpNRPIVZpLRPDONhlkRHmEo',
#   'pickup_postal': '013261',
#   'pickup_date': '1995-05-19',
#   'submission_time': datetime.datetime(1972, 12, 5, 22, 54, 37),
#   'num_days_needed': 14,
#   'price': 37.82,
#   'customer_id': 527,
#   'evaluater_id': 1,
#   'status': 'unsuccessful',
#   'card_number': '681721283260',
#   'payment_time': datetime.datetime(1977, 8, 2, 2, 48, 1),
#   'monitor_id': 10},
#  48: {'recipient_name': 'bQNEyIhJpDbmfAJQ',
#   'recipient_addr': 'UsMefyhbDUwcYVZBNllrPHaJzNPRDgGc',
#   'recipient_postal': '036833',
#   'pickup_addr': 'cIwTHBFyEyALsnggYgqMAculJrpxlEAN',
#   'pickup_postal': '656666',
#   'pickup_date': '1993-02-18',
#   'submission_time': datetime.datetime(2019, 10, 10, 2, 10, 46),
#   'num_days_needed': 10,
#   'price': 10.26,
#   'customer_id': 348,
#   'evaluater_id': 49,
#   'status': 'withdrawn'},
#  49: {'recipient_name': 'jJeWVYHjXcaHIvDS',
#   'recipient_addr': 'JvjHqplxLbRuvvLWHQTyuHrsRaaLPDbr',
#   'recipient_postal': '399626',
#   'pickup_addr': 'SYxBWlDxVAjBfkQIEqhdasBqnIFRqsYn',
#   'pickup_postal': '159100',
#   'pickup_date': '1988-04-02',
#   'submission_time': datetime.datetime(2008, 10, 20, 11, 40, 27),
#   'num_days_needed': 11,
#   'price': 34.81,
#   'customer_id': 165,
#   'evaluater_id': 46,
#   'status': 'accepted',
#   'card_number': '223784697165',
#   'payment_time': datetime.datetime(1974, 6, 10, 3, 44, 54),
#   'monitor_id': 30},
#  50: {'recipient_name': 'HBWsRqnRbFlyqwKw',
#   'recipient_addr': 'wyiLfWbXWDxRqSVsuIlsfPeIEEFpqezj',
#   'recipient_postal': '956405',
#   'pickup_addr': 'UlPMQiHlZRRtQoTCwguNPlrFZaDoqlzW',
#   'pickup_postal': '346676',
#   'pickup_date': '2018-12-17',
#   'submission_time': datetime.datetime(2013, 8, 27, 9, 41, 7),
#   'num_days_needed': 8,
#   'price': 49.59,
#   'customer_id': 635,
#   'evaluater_id': 16,
#   'status': 'accepted',
#   'card_number': '506180760667',
#   'payment_time': datetime.datetime(1993, 7, 7, 0, 40, 23),
#   'monitor_id': 13},
#  51: {'recipient_name': 'LLoqhxHpkWklKgEG',
#   'recipient_addr': 'YJNgzKvoohXIsFULwnANwwneiTEuQffB',
#   'recipient_postal': '332067',
#   'pickup_addr': 'ivbhgEsxCOoxCmAlCwLyuEmHqymHcJnh',
#   'pickup_postal': '979456',
#   'pickup_date': '2022-02-01',
#   'submission_time': datetime.datetime(1993, 7, 16, 16, 18, 19),
#   'num_days_needed': 10,
#   'price': 73.19,
#   'customer_id': 811,
#   'evaluater_id': 1,
#   'status': 'evaluated'},
#  52: {'recipient_name': 'bJmgJmhgQCnywpYq',
#   'recipient_addr': 'mlRDVukWUgUQTNcBgeGBnsXttFnYEFNZ',
#   'recipient_postal': '209475',
#   'pickup_addr': 'BrWaRnPoDxnqIplouEiiSSdjdpLBcdXZ',
#   'pickup_postal': '139994',
#   'pickup_date': '1985-10-14',
#   'submission_time': datetime.datetime(1994, 11, 1, 0, 52, 59),
#   'num_days_needed': 2,
#   'price': 72.94,
#   'customer_id': 849,
#   'evaluater_id': 43,
#   'status': 'evaluated'},
#  53: {'recipient_name': 'HjRZGWbDaHKbsqFh',
#   'recipient_addr': 'RWBoDSVEgkswoJlasikzmHfxtykFCOQP',
#   'recipient_postal': '992190',
#   'pickup_addr': 'ruVALIbSyAmIFHjXfGdbNWaflFNrYXil',
#   'pickup_postal': '201985',
#   'pickup_date': '2002-03-28',
#   'submission_time': datetime.datetime(1985, 7, 28, 8, 53, 47),
#   'num_days_needed': 5,
#   'price': 54.34,
#   'customer_id': 835,
#   'evaluater_id': 40,
#   'status': 'cancelled',
#   'card_number': '070477645613',
#   'payment_time': datetime.datetime(1985, 3, 13, 19, 33, 12),
#   'monitor_id': 21,
#   'cancel_time': datetime.datetime(1985, 7, 28, 13, 53, 47)},
#  54: {'recipient_name': 'COZXhyQLCOzhvCSt',
#   'recipient_addr': 'vggHTPeXCeDExzHdtbhbSOpjsPDiDxIM',
#   'recipient_postal': '741692',
#   'pickup_addr': 'zUfFEilfAuAWxZKWbLVFzTSzBBimBHxb',
#   'pickup_postal': '708304',
#   'pickup_date': '1997-01-07',
#   'submission_time': datetime.datetime(1993, 9, 16, 15, 56, 43),
#   'num_days_needed': 2,
#   'price': 11.49,
#   'customer_id': 262,
#   'evaluater_id': 5,
#   'status': 'completed',
#   'card_number': '350779835414',
#   'payment_time': datetime.datetime(2019, 6, 24, 12, 52, 35),
#   'monitor_id': 40},
#  55: {'recipient_name': 'TbyRJxxDOkxfWHBb',
#   'recipient_addr': 'dUNRnrWTLDIZRzLZrsQLtxcsfPIXJGmH',
#   'recipient_postal': '045274',
#   'pickup_addr': 'gZfsYEswyAFEtTdWjIsTykozIPFqDeUD',
#   'pickup_postal': '263162',
#   'pickup_date': '1995-07-09',
#   'submission_time': datetime.datetime(2009, 10, 7, 10, 43, 38),
#   'num_days_needed': 4,
#   'price': 42.29,
#   'customer_id': 660,
#   'evaluater_id': 5,
#   'status': 'withdrawn'},
#  56: {'recipient_name': 'LhQAsMDXKoeWTwcm',
#   'recipient_addr': 'cwZRCnGSmEmUUWLwPhITMaagBDVnfRGN',
#   'recipient_postal': '194539',
#   'pickup_addr': 'nEKopWBGQOeOVBlrmpEjokXVrAWLeqpe',
#   'pickup_postal': '298216',
#   'pickup_date': '2006-05-27',
#   'submission_time': datetime.datetime(2009, 8, 6, 11, 3, 53),
#   'num_days_needed': 13,
#   'price': 55.61,
#   'customer_id': 395,
#   'evaluater_id': 13,
#   'status': 'accepted',
#   'card_number': '187174859632',
#   'payment_time': datetime.datetime(2003, 5, 16, 0, 14, 20),
#   'monitor_id': 8},
#  57: {'recipient_name': 'QSeOyGnSbAXqJADK',
#   'recipient_addr': 'JXlmNYxuqLIVpBcxJNvHnlrZamyeatPX',
#   'recipient_postal': '525139',
#   'pickup_addr': 'UijcMNhIgdjVWwZUTpvUjYGkBAfLqOrf',
#   'pickup_postal': '744234',
#   'pickup_date': '1986-11-18',
#   'submission_time': datetime.datetime(1979, 4, 20, 10, 38, 56),
#   'num_days_needed': 8,
#   'price': 5.17,
#   'customer_id': 564,
#   'evaluater_id': 15,
#   'status': 'submitted'},
#  58: {'recipient_name': 'vjsLDNXeOjTPOwNx',
#   'recipient_addr': 'wlGCEFnBTCaGbHoZBclRTpNFKzSaKtmj',
#   'recipient_postal': '203364',
#   'pickup_addr': 'kpguOmFBeyvaJjUUjjEfLnbaBFykroys',
#   'pickup_postal': '725267',
#   'pickup_date': '1994-04-15',
#   'submission_time': datetime.datetime(1986, 2, 5, 3, 54, 27),
#   'num_days_needed': 5,
#   'price': 72.39,
#   'customer_id': 89,
#   'evaluater_id': 43,
#   'status': 'withdrawn'},
#  59: {'recipient_name': 'PRSZvqfYzwFpKHKG',
#   'recipient_addr': 'ptnGJyETWomtXDsmsJhTbXyfZIJwNnsu',
#   'recipient_postal': '351421',
#   'pickup_addr': 'eyZOlNHedzdEFhPZpSxUsvFRDdfvoozK',
#   'pickup_postal': '426317',
#   'pickup_date': '2015-05-11',
#   'submission_time': datetime.datetime(1974, 7, 2, 2, 27, 44),
#   'num_days_needed': 10,
#   'price': 26.64,
#   'customer_id': 104,
#   'evaluater_id': 45,
#   'status': 'submitted'},
#  60: {'recipient_name': 'uPvuBHYUehLpyARZ',
#   'recipient_addr': 'NjGNADWXGWZUEAobrhZPWzCfFDXtKxXI',
#   'recipient_postal': '702311',
#   'pickup_addr': 'alDXwrssbaVwTuzufzddPYKMmFTzMvtG',
#   'pickup_postal': '129646',
#   'pickup_date': '2010-04-01',
#   'submission_time': datetime.datetime(2003, 2, 27, 19, 40, 48),
#   'num_days_needed': 2,
#   'price': 17.76,
#   'customer_id': 307,
#   'evaluater_id': 1,
#   'status': 'submitted'},
#  61: {'recipient_name': 'rfMJYlidDKiBNTJZ',
#   'recipient_addr': 'gmZYfspxKAeNbpwXAzlOxJJVCrZBEqvw',
#   'recipient_postal': '631341',
#   'pickup_addr': 'DzNPdgFJNNcNDrtUozymeJWhmlkRIqCD',
#   'pickup_postal': '882857',
#   'pickup_date': '1985-08-06',
#   'submission_time': datetime.datetime(1994, 9, 2, 2, 27, 34),
#   'num_days_needed': 7,
#   'price': 51.63,
#   'customer_id': 672,
#   'evaluater_id': 47,
#   'status': 'accepted',
#   'card_number': '159337076388',
#   'payment_time': datetime.datetime(1979, 11, 12, 15, 57, 49),
#   'monitor_id': 26},
#  62: {'recipient_name': 'xbObpxRbedSkYOrj',
#   'recipient_addr': 'HQBitvxcbcAXaGmNWEMCSIqzvxnqZqPB',
#   'recipient_postal': '945711',
#   'pickup_addr': 'UWsWTmnTflzxylJUQaHEKFKWknrVRCAK',
#   'pickup_postal': '152590',
#   'pickup_date': '2003-06-24',
#   'submission_time': datetime.datetime(2001, 11, 25, 9, 59, 51),
#   'num_days_needed': 16,
#   'price': 52.59,
#   'customer_id': 273,
#   'evaluater_id': 36,
#   'status': 'cancelled',
#   'card_number': '978454123980',
#   'payment_time': datetime.datetime(1978, 9, 24, 4, 49, 40),
#   'monitor_id': 5,
#   'cancel_time': datetime.datetime(2001, 11, 25, 15, 59, 51)},
#  63: {'recipient_name': 'wyHGqLYKCEHpNCND',
#   'recipient_addr': 'EuqgvKvQDpAVSnyRNkKOnGVzFgNpMwWi',
#   'recipient_postal': '653304',
#   'pickup_addr': 'bXiqcHEKpMwguJjSipgFryZMgnrJuUtm',
#   'pickup_postal': '019790',
#   'pickup_date': '1971-04-15',
#   'submission_time': datetime.datetime(1979, 7, 1, 20, 13, 12),
#   'num_days_needed': 9,
#   'price': 44.35,
#   'customer_id': 778,
#   'evaluater_id': 22,
#   'status': 'accepted',
#   'card_number': '466291097458',
#   'payment_time': datetime.datetime(2007, 6, 7, 14, 35, 15),
#   'monitor_id': 40},
#  64: {'recipient_name': 'fusTuUmheNOcQrqw',
#   'recipient_addr': 'EEMswjMPBwgbjJtAMFrIQhVkJVIyRwnH',
#   'recipient_postal': '229701',
#   'pickup_addr': 'yAxRrkMbDoSWqHYJUOuxbpxBOdMVRrDs',
#   'pickup_postal': '779059',
#   'pickup_date': '1980-03-19',
#   'submission_time': datetime.datetime(1999, 8, 14, 15, 51, 9),
#   'num_days_needed': 16,
#   'price': 87.13,
#   'customer_id': 228,
#   'evaluater_id': 24,
#   'status': 'accepted',
#   'card_number': '600637835644',
#   'payment_time': datetime.datetime(1995, 9, 8, 5, 14, 22),
#   'monitor_id': 12},
#  65: {'recipient_name': 'TgUujIOXDkkEsUWe',
#   'recipient_addr': 'uiGfonFXHJOZUnFhQXhoZCeKcAKVJYCy',
#   'recipient_postal': '379476',
#   'pickup_addr': 'tWzhuUQjWAvIGVUgLOcXNVzHLxpMEUPw',
#   'pickup_postal': '373069',
#   'pickup_date': '2015-09-16',
#   'submission_time': datetime.datetime(1976, 3, 2, 21, 7, 51),
#   'num_days_needed': 6,
#   'price': 36.81,
#   'customer_id': 811,
#   'evaluater_id': 24,
#   'status': 'completed',
#   'card_number': '460638733853',
#   'payment_time': datetime.datetime(2015, 6, 3, 9, 8, 4),
#   'monitor_id': 10},
#  66: {'recipient_name': 'SsBFNesqpnSjRhNX',
#   'recipient_addr': 'XiLyCXxqFPeeOAgAuMMmijKVWWdSTbEk',
#   'recipient_postal': '822285',
#   'pickup_addr': 'nUHfNwSOijtEjQKevtVLJfzBHqCknVFm',
#   'pickup_postal': '209696',
#   'pickup_date': '1986-02-27',
#   'submission_time': datetime.datetime(2021, 7, 12, 5, 44, 36),
#   'num_days_needed': 3,
#   'price': 89.82,
#   'customer_id': 237,
#   'evaluater_id': 37,
#   'status': 'cancelled',
#   'card_number': '391651865189',
#   'payment_time': datetime.datetime(1992, 12, 17, 13, 53, 55),
#   'monitor_id': 6,
#   'cancel_time': datetime.datetime(2021, 7, 12, 13, 44, 36)},
#  67: {'recipient_name': 'pbLBqftNorVIzewH',
#   'recipient_addr': 'ejBwdnjxvzPoIyLlMtufdAYBIeyNfjgE',
#   'recipient_postal': '299858',
#   'pickup_addr': 'WmGgbrHRXavmGvEYlAnXfwOgSilYTkba',
#   'pickup_postal': '018577',
#   'pickup_date': '1999-03-31',
#   'submission_time': datetime.datetime(1970, 3, 3, 0, 38, 12),
#   'num_days_needed': 12,
#   'price': 44.26,
#   'customer_id': 892,
#   'evaluater_id': 27,
#   'status': 'cancelled',
#   'card_number': '520488708033',
#   'payment_time': datetime.datetime(1978, 5, 2, 9, 52, 50),
#   'monitor_id': 10,
#   'cancel_time': datetime.datetime(1970, 3, 3, 9, 38, 12)},
#  68: {'recipient_name': 'lJulwGYnQWNANzup',
#   'recipient_addr': 'RBmTBEZSSJLfrWlgNlIgJbNRkioKULWW',
#   'recipient_postal': '791231',
#   'pickup_addr': 'czluUGzRZNXdODlWOSzAVHATpIimblSt',
#   'pickup_postal': '811888',
#   'pickup_date': '2010-12-26',
#   'submission_time': datetime.datetime(2009, 3, 18, 22, 37, 21),
#   'num_days_needed': 5,
#   'price': 68.91,
#   'customer_id': 374,
#   'evaluater_id': 38,
#   'status': 'completed',
#   'card_number': '288140458398',
#   'payment_time': datetime.datetime(2002, 6, 15, 13, 26, 14),
#   'monitor_id': 42},
#  69: {'recipient_name': 'PWddchnnrHNbFGKd',
#   'recipient_addr': 'eYpUmBTOCNQaqRdMPOUhLYTmlYWqnubp',
#   'recipient_postal': '566959',
#   'pickup_addr': 'XpnGeMUuEfbWKMUkOCTyGcDnTUhsnSgD',
#   'pickup_postal': '393488',
#   'pickup_date': '2014-03-09',
#   'submission_time': datetime.datetime(1981, 9, 3, 8, 25, 15),
#   'num_days_needed': 10,
#   'price': 86.06,
#   'customer_id': 903,
#   'evaluater_id': 11,
#   'status': 'completed',
#   'card_number': '893398739078',
#   'payment_time': datetime.datetime(1988, 11, 11, 1, 21, 23),
#   'monitor_id': 35},
#  70: {'recipient_name': 'FTyUsWODwIeokAEj',
#   'recipient_addr': 'HJAAqAyhtLQsORfMhPoeEHaWnDOlvEai',
#   'recipient_postal': '706204',
#   'pickup_addr': 'kQtSJquVyQDiBmAHUgxuBsfSviMqGtnQ',
#   'pickup_postal': '962978',
#   'pickup_date': '1976-09-12',
#   'submission_time': datetime.datetime(2020, 12, 2, 9, 12, 26),
#   'num_days_needed': 2,
#   'price': 22.59,
#   'customer_id': 388,
#   'evaluater_id': 41,
#   'status': 'accepted',
#   'card_number': '227335530010',
#   'payment_time': datetime.datetime(2012, 6, 13, 19, 25, 7),
#   'monitor_id': 49},
#  71: {'recipient_name': 'SLFjcnlmuPyWseoD',
#   'recipient_addr': 'gKyqXZWXYxbCtRlyGKmicdWgqBDQLftS',
#   'recipient_postal': '484608',
#   'pickup_addr': 'TkUxEyfAMeTQtjpQUTzwpkWFJZFbFtEm',
#   'pickup_postal': '526165',
#   'pickup_date': '2009-06-22',
#   'submission_time': datetime.datetime(2016, 8, 15, 20, 22, 51),
#   'num_days_needed': 5,
#   'price': 89.25,
#   'customer_id': 936,
#   'evaluater_id': 23,
#   'status': 'completed',
#   'card_number': '372999649442',
#   'payment_time': datetime.datetime(1996, 8, 2, 20, 4, 57),
#   'monitor_id': 48},
#  72: {'recipient_name': 'JnuAzfcgCHTRAghj',
#   'recipient_addr': 'nIqgSDPwlwmakLwhLhoxbpwXFzNZBCtF',
#   'recipient_postal': '959819',
#   'pickup_addr': 'FtQcGDMugYxSjHNeikYquRFDngSvAifa',
#   'pickup_postal': '346531',
#   'pickup_date': '1988-09-09',
#   'submission_time': datetime.datetime(1972, 10, 28, 22, 51, 6),
#   'num_days_needed': 12,
#   'price': 62.75,
#   'customer_id': 41,
#   'evaluater_id': 30,
#   'status': 'accepted',
#   'card_number': '789885612446',
#   'payment_time': datetime.datetime(1999, 2, 2, 21, 6, 25),
#   'monitor_id': 7},
#  73: {'recipient_name': 'HOGbbDmpmJibjCZX',
#   'recipient_addr': 'YowAqsXVJIfkCuRsXECwCcsMujyPsBIO',
#   'recipient_postal': '149939',
#   'pickup_addr': 'GqbicEmYLnOOmesoUkbXjhdOyhxdudhY',
#   'pickup_postal': '971795',
#   'pickup_date': '2023-01-06',
#   'submission_time': datetime.datetime(2020, 9, 27, 6, 25, 59),
#   'num_days_needed': 5,
#   'price': 59.29,
#   'customer_id': 240,
#   'evaluater_id': 18,
#   'status': 'completed',
#   'card_number': '669123759724',
#   'payment_time': datetime.datetime(1977, 7, 19, 5, 15, 23),
#   'monitor_id': 6},
#  74: {'recipient_name': 'phtMjtfSixvohcaD',
#   'recipient_addr': 'YgfGOYprUNCWqKbuVnxkVuyEOFgkBFla',
#   'recipient_postal': '655080',
#   'pickup_addr': 'pavUMOKDyCCQSHYcecOjuzCTxHhJsqnx',
#   'pickup_postal': '248462',
#   'pickup_date': '1989-10-05',
#   'submission_time': datetime.datetime(1991, 1, 13, 3, 6, 51),
#   'num_days_needed': 11,
#   'price': 97.15,
#   'customer_id': 837,
#   'evaluater_id': 4,
#   'status': 'submitted'},
#  75: {'recipient_name': 'QBqaJRdTgmyFPitj',
#   'recipient_addr': 'mPWSmAXzHxJqpHbcTNwVBIipbrUiIdze',
#   'recipient_postal': '199687',
#   'pickup_addr': 'eevNUbnnbFmMBPxGvbYHWnVjIszWqFzw',
#   'pickup_postal': '156368',
#   'pickup_date': '1983-08-28',
#   'submission_time': datetime.datetime(1992, 10, 20, 23, 51, 31),
#   'num_days_needed': 5,
#   'price': 38.67,
#   'customer_id': 320,
#   'evaluater_id': 17,
#   'status': 'unsuccessful',
#   'card_number': '552061259925',
#   'payment_time': datetime.datetime(1984, 11, 23, 7, 6, 1),
#   'monitor_id': 36},
#  76: {'recipient_name': 'ySMwUNqWoMcTNEzZ',
#   'recipient_addr': 'KvZYTmTUBExcJpjzWiYSGtqNgJOnFlyY',
#   'recipient_postal': '562458',
#   'pickup_addr': 'oAGXIEnkXRHlrQbmeAKVrreGgXhYOohg',
#   'pickup_postal': '139924',
#   'pickup_date': '1980-07-11',
#   'submission_time': datetime.datetime(1997, 3, 13, 2, 31, 4),
#   'num_days_needed': 8,
#   'price': 42.59,
#   'customer_id': 734,
#   'evaluater_id': 41,
#   'status': 'submitted'},
#  77: {'recipient_name': 'mUlnMtcyOZSFDGZL',
#   'recipient_addr': 'PIzGsPmPPTYstmUpzImNafwtuNZLsZQA',
#   'recipient_postal': '647301',
#   'pickup_addr': 'KWjFGdpiKHrsDVaGtevoNgPztDgYhySb',
#   'pickup_postal': '039201',
#   'pickup_date': '2001-04-08',
#   'submission_time': datetime.datetime(1997, 8, 18, 22, 58, 25),
#   'num_days_needed': 14,
#   'price': 23.86,
#   'customer_id': 162,
#   'evaluater_id': 22,
#   'status': 'cancelled',
#   'card_number': '319386569366',
#   'payment_time': datetime.datetime(1987, 7, 5, 14, 1, 43),
#   'monitor_id': 7,
#   'cancel_time': datetime.datetime(1997, 8, 19, 4, 58, 25)},
#  78: {'recipient_name': 'dMDOPGAQBIGyEBRp',
#   'recipient_addr': 'nopiwOlrctLFAvdlBpNAOpSxCiKnCOnW',
#   'recipient_postal': '677066',
#   'pickup_addr': 'vYckWlrJWojExZvJgeIczHLbGGcwgzLx',
#   'pickup_postal': '554075',
#   'pickup_date': '2002-11-19',
#   'submission_time': datetime.datetime(2009, 12, 12, 14, 3, 31),
#   'num_days_needed': 13,
#   'price': 18.44,
#   'customer_id': 324,
#   'evaluater_id': 18,
#   'status': 'evaluated'},
#  79: {'recipient_name': 'bGQAjFndvpzFNuxP',
#   'recipient_addr': 'BHFuTrqutTmrPGOUtlbSsZuzAWmdwsTd',
#   'recipient_postal': '439177',
#   'pickup_addr': 'RMWzzSJuxkobkKdYXkcMJnJMTcUryMwe',
#   'pickup_postal': '490973',
#   'pickup_date': '1985-07-24',
#   'submission_time': datetime.datetime(2016, 4, 9, 12, 19, 28),
#   'num_days_needed': 2,
#   'price': 73.77,
#   'customer_id': 895,
#   'evaluater_id': 20,
#   'status': 'accepted',
#   'card_number': '571613338023',
#   'payment_time': datetime.datetime(2015, 5, 2, 4, 11, 18),
#   'monitor_id': 20},
#  80: {'recipient_name': 'cBbfLprcKevegWhT',
#   'recipient_addr': 'bKyaaeFTcIOgEWKbNsaDjPOcyYENAKCP',
#   'recipient_postal': '858951',
#   'pickup_addr': 'vslqZOXbmHoralSfyydWtcsKRSgQMWen',
#   'pickup_postal': '836756',
#   'pickup_date': '1971-10-08',
#   'submission_time': datetime.datetime(1982, 3, 17, 21, 19, 27),
#   'num_days_needed': 14,
#   'price': 51.1,
#   'customer_id': 362,
#   'evaluater_id': 26,
#   'status': 'evaluated'},
#  81: {'recipient_name': 'moQkvPWrhytDVVEu',
#   'recipient_addr': 'JtHCfnoHGaAhSOwvCNjsAHIyQIfGrKYy',
#   'recipient_postal': '804606',
#   'pickup_addr': 'dGhvihmbBkaGeOWNtXMrvATgnqGakAoR',
#   'pickup_postal': '206681',
#   'pickup_date': '2007-01-05',
#   'submission_time': datetime.datetime(2020, 12, 3, 4, 8, 5),
#   'num_days_needed': 12,
#   'price': 8.69,
#   'customer_id': 706,
#   'evaluater_id': 28,
#   'status': 'completed',
#   'card_number': '415101904702',
#   'payment_time': datetime.datetime(2007, 5, 2, 23, 43, 14),
#   'monitor_id': 2},
#  82: {'recipient_name': 'oikYzMXizOXrmeEp',
#   'recipient_addr': 'PaSubTSAviKeRFgyQgBttgCRmCIAfCTT',
#   'recipient_postal': '738063',
#   'pickup_addr': 'NrwqZNyYQzOLeDrDRUKcordQVdsdLnwx',
#   'pickup_postal': '526990',
#   'pickup_date': '1984-07-05',
#   'submission_time': datetime.datetime(2013, 12, 15, 14, 45, 34),
#   'num_days_needed': 6,
#   'price': 42.6,
#   'customer_id': 590,
#   'evaluater_id': 37,
#   'status': 'submitted'},
#  83: {'recipient_name': 'gzlwpVpVhdTzQnwt',
#   'recipient_addr': 'VOiRkKtloqXDRFSrblxiNKSNKkBWmLSP',
#   'recipient_postal': '811959',
#   'pickup_addr': 'zmXioZkSkseFzfMNnXJWftvzJChCUctw',
#   'pickup_postal': '074643',
#   'pickup_date': '2016-03-23',
#   'submission_time': datetime.datetime(1974, 5, 16, 3, 47, 11),
#   'num_days_needed': 6,
#   'price': 78.12,
#   'customer_id': 817,
#   'evaluater_id': 29,
#   'status': 'submitted'},
#  84: {'recipient_name': 'tjtJmFixcJIndtGs',
#   'recipient_addr': 'YRpvBRhORbTarpqkjEvzGmajeoqYhfXs',
#   'recipient_postal': '644044',
#   'pickup_addr': 'zlRkzCzhDrXwMZWLvJBwgWLiddJHyJMo',
#   'pickup_postal': '009540',
#   'pickup_date': '1981-03-21',
#   'submission_time': datetime.datetime(1983, 2, 12, 16, 1, 35),
#   'num_days_needed': 12,
#   'price': 53.52,
#   'customer_id': 932,
#   'evaluater_id': 48,
#   'status': 'unsuccessful',
#   'card_number': '368382200248',
#   'payment_time': datetime.datetime(1982, 6, 7, 23, 10, 51),
#   'monitor_id': 20},
#  85: {'recipient_name': 'rBHceBfrYrbZHVmR',
#   'recipient_addr': 'ohqsuktbskdzuqKeiHKHOSejpyITPEDs',
#   'recipient_postal': '016339',
#   'pickup_addr': 'JacDIIDevQYXrPOVTypuVyPrSgcNlBzc',
#   'pickup_postal': '035121',
#   'pickup_date': '2013-09-12',
#   'submission_time': datetime.datetime(1986, 8, 31, 20, 46, 32),
#   'num_days_needed': 14,
#   'price': 5.19,
#   'customer_id': 328,
#   'evaluater_id': 20,
#   'status': 'submitted'},
#  86: {'recipient_name': 'GqFDokxUmmdEsRfn',
#   'recipient_addr': 'kRZmbrphjZMcfhSKoomuQvcejfgKiLhr',
#   'recipient_postal': '485318',
#   'pickup_addr': 'QRXsdyxStepwbHylMPgCZgtlOETDtweA',
#   'pickup_postal': '295530',
#   'pickup_date': '2019-02-21',
#   'submission_time': datetime.datetime(2000, 5, 20, 2, 50, 27),
#   'num_days_needed': 15,
#   'price': 20.73,
#   'customer_id': 471,
#   'evaluater_id': 27,
#   'status': 'unsuccessful',
#   'card_number': '461467785321',
#   'payment_time': datetime.datetime(1992, 7, 8, 14, 18, 30),
#   'monitor_id': 49},
#  87: {'recipient_name': 'ISTRqCPfcEWAMvbP',
#   'recipient_addr': 'PkOecREHfVKIKehtghVlndbvxZASMOGX',
#   'recipient_postal': '137120',
#   'pickup_addr': 'bePyZYTRIeDvHiWKmdxDEMJVFWgZsTlo',
#   'pickup_postal': '830475',
#   'pickup_date': '1979-03-27',
#   'submission_time': datetime.datetime(1997, 3, 18, 1, 53, 14),
#   'num_days_needed': 15,
#   'price': 26.35,
#   'customer_id': 420,
#   'evaluater_id': 5,
#   'status': 'withdrawn'},
#  88: {'recipient_name': 'JNOqaHQlydhlFyXM',
#   'recipient_addr': 'fuhngdOWdhCEZJVNpuynHPqXVFQVyVtp',
#   'recipient_postal': '578289',
#   'pickup_addr': 'qOIJXxMbwzHarEAEpqLhYKtJvpZolpdF',
#   'pickup_postal': '349798',
#   'pickup_date': '1972-04-07',
#   'submission_time': datetime.datetime(1984, 8, 17, 3, 11, 7),
#   'num_days_needed': 3,
#   'price': 95.83,
#   'customer_id': 239,
#   'evaluater_id': 12,
#   'status': 'evaluated'},
#  89: {'recipient_name': 'vEFJuUJPxHXaIRSz',
#   'recipient_addr': 'XCLKVESCofGIWfeQCJqcvgkTxKYPpvZj',
#   'recipient_postal': '949988',
#   'pickup_addr': 'gRDKDDLIYUNmguxAywiDgzYtsnzndeXj',
#   'pickup_postal': '513049',
#   'pickup_date': '2019-05-07',
#   'submission_time': datetime.datetime(2015, 9, 18, 13, 5, 32),
#   'num_days_needed': 12,
#   'price': 44.97,
#   'customer_id': 588,
#   'evaluater_id': 47,
#   'status': 'submitted'},
#  90: {'recipient_name': 'QKFImuGAkdVeDJun',
#   'recipient_addr': 'OHQCoJdGxUxaqWDUMXzOBiHodkBGaNhh',
#   'recipient_postal': '533373',
#   'pickup_addr': 'MOyQXjDIAgKCjPhfMqDPduCFSrFkYhnw',
#   'pickup_postal': '399750',
#   'pickup_date': '2001-11-27',
#   'submission_time': datetime.datetime(1990, 2, 4, 14, 0, 35),
#   'num_days_needed': 14,
#   'price': 63.82,
#   'customer_id': 594,
#   'evaluater_id': 28,
#   'status': 'cancelled',
#   'card_number': '543120276629',
#   'payment_time': datetime.datetime(2007, 9, 9, 12, 15, 57),
#   'monitor_id': 11,
#   'cancel_time': datetime.datetime(1990, 2, 4, 21, 0, 35)},
#  91: {'recipient_name': 'CXbwCIWmQOskWgge',
#   'recipient_addr': 'YEukhSDWPFtuCGRRcrmAbFSxtiUtVPuM',
#   'recipient_postal': '242075',
#   'pickup_addr': 'UvqnvUevtQafDfEBHvXYpTjpuSsSUgSM',
#   'pickup_postal': '582496',
#   'pickup_date': '2019-04-09',
#   'submission_time': datetime.datetime(2020, 3, 30, 23, 22, 48),
#   'num_days_needed': 2,
#   'price': 57.39,
#   'customer_id': 165,
#   'evaluater_id': 29,
#   'status': 'unsuccessful',
#   'card_number': '620402317650',
#   'payment_time': datetime.datetime(2022, 1, 13, 10, 52, 26),
#   'monitor_id': 19},
#  92: {'recipient_name': 'tczCsEIHbGoLIjGA',
#   'recipient_addr': 'diKLqFaARKuYEKltRrFztCHIItBShfCt',
#   'recipient_postal': '993298',
#   'pickup_addr': 'yKcHAdPghlRlrqKQWhDqssGIyZHJclZv',
#   'pickup_postal': '859382',
#   'pickup_date': '1973-09-08',
#   'submission_time': datetime.datetime(1989, 3, 9, 0, 10, 6),
#   'num_days_needed': 3,
#   'price': 35.81,
#   'customer_id': 621,
#   'evaluater_id': 40,
#   'status': 'evaluated'},
#  93: {'recipient_name': 'gGcvftJnOXCMEhif',
#   'recipient_addr': 'AoIjFyIwEeNnqQddtjXbnaVyUwjXLsSB',
#   'recipient_postal': '833599',
#   'pickup_addr': 'MTQXFHnlDRpogbuHZsVWkKCRlFUfZiuK',
#   'pickup_postal': '218452',
#   'pickup_date': '1988-03-24',
#   'submission_time': datetime.datetime(1986, 12, 16, 17, 23, 8),
#   'num_days_needed': 13,
#   'price': 0.35,
#   'customer_id': 558,
#   'evaluater_id': 9,
#   'status': 'cancelled',
#   'card_number': '557874753350',
#   'payment_time': datetime.datetime(2009, 12, 18, 5, 13, 6),
#   'monitor_id': 19,
#   'cancel_time': datetime.datetime(1986, 12, 16, 20, 23, 8)},
#  94: {'recipient_name': 'zLHmNaJaRbiZeqtU',
#   'recipient_addr': 'IrfBkyZjdHuuViYYeMXSrPRQXbaoSLmV',
#   'recipient_postal': '640804',
#   'pickup_addr': 'hhOYmsyjcqFKiOHuYLVWgjqPNeuBSqaR',
#   'pickup_postal': '608595',
#   'pickup_date': '1987-11-21',
#   'submission_time': datetime.datetime(1994, 10, 11, 6, 7, 8),
#   'num_days_needed': 13,
#   'price': 13.73,
#   'customer_id': 785,
#   'evaluater_id': 7,
#   'status': 'cancelled',
#   'card_number': '406879277092',
#   'payment_time': datetime.datetime(1974, 5, 1, 12, 25, 54),
#   'monitor_id': 17,
#   'cancel_time': datetime.datetime(1994, 10, 11, 9, 7, 8)},
#  95: {'recipient_name': 'faKBRrKBjNffYuXN',
#   'recipient_addr': 'CkFOytnqUAoxrZNTBdypwuvrPMYrxOmB',
#   'recipient_postal': '131810',
#   'pickup_addr': 'xockeYMvvimgqnmDsBeyPjPxLTlFaQMJ',
#   'pickup_postal': '650408',
#   'pickup_date': '2005-03-10',
#   'submission_time': datetime.datetime(2006, 2, 16, 2, 10, 13),
#   'num_days_needed': 9,
#   'price': 8.87,
#   'customer_id': 347,
#   'evaluater_id': 44,
#   'status': 'submitted'},
#  96: {'recipient_name': 'pMHWLCnWmazCUvPt',
#   'recipient_addr': 'SSdsNpGlJJRyCUbczWDtrLEsJWkegbAe',
#   'recipient_postal': '780921',
#   'pickup_addr': 'ZXWbDmrLMylBHOzMtEonbQwlcYkZaVnG',
#   'pickup_postal': '121177',
#   'pickup_date': '1978-02-14',
#   'submission_time': datetime.datetime(1985, 12, 18, 19, 33, 44),
#   'num_days_needed': 9,
#   'price': 5.17,
#   'customer_id': 17,
#   'evaluater_id': 13,
#   'status': 'withdrawn'},
#  97: {'recipient_name': 'CqnjsnIiKpinveKX',
#   'recipient_addr': 'RcbOYucZmipQrLeIbpLRbXJyzvwIHXVk',
#   'recipient_postal': '260089',
#   'pickup_addr': 'PRRmnlTaLdgVkcTehvtDHwjPvNJnbBOD',
#   'pickup_postal': '173123',
#   'pickup_date': '1989-05-03',
#   'submission_time': datetime.datetime(1998, 12, 18, 4, 50, 48),
#   'num_days_needed': 11,
#   'price': 84.22,
#   'customer_id': 138,
#   'evaluater_id': 23,
#   'status': 'accepted',
#   'card_number': '282831932187',
#   'payment_time': datetime.datetime(2007, 8, 13, 13, 17, 59),
#   'monitor_id': 33},
#  98: {'recipient_name': 'YKYeRsboBiyIYuju',
#   'recipient_addr': 'hbhrmgGHbBmCCcXHDrkNQABDjZyzljuF',
#   'recipient_postal': '979612',
#   'pickup_addr': 'QIrbDLStnPmBhRsdAQQSrgockgasWaAk',
#   'pickup_postal': '597103',
#   'pickup_date': '1991-10-24',
#   'submission_time': datetime.datetime(2022, 1, 12, 10, 32, 14),
#   'num_days_needed': 13,
#   'price': 8.13,
#   'customer_id': 845,
#   'evaluater_id': 1,
#   'status': 'evaluated'},
#  99: {'recipient_name': 'TsWlWzOeMnwCulSz',
#   'recipient_addr': 'aRmaXxhFinGBPTTmVbJUAZVJmaviPMjF',
#   'recipient_postal': '799656',
#   'pickup_addr': 'GHncvYCzkxNNwlywLbmVMJVBENXlBOlF',
#   'pickup_postal': '072399',
#   'pickup_date': '1970-11-26',
#   'submission_time': datetime.datetime(2020, 6, 11, 7, 0, 43),
#   'num_days_needed': 4,
#   'price': 75.28,
#   'customer_id': 695,
#   'evaluater_id': 17,
#   'status': 'completed',
#   'card_number': '353850709900',
#   'payment_time': datetime.datetime(1982, 10, 20, 16, 33, 51),
# ...
#   'recipient_postal': '314852',
#   'pickup_addr': 'uwYnUdJzKvaSZDXhaHqaUKRBIIUWFurl',
#   'pickup_postal': '605053',
#   'pickup_date': '2006-01-27',
#   'submission_time': datetime.datetime(1981, 5, 5, 12, 0, 45),
#   'num_days_needed': 12,
#   'price': 77.3,
#   'customer_id': 331,
#   'evaluater_id': 41,
#   'status': 'submitted'},
#  971: {'recipient_name': 'XwRJiwQCMmxtQtUQ',
#   'recipient_addr': 'shWRQgfIcUNkaFceeNrDdVodazZxgVpT',
#   'recipient_postal': '270697',
#   'pickup_addr': 'zuPdwsXVqqQEFKAYXgsqpLWGRYDtHEgf',
#   'pickup_postal': '503017',
#   'pickup_date': '2010-02-16',
#   'submission_time': datetime.datetime(2013, 4, 4, 17, 29, 22),
#   'num_days_needed': 8,
#   'price': 45.48,
#   'customer_id': 272,
#   'evaluater_id': 45,
#   'status': 'completed',
#   'card_number': '701850343467',
#   'payment_time': datetime.datetime(2020, 2, 13, 1, 32, 15),
#   'monitor_id': 25},
#  972: {'recipient_name': 'LpNKIGNaNnWZSBrC',
#   'recipient_addr': 'UkHTausBQrlQkwgalYWkHseyPgkjJqZp',
#   'recipient_postal': '021381',
#   'pickup_addr': 'PQQeJFfWVUCBTswErRVpNVFJtsoIihvx',
#   'pickup_postal': '634466',
#   'pickup_date': '1991-11-16',
#   'submission_time': datetime.datetime(1983, 10, 26, 6, 54, 42),
#   'num_days_needed': 10,
#   'price': 49.89,
#   'customer_id': 169,
#   'evaluater_id': 18,
#   'status': 'completed',
#   'card_number': '850072047399',
#   'payment_time': datetime.datetime(2007, 11, 23, 5, 55, 33),
#   'monitor_id': 10},
#  973: {'recipient_name': 'WHlZgNIaMXjDOFBL',
#   'recipient_addr': 'zaCzYwbwMVSAbRIyKGwZBclacoLqtxsO',
#   'recipient_postal': '510572',
#   'pickup_addr': 'DqowHUIAcOsbqbDJrLTGLxreweIuOrNN',
#   'pickup_postal': '075736',
#   'pickup_date': '1970-06-04',
#   'submission_time': datetime.datetime(1971, 11, 5, 6, 19, 12),
#   'num_days_needed': 11,
#   'price': 2.35,
#   'customer_id': 496,
#   'evaluater_id': 45,
#   'status': 'submitted'},
#  974: {'recipient_name': 'bqPvrMCXKzhAsgRw',
#   'recipient_addr': 'fudwZHKTYRdZYNSsyEVFNPsYeqoysddC',
#   'recipient_postal': '647084',
#   'pickup_addr': 'ZFufBODgGKkoHPcPjxbfvnAFyzrabiRI',
#   'pickup_postal': '599513',
#   'pickup_date': '1986-12-09',
#   'submission_time': datetime.datetime(2021, 9, 8, 2, 0, 23),
#   'num_days_needed': 9,
#   'price': 63.67,
#   'customer_id': 811,
#   'evaluater_id': 11,
#   'status': 'completed',
#   'card_number': '645105636788',
#   'payment_time': datetime.datetime(1972, 12, 11, 6, 49, 44),
#   'monitor_id': 24},
#  975: {'recipient_name': 'ohMMqINTJTeygmrN',
#   'recipient_addr': 'HiihDXDUrRNzLPOMcXakvflNBIIUweiq',
#   'recipient_postal': '167597',
#   'pickup_addr': 'VJnuTxdMGAGVvktZBStvgvYuiyKnpEOS',
#   'pickup_postal': '464223',
#   'pickup_date': '1996-09-06',
#   'submission_time': datetime.datetime(1982, 7, 9, 3, 43, 10),
#   'num_days_needed': 7,
#   'price': 24.09,
#   'customer_id': 729,
#   'evaluater_id': 40,
#   'status': 'unsuccessful',
#   'card_number': '280389598287',
#   'payment_time': datetime.datetime(1974, 2, 9, 22, 13, 43),
#   'monitor_id': 45},
#  976: {'recipient_name': 'hRytRLdaPiTDeuLr',
#   'recipient_addr': 'ODBHpdphtMkTNIVdrOeQJZMrnaIjjrTr',
#   'recipient_postal': '758454',
#   'pickup_addr': 'kIJgysaWJiRSHjTOUkJyDtNaLKxJzloO',
#   'pickup_postal': '350854',
#   'pickup_date': '1996-02-01',
#   'submission_time': datetime.datetime(2007, 3, 13, 0, 10, 21),
#   'num_days_needed': 12,
#   'price': 72.79,
#   'customer_id': 827,
#   'evaluater_id': 27,
#   'status': 'cancelled',
#   'card_number': '977085372463',
#   'payment_time': datetime.datetime(2005, 9, 9, 17, 54, 57),
#   'monitor_id': 49,
#   'cancel_time': datetime.datetime(2007, 3, 13, 12, 10, 21)},
#  977: {'recipient_name': 'iPRMAajNdWAIBKDA',
#   'recipient_addr': 'cGlZJPPGnouzCeeVKkwpiadyMsTBjfJi',
#   'recipient_postal': '700911',
#   'pickup_addr': 'UHUWzcvgrfWgGYpCkUCynKmtLmZcTXhe',
#   'pickup_postal': '131798',
#   'pickup_date': '2011-12-13',
#   'submission_time': datetime.datetime(1996, 1, 30, 1, 21, 45),
#   'num_days_needed': 2,
#   'price': 31.36,
#   'customer_id': 297,
#   'evaluater_id': 25,
#   'status': 'unsuccessful',
#   'card_number': '944017409873',
#   'payment_time': datetime.datetime(2011, 11, 2, 3, 19, 5),
#   'monitor_id': 23},
#  978: {'recipient_name': 'XnfaQnvlvlkBALnZ',
#   'recipient_addr': 'PjmzjLFdcMRPEwiOpTrZNfGsfDILvHLV',
#   'recipient_postal': '657142',
#   'pickup_addr': 'BickQOiVDBcBGVvxfHgzZnFyYVLglKik',
#   'pickup_postal': '661845',
#   'pickup_date': '2020-08-06',
#   'submission_time': datetime.datetime(1997, 8, 31, 22, 58, 41),
#   'num_days_needed': 4,
#   'price': 57.45,
#   'customer_id': 171,
#   'evaluater_id': 20,
#   'status': 'evaluated'},
#  979: {'recipient_name': 'koohxnMjfDVVtISi',
#   'recipient_addr': 'kAWeuiKxOGTDTDjTamwodMxboWDbnVee',
#   'recipient_postal': '522694',
#   'pickup_addr': 'BUCCedQpzXptVptGuryecxAbmAYDmInW',
#   'pickup_postal': '844137',
#   'pickup_date': '1988-05-02',
#   'submission_time': datetime.datetime(2017, 11, 21, 5, 47, 33),
#   'num_days_needed': 2,
#   'price': 38.05,
#   'customer_id': 394,
#   'evaluater_id': 38,
#   'status': 'cancelled',
#   'card_number': '636917093247',
#   'payment_time': datetime.datetime(1977, 7, 29, 22, 30, 45),
#   'monitor_id': 8,
#   'cancel_time': datetime.datetime(2017, 11, 21, 10, 47, 33)},
#  980: {'recipient_name': 'XaOfIcMASSntUjzR',
#   'recipient_addr': 'TFPzIcAHDmVpjGGQxyCBmLmaSTWckjpL',
#   'recipient_postal': '735703',
#   'pickup_addr': 'AzCJMIuwXqYOJpBSmpxCLSzgVhXguFgi',
#   'pickup_postal': '760357',
#   'pickup_date': '2018-06-22',
#   'submission_time': datetime.datetime(1980, 5, 18, 4, 55, 27),
#   'num_days_needed': 11,
#   'price': 49.12,
#   'customer_id': 302,
#   'evaluater_id': 19,
#   'status': 'accepted',
#   'card_number': '140053023230',
#   'payment_time': datetime.datetime(1978, 1, 30, 17, 25, 26),
#   'monitor_id': 32},
#  981: {'recipient_name': 'thXKEGPmFWjCddSP',
#   'recipient_addr': 'fLbsQJhaaCeapfBwxJYasccORToAqPpt',
#   'recipient_postal': '872511',
#   'pickup_addr': 'aIXCVakuTyZRxcLcgIodGQWqYzNSKANY',
#   'pickup_postal': '191693',
#   'pickup_date': '1988-05-25',
#   'submission_time': datetime.datetime(1979, 2, 5, 18, 48, 49),
#   'num_days_needed': 13,
#   'price': 38.41,
#   'customer_id': 665,
#   'evaluater_id': 37,
#   'status': 'unsuccessful',
#   'card_number': '338642088783',
#   'payment_time': datetime.datetime(1989, 7, 23, 11, 29, 47),
#   'monitor_id': 33},
#  982: {'recipient_name': 'yhIYoOrJNLUcriAr',
#   'recipient_addr': 'ardsKrmUuHaubqLWrPVlXUssBmGZbDHt',
#   'recipient_postal': '837714',
#   'pickup_addr': 'VCEAkzmaAgwTUjIbrJmGMMKFKjongwbv',
#   'pickup_postal': '687824',
#   'pickup_date': '1991-07-29',
#   'submission_time': datetime.datetime(2000, 5, 16, 21, 1, 27),
#   'num_days_needed': 12,
#   'price': 41.14,
#   'customer_id': 626,
#   'evaluater_id': 3,
#   'status': 'accepted',
#   'card_number': '115652804720',
#   'payment_time': datetime.datetime(1990, 12, 5, 14, 5, 57),
#   'monitor_id': 37},
#  983: {'recipient_name': 'cTfCKOqRGeIHCJSr',
#   'recipient_addr': 'eaRKKDOyvSrNuZUFOtiQnkurQGhYMItV',
#   'recipient_postal': '641978',
#   'pickup_addr': 'iUKgqebfAIOCJVwLzNobNPAcgtpJufAH',
#   'pickup_postal': '508064',
#   'pickup_date': '1990-03-31',
#   'submission_time': datetime.datetime(1986, 9, 9, 13, 19, 29),
#   'num_days_needed': 2,
#   'price': 84.29,
#   'customer_id': 464,
#   'evaluater_id': 18,
#   'status': 'completed',
#   'card_number': '952085773419',
#   'payment_time': datetime.datetime(1983, 8, 3, 3, 38, 15),
#   'monitor_id': 46},
#  984: {'recipient_name': 'ZRhTEqIjjVfgdhkD',
#   'recipient_addr': 'oRqLAFUctGTfXdEllDPEUbGLUcyugLll',
#   'recipient_postal': '559642',
#   'pickup_addr': 'WQkJUFFoeYTDwuZWHesmhOGFaPyOqhZe',
#   'pickup_postal': '527646',
#   'pickup_date': '1984-09-01',
#   'submission_time': datetime.datetime(2005, 4, 9, 13, 35, 57),
#   'num_days_needed': 6,
#   'price': 50.32,
#   'customer_id': 553,
#   'evaluater_id': 2,
#   'status': 'cancelled',
#   'card_number': '657897800795',
#   'payment_time': datetime.datetime(1992, 4, 4, 20, 20, 56),
#   'monitor_id': 6,
#   'cancel_time': datetime.datetime(2005, 4, 10, 1, 35, 57)},
#  985: {'recipient_name': 'bzqHFfvHhhyyUwol',
#   'recipient_addr': 'xBPMTsoGTvQOmEcPsMWSTFaJJthkpVkZ',
#   'recipient_postal': '578041',
#   'pickup_addr': 'naJaCEOmNYNoRXLSEJWmGcKrRRUvQVUw',
#   'pickup_postal': '717410',
#   'pickup_date': '2010-09-12',
#   'submission_time': datetime.datetime(2016, 10, 29, 21, 23, 54),
#   'num_days_needed': 16,
#   'price': 46.62,
#   'customer_id': 51,
#   'evaluater_id': 47,
#   'status': 'withdrawn'},
#  986: {'recipient_name': 'qIRYAMGtrwYDmjIP',
#   'recipient_addr': 'fuNhWwuDSKrAlTZrFNQUFMTziZFaXMxt',
#   'recipient_postal': '627086',
#   'pickup_addr': 'UIkeEuJmMRAhYzfZcMAwjLdUAeicrAJl',
#   'pickup_postal': '938440',
#   'pickup_date': '2003-06-19',
#   'submission_time': datetime.datetime(2018, 6, 17, 14, 6, 48),
#   'num_days_needed': 8,
#   'price': 67.95,
#   'customer_id': 774,
#   'evaluater_id': 36,
#   'status': 'accepted',
#   'card_number': '016727646872',
#   'payment_time': datetime.datetime(1993, 7, 16, 10, 37, 5),
#   'monitor_id': 13},
#  987: {'recipient_name': 'tnitSjUtVeFHkWbo',
#   'recipient_addr': 'kMbTnLlEfvoHqbZNQFuTkVYYDeJuQOAl',
#   'recipient_postal': '696012',
#   'pickup_addr': 'FwZXFjIllRqZxXhUTXXdqIzaMuUZEqRF',
#   'pickup_postal': '200097',
#   'pickup_date': '1973-09-28',
#   'submission_time': datetime.datetime(2012, 1, 28, 4, 23, 17),
#   'num_days_needed': 2,
#   'price': 84.77,
#   'customer_id': 26,
#   'evaluater_id': 30,
#   'status': 'unsuccessful',
#   'card_number': '053840048493',
#   'payment_time': datetime.datetime(1970, 10, 3, 4, 41, 1),
#   'monitor_id': 15},
#  988: {'recipient_name': 'oRvpjmygYKKWxwgI',
#   'recipient_addr': 'swDkVofjKusVnckbKiSpSQtduAfLVriZ',
#   'recipient_postal': '239732',
#   'pickup_addr': 'vQrQtRHaLtyaJqkGOJgsAwkDOrmKgpfn',
#   'pickup_postal': '432064',
#   'pickup_date': '2011-02-12',
#   'submission_time': datetime.datetime(1994, 11, 11, 9, 11, 17),
#   'num_days_needed': 2,
#   'price': 28.42,
#   'customer_id': 397,
#   'evaluater_id': 2,
#   'status': 'unsuccessful',
#   'card_number': '656218333904',
#   'payment_time': datetime.datetime(2018, 8, 1, 10, 29, 54),
#   'monitor_id': 40},
#  989: {'recipient_name': 'wymYGHtZRLrrFaVD',
#   'recipient_addr': 'hyLCIuVZNlXYzVuNuCJlgdXDOHbZRVly',
#   'recipient_postal': '737236',
#   'pickup_addr': 'evMCitvuglYhfAAKQXtinZRxTZxqdpJL',
#   'pickup_postal': '359823',
#   'pickup_date': '1983-12-03',
#   'submission_time': datetime.datetime(1993, 4, 1, 12, 46, 7),
#   'num_days_needed': 3,
#   'price': 40.02,
#   'customer_id': 472,
#   'evaluater_id': 45,
#   'status': 'withdrawn'},
#  990: {'recipient_name': 'SZXUxRLoLQkmGpkO',
#   'recipient_addr': 'goWwBtHYuApFEBsQbDdGJOFzHUHQUiPx',
#   'recipient_postal': '861486',
#   'pickup_addr': 'dFvTwTKhRdZwiRlEfjNPomWPfHNXtdnP',
#   'pickup_postal': '813647',
#   'pickup_date': '2008-09-17',
#   'submission_time': datetime.datetime(1995, 12, 16, 4, 13, 36),
#   'num_days_needed': 10,
#   'price': 49.84,
#   'customer_id': 794,
#   'evaluater_id': 28,
#   'status': 'completed',
#   'card_number': '214251500669',
#   'payment_time': datetime.datetime(1972, 8, 1, 5, 21, 54),
#   'monitor_id': 40},
#  991: {'recipient_name': 'qYqlHKPBfdAZKuZQ',
#   'recipient_addr': 'awlpwtUeLzSFnnpGziIBAYwHARlkZTXH',
#   'recipient_postal': '417651',
#   'pickup_addr': 'ibjwhLNeYDfOUwhIFhCNDvjpXhkDOaqy',
#   'pickup_postal': '666682',
#   'pickup_date': '1978-05-03',
#   'submission_time': datetime.datetime(1991, 1, 12, 11, 36, 21),
#   'num_days_needed': 13,
#   'price': 86.28,
#   'customer_id': 180,
#   'evaluater_id': 12,
#   'status': 'accepted',
#   'card_number': '217177120063',
#   'payment_time': datetime.datetime(2008, 10, 13, 23, 58, 14),
#   'monitor_id': 3},
#  992: {'recipient_name': 'JWuhEjZgrkMJypCW',
#   'recipient_addr': 'kEMJHNHJIBiapaAcEFppuVmYuDdrldMl',
#   'recipient_postal': '261786',
#   'pickup_addr': 'pkaLYeyFoaFkNoNwkxFmIBTqAmyeoGjd',
#   'pickup_postal': '898259',
#   'pickup_date': '2008-10-23',
#   'submission_time': datetime.datetime(1987, 3, 21, 18, 33, 9),
#   'num_days_needed': 4,
#   'price': 11.37,
#   'customer_id': 581,
#   'evaluater_id': 1,
#   'status': 'cancelled',
#   'card_number': '779901431277',
#   'payment_time': datetime.datetime(1973, 4, 6, 21, 30, 10),
#   'monitor_id': 9,
#   'cancel_time': datetime.datetime(1987, 3, 21, 23, 33, 9)},
#  993: {'recipient_name': 'cojxPGHtyHLpNcVV',
#   'recipient_addr': 'VjcQaigbWeIZVZFKybjAJpGsIOFbdpYK',
#   'recipient_postal': '398045',
#   'pickup_addr': 'mtEjQZowdqOVfVCDlHADwPksbOojvEhs',
#   'pickup_postal': '888092',
#   'pickup_date': '2004-05-29',
#   'submission_time': datetime.datetime(2000, 11, 5, 7, 5, 3),
#   'num_days_needed': 5,
#   'price': 21.19,
#   'customer_id': 56,
#   'evaluater_id': 14,
#   'status': 'submitted'},
#  994: {'recipient_name': 'dtLLZMQQeXyqUHKw',
#   'recipient_addr': 'fqolgQHgoTjIeoxLGuSkkoJGCOWtMIUq',
#   'recipient_postal': '757640',
#   'pickup_addr': 'hTeSlIZJyUmNcJRbeQWBDvTjmDBOwgUg',
#   'pickup_postal': '429012',
#   'pickup_date': '2005-04-24',
#   'submission_time': datetime.datetime(1992, 12, 14, 16, 56, 26),
#   'num_days_needed': 15,
#   'price': 29.92,
#   'customer_id': 976,
#   'evaluater_id': 39,
#   'status': 'unsuccessful',
#   'card_number': '293316825989',
#   'payment_time': datetime.datetime(2002, 6, 10, 7, 4, 8),
#   'monitor_id': 17},
#  995: {'recipient_name': 'LYAWsfrwgGJCwbyS',
#   'recipient_addr': 'PjpwnOpZSdwjLRFRgPsRaUAZLkpCcfzF',
#   'recipient_postal': '255686',
#   'pickup_addr': 'NfmwPMUyAsJnuLdGwKhWEOtYPQVGPxUR',
#   'pickup_postal': '972430',
#   'pickup_date': '1975-05-09',
#   'submission_time': datetime.datetime(1978, 9, 5, 8, 47, 45),
#   'num_days_needed': 3,
#   'price': 63.64,
#   'customer_id': 829,
#   'evaluater_id': 33,
#   'status': 'unsuccessful',
#   'card_number': '490966191410',
#   'payment_time': datetime.datetime(1994, 3, 4, 21, 25, 47),
#   'monitor_id': 35},
#  996: {'recipient_name': 'HEfyOGrNXCEaGmyh',
#   'recipient_addr': 'GoYaatghJDsLTLBAXvDdHmznqurvkCuS',
#   'recipient_postal': '911562',
#   'pickup_addr': 'mkwqoNRWyVTXufOOsfstdkWnlhewSXhd',
#   'pickup_postal': '758153',
#   'pickup_date': '1990-02-20',
#   'submission_time': datetime.datetime(1997, 9, 6, 7, 1, 4),
#   'num_days_needed': 14,
#   'price': 50.77,
#   'customer_id': 514,
#   'evaluater_id': 6,
#   'status': 'accepted',
#   'card_number': '695914440397',
#   'payment_time': datetime.datetime(1986, 11, 24, 6, 57, 36),
#   'monitor_id': 29},
#  997: {'recipient_name': 'LJNkNGIaYnMxvhSq',
#   'recipient_addr': 'UIuOlffndtjordhuWLjiKbsepmbWkXOi',
#   'recipient_postal': '197130',
#   'pickup_addr': 'MnQrrlRVbJKfrHeJpebSrGSvWojoCQbt',
#   'pickup_postal': '057836',
#   'pickup_date': '1980-06-23',
#   'submission_time': datetime.datetime(1981, 2, 17, 0, 35, 12),
#   'num_days_needed': 13,
#   'price': 9.42,
#   'customer_id': 748,
#   'evaluater_id': 16,
#   'status': 'accepted',
#   'card_number': '316450236408',
#   'payment_time': datetime.datetime(2012, 3, 30, 14, 10, 45),
#   'monitor_id': 41},
#  998: {'recipient_name': 'vTstdvpZDWoPPRBB',
#   'recipient_addr': 'XTzMSApevosWXahcMqmCuCnstzfYCXAf',
#   'recipient_postal': '409745',
#   'pickup_addr': 'TyqfNQZeWDngiFcVMIsYQLRkihIXTSyt',
#   'pickup_postal': '971471',
#   'pickup_date': '2007-11-13',
#   'submission_time': datetime.datetime(1988, 1, 15, 23, 49, 50),
#   'num_days_needed': 14,
#   'price': 60.63,
#   'customer_id': 131,
#   'evaluater_id': 27,
#   'status': 'accepted',
#   'card_number': '092800369614',
#   'payment_time': datetime.datetime(2020, 10, 5, 3, 50, 41),
#   'monitor_id': 37},
#  999: {'recipient_name': 'XCELubDPlSpyKlxZ',
#   'recipient_addr': 'cVDYDtvsSvLgVabQyNrtIkMtIaPiwcJs',
#   'recipient_postal': '749330',
#   'pickup_addr': 'UxZDPyWeNmdoczNgddAJhkEBLIBcZPcm',
#   'pickup_postal': '041105',
#   'pickup_date': '2010-10-19',
#   'submission_time': datetime.datetime(2007, 9, 14, 21, 35, 10),
#   'num_days_needed': 13,
#   'price': 84.03,
#   'customer_id': 160,
#   'evaluater_id': 43,
#   'status': 'accepted',
#   'card_number': '219717971987',
#   'payment_time': datetime.datetime(2017, 12, 6, 9, 54, 15),
#   'monitor_id': 30},
#  1000: {'recipient_name': 'SVtrPJorODkGGvQv',
#   'recipient_addr': 'jsKltlImdXFzeocQzzjsbQZXbgHmMoHu',
#   'recipient_postal': '699984',
#   'pickup_addr': 'aohfQvSspKGJFszaecgbZKrcCVZHJfnU',
#   'pickup_postal': '068109',
#   'pickup_date': '1990-07-10',
#   'submission_time': datetime.datetime(1998, 10, 22, 18, 35, 35),
#   'num_days_needed': 3,
#   'price': 50.1,
#   'customer_id': 13,
#   'evaluater_id': 32,
#   'status': 'evaluated'},
#  ...}

# %%
accepted_req_id
# Out:
# {9,
#  11,
#  12,
#  13,
#  15,
#  19,
#  23,
#  24,
#  27,
#  28,
#  29,
#  30,
#  31,
#  32,
#  35,
#  36,
#  46,
#  47,
#  49,
#  50,
#  53,
#  54,
#  56,
#  61,
#  62,
#  63,
#  64,
#  65,
#  66,
#  67,
#  68,
#  69,
#  70,
#  71,
#  72,
#  73,
#  75,
#  77,
#  79,
#  81,
#  84,
#  86,
#  90,
#  91,
#  93,
#  94,
#  97,
#  99,
#  100,
#  102,
#  103,
#  104,
#  105,
#  106,
#  107,
#  109,
#  111,
#  112,
#  115,
#  118,
#  119,
#  120,
#  121,
#  122,
#  125,
#  126,
#  127,
#  133,
#  134,
#  136,
#  137,
#  138,
#  139,
#  140,
#  143,
#  145,
#  146,
#  147,
#  148,
#  149,
#  151,
#  152,
#  153,
#  154,
#  155,
#  159,
#  160,
#  162,
#  163,
#  165,
#  166,
#  167,
#  168,
#  169,
#  170,
#  172,
#  173,
#  175,
#  177,
#  179,
#  180,
#  181,
#  183,
#  184,
#  185,
#  186,
#  187,
#  188,
#  189,
#  190,
#  191,
#  192,
#  193,
#  194,
#  196,
#  201,
#  205,
#  208,
#  209,
#  210,
#  211,
#  213,
#  219,
#  220,
#  221,
#  223,
#  225,
#  226,
#  227,
#  228,
#  230,
#  232,
#  236,
#  238,
#  239,
#  243,
#  244,
#  246,
#  248,
#  252,
#  253,
#  258,
#  259,
#  260,
#  262,
#  263,
#  264,
#  265,
#  267,
#  269,
#  273,
#  274,
#  278,
#  279,
#  283,
#  286,
#  287,
#  288,
#  289,
#  290,
#  291,
#  293,
#  294,
#  296,
#  297,
#  299,
#  300,
#  301,
#  303,
#  304,
#  305,
#  308,
#  309,
#  310,
#  311,
#  312,
#  314,
#  315,
#  316,
#  318,
#  319,
#  320,
#  321,
#  322,
#  323,
#  324,
#  326,
#  330,
#  332,
#  334,
#  335,
#  336,
#  337,
#  339,
#  340,
#  342,
#  343,
#  344,
#  345,
#  346,
#  347,
#  350,
#  354,
#  355,
#  356,
#  359,
#  361,
#  362,
#  365,
#  366,
#  369,
#  370,
#  376,
#  378,
#  380,
#  381,
#  382,
#  383,
#  385,
#  389,
#  391,
#  393,
#  394,
#  395,
#  400,
#  403,
#  406,
#  407,
#  408,
#  410,
#  412,
#  414,
#  415,
#  416,
#  417,
#  418,
#  421,
#  422,
#  423,
#  424,
#  426,
#  428,
#  431,
#  432,
#  434,
#  436,
#  438,
#  439,
#  442,
#  443,
#  445,
#  448,
#  450,
#  454,
#  456,
#  461,
#  462,
#  463,
#  466,
#  467,
#  469,
#  470,
#  471,
#  477,
#  478,
#  480,
#  481,
#  482,
#  485,
#  486,
#  488,
#  489,
#  492,
#  493,
#  494,
#  495,
#  496,
#  499,
#  501,
#  502,
#  504,
#  505,
#  506,
#  508,
#  509,
#  510,
#  512,
#  514,
#  515,
#  516,
#  517,
#  518,
#  519,
#  520,
#  521,
#  522,
#  523,
#  524,
#  526,
#  527,
#  528,
#  530,
#  531,
#  532,
#  533,
#  534,
#  535,
#  537,
#  538,
#  539,
#  540,
#  541,
#  542,
#  544,
#  545,
#  548,
#  552,
#  557,
#  562,
#  563,
#  564,
#  565,
#  566,
#  568,
#  570,
#  572,
#  574,
#  575,
#  576,
#  578,
#  580,
#  581,
#  582,
#  583,
#  584,
#  585,
#  587,
#  591,
#  592,
#  593,
#  595,
#  596,
#  597,
#  598,
#  600,
#  601,
#  603,
#  607,
#  608,
#  610,
#  611,
#  613,
#  615,
#  617,
#  619,
#  621,
#  622,
#  623,
#  625,
#  626,
#  627,
#  629,
#  630,
#  631,
#  634,
#  635,
#  636,
#  637,
#  640,
#  643,
#  646,
#  649,
#  651,
#  655,
#  656,
#  660,
#  661,
#  662,
#  663,
#  665,
#  666,
#  667,
#  669,
#  670,
#  671,
#  676,
#  678,
#  679,
#  680,
#  681,
#  682,
#  684,
#  685,
#  687,
#  689,
#  691,
#  694,
#  695,
#  696,
#  697,
#  698,
#  699,
#  702,
#  705,
#  706,
#  707,
#  709,
#  710,
#  711,
#  712,
#  713,
#  714,
#  715,
#  716,
#  719,
#  723,
#  725,
#  728,
#  730,
#  731,
#  737,
#  740,
#  741,
#  743,
#  745,
#  749,
#  751,
#  752,
#  754,
#  755,
#  758,
#  759,
#  760,
#  762,
#  764,
#  767,
#  768,
#  769,
#  771,
#  772,
#  773,
#  774,
#  775,
#  776,
#  777,
#  779,
#  780,
#  783,
#  784,
#  785,
#  789,
#  792,
#  793,
#  794,
#  795,
#  796,
#  798,
#  799,
#  800,
#  802,
#  803,
#  806,
#  807,
#  808,
#  810,
#  813,
#  815,
#  818,
#  819,
#  822,
#  823,
#  824,
#  825,
#  826,
#  827,
#  828,
#  829,
#  830,
#  831,
#  832,
#  833,
#  837,
#  839,
#  840,
#  841,
#  843,
#  844,
#  846,
#  847,
#  848,
#  849,
#  850,
#  852,
#  853,
#  854,
#  855,
#  860,
#  861,
#  862,
#  863,
#  865,
#  866,
#  867,
#  868,
#  871,
#  873,
#  874,
#  875,
#  876,
#  877,
#  879,
#  880,
#  882,
#  883,
#  885,
#  887,
#  889,
#  893,
#  897,
#  898,
#  899,
#  900,
#  901,
#  902,
#  904,
#  906,
#  907,
#  908,
#  909,
#  910,
#  911,
#  914,
#  915,
#  916,
#  917,
#  919,
#  920,
#  921,
#  922,
#  927,
#  928,
#  929,
#  930,
#  933,
#  939,
#  941,
#  942,
#  943,
#  945,
#  948,
#  950,
#  951,
#  955,
#  957,
#  958,
#  959,
#  960,
#  961,
#  962,
#  964,
#  965,
#  968,
#  971,
#  972,
#  974,
#  975,
#  976,
#  977,
#  979,
#  980,
#  981,
#  982,
#  983,
#  984,
#  986,
#  987,
#  988,
#  990,
#  991,
#  992,
#  994,
#  995,
#  996,
#  997,
#  998,
#  999,
#  1001,
#  1002,
#  1003,
#  1005,
#  1007,
#  1008,
#  1009,
#  1010,
#  1012,
#  1014,
#  1015,
#  1016,
#  1019,
#  1021,
#  1023,
#  1024,
#  1027,
#  1028,
#  1031,
#  1032,
#  1033,
#  1034,
#  1035,
#  1036,
#  1038,
#  1039,
#  1040,
#  1042,
#  1043,
#  1046,
#  1047,
#  1049,
#  1050,
#  1051,
#  1052,
#  1053,
#  1054,
#  1055,
#  1056,
#  1057,
#  1058,
#  1059,
#  1062,
#  1063,
#  1065,
#  1066,
#  1067,
#  1068,
#  1069,
#  1073,
#  1074,
#  1078,
#  1079,
#  1080,
#  1083,
#  1085,
#  1086,
#  1087,
#  1091,
#  1092,
#  1094,
#  1096,
#  1099,
#  1101,
#  1103,
#  1105,
#  1107,
#  1108,
#  1111,
#  1112,
#  1114,
#  1116,
#  1118,
#  1119,
#  1120,
#  1121,
#  1122,
#  1125,
#  1129,
#  1131,
#  1132,
#  1133,
#  1134,
#  1136,
#  1137,
#  1138,
#  1139,
#  1140,
#  1141,
#  1142,
#  1145,
#  1146,
#  1149,
#  1151,
#  1152,
#  1153,
#  1155,
#  1157,
#  1158,
#  1161,
#  1163,
#  1167,
#  1168,
#  1169,
#  1171,
#  1176,
#  1177,
#  1183,
#  1185,
#  1186,
#  1187,
#  1192,
#  1195,
#  1196,
#  1197,
#  1200,
#  1201,
#  1202,
#  1203,
#  1204,
#  1205,
#  1206,
#  1208,
#  1210,
#  1211,
#  1212,
#  1213,
#  1215,
#  1219,
#  1220,
#  1222,
#  1223,
#  1225,
#  1226,
#  1227,
#  1228,
#  1229,
#  1230,
#  1231,
#  1233,
#  1234,
#  1236,
#  1237,
#  1240,
#  1241,
#  1243,
#  1244,
#  1246,
#  1247,
#  1248,
#  1249,
#  1251,
#  1252,
#  1255,
#  1260,
#  1263,
#  1264,
#  1268,
#  1269,
#  1270,
#  1271,
#  1272,
#  1275,
#  1277,
#  1279,
#  1280,
#  1283,
#  1284,
#  1285,
#  1286,
#  1287,
#  1290,
#  1291,
#  1292,
#  1293,
#  1294,
#  1295,
#  1296,
#  1299,
#  1300,
#  1301,
#  1303,
#  1305,
#  1306,
#  1307,
#  1309,
#  1311,
#  1313,
#  1314,
#  1318,
#  1319,
#  1320,
#  1322,
#  1324,
#  1325,
#  1327,
#  1328,
#  1330,
#  1331,
#  1335,
#  1341,
#  1343,
#  1344,
#  1347,
#  1348,
#  1350,
#  1352,
#  1354,
#  1360,
#  1361,
#  1362,
#  1365,
#  1366,
#  1367,
#  1368,
#  1369,
#  1373,
#  1377,
#  1379,
#  1380,
#  1381,
#  1383,
#  1384,
#  1385,
#  1386,
#  1388,
#  1389,
#  1391,
#  1392,
#  1395,
#  1396,
#  1397,
#  1398,
#  1400,
#  1401,
#  1405,
#  1411,
#  1412,
#  1413,
#  1414,
#  1416,
#  1419,
#  1420,
#  1421,
#  1425,
#  1428,
#  1429,
#  1430,
#  1433,
#  1434,
#  1436,
#  1437,
#  1442,
#  1443,
#  1446,
#  1448,
#  1449,
#  1450,
#  1451,
#  1452,
#  1456,
#  1462,
#  1464,
#  1465,
#  1467,
#  1468,
#  1469,
#  1472,
#  1473,
#  1475,
#  1477,
#  1478,
#  1479,
#  1482,
#  1483,
#  1484,
#  1490,
#  1493,
#  1494,
#  1495,
#  1496,
#  1497,
#  1498,
#  1499,
#  1503,
#  1504,
#  1505,
#  1507,
#  1510,
#  1511,
#  1512,
#  1513,
#  1514,
#  1516,
#  1517,
#  1522,
#  1523,
#  1524,
#  1526,
#  1528,
#  1529,
#  1530,
#  1531,
#  1533,
#  1535,
#  1538,
#  1539,
#  1540,
#  1542,
#  1543,
#  1544,
#  1546,
#  1547,
#  1550,
#  1553,
#  1554,
#  1556,
#  1558,
#  1559,
#  1561,
#  1562,
#  1566,
#  1568,
#  1571,
#  1572,
#  1574,
#  1575,
#  1577,
#  1582,
#  1584,
#  1585,
#  1586,
#  1587,
#  1590,
#  1591,
#  1592,
#  1593,
#  1596,
#  1597,
#  1599,
#  1601,
#  1602,
#  1603,
#  1604,
#  1605,
#  1606,
#  1607,
#  1609,
#  1610,
#  1611,
#  1612,
#  1613,
#  1614,
#  1617,
#  1618,
#  1619,
#  1622,
#  1623,
#  1624,
#  1628,
#  1630,
#  1631,
#  1633,
#  1635,
#  1637,
#  1638,
#  1639,
#  1641,
#  1643,
#  1644,
#  1645,
#  1646,
#  1647,
#  1648,
#  1650,
#  1651,
#  1652,
#  1653,
#  1655,
#  1656,
#  1657,
#  1658,
#  1659,
#  1660,
#  1662,
#  1664,
#  1665,
#  1666,
#  1668,
#  1669,
#  1670,
#  1671,
#  1672,
#  1675,
#  1676,
#  1677,
#  1680,
#  1681,
#  1682,
#  1683,
#  1685,
#  1686,
#  1690,
#  1691,
#  1692,
#  1694,
#  1696,
#  1697,
#  1700,
#  1701,
#  1703,
#  1704,
#  1707,
#  1709,
#  ...}

# %%
packages = {}
for request_id in delivery_requests.keys():
    current_timestamp = random_timestamp()
    for package_id in range(1, get_random_int_to(2, 6)):
        to_add = {}
        to_add['request_id'] = request_id
        to_add['package_id'] = package_id
        this_id = (to_add['request_id'], to_add['package_id'])
        to_add['reported_height'] = get_random_float_from_to(2, 1000)
        to_add['reported_width'] = get_random_float_from_to(2, 1000)
        to_add['reported_depth'] = get_random_float_from_to(2, 1000)
        to_add['reported_weight'] = get_random_float_from_to(2, 1000)
        to_add['actual_height'] = random_plus_minus(to_add['reported_height'])
        to_add['actual_width'] = random_plus_minus(to_add['reported_width'])
        to_add['actual_depth'] = random_plus_minus(to_add['reported_depth'])
        to_add['actual_weight'] = random_plus_minus(to_add['reported_weight'])
        to_add['content'] = get_random_string(12)
        to_add['estimated_value'] = get_random_price()   
        packages[this_id] = to_add
    
packages
# Out:
# {(1, 1): {'request_id': 1,
#   'package_id': 1,
#   'reported_height': 342.41,
#   'reported_width': 37.68,
#   'reported_depth': 149.82,
#   'reported_weight': 689.33,
#   'actual_height': 343.9888848753934,
#   'actual_width': 39.733726572538835,
#   'actual_depth': 153.5662995770113,
#   'actual_weight': 692.9878497585966,
#   'content': 'EgsfFFiJEczo',
#   'estimated_value': 39.82},
#  (1, 2): {'request_id': 1,
#   'package_id': 2,
#   'reported_height': 396.71,
#   'reported_width': 215.7,
#   'reported_depth': 682.89,
#   'reported_weight': 246.36,
#   'actual_height': 398.2854606084891,
#   'actual_width': 215.50435251177768,
#   'actual_depth': 681.3009435504886,
#   'actual_weight': 250.22468273562552,
#   'content': 'rzRyQykFxxuf',
#   'estimated_value': 30.1},
#  (1, 3): {'request_id': 1,
#   'package_id': 3,
#   'reported_height': 433.31,
#   'reported_width': 698.15,
#   'reported_depth': 106.72,
#   'reported_weight': 715.88,
#   'actual_height': 431.62505744979,
#   'actual_width': 698.3662798242389,
#   'actual_depth': 105.6118456649894,
#   'actual_weight': 715.2837526116934,
#   'content': 'ZvsbfYJEkPyj',
#   'estimated_value': 23.71},
#  (1, 4): {'request_id': 1,
#   'package_id': 4,
#   'reported_height': 183.14,
#   'reported_width': 334.3,
#   'reported_depth': 777.88,
#   'reported_weight': 723.52,
#   'actual_height': 183.10992643144363,
#   'actual_width': 335.4221547758181,
#   'actual_depth': 779.122242926122,
#   'actual_weight': 720.6936322411455,
#   'content': 'NKyFsktiSCOq',
#   'estimated_value': 47.24},
#  (1, 5): {'request_id': 1,
#   'package_id': 5,
#   'reported_height': 9.26,
#   'reported_width': 741.75,
#   'reported_depth': 630.3,
#   'reported_weight': 225.25,
#   'actual_height': 8.36291736118407,
#   'actual_width': 743.5536052491572,
#   'actual_depth': 628.3509210462299,
#   'actual_weight': 222.34255934024466,
#   'content': 'CPmDGEMSPSOj',
#   'estimated_value': 2.73},
#  (2, 1): {'request_id': 2,
#   'package_id': 1,
#   'reported_height': 706.14,
#   'reported_width': 827.24,
#   'reported_depth': 59.39,
#   'reported_weight': 151.27,
#   'actual_height': 708.2020716903316,
#   'actual_width': 824.7266582265875,
#   'actual_depth': 60.68929754759468,
#   'actual_weight': 154.5960973028006,
#   'content': 'FzFjEFKInvQh',
#   'estimated_value': 0.69},
#  (2, 2): {'request_id': 2,
#   'package_id': 2,
#   'reported_height': 121.43,
#   'reported_width': 929.41,
#   'reported_depth': 827.06,
#   'reported_weight': 806.2,
#   'actual_height': 117.18973074744181,
#   'actual_width': 930.9916867036543,
#   'actual_depth': 829.3757072430082,
#   'actual_weight': 805.9227068069168,
#   'content': 'dxUvCppmiAyJ',
#   'estimated_value': 16.86},
#  (3, 1): {'request_id': 3,
#   'package_id': 1,
#   'reported_height': 531.62,
#   'reported_width': 440.7,
#   'reported_depth': 835.32,
#   'reported_weight': 894.08,
#   'actual_height': 529.9935579523785,
#   'actual_width': 441.45289485739806,
#   'actual_depth': 833.6366325486215,
#   'actual_weight': 894.3154415751454,
#   'content': 'famBmDVvGEGB',
#   'estimated_value': 15.36},
#  (3, 2): {'request_id': 3,
#   'package_id': 2,
#   'reported_height': 888.6,
#   'reported_width': 450.63,
#   'reported_depth': 17.18,
#   'reported_weight': 967.91,
#   'actual_height': 892.5163201760924,
#   'actual_width': 450.76520280758,
#   'actual_depth': 14.631148941352393,
#   'actual_weight': 970.696917228927,
#   'content': 'fWJZkOZOWgax',
#   'estimated_value': 12.74},
#  (3, 3): {'request_id': 3,
#   'package_id': 3,
#   'reported_height': 210.68,
#   'reported_width': 355.81,
#   'reported_depth': 824.75,
#   'reported_weight': 867.88,
#   'actual_height': 211.9835590273987,
#   'actual_width': 358.01747406309283,
#   'actual_depth': 825.9002343717798,
#   'actual_weight': 868.0240002320878,
#   'content': 'LFDvESrnMbRY',
#   'estimated_value': 41.99},
#  (4, 1): {'request_id': 4,
#   'package_id': 1,
#   'reported_height': 350.38,
#   'reported_width': 180.59,
#   'reported_depth': 708.97,
#   'reported_weight': 853.41,
#   'actual_height': 349.67541313870817,
#   'actual_width': 180.31641062455103,
#   'actual_depth': 713.7084402621575,
#   'actual_weight': 852.0753895959016,
#   'content': 'wzqKFwnFawVw',
#   'estimated_value': 40.83},
#  (5, 1): {'request_id': 5,
#   'package_id': 1,
#   'reported_height': 677.41,
#   'reported_width': 486.08,
#   'reported_depth': 483.83,
#   'reported_weight': 913.18,
#   'actual_height': 674.278494323434,
#   'actual_width': 487.025816313406,
#   'actual_depth': 481.36622222929054,
#   'actual_weight': 914.7855531779384,
#   'content': 'IScQlOfktBeY',
#   'estimated_value': 39.76},
#  (5, 2): {'request_id': 5,
#   'package_id': 2,
#   'reported_height': 968.63,
#   'reported_width': 910.65,
#   'reported_depth': 830.56,
#   'reported_weight': 405.52,
#   'actual_height': 965.7222491232283,
#   'actual_width': 906.427483391304,
#   'actual_depth': 829.8222772486776,
#   'actual_weight': 408.2964062761503,
#   'content': 'pyPMjAWPEpnU',
#   'estimated_value': 82.58},
#  (5, 3): {'request_id': 5,
#   'package_id': 3,
#   'reported_height': 462.59,
#   'reported_width': 189.2,
#   'reported_depth': 1000.28,
#   'reported_weight': 967.01,
#   'actual_height': 460.67489275435196,
#   'actual_width': 186.50052673436232,
#   'actual_depth': 1000.87034606516,
#   'actual_weight': 966.2983003157259,
#   'content': 'ZndRKYblRUwf',
#   'estimated_value': 65.6},
#  (5, 4): {'request_id': 5,
#   'package_id': 4,
#   'reported_height': 374.97,
#   'reported_width': 820.99,
#   'reported_depth': 387.0,
#   'reported_weight': 216.82,
#   'actual_height': 377.05133223086915,
#   'actual_width': 816.4120592995956,
#   'actual_depth': 384.48419807714924,
#   'actual_weight': 216.7968218771714,
#   'content': 'FfOuuTFZUxgI',
#   'estimated_value': 97.29},
#  (6, 1): {'request_id': 6,
#   'package_id': 1,
#   'reported_height': 592.1,
#   'reported_width': 600.99,
#   'reported_depth': 873.62,
#   'reported_weight': 54.86,
#   'actual_height': 594.9728922293605,
#   'actual_width': 602.9486295782979,
#   'actual_depth': 874.446864242588,
#   'actual_weight': 54.43328104428615,
#   'content': 'ZaKweaOzXoDi',
#   'estimated_value': 87.38},
#  (6, 2): {'request_id': 6,
#   'package_id': 2,
#   'reported_height': 430.07,
#   'reported_width': 633.37,
#   'reported_depth': 980.5,
#   'reported_weight': 177.2,
#   'actual_height': 429.96674338999986,
#   'actual_width': 635.0781037661278,
#   'actual_depth': 981.4401202887457,
#   'actual_weight': 178.8013470001581,
#   'content': 'yDEdnWcfxxeD',
#   'estimated_value': 48.63},
#  (6, 3): {'request_id': 6,
#   'package_id': 3,
#   'reported_height': 492.99,
#   'reported_width': 417.57,
#   'reported_depth': 930.7,
#   'reported_weight': 541.5,
#   'actual_height': 490.9939747195283,
#   'actual_width': 420.99887828566807,
#   'actual_depth': 930.7193527752379,
#   'actual_weight': 542.3281702547023,
#   'content': 'ITpZmjCZaDZT',
#   'estimated_value': 94.61},
#  (7, 1): {'request_id': 7,
#   'package_id': 1,
#   'reported_height': 574.65,
#   'reported_width': 874.19,
#   'reported_depth': 941.15,
#   'reported_weight': 985.1,
#   'actual_height': 578.0562488501596,
#   'actual_width': 876.5054325941381,
#   'actual_depth': 941.5649465631328,
#   'actual_weight': 983.0185573770591,
#   'content': 'tjlDMhUaOAdk',
#   'estimated_value': 84.15},
#  (7, 2): {'request_id': 7,
#   'package_id': 2,
#   'reported_height': 269.0,
#   'reported_width': 747.33,
#   'reported_depth': 911.7,
#   'reported_weight': 85.23,
#   'actual_height': 266.2987518834234,
#   'actual_width': 745.0832622132137,
#   'actual_depth': 910.2838112219214,
#   'actual_weight': 81.70025522618853,
#   'content': 'PWFEeFpXQDlW',
#   'estimated_value': 57.1},
#  (7, 3): {'request_id': 7,
#   'package_id': 3,
#   'reported_height': 949.86,
#   'reported_width': 417.02,
#   'reported_depth': 310.31,
#   'reported_weight': 25.81,
#   'actual_height': 949.8640530638917,
#   'actual_width': 418.1222120295285,
#   'actual_depth': 314.53856430883803,
#   'actual_weight': 27.931879560683413,
#   'content': 'WniXyOziTqJG',
#   'estimated_value': 68.51},
#  (7, 4): {'request_id': 7,
#   'package_id': 4,
#   'reported_height': 894.55,
#   'reported_width': 9.59,
#   'reported_depth': 383.28,
#   'reported_weight': 371.77,
#   'actual_height': 898.3053275626036,
#   'actual_width': 9.950567260158355,
#   'actual_depth': 379.1003252477239,
#   'actual_weight': 373.3947398474511,
#   'content': 'NvOfJgFSjvqJ',
#   'estimated_value': 72.35},
#  (8, 1): {'request_id': 8,
#   'package_id': 1,
#   'reported_height': 208.54,
#   'reported_width': 16.95,
#   'reported_depth': 199.59,
#   'reported_weight': 988.65,
#   'actual_height': 208.90311903185707,
#   'actual_width': 13.053732405028843,
#   'actual_depth': 201.5375106138608,
#   'actual_weight': 987.223524326701,
#   'content': 'qvcQUOgqYqHG',
#   'estimated_value': 28.52},
#  (8, 2): {'request_id': 8,
#   'package_id': 2,
#   'reported_height': 379.88,
#   'reported_width': 622.62,
#   'reported_depth': 626.39,
#   'reported_weight': 40.81,
#   'actual_height': 378.8973841394861,
#   'actual_width': 620.4165223943764,
#   'actual_depth': 625.890167221227,
#   'actual_weight': 38.09580692335326,
#   'content': 'DyTVSsrzllmy',
#   'estimated_value': 58.54},
#  (8, 3): {'request_id': 8,
#   'package_id': 3,
#   'reported_height': 872.0,
#   'reported_width': 135.02,
#   'reported_depth': 902.66,
#   'reported_weight': 86.52,
#   'actual_height': 872.8283393944781,
#   'actual_width': 134.59268414668554,
#   'actual_depth': 902.1656077675377,
#   'actual_weight': 87.41233301878657,
#   'content': 'ymkCoRghssEY',
#   'estimated_value': 30.39},
#  (8, 4): {'request_id': 8,
#   'package_id': 4,
#   'reported_height': 360.04,
#   'reported_width': 571.93,
#   'reported_depth': 940.36,
#   'reported_weight': 460.1,
#   'actual_height': 363.77554192427783,
#   'actual_width': 573.5686343279835,
#   'actual_depth': 936.2039852011983,
#   'actual_weight': 460.53968493895525,
#   'content': 'aDFEptArmgFI',
#   'estimated_value': 57.81},
#  (9, 1): {'request_id': 9,
#   'package_id': 1,
#   'reported_height': 842.55,
#   'reported_width': 261.73,
#   'reported_depth': 459.01,
#   'reported_weight': 151.98,
#   'actual_height': 839.8681037683019,
#   'actual_width': 262.5227146639724,
#   'actual_depth': 459.50320046587336,
#   'actual_weight': 149.38167126691394,
#   'content': 'RMLpYLzPkRDC',
#   'estimated_value': 78.15},
#  (9, 2): {'request_id': 9,
#   'package_id': 2,
#   'reported_height': 820.94,
#   'reported_width': 972.77,
#   'reported_depth': 822.8,
#   'reported_weight': 345.89,
#   'actual_height': 817.4813356545837,
#   'actual_width': 969.0165099232578,
#   'actual_depth': 822.0825124463926,
#   'actual_weight': 348.3277478961818,
#   'content': 'mXZqbmxmymtA',
#   'estimated_value': 16.19},
#  (9, 3): {'request_id': 9,
#   'package_id': 3,
#   'reported_height': 530.15,
#   'reported_width': 433.48,
#   'reported_depth': 5.45,
#   'reported_weight': 881.61,
#   'actual_height': 527.7964561515907,
#   'actual_width': 437.48372931977934,
#   'actual_depth': 2.583569322744991,
#   'actual_weight': 881.1767791939225,
#   'content': 'FRFTBYuaCicD',
#   'estimated_value': 43.06},
#  (10, 1): {'request_id': 10,
#   'package_id': 1,
#   'reported_height': 676.81,
#   'reported_width': 905.66,
#   'reported_depth': 43.51,
#   'reported_weight': 571.58,
#   'actual_height': 680.1647418495646,
#   'actual_width': 904.8765292860985,
#   'actual_depth': 43.154062142476036,
#   'actual_weight': 571.6017819147618,
#   'content': 'TmKfdGqpTYxJ',
#   'estimated_value': 19.65},
#  (10, 2): {'request_id': 10,
#   'package_id': 2,
#   'reported_height': 609.53,
#   'reported_width': 97.7,
#   'reported_depth': 914.78,
#   'reported_weight': 233.28,
#   'actual_height': 611.5263924069609,
#   'actual_width': 98.43739448977362,
#   'actual_depth': 913.2405430509475,
#   'actual_weight': 232.60985987063316,
#   'content': 'BscMQngAPZIg',
#   'estimated_value': 43.92},
#  (10, 3): {'request_id': 10,
#   'package_id': 3,
#   'reported_height': 957.27,
#   'reported_width': 123.79,
#   'reported_depth': 91.1,
#   'reported_weight': 988.88,
#   'actual_height': 958.4283526549065,
#   'actual_width': 125.67908848210064,
#   'actual_depth': 90.22678074313544,
#   'actual_weight': 991.6194740652239,
#   'content': 'KRMbEZMwAJbc',
#   'estimated_value': 37.71},
#  (10, 4): {'request_id': 10,
#   'package_id': 4,
#   'reported_height': 881.76,
#   'reported_width': 643.24,
#   'reported_depth': 286.41,
#   'reported_weight': 625.08,
#   'actual_height': 880.532744109669,
#   'actual_width': 643.1508165204363,
#   'actual_depth': 287.6844946554263,
#   'actual_weight': 623.7013799501192,
#   'content': 'PDxaxfKzBbRW',
#   'estimated_value': 28.66},
#  (10, 5): {'request_id': 10,
#   'package_id': 5,
#   'reported_height': 183.01,
#   'reported_width': 738.52,
#   'reported_depth': 945.47,
#   'reported_weight': 856.41,
#   'actual_height': 181.2934532244766,
#   'actual_width': 738.0280414397444,
#   'actual_depth': 942.417611568486,
#   'actual_weight': 859.8597033123973,
#   'content': 'AkpbfpWWEPqf',
#   'estimated_value': 15.29},
#  (11, 1): {'request_id': 11,
#   'package_id': 1,
#   'reported_height': 955.98,
#   'reported_width': 772.12,
#   'reported_depth': 419.7,
#   'reported_weight': 251.13,
#   'actual_height': 954.2971575337406,
#   'actual_width': 769.5836240394958,
#   'actual_depth': 421.0029634504006,
#   'actual_weight': 252.93961223874385,
#   'content': 'BjvaCUCcmJew',
#   'estimated_value': 13.64},
#  (11, 2): {'request_id': 11,
#   'package_id': 2,
#   'reported_height': 555.29,
#   'reported_width': 663.26,
#   'reported_depth': 615.94,
#   'reported_weight': 567.48,
#   'actual_height': 554.8348850956653,
#   'actual_width': 662.6035325450425,
#   'actual_depth': 617.4758844893618,
#   'actual_weight': 564.9152773472484,
#   'content': 'SJoFmIPYoKwY',
#   'estimated_value': 51.23},
#  (11, 3): {'request_id': 11,
#   'package_id': 3,
#   'reported_height': 503.04,
#   'reported_width': 34.75,
#   'reported_depth': 478.07,
#   'reported_weight': 916.94,
#   'actual_height': 500.28345727198115,
#   'actual_width': 33.27028422091058,
#   'actual_depth': 480.25859244775205,
#   'actual_weight': 918.0434438958677,
#   'content': 'QaPXaaLABinu',
#   'estimated_value': 53.48},
#  (11, 4): {'request_id': 11,
#   'package_id': 4,
#   'reported_height': 896.37,
#   'reported_width': 448.15,
#   'reported_depth': 684.58,
#   'reported_weight': 1000.94,
#   'actual_height': 895.3026341519692,
#   'actual_width': 448.85632638144506,
#   'actual_depth': 682.7376887602912,
#   'actual_weight': 997.6587469911358,
#   'content': 'zFfHrEgVttAB',
#   'estimated_value': 52.65},
#  (11, 5): {'request_id': 11,
#   'package_id': 5,
#   'reported_height': 957.73,
#   'reported_width': 771.23,
#   'reported_depth': 572.22,
#   'reported_weight': 957.17,
#   'actual_height': 956.366057955589,
#   'actual_width': 775.197061819321,
#   'actual_depth': 573.1755903589636,
#   'actual_weight': 959.2396862789648,
#   'content': 'ibpEWyuKHrqM',
#   'estimated_value': 36.69},
#  (12, 1): {'request_id': 12,
#   'package_id': 1,
#   'reported_height': 830.84,
#   'reported_width': 128.28,
#   'reported_depth': 207.29,
#   'reported_weight': 798.11,
#   'actual_height': 829.7457171621267,
#   'actual_width': 127.03783401782108,
#   'actual_depth': 206.5185929620483,
#   'actual_weight': 800.4511646618565,
#   'content': 'oXVBVHnkrrvN',
#   'estimated_value': 15.32},
#  (12, 2): {'request_id': 12,
#   'package_id': 2,
#   'reported_height': 680.85,
#   'reported_width': 900.9,
#   'reported_depth': 579.54,
#   'reported_weight': 553.72,
#   'actual_height': 680.443045449212,
#   'actual_width': 902.0925524045564,
#   'actual_depth': 581.3209441135224,
#   'actual_weight': 552.2505566337524,
#   'content': 'sSuZpXeWkAMk',
#   'estimated_value': 34.02},
#  (12, 3): {'request_id': 12,
#   'package_id': 3,
#   'reported_height': 121.76,
#   'reported_width': 135.84,
#   'reported_depth': 967.45,
#   'reported_weight': 272.45,
#   'actual_height': 120.66140164692882,
#   'actual_width': 135.0130199846137,
#   'actual_depth': 968.6269891152742,
#   'actual_weight': 271.73907121496336,
#   'content': 'GtvOkhsihXSo',
#   'estimated_value': 22.56},
#  (13, 1): {'request_id': 13,
#   'package_id': 1,
#   'reported_height': 83.61,
#   'reported_width': 109.52,
#   'reported_depth': 46.57,
#   'reported_weight': 477.57,
#   'actual_height': 83.20767673959877,
#   'actual_width': 109.483264161623,
#   'actual_depth': 46.708041289566445,
#   'actual_weight': 480.5272670036294,
#   'content': 'JBUkZcGfghry',
#   'estimated_value': 36.84},
#  (13, 2): {'request_id': 13,
#   'package_id': 2,
#   'reported_height': 592.33,
#   'reported_width': 562.93,
#   'reported_depth': 640.78,
#   'reported_weight': 618.82,
#   'actual_height': 592.7747867727769,
#   'actual_width': 561.6215889375575,
#   'actual_depth': 639.6000124756034,
#   'actual_weight': 621.908977246222,
#   'content': 'QozGpvsxNVIL',
#   'estimated_value': 83.62},
#  (13, 3): {'request_id': 13,
#   'package_id': 3,
#   'reported_height': 285.63,
#   'reported_width': 481.55,
#   'reported_depth': 121.44,
#   'reported_weight': 903.74,
#   'actual_height': 283.9570827580391,
#   'actual_width': 481.6611349694973,
#   'actual_depth': 120.3028834406159,
#   'actual_weight': 905.5106677663645,
#   'content': 'oHlaCIvzXEia',
#   'estimated_value': 95.28},
#  (14, 1): {'request_id': 14,
#   'package_id': 1,
#   'reported_height': 131.87,
#   'reported_width': 975.22,
#   'reported_depth': 505.58,
#   'reported_weight': 422.26,
#   'actual_height': 130.4182979845833,
#   'actual_width': 974.4880017611633,
#   'actual_depth': 507.3632429868898,
#   'actual_weight': 423.8600051561342,
#   'content': 'CKQcgoRDaAQR',
#   'estimated_value': 41.5},
#  (14, 2): {'request_id': 14,
#   'package_id': 2,
#   'reported_height': 89.79,
#   'reported_width': 785.11,
#   'reported_depth': 507.23,
#   'reported_weight': 430.95,
#   'actual_height': 89.63061595366236,
#   'actual_width': 785.9478634252662,
#   'actual_depth': 508.56565782464423,
#   'actual_weight': 428.14368168877206,
#   'content': 'VRaUXROIcWcB',
#   'estimated_value': 96.3},
#  (14, 3): {'request_id': 14,
#   'package_id': 3,
#   'reported_height': 472.46,
#   'reported_width': 121.61,
#   'reported_depth': 115.68,
#   'reported_weight': 417.56,
#   'actual_height': 471.29474520311635,
#   'actual_width': 122.45361481537243,
#   'actual_depth': 117.34292335780518,
#   'actual_weight': 417.880696216213,
#   'content': 'ArDxsxEtSPYe',
#   'estimated_value': 60.07},
#  (14, 4): {'request_id': 14,
#   'package_id': 4,
#   'reported_height': 601.17,
#   'reported_width': 177.54,
#   'reported_depth': 739.77,
#   'reported_weight': 873.52,
#   'actual_height': 603.3243778287735,
#   'actual_width': 177.23313956269095,
#   'actual_depth': 739.491621821498,
#   'actual_weight': 874.4879466031392,
#   'content': 'QNwkiwpFZRWf',
#   'estimated_value': 82.54},
#  (14, 5): {'request_id': 14,
#   'package_id': 5,
#   'reported_height': 574.08,
#   'reported_width': 891.36,
#   'reported_depth': 16.85,
#   'reported_weight': 535.94,
#   'actual_height': 576.1363014695887,
#   'actual_width': 891.3999551456172,
#   'actual_depth': 12.920733039720492,
#   'actual_weight': 531.8248506959842,
#   'content': 'SftzbmWJSivd',
#   'estimated_value': 55.28},
#  (15, 1): {'request_id': 15,
#   'package_id': 1,
#   'reported_height': 240.06,
#   'reported_width': 667.69,
#   'reported_depth': 342.25,
#   'reported_weight': 274.21,
#   'actual_height': 240.39532703581725,
#   'actual_width': 665.0640557755977,
#   'actual_depth': 343.87526021979795,
#   'actual_weight': 273.42048810149936,
#   'content': 'JxlnUtArIlSY',
#   'estimated_value': 44.87},
#  (15, 2): {'request_id': 15,
#   'package_id': 2,
#   'reported_height': 90.59,
#   'reported_width': 808.47,
#   'reported_depth': 887.03,
#   'reported_weight': 721.85,
#   'actual_height': 91.28798828597142,
#   'actual_width': 806.6385999549038,
#   'actual_depth': 884.893712850066,
#   'actual_weight': 719.1763994269597,
#   'content': 'frheHpyOSBGG',
#   'estimated_value': 89.59},
#  (15, 3): {'request_id': 15,
#   'package_id': 3,
#   'reported_height': 585.27,
#   'reported_width': 156.67,
#   'reported_depth': 399.08,
#   'reported_weight': 726.9,
#   'actual_height': 587.748253965004,
#   'actual_width': 161.1353473979764,
#   'actual_depth': 400.8436366797461,
#   'actual_weight': 727.0843027714022,
#   'content': 'mDXLGheBfQSk',
#   'estimated_value': 12.32},
#  (15, 4): {'request_id': 15,
#   'package_id': 4,
#   'reported_height': 922.89,
#   'reported_width': 84.28,
#   'reported_depth': 769.58,
#   'reported_weight': 886.52,
#   'actual_height': 923.6033915208818,
#   'actual_width': 83.4840897364892,
#   'actual_depth': 770.3718792176464,
#   'actual_weight': 886.3753607232683,
#   'content': 'zsdMBFOcBQOm',
#   'estimated_value': 58.34},
#  (15, 5): {'request_id': 15,
#   'package_id': 5,
#   'reported_height': 201.01,
#   'reported_width': 182.92,
#   'reported_depth': 446.12,
#   'reported_weight': 666.87,
#   'actual_height': 205.50389774913015,
#   'actual_width': 183.53388883615483,
#   'actual_depth': 450.0272921596197,
#   'actual_weight': 663.4716484999244,
#   'content': 'EaBaHXQiMAPW',
#   'estimated_value': 45.12},
#  (16, 1): {'request_id': 16,
#   'package_id': 1,
#   'reported_height': 464.93,
#   'reported_width': 587.55,
#   'reported_depth': 426.63,
#   'reported_weight': 443.32,
#   'actual_height': 465.68012678244725,
#   'actual_width': 588.10938090796,
#   'actual_depth': 428.6388822438738,
#   'actual_weight': 444.24476003288567,
#   'content': 'DnocRtXyQsOt',
#   'estimated_value': 96.93},
#  (16, 2): {'request_id': 16,
#   'package_id': 2,
#   'reported_height': 507.11,
#   'reported_width': 166.83,
#   'reported_depth': 442.93,
#   'reported_weight': 791.1,
#   'actual_height': 505.14105054520377,
#   'actual_width': 167.3832198530979,
#   'actual_depth': 441.43568153772816,
#   'actual_weight': 789.5955875988302,
#   'content': 'tdeuqFQgarhX',
#   'estimated_value': 85.96},
#  (16, 3): {'request_id': 16,
#   'package_id': 3,
#   'reported_height': 921.51,
#   'reported_width': 113.8,
#   'reported_depth': 508.4,
#   'reported_weight': 441.07,
#   'actual_height': 921.5421290449482,
#   'actual_width': 112.0311841731567,
#   'actual_depth': 508.7174917325352,
#   'actual_weight': 443.981728026102,
#   'content': 'wmqtQUYsAODc',
#   'estimated_value': 48.64},
#  (16, 4): {'request_id': 16,
#   'package_id': 4,
#   'reported_height': 493.95,
#   'reported_width': 234.26,
#   'reported_depth': 347.27,
#   'reported_weight': 135.24,
#   'actual_height': 497.715997706922,
#   'actual_width': 237.28571700911183,
#   'actual_depth': 350.08966429141066,
#   'actual_weight': 138.58738217576195,
#   'content': 'uSKyptclRzxd',
#   'estimated_value': 34.02},
#  (16, 5): {'request_id': 16,
#   'package_id': 5,
#   'reported_height': 470.05,
#   'reported_width': 673.98,
#   'reported_depth': 80.3,
#   'reported_weight': 938.53,
#   'actual_height': 468.2979267760057,
#   'actual_width': 671.0189786002932,
#   'actual_depth': 81.20772805174224,
#   'actual_weight': 941.3836257027208,
#   'content': 'fgOLKWRCPTxA',
#   'estimated_value': 89.18},
#  (17, 1): {'request_id': 17,
#   'package_id': 1,
#   'reported_height': 813.73,
#   'reported_width': 422.14,
#   'reported_depth': 498.57,
#   'reported_weight': 540.41,
#   'actual_height': 813.0150363242585,
#   'actual_width': 422.95519917992686,
#   'actual_depth': 499.8594306730538,
#   'actual_weight': 540.0865152666262,
#   'content': 'KQsCAPbWNkui',
#   'estimated_value': 79.76},
#  (17, 2): {'request_id': 17,
#   'package_id': 2,
#   'reported_height': 719.04,
#   'reported_width': 136.03,
#   'reported_depth': 888.26,
#   'reported_weight': 26.96,
#   'actual_height': 716.5561874431995,
#   'actual_width': 134.46333453841336,
#   'actual_depth': 886.5843024533277,
#   'actual_weight': 29.059686272441667,
#   'content': 'qKWmmIcmnwwx',
#   'estimated_value': 26.33},
#  (17, 3): {'request_id': 17,
#   'package_id': 3,
#   'reported_height': 479.56,
#   'reported_width': 516.58,
#   'reported_depth': 454.98,
#   'reported_weight': 428.23,
#   'actual_height': 479.50642812784105,
#   'actual_width': 515.6217849757718,
#   'actual_depth': 451.72692385585765,
#   'actual_weight': 425.2742017733213,
#   'content': 'FsQfPTfiSOTV',
#   'estimated_value': 56.36},
#  (17, 4): {'request_id': 17,
#   'package_id': 4,
#   'reported_height': 402.9,
#   'reported_width': 406.53,
#   'reported_depth': 606.21,
#   'reported_weight': 549.69,
#   'actual_height': 405.30123764955465,
#   'actual_width': 405.82356448560927,
#   'actual_depth': 609.2615801862092,
#   'actual_weight': 545.3362147932953,
#   'content': 'jgmkuWIwKjXC',
#   'estimated_value': 82.68},
#  (18, 1): {'request_id': 18,
#   'package_id': 1,
#   'reported_height': 640.28,
#   'reported_width': 380.47,
#   'reported_depth': 938.86,
#   'reported_weight': 164.77,
#   'actual_height': 639.4830320552918,
#   'actual_width': 384.0769439361701,
#   'actual_depth': 940.7657098648792,
#   'actual_weight': 164.68166318305762,
#   'content': 'fWxjazYbPoBr',
#   'estimated_value': 50.9},
#  (18, 2): {'request_id': 18,
#   'package_id': 2,
#   'reported_height': 221.71,
#   'reported_width': 159.77,
#   'reported_depth': 462.33,
#   'reported_weight': 607.92,
#   'actual_height': 221.16078781458427,
#   'actual_width': 157.6806068632421,
#   'actual_depth': 461.32845627996795,
#   'actual_weight': 607.5881658123135,
#   'content': 'lemMkqXBIysF',
#   'estimated_value': 67.77},
#  (18, 3): {'request_id': 18,
#   'package_id': 3,
#   'reported_height': 812.95,
#   'reported_width': 82.58,
#   'reported_depth': 383.42,
#   'reported_weight': 673.85,
#   'actual_height': 817.0370248840131,
#   'actual_width': 83.94257352962612,
#   'actual_depth': 386.77578187943413,
#   'actual_weight': 678.586952737362,
#   'content': 'ySHVBsnKvFTU',
#   'estimated_value': 93.44},
#  (18, 4): {'request_id': 18,
#   'package_id': 4,
#   'reported_height': 395.92,
#   'reported_width': 798.5,
#   'reported_depth': 118.35,
#   'reported_weight': 674.79,
#   'actual_height': 395.7760981533233,
#   'actual_width': 795.4058519639032,
#   'actual_depth': 113.51059440495479,
#   'actual_weight': 675.291678626796,
#   'content': 'eCZmRiUMfZMZ',
#   'estimated_value': 72.14},
#  (19, 1): {'request_id': 19,
#   'package_id': 1,
#   'reported_height': 896.81,
#   'reported_width': 250.66,
#   'reported_depth': 681.22,
#   'reported_weight': 691.56,
#   'actual_height': 895.0032772030552,
#   'actual_width': 249.5801108206457,
#   'actual_depth': 678.9295852752597,
#   'actual_weight': 694.3778622095202,
#   'content': 'rSOJQWmuhfxB',
#   'estimated_value': 33.32},
#  (19, 2): {'request_id': 19,
#   'package_id': 2,
#   'reported_height': 628.51,
#   'reported_width': 999.08,
#   'reported_depth': 536.5,
#   'reported_weight': 173.7,
#   'actual_height': 629.3018770181152,
#   'actual_width': 995.9909336083166,
#   'actual_depth': 538.6651456707323,
#   'actual_weight': 176.06146509891224,
#   'content': 'uviWquiNStGa',
#   'estimated_value': 22.52},
#  (19, 3): {'request_id': 19,
#   'package_id': 3,
#   'reported_height': 68.11,
#   'reported_width': 707.17,
#   'reported_depth': 997.94,
#   'reported_weight': 573.86,
#   'actual_height': 69.43037308691368,
#   'actual_width': 706.2519541514938,
#   'actual_depth': 1001.213389967983,
#   'actual_weight': 574.4773081331784,
#   'content': 'HqENtmJsoiXK',
#   'estimated_value': 58.18},
#  (20, 1): {'request_id': 20,
#   'package_id': 1,
#   'reported_height': 784.75,
#   'reported_width': 895.13,
#   'reported_depth': 993.04,
#   'reported_weight': 478.99,
#   'actual_height': 786.7161339969075,
#   'actual_width': 895.8130447844915,
#   'actual_depth': 993.6875752265323,
#   'actual_weight': 476.0719347190232,
#   'content': 'lsHNDotHjMbX',
#   'estimated_value': 10.42},
#  (20, 2): {'request_id': 20,
#   'package_id': 2,
#   'reported_height': 434.24,
#   'reported_width': 506.67,
#   'reported_depth': 179.0,
#   'reported_weight': 104.4,
#   'actual_height': 433.8222919183567,
#   'actual_width': 506.7940645137372,
#   'actual_depth': 178.9435913570262,
#   'actual_weight': 105.59470618930438,
#   'content': 'dwfwVENGYonF',
#   'estimated_value': 23.67},
#  (20, 3): {'request_id': 20,
#   'package_id': 3,
#   'reported_height': 745.59,
#   'reported_width': 444.83,
#   'reported_depth': 664.44,
#   'reported_weight': 619.83,
#   'actual_height': 745.7236478255736,
#   'actual_width': 448.9051693035961,
#   'actual_depth': 664.0636225326109,
#   'actual_weight': 618.7164626600072,
#   'content': 'TlKIeQIYgyXV',
#   'estimated_value': 10.92},
#  (20, 4): {'request_id': 20,
#   'package_id': 4,
#   'reported_height': 309.05,
#   'reported_width': 348.37,
#   'reported_depth': 754.62,
#   'reported_weight': 541.02,
#   'actual_height': 308.1973505835972,
#   'actual_width': 350.2668544783385,
#   'actual_depth': 753.2267481904146,
#   'actual_weight': 538.8685824907764,
#   'content': 'bfkZppBHiCaF',
#   'estimated_value': 62.71},
#  (21, 1): {'request_id': 21,
#   'package_id': 1,
#   'reported_height': 963.77,
#   'reported_width': 992.16,
#   'reported_depth': 353.76,
#   'reported_weight': 410.4,
#   'actual_height': 965.0799647642332,
#   'actual_width': 996.8815241055701,
#   'actual_depth': 353.4951826538191,
#   'actual_weight': 411.7073742549412,
#   'content': 'xbVDzpLYcYht',
#   'estimated_value': 24.36},
#  (21, 2): {'request_id': 21,
#   'package_id': 2,
#   'reported_height': 786.75,
#   'reported_width': 233.06,
#   'reported_depth': 840.91,
#   'reported_weight': 483.74,
#   'actual_height': 786.7795595587997,
#   'actual_width': 233.30366271327037,
#   'actual_depth': 841.1580922844222,
#   'actual_weight': 482.65972639592866,
#   'content': 'zajofbaIhPKe',
#   'estimated_value': 52.43},
#  (21, 3): {'request_id': 21,
#   'package_id': 3,
#   'reported_height': 491.49,
#   'reported_width': 25.51,
#   'reported_depth': 901.68,
#   'reported_weight': 55.59,
#   'actual_height': 490.2183118649092,
#   'actual_width': 24.949188817384528,
#   'actual_depth': 905.3640500044093,
#   'actual_weight': 55.165365843973454,
#   'content': 'CTjTQSIVsiBu',
#   'estimated_value': 31.9},
#  (21, 4): {'request_id': 21,
#   'package_id': 4,
#   'reported_height': 262.66,
#   'reported_width': 160.2,
#   'reported_depth': 287.74,
#   'reported_weight': 697.88,
#   'actual_height': 262.26289123560076,
#   'actual_width': 160.5697297931379,
#   'actual_depth': 291.04612413542327,
#   'actual_weight': 698.6575144295265,
#   'content': 'CakcWCiDGdAp',
#   'estimated_value': 65.46},
#  (21, 5): {'request_id': 21,
#   'package_id': 5,
#   'reported_height': 595.42,
#   'reported_width': 43.67,
#   'reported_depth': 437.8,
#   'reported_weight': 526.5,
#   'actual_height': 594.1707607770028,
#   'actual_width': 40.35692156165368,
#   'actual_depth': 437.6596481480664,
#   'actual_weight': 522.4136426334605,
#   'content': 'lqSiALjJybgN',
#   'estimated_value': 49.17},
#  (22, 1): {'request_id': 22,
#   'package_id': 1,
#   'reported_height': 114.37,
#   'reported_width': 332.72,
#   'reported_depth': 223.9,
#   'reported_weight': 168.15,
#   'actual_height': 115.28667092698267,
#   'actual_width': 332.38836181675293,
#   'actual_depth': 221.49440822015217,
#   'actual_weight': 167.87784506848791,
#   'content': 'QQPCDYmVtNqS',
#   'estimated_value': 92.66},
#  (22, 2): {'request_id': 22,
#   'package_id': 2,
#   'reported_height': 679.6,
#   'reported_width': 371.74,
#   'reported_depth': 430.36,
#   'reported_weight': 568.78,
#   'actual_height': 682.1807392167025,
#   'actual_width': 370.5027263037371,
#   'actual_depth': 430.6290916743065,
#   'actual_weight': 571.9451863280292,
#   'content': 'CgJUsgUfNxEq',
#   'estimated_value': 54.28},
#  (23, 1): {'request_id': 23,
#   'package_id': 1,
#   'reported_height': 498.79,
#   'reported_width': 476.95,
#   'reported_depth': 176.46,
#   'reported_weight': 666.95,
#   'actual_height': 500.3928266754442,
#   'actual_width': 477.17889078865556,
#   'actual_depth': 177.6150020780024,
#   'actual_weight': 666.9269533146343,
#   'content': 'cvHQVEUXsfLq',
#   'estimated_value': 31.73},
#  (24, 1): {'request_id': 24,
#   'package_id': 1,
#   'reported_height': 946.71,
#   'reported_width': 892.81,
#   'reported_depth': 22.5,
#   'reported_weight': 653.84,
#   'actual_height': 949.8109589320594,
#   'actual_width': 894.7426844944179,
#   'actual_depth': 24.435526685598862,
#   'actual_weight': 654.5581172324648,
#   'content': 'KzBjIboagqVs',
#   'estimated_value': 79.12},
#  (24, 2): {'request_id': 24,
#   'package_id': 2,
#   'reported_height': 109.12,
#   'reported_width': 951.53,
#   'reported_depth': 397.05,
#   'reported_weight': 832.59,
#   'actual_height': 109.22833408996932,
#   'actual_width': 950.1301989919206,
#   'actual_depth': 398.7200647698898,
#   'actual_weight': 831.4554468637264,
#   'content': 'LAdzVBdjhVHo',
#   'estimated_value': 56.81},
#  (24, 3): {'request_id': 24,
#   'package_id': 3,
#   'reported_height': 265.65,
#   'reported_width': 355.33,
#   'reported_depth': 415.87,
#   'reported_weight': 859.66,
#   'actual_height': 263.4722420746518,
#   'actual_width': 354.8342431631473,
#   'actual_depth': 416.5026849359432,
#   'actual_weight': 860.605453301003,
#   'content': 'JHwnwNgRzdml',
#   'estimated_value': 18.85},
#  (24, 4): {'request_id': 24,
#   'package_id': 4,
#   'reported_height': 83.1,
#   'reported_width': 854.16,
#   'reported_depth': 204.35,
#   'reported_weight': 215.82,
#   'actual_height': 79.68009629271434,
#   'actual_width': 852.484432761707,
#   'actual_depth': 205.83379737069976,
#   'actual_weight': 215.6021344956202,
#   'content': 'odjXDtUVGBLE',
#   'estimated_value': 83.56},
#  (25, 1): {'request_id': 25,
#   'package_id': 1,
#   'reported_height': 173.0,
#   'reported_width': 906.66,
#   'reported_depth': 492.62,
#   'reported_weight': 636.76,
#   'actual_height': 173.16696664828862,
#   'actual_width': 904.2442237356797,
#   'actual_depth': 491.19014815420456,
#   'actual_weight': 636.5874618956442,
#   'content': 'TNKrAKTeMVzr',
#   'estimated_value': 0.09},
#  (25, 2): {'request_id': 25,
#   'package_id': 2,
#   'reported_height': 474.53,
#   'reported_width': 766.64,
#   'reported_depth': 863.73,
#   'reported_weight': 777.03,
#   'actual_height': 477.70646714291337,
#   'actual_width': 766.1159922955876,
#   'actual_depth': 866.7038910806153,
#   'actual_weight': 777.5248317408913,
#   'content': 'PqDrIBkxJiIB',
#   'estimated_value': 28.98},
#  (26, 1): {'request_id': 26,
#   'package_id': 1,
#   'reported_height': 717.65,
#   'reported_width': 107.34,
#   'reported_depth': 655.98,
#   'reported_weight': 970.87,
#   'actual_height': 717.3275806217265,
#   'actual_width': 106.98646624625462,
#   'actual_depth': 659.1181916708668,
#   'actual_weight': 967.4903358611672,
#   'content': 'KPKSBVKSfjMv',
#   'estimated_value': 20.89},
#  (26, 2): {'request_id': 26,
#   'package_id': 2,
#   'reported_height': 736.38,
#   'reported_width': 285.35,
#   'reported_depth': 66.16,
#   'reported_weight': 710.04,
#   'actual_height': 733.0555472783236,
#   'actual_width': 285.7520033255084,
#   'actual_depth': 63.424989131457686,
#   'actual_weight': 711.0632804587833,
#   'content': 'xIESfBuiGlzj',
#   'estimated_value': 44.65},
#  (26, 3): {'request_id': 26,
#   'package_id': 3,
#   'reported_height': 718.14,
#   'reported_width': 849.73,
#   'reported_depth': 261.56,
#   'reported_weight': 140.44,
#   'actual_height': 718.664562773471,
#   'actual_width': 849.8515407838821,
#   'actual_depth': 260.3240654119575,
#   'actual_weight': 140.0490935389092,
#   'content': 'wsJEhwzWaHDA',
#   'estimated_value': 73.88},
#  (26, 4): {'request_id': 26,
#   'package_id': 4,
#   'reported_height': 581.11,
#   'reported_width': 192.24,
#   'reported_depth': 41.3,
#   'reported_weight': 941.61,
#   'actual_height': 581.6223606270919,
#   'actual_width': 195.17456780003712,
#   'actual_depth': 43.01631061669515,
#   'actual_weight': 939.0270188378818,
#   'content': 'bqSmRrVjGhFg',
#   'estimated_value': 6.27},
#  (27, 1): {'request_id': 27,
#   'package_id': 1,
#   'reported_height': 472.23,
#   'reported_width': 763.83,
#   'reported_depth': 651.2,
#   'reported_weight': 1000.71,
#   'actual_height': 470.52303753048903,
#   'actual_width': 763.0928537481186,
#   'actual_depth': 651.5921739488339,
#   'actual_weight': 1004.146359780153,
#   'content': 'weakWSeBSxWC',
#   'estimated_value': 53.16},
#  (27, 2): {'request_id': 27,
#   'package_id': 2,
#   'reported_height': 302.5,
#   'reported_width': 806.17,
#   'reported_depth': 150.19,
#   'reported_weight': 861.74,
#   'actual_height': 304.2113538413181,
#   'actual_width': 809.7511640881348,
#   'actual_depth': 149.0982096271137,
#   'actual_weight': 862.0301422336623,
#   'content': 'NxlRRcrxXrwj',
#   'estimated_value': 26.95},
#  (27, 3): {'request_id': 27,
#   'package_id': 3,
#   'reported_height': 152.87,
#   'reported_width': 155.83,
#   'reported_depth': 410.14,
#   'reported_weight': 54.25,
#   'actual_height': 151.20287720197834,
#   'actual_width': 155.44448610160867,
#   'actual_depth': 412.9454947656543,
#   'actual_weight': 53.1165344392215,
#   'content': 'GGdeJKbyytiv',
#   'estimated_value': 94.08},
#  (27, 4): {'request_id': 27,
#   'package_id': 4,
#   'reported_height': 336.9,
#   'reported_width': 789.92,
#   'reported_depth': 751.7,
#   'reported_weight': 249.8,
#   'actual_height': 335.6593869044258,
#   'actual_width': 788.8430121667502,
#   'actual_depth': 754.655858196579,
#   'actual_weight': 250.2366243765197,
#   'content': 'PzYrIHUyqPGb',
#   'estimated_value': 44.64},
#  (27, 5): {'request_id': 27,
#   'package_id': 5,
#   'reported_height': 80.17,
#   'reported_width': 129.44,
#   'reported_depth': 937.98,
#   'reported_weight': 973.62,
#   'actual_height': 79.77807875958615,
#   'actual_width': 130.9185778408314,
#   'actual_depth': 937.2194569372201,
#   'actual_weight': 972.4204101079699,
#   'content': 'ZjDVHLmKdLah',
#   'estimated_value': 13.78},
#  (28, 1): {'request_id': 28,
#   'package_id': 1,
#   'reported_height': 408.88,
#   'reported_width': 742.78,
#   'reported_depth': 13.94,
#   'reported_weight': 64.13,
#   'actual_height': 407.1249552421754,
#   'actual_width': 742.4117478855471,
#   'actual_depth': 13.813745913709353,
#   'actual_weight': 62.762669502423655,
#   'content': 'AMryULjpGWxB',
#   'estimated_value': 62.75},
#  (28, 2): {'request_id': 28,
#   'package_id': 2,
#   'reported_height': 506.73,
#   'reported_width': 738.17,
#   'reported_depth': 159.08,
#   'reported_weight': 890.41,
#   'actual_height': 504.01438812098775,
#   'actual_width': 735.3729252915257,
#   'actual_depth': 157.60349303181846,
#   'actual_weight': 889.8826731371859,
#   'content': 'nnjzxwiUTLLh',
#   'estimated_value': 65.7},
#  (28, 3): {'request_id': 28,
#   'package_id': 3,
#   'reported_height': 453.43,
#   'reported_width': 667.23,
#   'reported_depth': 961.44,
#   'reported_weight': 55.17,
#   'actual_height': 454.0454465054888,
#   'actual_width': 666.0420188463253,
#   'actual_depth': 961.3214080222978,
#   'actual_weight': 53.38970166481937,
#   'content': 'acZYgyTLHDFz',
#   'estimated_value': 60.78},
#  (28, 4): {'request_id': 28,
#   'package_id': 4,
#   'reported_height': 843.34,
#   'reported_width': 391.6,
#   'reported_depth': 781.52,
#   'reported_weight': 987.62,
#   'actual_height': 842.6156647566187,
#   'actual_width': 388.2170313469254,
#   'actual_depth': 782.0537123847208,
#   'actual_weight': 985.302962100876,
#   'content': 'wWJKVqYegujM',
#   'estimated_value': 28.95},
#  (29, 1): {'request_id': 29,
#   'package_id': 1,
#   'reported_height': 175.05,
#   'reported_width': 685.54,
#   'reported_depth': 929.32,
#   'reported_weight': 562.31,
#   'actual_height': 172.9696318084228,
#   'actual_width': 683.3121686041266,
#   'actual_depth': 931.2487394843541,
#   'actual_weight': 565.435499650942,
#   'content': 'caoAYIhUfuaJ',
#   'estimated_value': 90.23},
#  (30, 1): {'request_id': 30,
#   'package_id': 1,
#   'reported_height': 416.35,
#   'reported_width': 516.06,
#   'reported_depth': 723.73,
#   'reported_weight': 930.79,
#   'actual_height': 417.05954860137484,
#   'actual_width': 518.9482264440403,
#   'actual_depth': 725.3501378804385,
#   'actual_weight': 930.4960503075368,
#   'content': 'JqMHMVllejuY',
#   'estimated_value': 54.85},
#  (30, 2): {'request_id': 30,
#   'package_id': 2,
#   'reported_height': 382.66,
#   'reported_width': 42.64,
#   'reported_depth': 594.03,
#   'reported_weight': 229.78,
#   'actual_height': 381.08657613393063,
#   'actual_width': 42.009970191999386,
#   'actual_depth': 592.6652825082421,
#   'actual_weight': 231.56449680813145,
#   'content': 'mOnUFrlvFgIH',
#   'estimated_value': 85.64},
#  (30, 3): {'request_id': 30,
#   'package_id': 3,
#   'reported_height': 253.68,
#   'reported_width': 513.94,
#   'reported_depth': 635.2,
#   'reported_weight': 208.21,
#   'actual_height': 255.8308779673001,
#   'actual_width': 512.9328719446294,
#   'actual_depth': 637.1791500486397,
#   'actual_weight': 211.24852218230757,
#   'content': 'KDzaPGCPORrL',
#   'estimated_value': 71.0},
#  (31, 1): {'request_id': 31,
#   'package_id': 1,
#   'reported_height': 437.04,
#   'reported_width': 648.05,
#   'reported_depth': 875.76,
#   'reported_weight': 630.49,
#   'actual_height': 433.32332661402046,
#   'actual_width': 649.5544095636878,
#   'actual_depth': 875.5346077700365,
#   'actual_weight': 632.231951626387,
#   'content': 'opPQFGWHViWK',
#   'estimated_value': 63.27},
#  (31, 2): {'request_id': 31,
#   'package_id': 2,
#   'reported_height': 626.39,
#   'reported_width': 623.31,
#   'reported_depth': 368.21,
#   'reported_weight': 836.24,
#   'actual_height': 630.3530173942548,
#   'actual_width': 621.3433856165786,
#   'actual_depth': 369.8019044838812,
#   'actual_weight': 833.4436032815065,
#   'content': 'rvvObQtxhMhV',
#   'estimated_value': 74.84},
#  (31, 3): {'request_id': 31,
#   'package_id': 3,
#   'reported_height': 893.78,
#   'reported_width': 36.13,
#   'reported_depth': 591.51,
#   'reported_weight': 748.11,
#   'actual_height': 896.4118751373153,
#   'actual_width': 37.331183307415714,
#   'actual_depth': 590.954367961241,
#   'actual_weight': 745.2466990534582,
#   'content': 'nrDNsXoKyQSJ',
#   'estimated_value': 11.85},
#  (32, 1): {'request_id': 32,
#   'package_id': 1,
#   'reported_height': 644.06,
#   'reported_width': 254.72,
#   'reported_depth': 594.57,
#   'reported_weight': 273.18,
#   'actual_height': 641.5023999358089,
#   'actual_width': 251.9957863190086,
#   'actual_depth': 597.6433147396505,
#   'actual_weight': 273.42002220405357,
#   'content': 'FMXMtkJONaeo',
#   'estimated_value': 3.18},
#  (32, 2): {'request_id': 32,
#   'package_id': 2,
#   'reported_height': 701.09,
#   'reported_width': 752.76,
#   'reported_depth': 613.83,
#   'reported_weight': 925.93,
#   'actual_height': 701.6016619663518,
#   'actual_width': 751.4792174122532,
#   'actual_depth': 615.5598655921808,
#   'actual_weight': 925.001450170611,
#   'content': 'VJKvpPnqVSyp',
#   'estimated_value': 32.44},
#  (32, 3): {'request_id': 32,
#   'package_id': 3,
#   'reported_height': 104.08,
#   'reported_width': 173.05,
#   'reported_depth': 447.69,
#   'reported_weight': 367.02,
#   'actual_height': 101.97824550436242,
#   'actual_width': 169.71080776415985,
#   'actual_depth': 447.4374642046992,
#   'actual_weight': 371.45084380558916,
#   'content': 'OlZjnZXKcvfe',
#   'estimated_value': 86.73},
#  (33, 1): {'request_id': 33,
#   'package_id': 1,
#   'reported_height': 971.76,
#   'reported_width': 623.85,
#   'reported_depth': 176.49,
#   'reported_weight': 452.04,
#   'actual_height': 968.6835022209264,
#   'actual_width': 623.4422942141153,
#   'actual_depth': 174.81533574815214,
#   'actual_weight': 449.5014516956078,
#   'content': 'JwUefQxwdhGx',
#   'estimated_value': 36.0},
#  (33, 2): {'request_id': 33,
#   'package_id': 2,
#   'reported_height': 92.94,
#   'reported_width': 997.49,
#   'reported_depth': 34.5,
#   'reported_weight': 160.5,
#   'actual_height': 88.128672820702,
#   'actual_width': 994.5266339377741,
#   'actual_depth': 37.51384376352691,
#   'actual_weight': 163.01689855863088,
#   'content': 'jPhIOQwwfSRC',
#   'estimated_value': 30.23},
#  (33, 3): {'request_id': 33,
#   'package_id': 3,
#   'reported_height': 387.71,
#   'reported_width': 351.4,
#   'reported_depth': 614.6,
#   'reported_weight': 446.48,
#   'actual_height': 389.1601924039167,
#   'actual_width': 347.1903240416927,
#   'actual_depth': 612.3719248205873,
#   'actual_weight': 446.92728446367346,
#   'content': 'JvhwfyClwFfu',
#   'estimated_value': 15.09},
#  (33, 4): {'request_id': 33,
#   'package_id': 4,
#   'reported_height': 351.24,
#   'reported_width': 911.34,
#   'reported_depth': 71.39,
#   'reported_weight': 237.77,
#   'actual_height': 352.46492839714176,
#   'actual_width': 909.1715480552191,
#   'actual_depth': 70.19602416658476,
#   'actual_weight': 234.7277051642483,
#   'content': 'ZCEejPOrmQkB',
#   'estimated_value': 43.12},
#  (33, 5): {'request_id': 33,
#   'package_id': 5,
#   'reported_height': 15.7,
#   'reported_width': 617.24,
#   'reported_depth': 564.06,
#   'reported_weight': 746.65,
#   'actual_height': 11.617307580253325,
#   'actual_width': 617.3702332665974,
#   'actual_depth': 563.4476079677087,
#   'actual_weight': 747.2224450141562,
#   'content': 'LDJRNMYqXYrq',
#   'estimated_value': 11.29},
#  (34, 1): {'request_id': 34,
#   'package_id': 1,
#   'reported_height': 960.49,
#   'reported_width': 17.23,
#   'reported_depth': 966.91,
#   'reported_weight': 382.69,
#   'actual_height': 956.4313834534462,
#   'actual_width': 19.24774324840264,
#   'actual_depth': 964.9930388451115,
#   'actual_weight': 381.2792415985048,
#   'content': 'KbzsHFYPSXrb',
#   'estimated_value': 83.34},
#  (34, 2): {'request_id': 34,
#   'package_id': 2,
#   'reported_height': 220.28,
#   'reported_width': 683.38,
#   'reported_depth': 690.61,
#   'reported_weight': 231.54,
#   'actual_height': 221.65404303751384,
#   'actual_width': 681.7112132600088,
#   'actual_depth': 688.9632941913518,
#   'actual_weight': 229.7301351053552,
#   'content': 'bqTZQEXvgtqq',
#   'estimated_value': 45.75},
#  (34, 3): {'request_id': 34,
#   'package_id': 3,
#   'reported_height': 237.2,
#   'reported_width': 671.63,
#   'reported_depth': 520.04,
#   'reported_weight': 32.85,
#   'actual_height': 235.69500492068047,
#   'actual_width': 670.1500845780057,
#   'actual_depth': 520.6125974116915,
#   'actual_weight': 32.666138898163496,
#   'content': 'rAOutFugnXxR',
#   'estimated_value': 53.6},
#  (35, 1): {'request_id': 35,
#   'package_id': 1,
#   'reported_height': 728.62,
#   'reported_width': 961.24,
#   'reported_depth': 198.59,
#   'reported_weight': 759.02,
#   'actual_height': 728.2218131878043,
#   'actual_width': 959.4360684142308,
#   'actual_depth': 199.26168743343482,
#   'actual_weight': 759.7347021390727,
#   'content': 'wOOQqvOnMJrL',
#   'estimated_value': 72.16},
#  (36, 1): {'request_id': 36,
#   'package_id': 1,
#   'reported_height': 37.16,
#   'reported_width': 783.49,
#   'reported_depth': 410.4,
#   'reported_weight': 843.22,
#   'actual_height': 37.872541867550524,
#   'actual_width': 782.2739890597574,
#   'actual_depth': 412.44589983034825,
#   'actual_weight': 843.6119784228246,
#   'content': 'PtDaUMaQaJXt',
#   'estimated_value': 59.32},
#  (36, 2): {'request_id': 36,
#   'package_id': 2,
#   'reported_height': 223.19,
#   'reported_width': 914.36,
#   'reported_depth': 108.08,
#   'reported_weight': 455.66,
#   'actual_height': 224.25526071736368,
#   'actual_width': 913.8671084344213,
#   'actual_depth': 107.83133180962989,
#   'actual_weight': 456.97728831659316,
#   'content': 'poLSREgBnezV',
#   'estimated_value': 62.27},
#  (36, 3): {'request_id': 36,
#   'package_id': 3,
#   'reported_height': 924.53,
#   'reported_width': 644.65,
#   'reported_depth': 891.15,
#   'reported_weight': 21.3,
#   'actual_height': 923.7139315171391,
#   'actual_width': 644.3686416037348,
#   'actual_depth': 888.804629280064,
#   'actual_weight': 18.520830565632732,
#   'content': 'mahOHhaPqVKY',
#   'estimated_value': 58.88},
#  (36, 4): {'request_id': 36,
#   'package_id': 4,
#   'reported_height': 126.18,
#   'reported_width': 805.32,
#   'reported_depth': 746.86,
#   'reported_weight': 69.49,
#   'actual_height': 129.06704142558453,
#   'actual_width': 803.9427423382632,
#   'actual_depth': 746.3308606403397,
#   'actual_weight': 69.53099868079444,
#   'content': 'ZgxILHYRAuoe',
#   'estimated_value': 1.61},
#  (36, 5): {'request_id': 36,
#   'package_id': 5,
#   'reported_height': 793.21,
#   'reported_width': 277.82,
#   'reported_depth': 262.57,
#   'reported_weight': 314.04,
#   'actual_height': 796.1963706459027,
#   'actual_width': 278.04647127483867,
#   'actual_depth': 266.7627966088945,
#   'actual_weight': 315.7468659088738,
#   'content': 'VmPVcoMZtgUf',
#   'estimated_value': 12.17},
#  (37, 1): {'request_id': 37,
#   'package_id': 1,
#   'reported_height': 315.29,
#   'reported_width': 40.87,
#   'reported_depth': 780.29,
#   'reported_weight': 770.58,
#   'actual_height': 317.2123486119991,
#   'actual_width': 43.7442711507792,
#   'actual_depth': 780.0798569738909,
#   'actual_weight': 771.4138648142377,
#   'content': 'bkbMPsTkywJg',
#   'estimated_value': 71.57},
#  (37, 2): {'request_id': 37,
#   'package_id': 2,
#   'reported_height': 280.06,
#   'reported_width': 4.46,
#   'reported_depth': 677.52,
#   'reported_weight': 763.12,
#   'actual_height': 279.9941516452861,
#   'actual_width': 4.216126215209255,
#   'actual_depth': 679.3160618301952,
#   'actual_weight': 764.6762314489736,
#   'content': 'DDUxPpyNXqwG',
#   'estimated_value': 30.83},
#  (37, 3): {'request_id': 37,
#   'package_id': 3,
#   'reported_height': 825.53,
#   'reported_width': 147.12,
#   'reported_depth': 792.02,
#   'reported_weight': 3.33,
#   'actual_height': 828.2971158407389,
#   'actual_width': 150.78742287326347,
#   'actual_depth': 791.257289037965,
#   'actual_weight': 6.067009211743468,
#   'content': 'hCInLwhNMaXQ',
#   'estimated_value': 66.33},
#  (38, 1): {'request_id': 38,
#   'package_id': 1,
#   'reported_height': 913.63,
#   'reported_width': 841.13,
#   'reported_depth': 764.67,
#   'reported_weight': 163.05,
#   'actual_height': 913.0730689494017,
#   'actual_width': 840.9232165943107,
#   'actual_depth': 766.4058808359158,
#   'actual_weight': 162.5902820702036,
#   'content': 'QPrydRAJdJlX',
#   'estimated_value': 0.95},
# ...
#  (309, 2): {'request_id': 309,
#   'package_id': 2,
#   'reported_height': 846.17,
#   'reported_width': 342.74,
#   'reported_depth': 62.48,
#   'reported_weight': 364.79,
#   'actual_height': 848.8488884729384,
#   'actual_width': 342.01278162525466,
#   'actual_depth': 58.317626818474615,
#   'actual_weight': 365.3786327717429,
#   'content': 'fSZMKNPJAxQy',
#   'estimated_value': 3.06},
#  (309, 3): {'request_id': 309,
#   'package_id': 3,
#   'reported_height': 289.96,
#   'reported_width': 586.24,
#   'reported_depth': 790.32,
#   'reported_weight': 905.56,
#   'actual_height': 286.0830350812132,
#   'actual_width': 584.9726730618776,
#   'actual_depth': 791.9982871584928,
#   'actual_weight': 906.5478004872925,
#   'content': 'pWaEziIVCVMe',
#   'estimated_value': 86.59},
#  (310, 1): {'request_id': 310,
#   'package_id': 1,
#   'reported_height': 376.16,
#   'reported_width': 389.42,
#   'reported_depth': 967.36,
#   'reported_weight': 289.12,
#   'actual_height': 371.3890406587833,
#   'actual_width': 387.39945658891946,
#   'actual_depth': 966.9401729487995,
#   'actual_weight': 289.49560285327175,
#   'content': 'sDChaZhRvBjS',
#   'estimated_value': 2.08},
#  (310, 2): {'request_id': 310,
#   'package_id': 2,
#   'reported_height': 824.53,
#   'reported_width': 869.5,
#   'reported_depth': 332.74,
#   'reported_weight': 387.95,
#   'actual_height': 824.9989033833658,
#   'actual_width': 872.0781724070234,
#   'actual_depth': 332.1765155190276,
#   'actual_weight': 387.90546166314664,
#   'content': 'VacWOuNLJTgg',
#   'estimated_value': 72.07},
#  (310, 3): {'request_id': 310,
#   'package_id': 3,
#   'reported_height': 911.17,
#   'reported_width': 124.21,
#   'reported_depth': 372.98,
#   'reported_weight': 897.98,
#   'actual_height': 914.8938836255649,
#   'actual_width': 126.65190505978173,
#   'actual_depth': 370.5897680088731,
#   'actual_weight': 896.9232624711245,
#   'content': 'JKbYyGMTpMvV',
#   'estimated_value': 32.82},
#  (310, 4): {'request_id': 310,
#   'package_id': 4,
#   'reported_height': 999.42,
#   'reported_width': 519.91,
#   'reported_depth': 90.8,
#   'reported_weight': 323.77,
#   'actual_height': 999.4418018073534,
#   'actual_width': 520.1838361178699,
#   'actual_depth': 89.90826961456676,
#   'actual_weight': 320.66649398188633,
#   'content': 'xQzEwupqNNPH',
#   'estimated_value': 88.61},
#  (310, 5): {'request_id': 310,
#   'package_id': 5,
#   'reported_height': 450.98,
#   'reported_width': 309.34,
#   'reported_depth': 112.83,
#   'reported_weight': 472.62,
#   'actual_height': 447.57566683970896,
#   'actual_width': 313.103163950684,
#   'actual_depth': 114.91446504978315,
#   'actual_weight': 476.0855046223454,
#   'content': 'NAxWQyEGBhPR',
#   'estimated_value': 11.03},
#  (311, 1): {'request_id': 311,
#   'package_id': 1,
#   'reported_height': 549.23,
#   'reported_width': 895.56,
#   'reported_depth': 59.84,
#   'reported_weight': 749.81,
#   'actual_height': 549.3817692349616,
#   'actual_width': 894.561504096353,
#   'actual_depth': 60.572551577421066,
#   'actual_weight': 746.8770228664351,
#   'content': 'lctSZQkrsbMp',
#   'estimated_value': 48.1},
#  (312, 1): {'request_id': 312,
#   'package_id': 1,
#   'reported_height': 363.37,
#   'reported_width': 284.31,
#   'reported_depth': 924.99,
#   'reported_weight': 101.39,
#   'actual_height': 363.4434113866026,
#   'actual_width': 282.73678727772267,
#   'actual_depth': 923.0540622617104,
#   'actual_weight': 97.76843255440438,
#   'content': 'YUjLhnumpUwz',
#   'estimated_value': 17.34},
#  (313, 1): {'request_id': 313,
#   'package_id': 1,
#   'reported_height': 66.95,
#   'reported_width': 159.24,
#   'reported_depth': 352.58,
#   'reported_weight': 753.32,
#   'actual_height': 67.40476557674839,
#   'actual_width': 158.29005375503624,
#   'actual_depth': 349.59286899806676,
#   'actual_weight': 750.1942012134294,
#   'content': 'UokLWrZPYxAY',
#   'estimated_value': 75.76},
#  (314, 1): {'request_id': 314,
#   'package_id': 1,
#   'reported_height': 133.08,
#   'reported_width': 987.88,
#   'reported_depth': 959.95,
#   'reported_weight': 230.77,
#   'actual_height': 132.29943231829213,
#   'actual_width': 984.6070668203258,
#   'actual_depth': 958.0027100875085,
#   'actual_weight': 234.13820345927027,
#   'content': 'HOkhkKufmmpn',
#   'estimated_value': 47.26},
#  (314, 2): {'request_id': 314,
#   'package_id': 2,
#   'reported_height': 539.35,
#   'reported_width': 639.02,
#   'reported_depth': 912.97,
#   'reported_weight': 18.68,
#   'actual_height': 541.3222544697422,
#   'actual_width': 638.1885322083884,
#   'actual_depth': 915.0916454880296,
#   'actual_weight': 18.839434085740503,
#   'content': 'YpDvSvwEwQhc',
#   'estimated_value': 55.01},
#  (314, 3): {'request_id': 314,
#   'package_id': 3,
#   'reported_height': 432.44,
#   'reported_width': 682.67,
#   'reported_depth': 362.08,
#   'reported_weight': 879.54,
#   'actual_height': 431.564580888139,
#   'actual_width': 679.9533783264097,
#   'actual_depth': 362.7916960666068,
#   'actual_weight': 882.1811408311667,
#   'content': 'SoXrUMMsnUMo',
#   'estimated_value': 7.84},
#  (315, 1): {'request_id': 315,
#   'package_id': 1,
#   'reported_height': 664.26,
#   'reported_width': 390.45,
#   'reported_depth': 159.46,
#   'reported_weight': 568.8,
#   'actual_height': 664.1209547457328,
#   'actual_width': 390.6349898772386,
#   'actual_depth': 161.90659259279755,
#   'actual_weight': 570.8344275798851,
#   'content': 'InkEPsnsghVu',
#   'estimated_value': 28.84},
#  (316, 1): {'request_id': 316,
#   'package_id': 1,
#   'reported_height': 472.28,
#   'reported_width': 904.21,
#   'reported_depth': 833.05,
#   'reported_weight': 375.27,
#   'actual_height': 475.6769462638246,
#   'actual_width': 900.7854207697053,
#   'actual_depth': 834.8328930222559,
#   'actual_weight': 374.6103174215206,
#   'content': 'tSfcWsYCTFeO',
#   'estimated_value': 67.84},
#  (316, 2): {'request_id': 316,
#   'package_id': 2,
#   'reported_height': 612.86,
#   'reported_width': 454.38,
#   'reported_depth': 323.86,
#   'reported_weight': 250.79,
#   'actual_height': 612.0693613497266,
#   'actual_width': 450.62222859406506,
#   'actual_depth': 323.32056104386334,
#   'actual_weight': 249.82212387798853,
#   'content': 'LhehAKcLCSqd',
#   'estimated_value': 71.33},
#  (316, 3): {'request_id': 316,
#   'package_id': 3,
#   'reported_height': 118.65,
#   'reported_width': 45.87,
#   'reported_depth': 437.93,
#   'reported_weight': 61.78,
#   'actual_height': 119.39115959351423,
#   'actual_width': 43.70755824161134,
#   'actual_depth': 437.9387242985622,
#   'actual_weight': 61.63412898529973,
#   'content': 'MNlLPZXTtEXy',
#   'estimated_value': 60.15},
#  (316, 4): {'request_id': 316,
#   'package_id': 4,
#   'reported_height': 552.19,
#   'reported_width': 58.98,
#   'reported_depth': 891.84,
#   'reported_weight': 229.95,
#   'actual_height': 550.9916835701557,
#   'actual_width': 62.62702999883595,
#   'actual_depth': 891.5062879489506,
#   'actual_weight': 231.89305304569228,
#   'content': 'KKBRisygbGmy',
#   'estimated_value': 61.09},
#  (317, 1): {'request_id': 317,
#   'package_id': 1,
#   'reported_height': 913.05,
#   'reported_width': 743.11,
#   'reported_depth': 543.69,
#   'reported_weight': 218.47,
#   'actual_height': 912.3319537761688,
#   'actual_width': 744.0667375715738,
#   'actual_depth': 546.3319634997907,
#   'actual_weight': 216.5523998014151,
#   'content': 'ORAeAVxvPxkY',
#   'estimated_value': 74.1},
#  (317, 2): {'request_id': 317,
#   'package_id': 2,
#   'reported_height': 954.56,
#   'reported_width': 764.66,
#   'reported_depth': 36.26,
#   'reported_weight': 746.49,
#   'actual_height': 955.2489192186157,
#   'actual_width': 766.5933612449114,
#   'actual_depth': 37.76060840306019,
#   'actual_weight': 744.056175748154,
#   'content': 'PZcmLZMvPXpw',
#   'estimated_value': 3.61},
#  (318, 1): {'request_id': 318,
#   'package_id': 1,
#   'reported_height': 427.34,
#   'reported_width': 642.51,
#   'reported_depth': 150.48,
#   'reported_weight': 826.92,
#   'actual_height': 430.21998606914667,
#   'actual_width': 641.0223446794114,
#   'actual_depth': 149.32298184939748,
#   'actual_weight': 824.4241668990311,
#   'content': 'LpDfyCJZNRoS',
#   'estimated_value': 32.71},
#  (318, 2): {'request_id': 318,
#   'package_id': 2,
#   'reported_height': 286.88,
#   'reported_width': 9.25,
#   'reported_depth': 2.44,
#   'reported_weight': 950.62,
#   'actual_height': 286.6977148824237,
#   'actual_width': 8.465998501048922,
#   'actual_depth': 2.8663175442215585,
#   'actual_weight': 947.1811775226703,
#   'content': 'oSqAdLlatPsv',
#   'estimated_value': 86.66},
#  (318, 3): {'request_id': 318,
#   'package_id': 3,
#   'reported_height': 4.71,
#   'reported_width': 157.1,
#   'reported_depth': 562.91,
#   'reported_weight': 71.42,
#   'actual_height': 5.675283502751235,
#   'actual_width': 154.71980411950892,
#   'actual_depth': 563.1457064166392,
#   'actual_weight': 68.94340763244756,
#   'content': 'NmYdsEsgSHoZ',
#   'estimated_value': 71.51},
#  (319, 1): {'request_id': 319,
#   'package_id': 1,
#   'reported_height': 768.35,
#   'reported_width': 805.89,
#   'reported_depth': 499.44,
#   'reported_weight': 943.75,
#   'actual_height': 768.0486990777254,
#   'actual_width': 804.1251394510125,
#   'actual_depth': 495.7454620630439,
#   'actual_weight': 943.1713413669685,
#   'content': 'YOfSRglHkwAD',
#   'estimated_value': 14.82},
#  (319, 2): {'request_id': 319,
#   'package_id': 2,
#   'reported_height': 579.77,
#   'reported_width': 788.72,
#   'reported_depth': 427.24,
#   'reported_weight': 72.94,
#   'actual_height': 580.6857957090504,
#   'actual_width': 791.1979533746264,
#   'actual_depth': 423.80659018302686,
#   'actual_weight': 69.89653454974243,
#   'content': 'NCRCLApsjJhX',
#   'estimated_value': 91.75},
#  (319, 3): {'request_id': 319,
#   'package_id': 3,
#   'reported_height': 297.78,
#   'reported_width': 71.53,
#   'reported_depth': 136.68,
#   'reported_weight': 992.75,
#   'actual_height': 297.87635692489397,
#   'actual_width': 71.6146049389259,
#   'actual_depth': 137.92274752227564,
#   'actual_weight': 990.9500087345782,
#   'content': 'rxjHnzKipGPa',
#   'estimated_value': 50.69},
#  (319, 4): {'request_id': 319,
#   'package_id': 4,
#   'reported_height': 83.9,
#   'reported_width': 687.8,
#   'reported_depth': 616.68,
#   'reported_weight': 371.44,
#   'actual_height': 84.6146881016468,
#   'actual_width': 687.2712263025659,
#   'actual_depth': 614.2931901678055,
#   'actual_weight': 372.82514862972465,
#   'content': 'PHkQUiEfISyQ',
#   'estimated_value': 81.48},
#  (319, 5): {'request_id': 319,
#   'package_id': 5,
#   'reported_height': 924.83,
#   'reported_width': 803.01,
#   'reported_depth': 244.27,
#   'reported_weight': 642.41,
#   'actual_height': 923.9291133982498,
#   'actual_width': 801.5247282600571,
#   'actual_depth': 245.53702048049004,
#   'actual_weight': 640.8948516988143,
#   'content': 'WeTJsgspvHHs',
#   'estimated_value': 6.39},
#  (320, 1): {'request_id': 320,
#   'package_id': 1,
#   'reported_height': 886.15,
#   'reported_width': 236.34,
#   'reported_depth': 418.27,
#   'reported_weight': 131.73,
#   'actual_height': 886.9830607819495,
#   'actual_width': 236.78467882151082,
#   'actual_depth': 419.72789213256306,
#   'actual_weight': 129.93881759657103,
#   'content': 'OHXtPOWVVLfq',
#   'estimated_value': 20.62},
#  (320, 2): {'request_id': 320,
#   'package_id': 2,
#   'reported_height': 713.37,
#   'reported_width': 116.88,
#   'reported_depth': 545.64,
#   'reported_weight': 629.15,
#   'actual_height': 715.354107401659,
#   'actual_width': 116.66378303656397,
#   'actual_depth': 546.6540098364308,
#   'actual_weight': 631.4326994662568,
#   'content': 'PQmHSYtmpNxV',
#   'estimated_value': 58.86},
#  (320, 3): {'request_id': 320,
#   'package_id': 3,
#   'reported_height': 418.83,
#   'reported_width': 355.45,
#   'reported_depth': 889.61,
#   'reported_weight': 29.96,
#   'actual_height': 418.2086784341756,
#   'actual_width': 354.92045646004675,
#   'actual_depth': 888.6774905097378,
#   'actual_weight': 27.651778458453997,
#   'content': 'niZAEiRPXjKv',
#   'estimated_value': 37.67},
#  (320, 4): {'request_id': 320,
#   'package_id': 4,
#   'reported_height': 163.13,
#   'reported_width': 169.68,
#   'reported_depth': 857.85,
#   'reported_weight': 403.83,
#   'actual_height': 161.9379659918122,
#   'actual_width': 169.6906716601417,
#   'actual_depth': 861.0116618095001,
#   'actual_weight': 403.30364588622496,
#   'content': 'QNBixZlifjFD',
#   'estimated_value': 38.3},
#  (321, 1): {'request_id': 321,
#   'package_id': 1,
#   'reported_height': 936.7,
#   'reported_width': 920.52,
#   'reported_depth': 183.31,
#   'reported_weight': 155.29,
#   'actual_height': 935.9575781744267,
#   'actual_width': 920.9022956482119,
#   'actual_depth': 184.65774031226786,
#   'actual_weight': 155.48015129672885,
#   'content': 'IgcKOvnzwZTX',
#   'estimated_value': 93.27},
#  (322, 1): {'request_id': 322,
#   'package_id': 1,
#   'reported_height': 462.97,
#   'reported_width': 565.07,
#   'reported_depth': 340.79,
#   'reported_weight': 295.63,
#   'actual_height': 461.8253689748696,
#   'actual_width': 564.2935405319375,
#   'actual_depth': 339.3892328525173,
#   'actual_weight': 293.49490849858535,
#   'content': 'sDJmVtkELcvl',
#   'estimated_value': 61.59},
#  (322, 2): {'request_id': 322,
#   'package_id': 2,
#   'reported_height': 343.52,
#   'reported_width': 725.99,
#   'reported_depth': 840.13,
#   'reported_weight': 808.41,
#   'actual_height': 344.11204498152057,
#   'actual_width': 722.1033333253259,
#   'actual_depth': 841.3122008437068,
#   'actual_weight': 808.0182759953042,
#   'content': 'PxWjcVNUKgrv',
#   'estimated_value': 38.25},
#  (322, 3): {'request_id': 322,
#   'package_id': 3,
#   'reported_height': 562.23,
#   'reported_width': 54.78,
#   'reported_depth': 862.58,
#   'reported_weight': 517.68,
#   'actual_height': 564.476906488397,
#   'actual_width': 54.32414709044313,
#   'actual_depth': 865.4012927183696,
#   'actual_weight': 518.891495408552,
#   'content': 'LNGfbQyEbiBg',
#   'estimated_value': 4.55},
#  (323, 1): {'request_id': 323,
#   'package_id': 1,
#   'reported_height': 220.74,
#   'reported_width': 442.48,
#   'reported_depth': 492.25,
#   'reported_weight': 228.91,
#   'actual_height': 221.0966186451742,
#   'actual_width': 442.1691601908571,
#   'actual_depth': 493.1316242671632,
#   'actual_weight': 231.58030285118835,
#   'content': 'dwmJXpBcFBYT',
#   'estimated_value': 1.02},
#  (323, 2): {'request_id': 323,
#   'package_id': 2,
#   'reported_height': 933.21,
#   'reported_width': 706.14,
#   'reported_depth': 906.45,
#   'reported_weight': 476.18,
#   'actual_height': 930.701484132949,
#   'actual_width': 709.5428250142796,
#   'actual_depth': 909.2899722080647,
#   'actual_weight': 474.62040377723054,
#   'content': 'sHTWhrLEJtEa',
#   'estimated_value': 77.08},
#  (323, 3): {'request_id': 323,
#   'package_id': 3,
#   'reported_height': 936.14,
#   'reported_width': 531.75,
#   'reported_depth': 126.87,
#   'reported_weight': 110.27,
#   'actual_height': 940.324303213045,
#   'actual_width': 532.2365332940547,
#   'actual_depth': 124.43892893993652,
#   'actual_weight': 109.41842836953062,
#   'content': 'kZGEOTAnAspi',
#   'estimated_value': 97.51},
#  (323, 4): {'request_id': 323,
#   'package_id': 4,
#   'reported_height': 329.5,
#   'reported_width': 747.46,
#   'reported_depth': 394.37,
#   'reported_weight': 22.23,
#   'actual_height': 327.5514996582402,
#   'actual_width': 748.917141041691,
#   'actual_depth': 395.14914471836033,
#   'actual_weight': 20.87162855871946,
#   'content': 'PoJCvcKluUUJ',
#   'estimated_value': 23.22},
#  (324, 1): {'request_id': 324,
#   'package_id': 1,
#   'reported_height': 163.23,
#   'reported_width': 64.15,
#   'reported_depth': 147.32,
#   'reported_weight': 965.58,
#   'actual_height': 161.48071138429796,
#   'actual_width': 65.32138590858139,
#   'actual_depth': 147.16914782898237,
#   'actual_weight': 968.9754740234144,
#   'content': 'rckAoVMAAacO',
#   'estimated_value': 27.88},
#  (324, 2): {'request_id': 324,
#   'package_id': 2,
#   'reported_height': 396.39,
#   'reported_width': 529.66,
#   'reported_depth': 566.66,
#   'reported_weight': 862.4,
#   'actual_height': 399.75754028622134,
#   'actual_width': 527.2438069352853,
#   'actual_depth': 566.2019283166494,
#   'actual_weight': 862.2288466189815,
#   'content': 'xZBzgqbPQTbd',
#   'estimated_value': 0.03},
#  (324, 3): {'request_id': 324,
#   'package_id': 3,
#   'reported_height': 20.64,
#   'reported_width': 365.92,
#   'reported_depth': 684.78,
#   'reported_weight': 838.35,
#   'actual_height': 21.64768121905199,
#   'actual_width': 365.34523431191894,
#   'actual_depth': 685.6585428820864,
#   'actual_weight': 841.3389795922168,
#   'content': 'viUJzSJfuRsI',
#   'estimated_value': 64.02},
#  ...}

# %%
facilities = {}

for i in range(NUM_FACILITIES):
    this_id = i + 1
    to_add = {}
    to_add['address'] = get_random_string(32)
    to_add['postal'] = get_random_string(6)
    facilities[this_id] = to_add
    
facilities
# Out:
# {1: {'address': 'kMBGFTDaLvooyELMRRvDnTloMPcfgwHM', 'postal': 'gOjERW'},
#  2: {'address': 'neNWhWUNpwPFkBTHNjlmDNxWsAbXHROb', 'postal': 'qUBypy'},
#  3: {'address': 'lzdiSkSjrzVaDqLoQWDaxhusMnSIkhyf', 'postal': 'RCpfnW'},
#  4: {'address': 'wFIrZZKAZwXykKEyNhWGSmdfrorJzJWM', 'postal': 'HOhrOM'},
#  5: {'address': 'WlWkdowyfBlRHwjAJAQxAIrRNvZBQklE', 'postal': 'wGCStp'},
#  6: {'address': 'dYwvpBVrZDjOgSAxefctTAgQiByIFXMq', 'postal': 'amQUxX'},
#  7: {'address': 'HMHUnNzoAtdFiEkVCKtlGYsgbvRuNsHq', 'postal': 'WRelmY'},
#  8: {'address': 'BCijicLIEjrBXafTwiaarMjcxtBIQcML', 'postal': 'VLkYLQ'},
#  9: {'address': 'QTBJSmBAJoKnuYGRIJxoBVkwZYClXLtH', 'postal': 'cSrWxe'},
#  10: {'address': 'jGhnkVxZTcxscQASuwFghXZSwHjgTknh', 'postal': 'TwRwIZ'}}

# %%
failed_pickups = {}
req_to_failed_pickup = {}
for accepted_id in accepted_req_id:
    if (random.choice([True,False])):
        cur_time = delivery_requests[accepted_id]['submission_time']
        last_pickup_id = 1
        for pickup_id in range(1, get_random_int_to(2, 4)):
            to_add = {}
            to_add["reason"] =  get_random_string(32)
            to_add['request_id'] = accepted_id
            to_add['handler_id'] = random.choice(list(delivery_staff_id))
            to_add['pickup_id'] = pickup_id
            this_id = (to_add['request_id'], to_add['pickup_id'])
            # Double check if this needs to be strictly after any other time
            cur_time += timedelta(hours=get_random_int_to(1,12))
            to_add["pickup_time"] = cur_time

            failed_pickups[this_id] = to_add
            last_pickup_id = pickup_id
        
        req_to_failed_pickup[accepted_id] = last_pickup_id
        
failed_pickups
# Out:
# {(15, 1): {'reason': 'snUDKoAWtEeKxsBjASaHxzjdetKSYSuG',
#   'request_id': 15,
#   'handler_id': 7,
#   'pickup_id': 1,
#   'pickup_time': datetime.datetime(1970, 9, 12, 11, 3, 3)},
#  (27, 1): {'reason': 'YmNXILvRkRgxRSxolmdPBDMwjvSJTtGO',
#   'request_id': 27,
#   'handler_id': 6,
#   'pickup_id': 1,
#   'pickup_time': datetime.datetime(1982, 2, 13, 21, 14, 29)},
#  (27, 2): {'reason': 'bgUPtsmxzwCabYZYnnASQQscxfwrAOsp',
#   'request_id': 27,
#   'handler_id': 8,
#   'pickup_id': 2,
#   'pickup_time': datetime.datetime(1982, 2, 14, 1, 14, 29)},
#  (30, 1): {'reason': 'NKEdwOFdBgdsWnMhocFtpseCRFKfowbp',
#   'request_id': 30,
#   'handler_id': 1,
#   'pickup_id': 1,
#   'pickup_time': datetime.datetime(1977, 3, 9, 19, 5, 33)},
#  (31, 1): {'reason': 'bMYNSERXilgzdNyCVRsJveknrFOLhSiV',
#   'request_id': 31,
#   'handler_id': 7,
#   'pickup_id': 1,
#   'pickup_time': datetime.datetime(2016, 3, 31, 11, 22, 33)},
#  (31, 2): {'reason': 'RNuMiLGXfzdnybRPESRVZTScXNlTXGmg',
#   'request_id': 31,
#   'handler_id': 5,
#   'pickup_id': 2,
#   'pickup_time': datetime.datetime(2016, 3, 31, 23, 22, 33)},
#  (31, 3): {'reason': 'gGcEPEIpdiviGSjscgfZUXytBcSFfKJm',
#   'request_id': 31,
#   'handler_id': 4,
#   'pickup_id': 3,
#   'pickup_time': datetime.datetime(2016, 4, 1, 9, 22, 33)},
#  (35, 1): {'reason': 'YrJwyUOSMEXSjdEGoPERqHxiwnuozpuL',
#   'request_id': 35,
#   'handler_id': 6,
#   'pickup_id': 1,
#   'pickup_time': datetime.datetime(2003, 4, 29, 20, 47, 21)},
#  (36, 1): {'reason': 'wfmZwQsaeadakAUvXnxMRSURfIDCeoLz',
#   'request_id': 36,
#   'handler_id': 1,
#   'pickup_id': 1,
#   'pickup_time': datetime.datetime(1977, 5, 11, 14, 32, 5)},
#  (36, 2): {'reason': 'SjFjlZwEsvsUfQHqpMUTtyAfUFCfzjSd',
#   'request_id': 36,
#   'handler_id': 8,
#   'pickup_id': 2,
#   'pickup_time': datetime.datetime(1977, 5, 12, 2, 32, 5)},
#  (36, 3): {'reason': 'hAMUpeWyBgjwZWLkynvhkZefCPzJCfSN',
#   'request_id': 36,
#   'handler_id': 2,
#   'pickup_id': 3,
#   'pickup_time': datetime.datetime(1977, 5, 12, 12, 32, 5)},
#  (50, 1): {'reason': 'OcIXeYQjQUumvuiWwKrXZgeZNqjIdwdB',
#   'request_id': 50,
#   'handler_id': 2,
#   'pickup_id': 1,
#   'pickup_time': datetime.datetime(2013, 8, 27, 14, 41, 7)},
#  (50, 2): {'reason': 'rklepCemzuoEckMkGdfDnTsfIFpjjGdC',
#   'request_id': 50,
#   'handler_id': 9,
#   'pickup_id': 2,
#   'pickup_time': datetime.datetime(2013, 8, 27, 23, 41, 7)},
#  (50, 3): {'reason': 'AIfCLXfdRAmuMkwLrPvAsjOZopMsymRt',
#   'request_id': 50,
#   'handler_id': 10,
#   'pickup_id': 3,
#   'pickup_time': datetime.datetime(2013, 8, 28, 3, 41, 7)},
#  (54, 1): {'reason': 'jYakAffXFKzxHqZZavokjXNLcCioHUTJ',
#   'request_id': 54,
#   'handler_id': 10,
#   'pickup_id': 1,
#   'pickup_time': datetime.datetime(1993, 9, 16, 22, 56, 43)},
#  (61, 1): {'reason': 'YkkWmdVIrqtwoCfZeVCkVsjLdDuUuNVn',
#   'request_id': 61,
#   'handler_id': 9,
#   'pickup_id': 1,
#   'pickup_time': datetime.datetime(1994, 9, 2, 3, 27, 34)},
#  (61, 2): {'reason': 'sDZbOoTXYXSWVpVWDVeyJrMbJgEqGefM',
#   'request_id': 61,
#   'handler_id': 4,
#   'pickup_id': 2,
#   'pickup_time': datetime.datetime(1994, 9, 2, 14, 27, 34)},
#  (61, 3): {'reason': 'JFPRGernCVIjIhcLXaqicgsYEaSceCsf',
#   'request_id': 61,
#   'handler_id': 4,
#   'pickup_id': 3,
#   'pickup_time': datetime.datetime(

#   'handler_id': 1,
#   'pickup_id': 1,
#   'pickup_time': datetime.datetime(1983, 8, 1, 21, 42, 19)},
#  (262, 2): {'reason': 'zToMsWLDwTpafonnYcHhvpZCJBLIcliL',
#   'request_id': 262,
#   'handler_id': 10,
#   'pickup_id': 2,
#   'pickup_time': datetime.datetime(1983, 8, 2, 1, 42, 19)},
#  (262, 3): {'reason': 'GnobXtuQkleUGKIpVuzimakHnzUURPMe',
#   'request_id': 262,
#   'handler_id': 9,
#   'pickup_id': 3,
#   'pickup_time': datetime.datetime(1983, 8, 2, 9, 42, 19)},
#  (263, 1): {'reason': 'FUDCoOFngiRHXjUWTyLEofZIkvvEVaXD',
#   'request_id': 263,
#   'handler_id': 8,
#   'pickup_id': 1,
#   'pickup_time': datetime.datetime(2002, 7, 31, 4, 57, 28)},
#  (265, 1): {'reason': 'IgXCNQapvyageDvHFUvIQEqqkSxVovSy',
#   'request_id': 265,
#   'handler_id': 1,
#   'pickup_id': 1,
#   'pickup_time': datetime.datetime(1987, 11, 6, 5, 45)},
#  (269, 1): {'reason': 'caEOpkRRiyDMtGDfIprVQzCZCsojTvLw',
#   'request_id': 269,
#   'handler_id': 6,
#   'pickup_id': 1,
#   'pickup_time': datetime.datetime(1984, 1, 1, 0, 2, 44)},
#  (273, 1): {'reason': 'bPSlRAHRKgQMuoEetgdcltHMvAVagOve',
#   'request_id': 273,
#   'handler_id': 1,
#   'pickup_id': 1,
#   'pickup_time': datetime.datetime(1984, 10, 26, 16, 18, 17)},
#  (273, 2): {'reason': 'WUvRmgwtUkUkbEqJcjPoROzuzwMiqNHo',
#   'request_id': 273,
#   'handler_id': 8,
#   'pickup_id': 2,
#   'pickup_time': datetime.datetime(1984, 10, 26, 22, 18, 17)},
#  (283, 1): {'reason': 'iSEjhAxFbtvSAHdYSppBYSHKQRvzXcpM',
#   'request_id': 283,
#   'handler_id': 6,
#   'pickup_id': 1,
#   'pickup_time': datetime.datetime(1979, 3, 30, 9, 49, 22)},
#  (283, 2): {'reason': 'BcpDzZoPAlDHOnUGrmZVVqeDMdtXlupJ',
#   'request_id': 283,
#   'handler_id': 7,
#   'pickup_id': 2,
#   'pickup_time': datetime.datetime(1979, 3, 30, 12, 49, 22)},
#  (287, 1): {'reason': 'yJoTVtEJaPKaKgNHvQTQAbsCiNElWbjl',
#   'request_id': 287,
#   'handler_id': 8,
#   'pickup_id': 1,
#   'pickup_time': datetime.datetime(1993, 8, 22, 3, 40, 29)},
#  (287, 2): {'reason': 'PMRUVETBwSdcqGfMgQIuasUqwCJveXVm',
#   'request_id': 287,
#   'handler_id': 4,
#   'pickup_id': 2,
#   'pickup_time': datetime.datetime(1993, 8, 22, 15, 40, 29)},
#  (288, 1): {'reason': 'ozGdOIJsAAwZKDHQRetlVVBeyyfyFlZj',
#   'request_id': 288,
#   'handler_id': 9,
#   'pickup_id': 1,
#   'pickup_time': datetime.datetime(1972, 12, 7, 2, 20, 58)},
#  (288, 2): {'reason': 'nnbvkaxCPvMtibSgRAMjnZABQiqUMgQa',
#   'request_id': 288,
#   'handler_id': 4,
#   'pickup_id': 2,
#   'pickup_time': datetime.datetime(1972, 12, 7, 14, 20, 58)},
#  (290, 1): {'reason': 'vTynlxfCMXQEhvzRmjDpvKhthRTDiPzd',
#   'request_id': 290,
#   'handler_id': 1,
#   'pickup_id': 1,
#   'pickup_time': datetime.datetime(2005, 9, 4, 7, 57, 35)},
#  (291, 1): {'reason': 'LtjhFEIELiWtbWeGFrRfoGKTAbnYpCKC',
#   'request_id': 291,
#   'handler_id': 6,
#   'pickup_id': 1,
#   'pickup_time': datetime.datetime(1980, 12, 26, 5, 55, 43)},
#  (293, 1): {'reason': 'pQZMIBZJEBEkRZlIaMvsUPdSDtyONzRg',
#   'request_id': 293,
#   'handler_id': 8,
#   'pickup_id': 1,
#   'pickup_time': datetime.datetime(2022, 10, 6, 15, 53, 34)},
#  (293, 2): {'reason': 'tssrlmQGneBdslAKyVjSkTZImLwUoJNJ',
#   'request_id': 293,
#   'handler_id': 10,
#   'pickup_id': 2,
#   'pickup_time': datetime.datetime(2022, 10, 6, 19, 53, 34)},
#  (299, 1): {'reason': 'xlHXnKHlkLrVLKBreZylcYshYaWjnYif',
#   'request_id': 299,
#   'handler_id': 7,
#   'pickup_id': 1,
#   'pickup_time': datetime.datetime(1983, 8, 29, 6, 35, 16)},
#  (299, 2): {'reason': 'XHdCfjUobGVYldQSXNLNUPjpBVWDuASi',
#   'request_id': 299,
#   'handler_id': 8,
#   'pickup_id': 2,
#   'pickup_time': datetime.datetime(1983, 8, 29, 12, 35, 16)},
#  (303, 1): {'reason': 'ssxGameNqrxxGvQgiGpOGkOIXBlaUxrx',
#   'request_id': 303,
#   'handler_id': 8,
#   'pickup_id': 1,
#   'pickup_time': datetime.datetime(

#   'handler_id': 7,
#   'pickup_id': 2,
#   'pickup_time': datetime.datetime(1983, 3, 21, 2, 35, 31)},
#  (1671, 3): {'reason': 'GWgiQbIslXhhKEhcQDtcnGVpdEtmtKHW',
#   'request_id': 1671,
#   'handler_id': 8,
#   'pickup_id': 3,
#   'pickup_time': datetime.datetime(1983, 3, 21, 8, 35, 31)},
#  (1672, 1): {'reason': 'KHFRKkmXBeSMWVcWNRnkExzwscQNDmwd',
#   'request_id': 1672,
#   'handler_id': 3,
#   'pickup_id': 1,
#   'pickup_time': datetime.datetime(1973, 10, 30, 23, 58, 32)},
#  (1680, 1): {'reason': 'olWgDsFvptyDQQMbdwlQkuckVcelbSKa',
#   'request_id': 1680,
#   'handler_id': 4,
#   'pickup_id': 1,
#   'pickup_time': datetime.datetime(2020, 1, 13, 22, 44, 2)},
#  (1681, 1): {'reason': 'LQhJsHhWtHvjEsRjNVgOXTLItnOHfBYh',
#   'request_id': 1681,
#   'handler_id': 10,
#   'pickup_id': 1,
#   'pickup_time': datetime.datetime(2022, 12, 26, 1, 0, 15)},
#  (1685, 1): {'reason': 'QwdYRmxIcklGvSpSjVJvMDGxnsaoyKXp',
#   'request_id': 1685,
#   'handler_id': 2,
#   'pickup_id': 1,
#   'pickup_time': datetime.datetime(2012, 2, 7, 23, 2, 6)},
#  (1690, 1): {'reason': 'ndqrNDEwVrkpMCmjBeVSkGngrbRAPZpy',
#   'request_id': 1690,
#   'handler_id': 9,
#   'pickup_id': 1,
#   'pickup_time': datetime.datetime(2014, 6, 19, 15, 18, 48)},
#  (1690, 2): {'reason': 'sgQptAaLBTNIUtpMfGHvobAiTnAMdjZE',
#   'request_id': 1690,
#   'handler_id': 3,
#   'pickup_id': 2,
#   'pickup_time': datetime.datetime(2014, 6, 19, 16, 18, 48)},
#  (1691, 1): {'reason': 'yuPGRrEFMWBDPWOQuPYzKGQcyNcbwMbB',
#   'request_id': 1691,
#   'handler_id': 6,
#   'pickup_id': 1,
#   'pickup_time': datetime.datetime(1971, 6, 1, 4, 20, 56)},
#  (1691, 2): {'reason': 'MryPSGjIbpCFDOmRcSdSGVXDzRcekCnv',
#   'request_id': 1691,
#   'handler_id': 9,
#   'pickup_id': 2,
#   'pickup_time': datetime.datetime(1971, 6, 1, 11, 20, 56)},
#  (1692, 1): {'reason': 'SXLSKOFhUCxPfBcMYWyfzsZVJYXaOGHE',
#   'request_id': 1692,
#   'handler_id': 3,
#   'pickup_id': 1,
#   'pickup_time': datetime.datetime(1990, 8, 22, 7, 40, 50)},
#  (1692, 2): {'reason': 'amFtXyteijDRPnEJcPxcTAohXUzVVBbB',
#   'request_id': 1692,
#   'handler_id': 7,
#   'pickup_id': 2,
#   'pickup_time': datetime.datetime(1990, 8, 22, 16, 40, 50)},
#  (1694, 1): {'reason': 'xGLGdrCkufFAAYEpBrBDLLHPQtJMspvV',
#   'request_id': 1694,
#   'handler_id': 8,
#   'pickup_id': 1,
#   'pickup_time': datetime.datetime(1985, 8, 5, 7, 57, 14)},
#  (1697, 1): {'reason': 'yzPFCyvimUkYWjmdgdQvmGVQfJSUZipW',
#   'request_id': 1697,
#   'handler_id': 4,
#   'pickup_id': 1,
#   'pickup_time': datetime.datetime(2007, 5, 9, 18, 30, 5)},
#  (1697, 2): {'reason': 'rRXJHSSewVSTVYVHskOKEhiJWGNjsPmO',
#   'request_id': 1697,
#   'handler_id': 8,
#   'pickup_id': 2,
#   'pickup_time': datetime.datetime(2007, 5, 9, 19, 30, 5)},
#  (1700, 1): {'reason': 'vioTWrTkFoTBBLZmPKEVAgWoiRPaGaSx',
#   'request_id': 1700,
#   'handler_id': 9,
#   'pickup_id': 1,
#   'pickup_time': datetime.datetime(1992, 10, 14, 7, 33)},
#  (1700, 2): {'reason': 'GrZtnnZmkoUbRuDbIpPwbMaHjWkMCzkQ',
#   'request_id': 1700,
#   'handler_id': 4,
#   'pickup_id': 2,
#   'pickup_time': datetime.datetime(1992, 10, 14, 9, 33)},
#  (1700, 3): {'reason': 'lXfTtEMaBWYBYapinFYKWUQxgdEuERfn',
#   'request_id': 1700,
#   'handler_id': 10,
#   'pickup_id': 3,
#   'pickup_time': datetime.datetime(1992, 10, 14, 19, 33)},
#  (1701, 1): {'reason': 'YROnJBcsenhSAolZbPCUCUYAnVeWCgyr',
#   'request_id': 1701,
#   'handler_id': 4,
#   'pickup_id': 1,
#   'pickup_time': datetime.datetime(2004, 11, 28, 9, 56, 3)},
#  (1701, 2): {'reason': 'uzeyPPmPwyZvbUVwAeygaxYPoOaxQOPU',
#   'request_id': 1701,
#   'handler_id': 4,
#   'pickup_id': 2,
#   'pickup_time': datetime.datetime(2004, 11, 28, 10, 56, 3)},
#  (1707, 1): {'reason': 'rqGWVDMewrBNsjGYUGdpeOnWAqfnhkzb',
#   'request_id': 1707,
#   'handler_id': 9,
#   'pickup_id': 1,
#   'pickup_time': datetime.datetime(1973, 1, 19, 13, 9, 51)},
#  (1707, 2): {'reason': 'vRUBRHoZlyHOOfWacsYyBVsWTCGfBJsV',
#   'request_id': 1707,
#   'handler_id': 4,
#   'pickup_id': 2,
#   'pickup_time': datetime.datetime(1973, 1, 19, 16, 9, 51)},
#  (1707, 3): {'reason': 'cuxoEAMtJqCWuIcvZhLzsbRJnpiYjtfR',
#   'request_id': 1707,
#   'handler_id': 7,
#   'pickup_id': 3,
#   'pickup_time': datetime.datetime(1973, 1, 20, 0, 9, 51)},
#  (1709, 1): {'reason': 'tVwnRelGVjxTirWfaijVWQMwVFUNBkHI',
#   'request_id': 1709,
#   'handler_id': 6,
#   'pickup_id': 1,
#   'pickup_time': datetime.datetime(2005, 3, 26, 2, 9, 31)},
#  (1709, 2): {'reason': 'SBWgRmcEDtbAaKnscgUwIJbCTYtWsFMF',
#   'request_id': 1709,
#   'handler_id': 2,
#   'pickup_id': 2,
#   'pickup_time': datetime.datetime(2005, 3, 26, 3, 9, 31)},
#  (1716, 1): {'reason': 'RmBSfNSUNyatOdjsKluZuurfNfANgauS',
#   'request_id': 1716,
#   'handler_id': 1,
#   'pickup_id': 1,
#   'pickup_time': datetime.datetime(2011, 8, 13, 6, 9, 57)},
#  (1716, 2): {'reason': 'bBUVSjQWCbKxYJmsahZocIvjbZIvZaLB',
#   'request_id': 1716,
#   'handler_id': 8,
#   'pickup_id': 2,
#   'pickup_time': datetime.datetime(2011, 8, 13, 17, 9, 57)},
#  (1716, 3): {'reason': 'QHgRhkhEGbdvUCGaIFMmGbQJCctjFbXG',
#   'request_id': 1716,
#   'handler_id': 3,
#   'pickup_id': 3,
#   'pickup_time': datetime.datetime(2011, 8, 14, 2, 9, 57)},
#  (1717, 1): {'reason': 'CAigbKPGdqRdaHLgVRKAiTzWldrsCErN',
#   'request_id': 1717,
#   'handler_id': 2,
#   'pickup_id': 1,
#   'pickup_time': datetime.datetime(2004, 11, 18, 21, 29, 23)},
#  (1717, 2): {'reason': 'YcdZaXOGEcYIawgiQcCUzzauTRCdhJxr',
#   'request_id': 1717,
#   'handler_id': 1,
#   'pickup_id': 2,
#   'pickup_time': datetime.datetime(2004, 11, 19, 8, 29, 23)},
#  (1717, 3): {'reason': 'yBCSZMcMRNAUzOuzDoGaEVjMhVSSlbid',
#   'request_id': 1717,
#   'handler_id': 2,
#   'pickup_id': 3,
#   'pickup_time': datetime.datetime(2004, 11, 19, 9, 29, 23)},
#  (1722, 1): {'reason': 'VGhxteIgCZtFKCezjLdtSyvIXAetfBgW',
#   'request_id': 1722,
#   'handler_id': 8,
#   'pickup_id': 1,
#   'pickup_time': datetime.datetime(1972, 7, 15, 17, 44, 24)},
#  (1727, 1): {'reason': 'qqxeZYMxWxCenuiOMmTQFKDDnObroBqS',
#   'request_id': 1727,
#   'handler_id': 4,
#   'pickup_id': 1,
#   'pickup_time': datetime.datetime(1991, 3, 30, 23, 6, 46)},
#  (1727, 2): {'reason': 'ZYMuwFormaVuFXgZXTaTeSAhpSpedETJ',
#   'request_id': 1727,
#   'handler_id': 8,
#   'pickup_id': 2,
#   'pickup_time': datetime.datetime(1991, 3, 31, 5, 6, 46)},
#  ...}

# %%
req_to_failed_pickup
# Out:
# {15: 1,
#  27: 2,
#  30: 1,
#  31: 3,
#  35: 1,
#  36: 3,
#  50: 3,
#  54: 1,
#  61: 3,
#  62: 1,
#  63: 3,
#  66: 1,
#  67: 2,
#  68: 3,
#  70: 1,
#  71: 2,
#  72: 2,
#  75: 2,
#  77: 3,
#  79: 1,
#  84: 2,
#  94: 2,
#  97: 1,
#  105: 3,
#  109: 2,
#  111: 3,
#  115: 3,
#  118: 2,
#  119: 3,
#  120: 3,
#  122: 2,
#  125: 2,
#  134: 1,
#  136: 2,
#  140: 1,
#  146: 1,
#  151: 2,
#  152: 3,
#  154: 3,
#  159: 2,
#  160: 2,
#  163: 1,
#  165: 3,
#  170: 1,
#  172: 1,
#  173: 1,
#  177: 1,
#  179: 3,
#  181: 2,
#  184: 2,
#  188: 3,
#  192: 2,
#  196: 1,
#  201: 3,
#  208: 1,
#  210: 1,
#  213: 3,
#  219: 1,
#  220: 1,
#  227: 2,
#  228: 2,
#  236: 2,
#  243: 2,
#  244: 3,
#  248: 1,
#  258: 3,
#  260: 3,
#  262: 3,
#  263: 1,
#  265: 1,
#  269: 1,
#  273: 2,
#  283: 2,
#  287: 2,
#  288: 2,
#  290: 1,
#  291: 1,
#  293: 2,
#  299: 2,
#  303: 3,
#  304: 2,
#  305: 1,
#  308: 2,
#  309: 2,
#  310: 2,
#  311: 3,
#  314: 1,
#  315: 1,
#  321: 3,
#  326: 3,
#  334: 2,
#  335: 1,
#  336: 2,
#  337: 1,
#  340: 2,
#  346: 1,
#  347: 1,
#  350: 1,
#  354: 2,
#  355: 1,
#  356: 2,
#  365: 1,
#  366: 1,
#  369: 2,
#  370: 2,
#  376: 1,
#  383: 1,
#  389: 1,
#  391: 3,
#  394: 2,
#  395: 2,
#  400: 2,
#  406: 2,
#  408: 3,
#  412: 1,
#  415: 2,
#  416: 1,
#  418: 3,
#  421: 1,
#  422: 3,
#  424: 1,
#  426: 1,
#  428: 1,
#  431: 1,
#  434: 3,
#  439: 3,
#  442: 1,
#  443: 1,
#  445: 3,
#  448: 3,
#  456: 1,
#  461: 1,
#  467: 2,
#  469: 3,
#  470: 2,
#  471: 3,
#  482: 1,
#  485: 2,
#  486: 3,
#  488: 2,
#  492: 1,
#  494: 1,
#  495: 2,
#  496: 2,
#  499: 3,
#  504: 3,
#  505: 3,
#  510: 1,
#  512: 3,
#  516: 1,
#  521: 2,
#  523: 3,
#  524: 3,
#  530: 1,
#  531: 1,
#  533: 1,
#  535: 3,
#  537: 3,
#  539: 1,
#  542: 3,
#  545: 3,
#  548: 1,
#  557: 1,
#  564: 2,
#  570: 3,
#  580: 1,
#  582: 2,
#  584: 2,
#  585: 3,
#  591: 3,
#  592: 1,
#  597: 1,
#  600: 3,
#  601: 2,
#  603: 2,
#  608: 2,
#  610: 3,
#  611: 2,
#  613: 3,
#  617: 2,
#  621: 3,
#  625: 2,
#  627: 3,
#  629: 1,
#  636: 2,
#  637: 1,
#  646: 2,
#  651: 2,
#  655: 1,
#  656: 2,
#  660: 3,
#  665: 2,
#  666: 2,
#  667: 1,
#  670: 3,
#  671: 1,
#  679: 2,
#  682: 2,
#  689: 3,
#  691: 1,
#  694: 3,
#  695: 2,
#  696: 1,
#  702: 3,
#  705: 2,
#  707: 3,
#  710: 1,
#  715: 1,
#  719: 2,
#  723: 3,
#  725: 3,
#  730: 1,
#  731: 3,
#  737: 2,
#  740: 3,
#  741: 2,
#  745: 1,
#  749: 2,
#  752: 3,
#  759: 2,
#  760: 3,
#  762: 1,
#  764: 3,
#  767: 2,
#  768: 3,
#  772: 2,
#  773: 1,
#  774: 1,
#  776: 1,
#  779: 2,
#  783: 1,
#  784: 2,
#  785: 3,
#  789: 1,
#  793: 3,
#  794: 3,
#  795: 2,
#  799: 2,
#  800: 2,
#  806: 1,
#  808: 1,
#  810: 2,
#  813: 1,
#  818: 2,
#  823: 1,
#  829: 2,
#  831: 2,
#  833: 2,
#  837: 1,
#  843: 2,
#  848: 1,
#  855: 3,
#  860: 1,
#  865: 2,
#  867: 1,
#  868: 1,
#  871: 3,
#  873: 2,
#  877: 1,
#  879: 1,
#  882: 2,
#  883: 3,
#  885: 2,
#  887: 2,
#  889: 1,
#  893: 1,
#  898: 3,
#  899: 1,
#  900: 3,
#  901: 2,
#  902: 3,
#  906: 1,
#  910: 3,
#  914: 3,
#  915: 2,
#  917: 2,
#  919: 1,
#  921: 1,
#  922: 3,
#  930: 1,
#  939: 2,
#  943: 3,
#  945: 2,
#  950: 3,
#  955: 3,
#  957: 1,
#  959: 2,
#  962: 3,
#  964: 3,
#  965: 2,
#  977: 3,
#  979: 1,
#  981: 1,
#  986: 1,
#  987: 2,
#  990: 3,
#  994: 2,
#  995: 2,
#  997: 2,
#  999: 1,
#  1001: 3,
#  1002: 3,
#  1005: 2,
#  1007: 1,
#  1008: 1,
#  1014: 2,
#  1019: 1,
#  1023: 3,
#  1024: 3,
#  1027: 1,
#  1028: 2,
#  1032: 1,
#  1035: 1,
#  1038: 3,
#  1039: 1,
#  1040: 1,
#  1047: 1,
#  1051: 3,
#  1054: 1,
#  1059: 3,
#  1068: 2,
#  1069: 1,
#  1074: 3,
#  1078: 3,
#  1079: 3,
#  1083: 2,
#  1086: 1,
#  1087: 3,
#  1094: 1,
#  1101: 2,
#  1119: 2,
#  1121: 2,
#  1125: 1,
#  1129: 1,
#  1131: 3,
#  1133: 2,
#  1134: 1,
#  1138: 1,
#  1139: 3,
#  1140: 1,
#  1141: 2,
#  1149: 3,
#  1152: 1,
#  1155: 3,
#  1157: 2,
#  1163: 2,
#  1169: 1,
#  1177: 3,
#  1186: 2,
#  1187: 1,
#  1192: 3,
#  1197: 1,
#  1200: 3,
#  1201: 3,
#  1202: 2,
#  1203: 3,
#  1204: 3,
#  1206: 3,
#  1210: 3,
#  1212: 3,
#  1213: 1,
#  1219: 1,
#  1220: 3,
#  1225: 2,
#  1230: 3,
#  1233: 1,
#  1234: 1,
#  1236: 3,
#  1241: 3,
#  1251: 2,
#  1255: 3,
#  1260: 1,
#  1264: 3,
#  1269: 2,
#  1271: 1,
#  1272: 3,
#  1275: 3,
#  1277: 3,
#  1283: 1,
#  1285: 2,
#  1286: 1,
#  1290: 1,
#  1292: 1,
#  1293: 1,
#  1301: 2,
#  1303: 3,
#  1314: 2,
#  1318: 2,
#  1325: 3,
#  1327: 1,
#  1328: 1,
#  1330: 1,
#  1331: 1,
#  1335: 1,
#  1343: 3,
#  1344: 1,
#  1350: 1,
#  1361: 2,
#  1366: 1,
#  1367: 1,
#  1368: 2,
#  1369: 3,
#  1377: 3,
#  1383: 1,
#  1384: 1,
#  1385: 2,
#  1395: 1,
#  1396: 3,
#  1400: 3,
#  1405: 3,
#  1411: 2,
#  1413: 2,
#  1416: 3,
#  1419: 2,
#  1421: 2,
#  1425: 3,
#  1428: 3,
#  1429: 2,
#  1437: 2,
#  1442: 3,
#  1446: 1,
#  1448: 2,
#  1450: 2,
#  1456: 2,
#  1464: 3,
#  1472: 1,
#  1473: 1,
#  1475: 2,
#  1477: 3,
#  1483: 1,
#  1490: 2,
#  1493: 1,
#  1494: 2,
#  1497: 2,
#  1499: 1,
#  1503: 2,
#  1504: 1,
#  1505: 2,
#  1507: 1,
#  1512: 1,
#  1513: 2,
#  1516: 3,
#  1523: 1,
#  1524: 3,
#  1526: 3,
#  1528: 2,
#  1529: 2,
#  1531: 2,
#  1538: 1,
#  1539: 3,
#  1542: 1,
#  1543: 2,
#  1546: 1,
#  1556: 1,
#  1561: 3,
#  1562: 2,
#  1568: 2,
#  1571: 2,
#  1574: 3,
#  1575: 1,
#  1577: 2,
#  1582: 3,
#  1584: 3,
#  1585: 1,
#  1590: 3,
#  1592: 3,
#  1596: 1,
#  1597: 1,
#  1601: 2,
#  1602: 3,
#  1605: 2,
#  1609: 2,
#  1611: 3,
#  1612: 3,
#  1614: 1,
#  1617: 2,
#  1619: 2,
#  1628: 1,
#  1630: 3,
#  1635: 1,
#  1637: 2,
#  1639: 2,
#  1641: 2,
#  1643: 2,
#  1644: 1,
#  1646: 1,
#  1647: 2,
#  1650: 1,
#  1653: 1,
#  1655: 1,
#  1656: 1,
#  1659: 1,
#  1660: 3,
#  1662: 3,
#  1664: 2,
#  1665: 1,
#  1668: 2,
#  1671: 3,
#  1672: 1,
#  1680: 1,
#  1681: 1,
#  1685: 1,
#  1690: 2,
#  1691: 2,
#  1692: 2,
#  1694: 1,
#  1697: 2,
#  1700: 3,
#  1701: 2,
#  1707: 3,
#  1709: 2,
#  1716: 3,
#  1717: 3,
#  1722: 1,
#  1727: 2,
#  1730: 2,
#  1741: 3,
#  1742: 2,
#  1749: 2,
#  1753: 1,
#  1759: 3,
#  1761: 3,
#  1764: 1,
#  1768: 1,
#  1771: 3,
#  1776: 1,
#  1781: 2,
#  1782: 1,
#  1783: 3,
#  1784: 2,
#  1786: 2,
#  1787: 3,
#  1795: 1,
#  1796: 2,
#  1803: 3,
#  1804: 1,
#  1809: 3,
#  1819: 3,
#  1823: 3,
#  1824: 1,
#  1830: 1,
#  1833: 1,
#  1834: 1,
#  1840: 2,
#  1841: 1,
#  1846: 3,
#  1851: 3,
#  1853: 1,
#  1854: 3,
#  1855: 1,
#  1859: 2,
#  1868: 1,
#  1871: 3,
#  1875: 1,
#  1883: 3,
#  1889: 3,
#  1890: 1,
#  1893: 2,
#  1895: 3,
#  1899: 2,
#  1900: 3,
#  1904: 2,
#  1911: 1,
#  1912: 2,
#  1913: 1,
#  1916: 3,
#  1917: 3,
#  1921: 3,
#  1922: 2,
#  1925: 2,
#  1931: 2,
#  1935: 3,
#  1936: 3,
#  1942: 3,
#  1945: 2,
#  1948: 2,
#  1951: 1,
#  1954: 2,
#  1960: 1,
#  1962: 3,
#  1964: 2,
#  1965: 2,
#  1968: 1,
#  1970: 2,
#  1972: 2,
#  1974: 2,
#  1977: 2,
#  1980: 3,
#  1985: 1,
#  1988: 3,
#  1989: 3,
#  1993: 3,
#  1995: 3}

# %%
legs = {}
# NUM_LEGS
req_to_last_leg = {}
    
potential_unsuccessful = set()
    
for accepted_id in accepted_req_id:
#     print(f"accepted_id: {accepted_id}")
    if (random.choice([True,False])):
        cur_time = delivery_requests[accepted_id]['submission_time']
        if accepted_id in req_to_failed_pickup:
            k = (accepted_id, req_to_failed_pickup[accepted_id])
            cur_time = failed_pickups[k]['pickup_time']
        leg_id  = 1
        up_to = get_random_int_to(2, 7)
        while(leg_id < up_to):
            to_add = {}
            this_id = (accepted_id, leg_id)
            # Check if need to match the pickup handler's id
            to_add['request_id'] = accepted_id
            to_add['leg_id'] = leg_id
            to_add['handler_id'] = random.choice(list(delivery_staff_id))
            cur_time += timedelta(hours=get_random_int_to(1,12))
            to_add['start_time'] = cur_time
            cur_time += timedelta(hours=get_random_int_to(1,12))
            to_add['destination_facility'] = random.choice(list(facilities.keys()))
            if leg_id < (up_to - 1):
                to_add['end_time'] = cur_time
            else:
                # None means mid way, a timestamp means complete
                to_add['end_time'] = random.choice([None, cur_time])
            legs[this_id] = to_add
            leg_id += 1
        if up_to <= 4:
            potential_unsuccessful.add(accepted_id)
        req_to_last_leg[accepted_id] = up_to - 1 
legs
# Out:
# {(11, 1): {'request_id': 11,
#   'leg_id': 1,
#   'handler_id': 5,
#   'start_time': datetime.datetime(1982, 8, 28, 19, 1, 49),
#   'destination_facility': 3,
#   'end_time': datetime.datetime(1982, 8, 29, 0, 1, 49)},
#  (11, 2): {'request_id': 11,
#   'leg_id': 2,
#   'handler_id': 10,
#   'start_time': datetime.datetime(1982, 8, 29, 9, 1, 49),
#   'destination_facility': 8,
#   'end_time': datetime.datetime(1982, 8, 29, 20, 1, 49)},
#  (11, 3): {'request_id': 11,
#   'leg_id': 3,
#   'handler_id': 3,
#   'start_time': datetime.datetime(1982, 8, 30, 0, 1, 49),
#   'destination_facility': 6,
#   'end_time': datetime.datetime(1982, 8, 30, 6, 1, 49)},
#  (12, 1): {'request_id': 12,
#   'leg_id': 1,
#   'handler_id': 3,
#   'start_time': datetime.datetime(1988, 11, 7, 7, 41, 5),
#   'destination_facility': 4,
#   'end_time': datetime.datetime(1988, 11, 7, 19, 41, 5)},
#  (15, 1): {'request_id': 15,
#   'leg_id': 1,
#   'handler_id': 3,
#   'start_time': datetime.datetime(1970, 9, 12, 16, 3, 3),
#   'destination_facility': 5,
#   'end_time': datetime.datetime(1970, 9, 12, 23, 3, 3)},
#  (15, 2): {'request_id': 15,
#   'leg_id': 2,
#   'handler_id': 9,
#   'start_time': datetime.datetime(1970, 9, 13, 9, 3, 3),
#   'destination_facility': 3,
#   'end_time': datetime.datetime(1970, 9, 13, 19, 3, 3)},
#  (15, 3): {'request_id': 15,
#   'leg_id': 3,
#   'handler_id': 10,
#   'start_time': datetime.datetime(1970, 9, 14, 4, 3, 3),
#   'destination_facility': 6,
#   'end_time': datetime.datetime(1970, 9, 14, 11, 3, 3)},
#  (15, 4): {'request_id': 15,
#   'leg_id': 4,
#   'handler_id': 9,
#   'start_time': datetime.datetime(1970, 9, 14, 23, 3, 3),
#   'destination_facility': 5,
#   'end_time': datetime.datetime(1970, 9, 15, 4, 3, 3)},
#  (15, 5): {'request_id': 15,
#   'leg_id': 5,
#   'handler_id': 6,
#   'start_time': datetime.datetime(1970, 9, 15, 9, 3, 3),
#   'destination_facility': 6,
#   'end_time': datetime.datetime(

#   'destination_facility': 2,
#   'end_time': datetime.datetime(2008, 10, 7, 12, 51, 2)},
#  (964, 5): {'request_id': 964,
#   'leg_id': 5,
#   'handler_id': 10,
#   'start_time': datetime.datetime(2008, 10, 7, 19, 51, 2),
#   'destination_facility': 8,
#   'end_time': None},
#  (968, 1): {'request_id': 968,
#   'leg_id': 1,
#   'handler_id': 1,
#   'start_time': datetime.datetime(2006, 3, 12, 8, 23, 48),
#   'destination_facility': 2,
#   'end_time': datetime.datetime(2006, 3, 12, 16, 23, 48)},
#  (968, 2): {'request_id': 968,
#   'leg_id': 2,
#   'handler_id': 5,
#   'start_time': datetime.datetime(2006, 3, 13, 4, 23, 48),
#   'destination_facility': 7,
#   'end_time': None},
#  (977, 1): {'request_id': 977,
#   'leg_id': 1,
#   'handler_id': 8,
#   'start_time': datetime.datetime(1996, 1, 30, 13, 21, 45),
#   'destination_facility': 3,
#   'end_time': datetime.datetime(1996, 1, 30, 20, 21, 45)},
#  (977, 2): {'request_id': 977,
#   'leg_id': 2,
#   'handler_id': 2,
#   'start_time': datetime.datetime(1996, 1, 31, 5, 21, 45),
#   'destination_facility': 5,
#   'end_time': datetime.datetime(1996, 1, 31, 6, 21, 45)},
#  (977, 3): {'request_id': 977,
#   'leg_id': 3,
#   'handler_id': 6,
#   'start_time': datetime.datetime(1996, 1, 31, 11, 21, 45),
#   'destination_facility': 1,
#   'end_time': datetime.datetime(1996, 1, 31, 14, 21, 45)},
#  (977, 4): {'request_id': 977,
#   'leg_id': 4,
#   'handler_id': 7,
#   'start_time': datetime.datetime(1996, 1, 31, 19, 21, 45),
#   'destination_facility': 2,
#   'end_time': datetime.datetime(1996, 2, 1, 4, 21, 45)},
#  (977, 5): {'request_id': 977,
#   'leg_id': 5,
#   'handler_id': 9,
#   'start_time': datetime.datetime(1996, 2, 1, 5, 21, 45),
#   'destination_facility': 8,
#   'end_time': datetime.datetime(1996, 2, 1, 16, 21, 45)},
#  (977, 6): {'request_id': 977,
#   'leg_id': 6,
#   'handler_id': 2,
#   'start_time': datetime.datetime(1996, 2, 2, 1, 21, 45),
#   'destination_facility': 2,
#   'end_time': datetime.datetime(1996, 2, 2, 9, 21, 45)},
#  (979, 1): {'request_id': 979,
#   'leg_id': 1,
#   'handler_id': 4,
#   'start_time': datetime.datetime(2017, 11, 21, 23, 47, 33),
#   'destination_facility': 6,
#   'end_time': datetime.datetime(2017, 11, 22, 4, 47, 33)},
#  (980, 1): {'request_id': 980,
#   'leg_id': 1,
#   'handler_id': 10,
#   'start_time': datetime.datetime(1980, 5, 18, 5, 55, 27),
#   'destination_facility': 10,
#   'end_time': datetime.datetime(1980, 5, 18, 13, 55, 27)},
#  (980, 2): {'request_id': 980,
#   'leg_id': 2,
#   'handler_id': 8,
#   'start_time': datetime.datetime(1980, 5, 19, 0, 55, 27),
#   'destination_facility': 6,
#   'end_time': datetime.datetime(1980, 5, 19, 1, 55, 27)},
#  (980, 3): {'request_id': 980,
#   'leg_id': 3,
#   'handler_id': 2,
#   'start_time': datetime.datetime(1980, 5, 19, 13, 55, 27),
#   'destination_facility': 3,
#   'end_time': datetime.datetime(1980, 5, 20, 1, 55, 27)},
#  (980, 4): {'request_id': 980,
#   'leg_id': 4,
#   'handler_id': 5,
#   'start_time': datetime.datetime(1980, 5, 20, 6, 55, 27),
#   'destination_facility': 4,
#   'end_time': None},
#  (981, 1): {'request_id': 981,
#   'leg_id': 1,
#   'handler_id': 7,
#   'start_time': datetime.datetime(1979, 2, 6, 0, 48, 49),
#   'destination_facility': 5,
#   'end_time': datetime.datetime(1979, 2, 6, 6, 48, 49)},
#  (983, 1): {'request_id': 983,
#   'leg_id': 1,
#   'handler_id': 9,
#   'start_time': datetime.datetime(1986, 9, 9, 16, 19, 29),
#   'destination_facility': 5,
#   'end_time': datetime.datetime(1986, 9, 10, 4, 19, 29)},
#  (988, 1): {'request_id': 988,
#   'leg_id': 1,
#   'handler_id': 7,
#   'start_time': datetime.datetime(1994, 11, 11, 19, 11, 17),
#   'destination_facility': 1,
#   'end_time': datetime.datetime(1994, 11, 11, 20, 11, 17)},
#  (988, 2): {'request_id': 988,
#   'leg_id': 2,
#   'handler_id': 1,
#   'start_time': datetime.datetime(1994, 11, 12, 3, 11, 17),
#   'destination_facility': 10,
#   'end_time': datetime.datetime(1994, 11, 12, 11, 11, 17)},
#  (988, 3): {'request_id': 988,
#   'leg_id': 3,
#   'handler_id': 4,
#   'start_time': datetime.datetime(1994, 11, 12, 13, 11, 17),
#   'destination_facility': 1,
#   'end_time': datetime.datetime(1994, 11, 13, 1, 11, 17)},
#  (988, 4): {'request_id': 988,
#   'leg_id': 4,
#   'handler_id': 7,
#   'start_time': datetime.datetime(1994, 11, 13, 3, 11, 17),
#   'destination_facility': 2,
#   'end_time': datetime.datetime(1994, 11, 13, 5, 11, 17)},
#  (988, 5): {'request_id': 988,
#   'leg_id': 5,
#   'handler_id': 5,
#   'start_time': datetime.datetime(1994, 11, 13, 16, 11, 17),
#   'destination_facility': 9,
#   'end_time': None},
#  (990, 1): {'request_id': 990,
#   'leg_id': 1,
#   'handler_id': 8,
#   'start_time': datetime.datetime(1995, 12, 17, 15, 13, 36),
#   'destination_facility': 5,
#   'end_time': datetime.datetime(1995, 12, 17, 18, 13, 36)},
#  ...}

# %%
req_to_last_leg
# Out:
# {11: 6,
#  13: 6,
#  15: 1,
#  19: 6,
#  23: 5,
#  24: 6,
#  27: 3,
#  28: 6,
#  30: 2,
#  31: 3,
#  32: 5,
#  35: 2,
#  46: 4,
#  47: 5,
#  49: 5,
#  53: 2,
#  56: 5,
#  61: 4,
#  62: 1,
#  64: 1,
#  65: 4,
#  68: 3,
#  70: 4,
#  71: 5,
#  73: 1,
#  75: 2,
#  79: 6,
#  84: 2,
#  86: 5,
#  97: 1,
#  99: 4,
#  100: 3,
#  102: 6,
#  103: 2,
#  104: 2,
#  105: 3,
#  109: 2,
#  111: 4,
#  115: 5,
#  118: 3,
#  119: 1,
#  120: 4,
#  127: 6,
#  148: 4,
#  152: 4,
#  159: 5,
#  160: 4,
#  163: 1,
#  166: 1,
#  172: 2,
#  175: 5,
#  177: 4,
#  184: 5,
#  185: 1,
#  186: 5,
#  187: 1,
#  188: 1,
#  189: 1,
#  193: 3,
#  208: 5,
#  209: 5,
#  210: 5,
#  211: 1,
#  213: 4,
#  221: 2,
#  223: 3,
#  227: 2,
#  232: 1,
#  238: 2,
#  243: 2,
#  252: 6,
#  253: 2,
#  258: 2,
#  263: 2,
#  265: 3,
#  269: 2,
#  273: 2,
#  274: 4,
#  288: 2,
#  294: 2,
#  296: 2,
#  300: 1,
#  301: 1,
#  303: 3,
#  305: 5,
#  309: 6,
#  312: 6,
#  314: 6,
#  315: 5,
#  320: 4,
#  321: 2,
#  322: 4,
#  323: 5,
#  330: 4,
#  335: 6,
#  337: 6,
#  339: 4,
#  340: 1,
#  344: 1,
#  346: 3,
#  350: 2,
#  354: 4,
#  355: 3,
#  356: 1,
#  359: 4,
#  361: 2,
#  362: 6,
#  365: 2,
#  369: 2,
#  376: 5,
#  378: 5,
#  380: 1,
#  389: 6,
#  395: 2,
#  400: 3,
#  403: 2,
#  406: 6,
#  407: 3,
#  408: 6,
#  412: 5,
#  422: 3,
#  431: 3,
#  436: 1,
#  438: 4,
#  442: 5,
#  443: 3,
#  445: 2,
#  448: 6,
#  462: 5,
#  463: 2,
#  467: 6,
#  469: 4,
#  470: 1,
#  471: 2,
#  478: 4,
#  485: 3,
#  492: 5,
#  494: 1,
#  499: 6,
#  501: 1,
#  506: 4,
#  508: 4,
#  509: 6,
#  510: 3,
#  514: 1,
#  515: 1,
#  516: 3,
#  518: 5,
#  519: 5,
#  523: 1,
#  531: 5,
#  535: 4,
#  538: 4,
#  540: 5,
#  541: 1,
#  542: 6,
#  548: 6,
#  552: 6,
#  557: 3,
#  565: 4,
#  566: 6,
#  570: 5,
#  572: 6,
#  574: 5,
#  576: 3,
#  580: 2,
#  581: 6,
#  585: 1,
#  587: 6,
#  591: 2,
#  592: 5,
#  596: 5,
#  597: 2,
#  598: 3,
#  601: 2,
#  603: 6,
#  607: 1,
#  608: 1,
#  611: 4,
#  613: 2,
#  615: 4,
#  617: 1,
#  619: 6,
#  623: 5,
#  629: 4,
#  631: 4,
#  634: 3,
#  635: 1,
#  636: 1,
#  637: 1,
#  640: 2,
#  646: 5,
#  655: 2,
#  663: 2,
#  666: 1,
#  667: 6,
#  669: 5,
#  676: 1,
#  678: 1,
#  679: 1,
#  680: 3,
#  682: 2,
#  684: 2,
#  685: 1,
#  691: 5,
#  694: 6,
#  695: 6,
#  696: 2,
#  698: 4,
#  709: 1,
#  716: 2,
#  719: 3,
#  728: 2,
#  730: 3,
#  740: 3,
#  741: 6,
#  743: 6,
#  749: 4,
#  751: 6,
#  752: 5,
#  755: 6,
#  762: 4,
#  764: 3,
#  768: 4,
#  769: 4,
#  777: 1,
#  780: 2,
#  783: 4,
#  792: 1,
#  795: 6,
#  799: 1,
#  808: 2,
#  810: 4,
#  813: 2,
#  818: 2,
#  825: 6,
#  826: 4,
#  827: 4,
#  829: 5,
#  830: 5,
#  831: 5,
#  832: 2,
#  837: 3,
#  841: 5,
#  843: 3,
#  844: 3,
#  846: 3,
#  848: 3,
#  850: 3,
#  854: 6,
#  860: 4,
#  861: 5,
#  862: 4,
#  865: 3,
#  866: 2,
#  867: 3,
#  873: 4,
#  875: 3,
#  877: 5,
#  880: 4,
#  882: 1,
#  883: 2,
#  885: 6,
#  887: 3,
#  901: 6,
#  911: 6,
#  916: 2,
#  919: 6,
#  921: 2,
#  928: 6,
#  929: 1,
#  933: 3,
#  941: 3,
#  943: 6,
#  948: 1,
#  951: 1,
#  955: 6,
#  959: 3,
#  960: 3,
#  961: 2,
#  964: 4,
#  965: 3,
#  968: 5,
#  971: 5,
#  972: 1,
#  974: 5,
#  979: 1,
#  980: 4,
#  981: 6,
#  983: 2,
#  991: 3,
#  994: 6,
#  996: 3,
#  998: 3,
#  1005: 3,
#  1007: 1,
#  1009: 6,
#  1010: 5,
#  1012: 3,
#  1015: 6,
#  1016: 3,
#  1024: 2,
#  1028: 1,
#  1031: 1,
#  1036: 3,
#  1038: 5,
#  1040: 5,
#  1042: 4,
#  1043: 3,
#  1047: 2,
#  1054: 4,
#  1062: 6,
#  1063: 2,
#  1067: 5,
#  1068: 3,
#  1073: 6,
#  1074: 3,
#  1080: 5,
#  1083: 5,
#  1085: 2,
#  1091: 6,
#  1092: 6,
#  1094: 2,
#  1099: 2,
#  1101: 5,
#  1105: 6,
#  1107: 2,
#  1116: 5,
#  1120: 2,
#  1122: 3,
#  1125: 2,
#  1132: 6,
#  1133: 1,
#  1134: 3,
#  1136: 3,
#  1137: 6,
#  1138: 3,
#  1149: 4,
#  1158: 5,
#  1163: 5,
#  1168: 3,
#  1169: 4,
#  1176: 4,
#  1177: 2,
#  1192: 3,
#  1195: 1,
#  1196: 5,
#  1200: 2,
#  1201: 3,
#  1202: 5,
#  1203: 2,
#  1211: 2,
#  1219: 5,
#  1225: 2,
#  1226: 6,
#  1227: 5,
#  1228: 2,
#  1229: 2,
#  1230: 3,
#  1236: 6,
#  1240: 3,
#  1241: 2,
#  1243: 6,
#  1244: 5,
#  1246: 2,
#  1248: 4,
#  1249: 3,
#  1251: 6,
#  1252: 1,
#  1255: 1,
#  1269: 2,
#  1272: 6,
#  1275: 3,
#  1277: 3,
#  1279: 3,
#  1280: 4,
#  1284: 1,
#  1287: 4,
#  1290: 4,
#  1292: 2,
#  1293: 2,
#  1300: 4,
#  1303: 2,
#  1305: 5,
#  1307: 6,
#  1309: 5,
#  1311: 6,
#  1319: 4,
#  1320: 6,
#  1322: 3,
#  1324: 2,
#  1325: 6,
#  1327: 4,
#  1331: 4,
#  1335: 6,
#  1341: 5,
#  1343: 2,
#  1348: 5,
#  1352: 6,
#  1354: 1,
#  1361: 4,
#  1365: 5,
#  1367: 4,
#  1369: 5,
#  1377: 1,
#  1379: 1,
#  1380: 2,
#  1385: 3,
#  1388: 2,
#  1389: 3,
#  1391: 5,
#  1396: 1,
#  1397: 1,
#  1398: 1,
#  1400: 2,
#  1401: 5,
#  1405: 6,
#  1411: 5,
#  1416: 6,
#  1420: 4,
#  1421: 1,
#  1429: 6,
#  1433: 1,
#  1434: 6,
#  1436: 5,
#  1437: 4,
#  1443: 2,
#  1450: 6,
#  1451: 3,
#  1452: 6,
#  1462: 1,
#  1464: 2,
#  1465: 2,
#  1467: 2,
#  1469: 5,
#  1472: 5,
#  1477: 2,
#  1482: 6,
#  1490: 4,
#  1493: 6,
#  1495: 1,
#  1497: 1,
#  1498: 6,
#  1499: 4,
#  1510: 5,
#  1511: 4,
#  1516: 5,
#  1517: 5,
#  1522: 3,
#  1523: 1,
#  1524: 2,
#  1526: 2,
#  1529: 5,
#  1530: 2,
#  1531: 1,
#  1535: 3,
#  1538: 6,
#  1542: 1,
#  1543: 1,
#  1544: 1,
#  1546: 5,
#  1547: 3,
#  1558: 2,
#  1562: 5,
#  1568: 3,
#  1571: 6,
#  1572: 5,
#  1574: 3,
#  1575: 5,
#  1582: 2,
#  1584: 3,
#  1585: 6,
#  1586: 6,
#  1587: 3,
#  1590: 3,
#  1593: 4,
#  1597: 5,
#  1599: 1,
#  1607: 1,
#  1609: 6,
#  1610: 6,
#  1612: 1,
#  1613: 6,
#  1617: 4,
#  1619: 3,
#  1622: 6,
#  1624: 4,
#  1628: 2,
#  1630: 1,
#  1635: 3,
#  1638: 2,
#  1639: 2,
#  1641: 3,
#  1643: 1,
#  1646: 3,
#  1648: 5,
#  1656: 3,
#  1659: 6,
#  1660: 3,
#  1665: 5,
#  1666: 2,
#  1669: 6,
#  1675: 2,
#  1676: 1,
#  1683: 5,
#  1690: 2,
#  1691: 2,
#  1692: 1,
#  1696: 6,
#  1697: 1,
#  1700: 1,
#  1701: 6,
#  1703: 2,
#  1726: 3,
#  1733: 4,
#  1737: 1,
#  1741: 6,
#  1745: 5,
#  1749: 4,
#  1750: 4,
#  1757: 4,
#  1761: 5,
#  1764: 3,
#  1768: 2,
#  1769: 6,
#  1776: 5,
#  1778: 1,
#  1781: 3,
#  1782: 6,
#  1784: 1,
#  1787: 6,
#  1788: 5,
#  1796: 5,
#  1797: 3,
#  1801: 3,
#  1808: 5,
#  1809: 3,
#  1812: 2,
#  1817: 4,
#  1818: 1,
#  1819: 1,
#  1824: 4,
#  1829: 4,
#  1840: 4,
#  1845: 3,
#  1846: 6,
#  1853: 3,
#  1854: 2,
#  1855: 4,
#  1858: 3,
#  1859: 5,
#  1867: 4,
#  1868: 6,
#  1871: 1,
#  1872: 5,
#  1880: 5,
#  1887: 1,
#  1889: 2,
#  1891: 1,
#  1892: 3,
#  1894: 5,
#  1899: 5,
#  1901: 4,
#  1902: 1,
#  1904: 3,
#  1906: 4,
#  1909: 3,
#  1912: 5,
#  1913: 2,
#  1914: 5,
#  1915: 3,
#  1917: 3,
#  1921: 3,
#  1922: 5,
#  1923: 4,
#  1928: 4,
#  1929: 6,
#  1931: 6,
#  1935: 4,
#  1942: 1,
#  1945: 6,
#  1951: 6,
#  1952: 5,
#  1954: 3,
#  1955: 4,
#  1956: 3,
#  1957: 3,
#  1961: 4,
#  1964: 5,
#  1968: 1,
#  1970: 4,
#  1972: 6,
#  1974: 6,
#  1977: 4,
#  1978: 5,
#  1979: 1,
#  1983: 2,
#  1984: 1,
#  1989: 6,
#  1993: 1,
#  1994: 4,
#  1995: 6,
#  1996: 4,
#  1997: 6,
#  1999: 3}

# %%
potential_unsuccessful
# Out:
# {11,
#  12,
#  23,
#  31,
#  32,
#  47,
#  66,
#  68,
#  94,
#  100,
#  102,
#  107,
#  111,
#  118,
#  119,
#  122,
#  125,
#  126,
#  127,
#  134,
#  139,
#  145,
#  148,
#  177,
#  191,
#  205,
#  210,
#  219,
#  220,
#  225,
#  260,
#  264,
#  287,
#  293,
#  300,
#  303,
#  321,
#  323,
#  330,
#  334,
#  344,
#  346,
#  350,
#  355,
#  356,
#  394,
#  406,
#  408,
#  410,
#  417,
#  422,
#  426,
#  428,
#  436,
#  438,
#  454,
#  466,
#  467,
#  469,
#  470,
#  478,
#  486,
#  488,
#  492,
#  493,
#  495,
#  508,
#  516,
#  518,
#  523,
#  531,
#  534,
#  540,
#  576,
#  580,
#  587,
#  598,
#  608,
#  621,
#  626,
#  643,
#  651,
#  661,
#  669,
#  676,
#  687,
#  689,
#  695,
#  699,
#  713,
#  755,
#  769,
#  772,
#  774,
#  775,
#  777,
#  789,
#  795,
#  799,
#  802,
#  807,
#  813,
#  819,
#  822,
#  823,
#  825,
#  826,
#  827,
#  843,
#  844,
#  847,
#  853,
#  866,
#  871,
#  879,
#  885,
#  897,
#  899,
#  904,
#  906,
#  917,
#  920,
#  928,
#  939,
#  948,
#  960,
#  961,
#  962,
#  968,
#  979,
#  981,
#  983,
#  992,
#  994,
#  997,
#  998,
#  1002,
#  1003,
#  1007,
#  1010,
#  1012,
#  1023,
#  1024,
#  1027,
#  1032,
#  1035,
#  1039,
#  1047,
#  1056,
#  1083,
#  1086,
#  1094,
#  1099,
#  1114,
#  1119,
#  1120,
#  1121,
#  1131,
#  1146,
#  1149,
#  1153,
#  1155,
#  1169,
#  1171,
#  1176,
#  1187,
#  1197,
#  1200,
#  1201,
#  1203,
#  1205,
#  1208,
#  1213,
#  1220,
#  1223,
#  1226,
#  1229,
#  1237,
#  1243,
#  1248,
#  1249,
#  1255,
#  1285,
#  1296,
#  1311,
#  1325,
#  1327,
#  1344,
#  1350,
#  1367,
#  1379,
#  1384,
#  1398,
#  1401,
#  1416,
#  1430,
#  1442,
#  1449,
#  1462,
#  1464,
#  1472,
#  1473,
#  1477,
#  1490,
#  1493,
#  1494,
#  1503,
#  1523,
#  1533,
#  1539,
#  1540,
#  1544,
#  1546,
#  1554,
#  1556,
#  1571,
#  1575,
#  1593,
#  1610,
#  1628,
#  1633,
#  1644,
#  1646,
#  1647,
#  1652,
#  1655,
#  1666,
#  1670,
#  1671,
#  1681,
#  1683,
#  1691,
#  1694,
#  1701,
#  1711,
#  1724,
#  1726,
#  1739,
#  1742,
#  1747,
#  1755,
#  1757,
#  1759,
#  1766,
#  1768,
#  1771,
#  1775,
#  1782,
#  1786,
#  1793,
#  1803,
#  1809,
#  1819,
#  1830,
#  1859,
#  1863,
#  1867,
#  1868,
#  1880,
#  1884,
#  1887,
#  1890,
#  1909,
#  1914,
#  1917,
#  1935,
#  1938,
#  1943,
#  1952,
#  1954,
#  1956,
#  1978,
#  1983,
#  1994,
#  1995,
#  1996}

# %%
unsuccessful_deliveries = {}
fail_cnt = 10

cur_req = 0
cur_fail_reqs = 0

for k, v in legs.items():
    to_ret = {}
    to_ret['request_id'] = k[0]
    
    to_ret['leg_id'] = k[1]
    if cur_req == to_ret['request_id']:
        cur_fail_reqs += 1
    else:
        if fail_cnt == 0:
            break
        fail_cnt -= 1
        cur_req = to_ret['request_id']
        cur_fail_reqs = 0
    
    if cur_fail_reqs >= 3:
        continue
    
    to_ret["reason"] = get_random_string(32)
    
    # Are there any constraints?
    to_ret["attempt_time"] = v['start_time'] + timedelta(hours=get_random_int_to(1,12))
    
    unsuccessful_deliveries[k] = to_ret
    

unsuccessful_deliveries
# Out:
# {(11, 1): {'request_id': 11,
#   'leg_id': 1,
#   'reason': 'asdTWDciwEreMSQfvopmFOsbwgEtLndb',
#   'attempt_time': datetime.datetime(1982, 8, 28, 23, 1, 49)},
#  (11, 2): {'request_id': 11,
#   'leg_id': 2,
#   'reason': 'FQKpFznocLQqTZhdvdFqUJChtFyoshho',
#   'attempt_time': datetime.datetime(1982, 8, 29, 19, 1, 49)},
#  (11, 3): {'request_id': 11,
#   'leg_id': 3,
#   'reason': 'AtuYgelKAtjRMTQOFXBgUwwpeGBLtwMT',
#   'attempt_time': datetime.datetime(1982, 8, 30, 9, 1, 49)},
#  (13, 1): {'request_id': 13,
#   'leg_id': 1,
#   'reason': 'DggCquFKiSHilJzhrHaytaGpyaJpDlAk',
#   'attempt_time': datetime.datetime(1995, 4, 21, 3, 58, 24)},
#  (13, 2): {'request_id': 13,
#   'leg_id': 2,
#   'reason': 'GkJrLojnRQXlHwiCovIkIkWzgIFWEACY',
#   'attempt_time': datetime.datetime(1995, 4, 21, 11, 58, 24)},
#  (13, 3): {'request_id': 13,
#   'leg_id': 3,
#   'reason': 'szRbMKrMPlnWOWYDDyowHMYDsJGEcPKk',
#   'attempt_time': datetime.datetime(1995, 4, 21, 21, 58, 24)},
#  (15, 1): {'request_id': 15,
#   'leg_id': 1,
#   'reason': 'zRiDFMmUqVjFPSRkaGtfjQlMXzEWOZAa',
#   'attempt_time': datetime.datetime(1970, 9, 12, 20, 3, 3)},
#  (19, 1): {'request_id': 19,
#   'leg_id': 1,
#   'reason': 'IckwbrzIpthNtlNIlggzNAMaEymAQuMy',
#   'attempt_time': datetime.datetime(1997, 3, 12, 7, 12, 5)},
#  (19, 2): {'request_id': 19,
#   'leg_id': 2,
#   'reason': 'MRsFstCDiBDlqMVCQNhXJECOrFyLNFrP',
#   'attempt_time': datetime.datetime(1997, 3, 12, 13, 12, 5)},
#  (19, 3): {'request_id': 19,
#   'leg_id': 3,
#   'reason': 'CeiOEkSGxHPgGfSNObcPUavXPurtHiKJ',
#   'attempt_time': datetime.datetime(1997, 3, 13, 1, 12, 5)},
#  (23, 1): {'request_id': 23,
#   'leg_id': 1,
#   'reason': 'HAZldSDptVATriuXehpYBXsNDYvbzNLV',
#   'attempt_time': datetime.datetime(1991, 5, 12, 18, 31, 53)},
#  (23, 2): {'request_id': 23,
#   'leg_id': 2,
#   'reason': 'DUPIHMzOxYmtKyfdWgqzlikjOVFjlqKJ',
#   'attempt_time': datetime.datetime(1991, 5, 13, 1, 31, 53)},
#  (23, 3): {'request_id': 23,
#   'leg_id': 3,
#   'reason': 'dmavmQQbINGteLsrUdsOjVSVGTTShOAx',
#   'attempt_time': datetime.datetime(1991, 5, 13, 4, 31, 53)},
#  (24, 1): {'request_id': 24,
#   'leg_id': 1,
#   'reason': 'WKNJgehIctPnloukLpKnJLIKpuejzEcN',
#   'attempt_time': datetime.datetime(1983, 1, 28, 1, 10, 9)},
#  (24, 2): {'request_id': 24,
#   'leg_id': 2,
#   'reason': 'vgrHzCyHVWNgLRKvfzNDdqsJIiOaKMCw',
#   'attempt_time': datetime.datetime(1983, 1, 28, 8, 10, 9)},
#  (24, 3): {'request_id': 24,
#   'leg_id': 3,
#   'reason': 'bbxETvKecsyDZWJFpIQuLdfINmWfrwNl',
#   'attempt_time': datetime.datetime(1983, 1, 29, 2, 10, 9)},
#  (27, 1): {'request_id': 27,
#   'leg_id': 1,
#   'reason': 'RCFUHaSasKRosJENqsDCrNRjpXQchnms',
#   'attempt_time': datetime.datetime(1982, 2, 14, 13, 14, 29)},
#  (27, 2): {'request_id': 27,
#   'leg_id': 2,
#   'reason': 'QxFZKFWhnPAECXfukciPfHKybcqJHMtB',
#   'attempt_time': datetime.datetime(1982, 2, 15, 8, 14, 29)},
#  (27, 3): {'request_id': 27,
#   'leg_id': 3,
#   'reason': 'vLsKXgFanJtELlMjmFeaWTtcsBJjMWwW',
#   'attempt_time': datetime.datetime(1982, 2, 15, 20, 14, 29)},
#  (28, 1): {'request_id': 28,
#   'leg_id': 1,
#   'reason': 'oppfhpZkPLyASTIrDUuPbXeZxENtVCbx',
#   'attempt_time': datetime.datetime(2007, 6, 17, 19, 49, 1)},
#  (28, 2): {'request_id': 28,
#   'leg_id': 2,
#   'reason': 'jjTYsjwkzrSExqCVRWLkOgtCnXEkOXxZ',
#   'attempt_time': datetime.datetime(2007, 6, 18, 17, 49, 1)},
#  (28, 3): {'request_id': 28,
#   'leg_id': 3,
#   'reason': 'dqxVECeesyThBTzeWbStnWDqmOliuTgT',
#   'attempt_time': datetime.datetime(2007, 6, 19, 1, 49, 1)},
#  (30, 1): {'request_id': 30,
#   'leg_id': 1,
#   'reason': 'QNdTuFXwaIcRwTpOmBAaApsqabeRWyKN',
#   'attempt_time': datetime.datetime(1977, 3, 10, 1, 5, 33)},
#  (30, 2): {'request_id': 30,
#   'leg_id': 2,
#   'reason': 'gDaphvGUCQEirMbifchchwWEpTXtsPoI',
#   'attempt_time': datetime.datetime(1977, 3, 10, 17, 5, 33)},
#  (31, 1): {'request_id': 31,
#   'leg_id': 1,
#   'reason': 'dDuhdYUvBqDBmzCUHkCquuTjLiLMNVkC',
#   'attempt_time': datetime.datetime(2016, 4, 1, 22, 22, 33)},
#  (31, 2): {'request_id': 31,
#   'leg_id': 2,
#   'reason': 'chuqenLMPRMfTUemmIONUNeGeoPjtxtL',
#   'attempt_time': datetime.datetime(2016, 4, 2, 14, 22, 33)},
#  (31, 3): {'request_id': 31,
#   'leg_id': 3,
#   'reason': 'yNjSGKBZXuSwzitYftwwXMcHWCewDAlR',
#   'attempt_time': datetime.datetime(2016, 4, 3, 7, 22, 33)}}

# %%
unsuccessful_deliveries.keys()
# Out:
# dict_keys([(11, 1), (11, 2), (11, 3), (13, 1), (13, 2), (13, 3), (15, 1), (19, 1), (19, 2), (19, 3), (23, 1), (23, 2), (23, 3), (24, 1), (24, 2), (24, 3), (27, 1), (27, 2), (27, 3), (28, 1), (28, 2), (28, 3), (30, 1), (30, 2), (31, 1), (31, 2), (31, 3)])

# %%
return_legs = {}
for request_id in cancelled_or_unsuccessful_requests_id:
    if (random.choice([True,False]) and request_id in req_to_last_leg):
        current_timestamp = random_timestamp()
        status = delivery_requests[request_id]['status']
        if (is_cancelled(status)):
            current_timestamp = delivery_requests[request_id]['cancel_time']
            current_timestamp += timedelta(hours=get_random_int_to(1,12))
            
        last_leg = req_to_last_leg[request_id]
#         print(legs[(request_id, last_leg)])
        last_end_time = legs[(request_id, last_leg)]['end_time']
#         print(f"last_end_time: {last_end_time}")
        if last_end_time == None:
            continue
            
        for leg_id in range(1, get_random_int_to(2, 6)):
#             print(f"current_timestamp: {current_timestamp}")
            if (last_end_time >= current_timestamp):
                break
            to_add = {}
            this_id = (request_id, leg_id)
            # Check if need to match the pickup handler's id
            to_add['request_id'] = request_id
            to_add['leg_id'] = leg_id
            to_add['handler_id'] = random.choice(list(delivery_staff_id))
            to_add['start_time'] = current_timestamp
            current_timestamp += timedelta(hours=get_random_int_to(1,12))
            to_add['end_time'] = current_timestamp
            to_add['source_facility'] = random.choice(list(facilities.keys()))
            return_legs[this_id] = to_add
            
return_legs
# Out:
# {(189, 1): {'request_id': 189,
#   'leg_id': 1,
#   'handler_id': 9,
#   'start_time': datetime.datetime(2001, 2, 22, 6, 28, 46),
#   'end_time': datetime.datetime(2001, 2, 22, 13, 28, 46),
#   'source_facility': 10},
#  (189, 2): {'request_id': 189,
#   'leg_id': 2,
#   'handler_id': 5,
#   'start_time': datetime.datetime(2001, 2, 22, 13, 28, 46),
#   'end_time': datetime.datetime(2001, 2, 22, 18, 28, 46),
#   'source_facility': 9},
#  (189, 3): {'request_id': 189,
#   'leg_id': 3,
#   'handler_id': 2,
#   'start_time': datetime.datetime(2001, 2, 22, 18, 28, 46),
#   'end_time': datetime.datetime(2001, 2, 22, 22, 28, 46),
#   'source_facility': 4},
#  (189, 4): {'request_id': 189,
#   'leg_id': 4,
#   'handler_id': 3,
#   'start_time': datetime.datetime(2001, 2, 22, 22, 28, 46),
#   'end_time': datetime.datetime(2001, 2, 23, 9, 28, 46),
#   'source_facility': 6},
#  (269, 1): {'request_id': 269,
#   'leg_id': 1,
#   'handler_id': 1,
#   'start_time': datetime.datetime(2003, 6, 30, 15, 23, 51),
#   'end_time': datetime.datetime(2003, 7, 1, 1, 23, 51),
#   'source_facility': 6},
#  (300, 1): {'request_id': 300,
#   'leg_id': 1,
#   'handler_id': 5,
#   'start_time': datetime.datetime(1993, 3, 19, 2, 36, 27),
#   'end_time': datetime.datetime(1993, 3, 19, 4, 36, 27),
#   'source_facility': 9},
#  (300, 2): {'request_id': 300,
#   'leg_id': 2,
#   'handler_id': 10,
#   'start_time': datetime.datetime(1993, 3, 19, 4, 36, 27),
#   'end_time': datetime.datetime(1993, 3, 19, 5, 36, 27),
#   'source_facility': 5},
#  (300, 3): {'request_id': 300,
#   'leg_id': 3,
#   'handler_id': 1,
#   'start_time': datetime.datetime(1993, 3, 19, 5, 36, 27),
#   'end_time': datetime.datetime(1993, 3, 19, 9, 36, 27),
#   'source_facility': 7},
#  (300, 4): {'request_id': 300,
#   'leg_id': 4,
#   'handler_id': 4,
#   'start_time': datetime.datetime(1993, 3, 19, 9, 36, 27),
#   'end_time': datetime.datetime(1993, 3, 19, 19, 36, 27),
#   'source_facility': 2},
#  (709, 1): {'request_id': 709,
#   'leg_id': 1,
#   'handler_id': 10,
#   'start_time': datetime.datetime(2004, 11, 26, 0, 28, 24),
#   'end_time': datetime.datetime(2004, 11, 26, 4, 28, 24),
#   'source_facility': 10},
#  (709, 2): {'request_id': 709,
#   'leg_id': 2,
#   'handler_id': 2,
#   'start_time': datetime.datetime(2004, 11, 26, 4, 28, 24),
#   'end_time': datetime.datetime(2004, 11, 26, 5, 28, 24),
#   'source_facility': 7},
#  (709, 3): {'request_id': 709,
#   'leg_id': 3,
#   'handler_id': 9,
#   'start_time': datetime.datetime(2004, 11, 26, 5, 28, 24),
#   'end_time': datetime.datetime(2004, 11, 26, 12, 28, 24),
#   'source_facility': 7},
#  (844, 1): {'request_id': 844,
#   'leg_id': 1,
#   'handler_id': 6,
#   'start_time': datetime.datetime(2022, 5, 20, 8, 25, 41),
#   'end_time': datetime.datetime(2022, 5, 20, 10, 25, 41),
#   'source_facility': 5},
#  (844, 2): {'request_id': 844,
#   'leg_id': 2,
#   'handler_id': 10,
#   'start_time': datetime.datetime(2022, 5, 20, 10, 25, 41),
#   'end_time': datetime.datetime(2022, 5, 20, 16, 25, 41),
#   'source_facility': 6},
#  (844, 3): {'request_id': 844,
#   'leg_id': 3,
#   'handler_id': 8,
#   'start_time': datetime.datetime(2022, 5, 20, 16, 25, 41),
#   'end_time': datetime.datetime(2022, 5, 20, 18, 25, 41),
#   'source_facility': 1},
#  (844, 4): {'request_id': 844,
#   'leg_id': 4,
#   'handler_id': 2,
#   'start_time': datetime.datetime(2022, 5, 20, 18, 25, 41),
#   'end_time': datetime.datetime(2022, 5, 21, 4, 25, 41),
#   'source_facility': 7},
#  (951, 1): {'request_id': 951,
#   'leg_id': 1,
#   'handler_id': 8,
#   'start_time': datetime.datetime(1999, 12, 30, 9, 59, 7),
#   'end_time': datetime.datetime(1999, 12, 30, 17, 59, 7),
#   'source_facility': 4},
#  (951, 2): {'request_id': 951,
#   'leg_id': 2,
#   'handler_id': 7,
#   'start_time': datetime.datetime(1999, 12, 30, 17, 59, 7),
#   'end_time': datetime.datetime(1999, 12, 31, 2, 59, 7),
#   'source_facility': 6},
#  (951, 3): {'request_id': 951,
#   'leg_id': 3,
#   'handler_id': 5,
#   'start_time': datetime.datetime(1999, 12, 31, 2, 59, 7),
#   'end_time': datetime.datetime(1999, 12, 31, 12, 59, 7),
#   'source_facility': 9},
#  (951, 4): {'request_id': 951,
#   'leg_id': 4,
#   'handler_id': 9,
#   'start_time': datetime.datetime(1999, 12, 31, 12, 59, 7),
#   'end_time': datetime.datetime(1999, 12, 31, 16, 59, 7),
#   'source_facility': 9},
#  (981, 1): {'request_id': 981,
#   'leg_id': 1,
#   'handler_id': 7,
#   'start_time': datetime.datetime(1986, 5, 7, 11, 31, 19),
#   'end_time': datetime.datetime(1986, 5, 7, 23, 31, 19),
#   'source_facility': 10},
#  (981, 2): {'request_id': 981,
#   'leg_id': 2,
#   'handler_id': 6,
#   'start_time': datetime.datetime(1986, 5, 7, 23, 31, 19),
#   'end_time': datetime.datetime(1986, 5, 8, 2, 31, 19),
#   'source_facility': 2},
#  (1016, 1): {'request_id': 1016,
#   'leg_id': 1,
#   'handler_id': 6,
#   'start_time': datetime.datetime(2016, 9, 25, 15, 23, 32),
#   'end_time': datetime.datetime(2016, 9, 25, 23, 23, 32),
#   'source_facility': 9},
#  (1016, 2): {'request_id': 1016,
#   'leg_id': 2,
#   'handler_id': 5,
#   'start_time': datetime.datetime(2016, 9, 25, 23, 23, 32),
#   'end_time': datetime.datetime(2016, 9, 26, 1, 23, 32),
#   'source_facility': 10},
#  (1016, 3): {'request_id': 1016,
#   'leg_id': 3,
#   'handler_id': 6,
#   'start_time': datetime.datetime(2016, 9, 26, 1, 23, 32),
#   'end_time': datetime.datetime(2016, 9, 26, 10, 23, 32),
#   'source_facility': 4},
#  (1192, 1): {'request_id': 1192,
#   'leg_id': 1,
#   'handler_id': 9,
#   'start_time': datetime.datetime(2009, 10, 21, 1, 43, 14),
#   'end_time': datetime.datetime(2009, 10, 21, 10, 43, 14),
#   'source_facility': 4},
#  (1192, 2): {'request_id': 1192,
#   'leg_id': 2,
#   'handler_id': 4,
#   'start_time': datetime.datetime(2009, 10, 21, 10, 43, 14),
#   'end_time': datetime.datetime(2009, 10, 21, 11, 43, 14),
#   'source_facility': 2},
#  (1227, 1): {'request_id': 1227,
#   'leg_id': 1,
#   'handler_id': 3,
#   'start_time': datetime.datetime(1998, 4, 12, 20, 2, 7),
#   'end_time': datetime.datetime(1998, 4, 12, 21, 2, 7),
#   'source_facility': 10},
#  (1227, 2): {'request_id': 1227,
#   'leg_id': 2,
#   'handler_id': 1,
#   'start_time': datetime.datetime(1998, 4, 12, 21, 2, 7),
#   'end_time': datetime.datetime(1998, 4, 13, 5, 2, 7),
#   'source_facility': 1},
#  (1227, 3): {'request_id': 1227,
#   'leg_id': 3,
#   'handler_id': 4,
#   'start_time': datetime.datetime(1998, 4, 13, 5, 2, 7),
#   'end_time': datetime.datetime(1998, 4, 13, 9, 2, 7),
#   'source_facility': 4},
#  (1227, 4): {'request_id': 1227,
#   'leg_id': 4,
#   'handler_id': 7,
#   'start_time': datetime.datetime(1998, 4, 13, 9, 2, 7),
#   'end_time': datetime.datetime(1998, 4, 13, 16, 2, 7),
#   'source_facility': 4},
#  (1228, 1): {'request_id': 1228,
#   'leg_id': 1,
#   'handler_id': 1,
#   'start_time': datetime.datetime(2001, 9, 22, 11, 5, 5),
#   'end_time': datetime.datetime(2001, 9, 22, 17, 5, 5),
#   'source_facility': 6},
#  (1228, 2): {'request_id': 1228,
#   'leg_id': 2,
#   'handler_id': 9,
#   'start_time': datetime.datetime(2001, 9, 22, 17, 5, 5),
#   'end_time': datetime.datetime(2001, 9, 22, 22, 5, 5),
#   'source_facility': 1},
#  (1228, 3): {'request_id': 1228,
#   'leg_id': 3,
#   'handler_id': 5,
#   'start_time': datetime.datetime(2001, 9, 22, 22, 5, 5),
#   'end_time': datetime.datetime(2001, 9, 23, 3, 5, 5),
#   'source_facility': 6},
#  (1305, 1): {'request_id': 1305,
#   'leg_id': 1,
#   'handler_id': 2,
#   'start_time': datetime.datetime(1983, 11, 20, 20, 51, 19),
#   'end_time': datetime.datetime(1983, 11, 21, 7, 51, 19),
#   'source_facility': 3},
#  (1305, 2): {'request_id': 1305,
#   'leg_id': 2,
#   'handler_id': 2,
#   'start_time': datetime.datetime(1983, 11, 21, 7, 51, 19),
#   'end_time': datetime.datetime(1983, 11, 21, 19, 51, 19),
#   'source_facility': 7},
#  (1307, 1): {'request_id': 1307,
#   'leg_id': 1,
#   'handler_id': 2,
#   'start_time': datetime.datetime(2022, 8, 10, 23, 9, 18),
#   'end_time': datetime.datetime(2022, 8, 11, 9, 9, 18),
#   'source_facility': 8},
#  (1307, 2): {'request_id': 1307,
#   'leg_id': 2,
#   'handler_id': 6,
#   'start_time': datetime.datetime(2022, 8, 11, 9, 9, 18),
#   'end_time': datetime.datetime(2022, 8, 11, 20, 9, 18),
#   'source_facility': 2},
#  (1307, 3): {'request_id': 1307,
#   'leg_id': 3,
#   'handler_id': 8,
#   'start_time': datetime.datetime(2022, 8, 11, 20, 9, 18),
#   'end_time': datetime.datetime(2022, 8, 11, 21, 9, 18),
#   'source_facility': 10},
#  (1307, 4): {'request_id': 1307,
#   'leg_id': 4,
#   'handler_id': 3,
#   'start_time': datetime.datetime(2022, 8, 11, 21, 9, 18),
#   'end_time': datetime.datetime(2022, 8, 11, 23, 9, 18),
#   'source_facility': 4},
#  (1377, 1): {'request_id': 1377,
#   'leg_id': 1,
#   'handler_id': 3,
#   'start_time': datetime.datetime(1999, 10, 24, 6, 32, 48),
#   'end_time': datetime.datetime(1999, 10, 24, 7, 32, 48),
#   'source_facility': 4},
#  (1377, 2): {'request_id': 1377,
#   'leg_id': 2,
#   'handler_id': 1,
#   'start_time': datetime.datetime(1999, 10, 24, 7, 32, 48),
#   'end_time': datetime.datetime(1999, 10, 24, 14, 32, 48),
#   'source_facility': 4},
#  (1377, 3): {'request_id': 1377,
#   'leg_id': 3,
#   'handler_id': 1,
#   'start_time': datetime.datetime(1999, 10, 24, 14, 32, 48),
#   'end_time': datetime.datetime(1999, 10, 25, 0, 32, 48),
#   'source_facility': 10},
#  (1377, 4): {'request_id': 1377,
#   'leg_id': 4,
#   'handler_id': 5,
#   'start_time': datetime.datetime(1999, 10, 25, 0, 32, 48),
#   'end_time': datetime.datetime(1999, 10, 25, 11, 32, 48),
#   'source_facility': 7},
#  (1377, 5): {'request_id': 1377,
#   'leg_id': 5,
#   'handler_id': 5,
#   'start_time': datetime.datetime(1999, 10, 25, 11, 32, 48),
#   'end_time': datetime.datetime(1999, 10, 25, 14, 32, 48),
#   'source_facility': 1},
#  (1398, 1): {'request_id': 1398,
#   'leg_id': 1,
#   'handler_id': 8,
#   'start_time': datetime.datetime(2000, 1, 25, 14, 35, 18),
#   'end_time': datetime.datetime(2000, 1, 25, 23, 35, 18),
#   'source_facility': 2},
#  (1398, 2): {'request_id': 1398,
#   'leg_id': 2,
#   'handler_id': 10,
#   'start_time': datetime.datetime(2000, 1, 25, 23, 35, 18),
#   'end_time': datetime.datetime(2000, 1, 26, 11, 35, 18),
#   'source_facility': 7},
#  (1429, 1): {'request_id': 1429,
#   'leg_id': 1,
#   'handler_id': 4,
#   'start_time': datetime.datetime(2016, 3, 26, 2, 48, 42),
#   'end_time': datetime.datetime(2016, 3, 26, 11, 48, 42),
#   'source_facility': 4},
#  (1429, 2): {'request_id': 1429,
#   'leg_id': 2,
#   'handler_id': 5,
#   'start_time': datetime.datetime(2016, 3, 26, 11, 48, 42),
#   'end_time': datetime.datetime(2016, 3, 26, 18, 48, 42),
#   'source_facility': 7},
#  (1429, 3): {'request_id': 1429,
#   'leg_id': 3,
#   'handler_id': 7,
#   'start_time': datetime.datetime(2016, 3, 26, 18, 48, 42),
#   'end_time': datetime.datetime(2016, 3, 27, 1, 48, 42),
#   'source_facility': 8},
#  (1429, 4): {'request_id': 1429,
#   'leg_id': 4,
#   'handler_id': 8,
#   'start_time': datetime.datetime(2016, 3, 27, 1, 48, 42),
#   'end_time': datetime.datetime(2016, 3, 27, 11, 48, 42),
#   'source_facility': 8},
#  (1490, 1): {'request_id': 1490,
#   'leg_id': 1,
#   'handler_id': 4,
#   'start_time': datetime.datetime(2011, 3, 3, 4, 12, 48),
#   'end_time': datetime.datetime(2011, 3, 3, 16, 12, 48),
#   'source_facility': 5},
#  (1490, 2): {'request_id': 1490,
#   'leg_id': 2,
#   'handler_id': 3,
#   'start_time': datetime.datetime(2011, 3, 3, 16, 12, 48),
#   'end_time': datetime.datetime(2011, 3, 4, 1, 12, 48),
#   'source_facility': 7},
#  (1490, 3): {'request_id': 1490,
#   'leg_id': 3,
#   'handler_id': 4,
#   'start_time': datetime.datetime(2011, 3, 4, 1, 12, 48),
#   'end_time': datetime.datetime(2011, 3, 4, 8, 12, 48),
#   'source_facility': 1},
#  (1490, 4): {'request_id': 1490,
#   'leg_id': 4,
#   'handler_id': 3,
#   'start_time': datetime.datetime(2011, 3, 4, 8, 12, 48),
#   'end_time': datetime.datetime(2011, 3, 4, 9, 12, 48),
#   'source_facility': 9},
#  (1544, 1): {'request_id': 1544,
#   'leg_id': 1,
#   'handler_id': 1,
#   'start_time': datetime.datetime(1985, 8, 17, 11, 10, 7),
#   'end_time': datetime.datetime(1985, 8, 17, 12, 10, 7),
#   'source_facility': 3},
#  (1558, 1): {'request_id': 1558,
#   'leg_id': 1,
#   'handler_id': 1,
#   'start_time': datetime.datetime(1999, 5, 5, 1, 42, 41),
#   'end_time': datetime.datetime(1999, 5, 5, 2, 42, 41),
#   'source_facility': 8},
#  (1586, 1): {'request_id': 1586,
#   'leg_id': 1,
#   'handler_id': 3,
#   'start_time': datetime.datetime(2007, 6, 24, 3, 28, 7),
#   'end_time': datetime.datetime(2007, 6, 24, 10, 28, 7),
#   'source_facility': 7},
#  (1586, 2): {'request_id': 1586,
#   'leg_id': 2,
#   'handler_id': 4,
#   'start_time': datetime.datetime(2007, 6, 24, 10, 28, 7),
#   'end_time': datetime.datetime(2007, 6, 24, 11, 28, 7),
#   'source_facility': 7},
#  (1586, 3): {'request_id': 1586,
#   'leg_id': 3,
#   'handler_id': 2,
#   'start_time': datetime.datetime(2007, 6, 24, 11, 28, 7),
#   'end_time': datetime.datetime(2007, 6, 24, 14, 28, 7),
#   'source_facility': 7},
#  (1624, 1): {'request_id': 1624,
#   'leg_id': 1,
#   'handler_id': 3,
#   'start_time': datetime.datetime(2010, 11, 2, 21, 26, 46),
#   'end_time': datetime.datetime(2010, 11, 3, 8, 26, 46),
#   'source_facility': 4},
#  (1675, 1): {'request_id': 1675,
#   'leg_id': 1,
#   'handler_id': 6,
#   'start_time': datetime.datetime(1991, 12, 6, 1, 43, 5),
#   'end_time': datetime.datetime(1991, 12, 6, 4, 43, 5),
#   'source_facility': 6},
#  (1675, 2): {'request_id': 1675,
#   'leg_id': 2,
#   'handler_id': 10,
#   'start_time': datetime.datetime(1991, 12, 6, 4, 43, 5),
#   'end_time': datetime.datetime(1991, 12, 6, 12, 43, 5),
#   'source_facility': 1},
#  (1675, 3): {'request_id': 1675,
#   'leg_id': 3,
#   'handler_id': 6,
#   'start_time': datetime.datetime(1991, 12, 6, 12, 43, 5),
#   'end_time': datetime.datetime(1991, 12, 6, 22, 43, 5),
#   'source_facility': 1},
#  (1904, 1): {'request_id': 1904,
#   'leg_id': 1,
#   'handler_id': 6,
#   'start_time': datetime.datetime(1988, 11, 14, 9, 45, 52),
#   'end_time': datetime.datetime(1988, 11, 14, 13, 45, 52),
#   'source_facility': 3},
#  (1917, 1): {'request_id': 1917,
#   'leg_id': 1,
#   'handler_id': 3,
#   'start_time': datetime.datetime(1992, 12, 18, 2, 22, 5),
#   'end_time': datetime.datetime(1992, 12, 18, 3, 22, 5),
#   'source_facility': 10},
#  (1917, 2): {'request_id': 1917,
#   'leg_id': 2,
#   'handler_id': 4,
#   'start_time': datetime.datetime(1992, 12, 18, 3, 22, 5),
#   'end_time': datetime.datetime(1992, 12, 18, 10, 22, 5),
#   'source_facility': 8}}

# %%
unsuccessful_return_deliveries = {}

for k,v in return_legs.items():
    to_add={}
    to_add['request_id'] = k[0]
    to_add['leg_id'] = k[1]
    to_add["reason"] = get_random_string(32)
    
    # Are there any constraints?
    to_add["attempt_time"] = v['start_time'] + timedelta(hours=get_random_int_to(1,12))
    
    
    unsuccessful_return_deliveries[k] = to_add

unsuccessful_return_deliveries
# Out:
# {(189, 1): {'request_id': 189,
#   'leg_id': 1,
#   'reason': 'JoQhfJVHYyTAllrKFmLGOAuEwNBCjuKK',
#   'attempt_time': datetime.datetime(2001, 2, 22, 15, 28, 46)},
#  (189, 2): {'request_id': 189,
#   'leg_id': 2,
#   'reason': 'QIVCURfbChyzCCACuTdtHQMdIxnODNWS',
#   'attempt_time': datetime.datetime(2001, 2, 22, 15, 28, 46)},
#  (189, 3): {'request_id': 189,
#   'leg_id': 3,
#   'reason': 'SCaPhlmMvRsHGCfesPyHeQwqQXmyOhuE',
#   'attempt_time': datetime.datetime(2001, 2, 22, 23, 28, 46)},
#  (189, 4): {'request_id': 189,
#   'leg_id': 4,
#   'reason': 'BfGMGZJRtNhKuyGEWBvsHVzleiiMbyHh',
#   'attempt_time': datetime.datetime(2001, 2, 23, 6, 28, 46)},
#  (269, 1): {'request_id': 269,
#   'leg_id': 1,
#   'reason': 'RcXhpIrsHAocsDhjdsMCWIQUsjlzymPP',
#   'attempt_time': datetime.datetime(2003, 6, 30, 17, 23, 51)},
#  (300, 1): {'request_id': 300,
#   'leg_id': 1,
#   'reason': 'YZmJFzBfBiLCAIfCDcyqqaQsMALQhWHG',
#   'attempt_time': datetime.datetime(1993, 3, 19, 5, 36, 27)},
#  (300, 2): {'request_id': 300,
#   'leg_id': 2,
#   'reason': 'bozllyqRlwQqjInReaAkOoWldRkupwLS',
#   'attempt_time': datetime.datetime(1993, 3, 19, 13, 36, 27)},
#  (300, 3): {'request_id': 300,
#   'leg_id': 3,
#   'reason': 'nglJQMUAZoogphRpfoReNpkhpUIpEDfa',
#   'attempt_time': datetime.datetime(1993, 3, 19, 10, 36, 27)},
#  (300, 4): {'request_id': 300,
#   'leg_id': 4,
#   'reason': 'UrYhbUxWmCrpwuYtqmYFciHsnkRQAUAK',
#   'attempt_time': datetime.datetime(1993, 3, 19, 21, 36, 27)},
#  (709, 1): {'request_id': 709,
#   'leg_id': 1,
#   'reason': 'euHQeorKlQxkawwtYZRdFRjmIUsIZzjR',
#   'attempt_time': datetime.datetime(2004, 11, 26, 3, 28, 24)},
#  (709, 2): {'request_id': 709,
#   'leg_id': 2,
#   'reason': 'AlbyGuXsaZDvtkGQTbPTDsKBkRLblyxM',
#   'attempt_time': datetime.datetime(2004, 11, 26, 13, 28, 24)},
#  (709, 3): {'request_id': 709,
#   'leg_id': 3,
#   'reason': 'uTGRdjXEBFmpazMUAIfkyFrtuMXNaOme',
#   'attempt_time': datetime.datetime(2004, 11, 26, 6, 28, 24)},
#  (844, 1): {'request_id': 844,
#   'leg_id': 1,
#   'reason': 'OzBWbdMrugowmgizvBIIUkjfOqoQjQjC',
#   'attempt_time': datetime.datetime(2022, 5, 20, 14, 25, 41)},
#  (844, 2): {'request_id': 844,
#   'leg_id': 2,
#   'reason': 'acpWwTVenkrOFnrnXCPEzYszJAugoOYi',
#   'attempt_time': datetime.datetime(2022, 5, 20, 14, 25, 41)},
#  (844, 3): {'request_id': 844,
#   'leg_id': 3,
#   'reason': 'liAudtKStEtHmcYrsVFGGTJXdpmRKTTv',
#   'attempt_time': datetime.datetime(2022, 5, 21, 3, 25, 41)},
#  (844, 4): {'request_id': 844,
#   'leg_id': 4,
#   'reason': 'CYcEeJnsVnOuIyYQlXnTpklrmkTSPBTK',
#   'attempt_time': datetime.datetime(2022, 5, 20, 19, 25, 41)},
#  (951, 1): {'request_id': 951,
#   'leg_id': 1,
#   'reason': 'hWhFVMyPIyDpECxjEraUpeUpEFpjPWPq',
#   'attempt_time': datetime.datetime(1999, 12, 30, 13, 59, 7)},
#  (951, 2): {'request_id': 951,
#   'leg_id': 2,
#   'reason': 'RyISFUZznDXTypGIpLVRCjnMrPOottdf',
#   'attempt_time': datetime.datetime(1999, 12, 30, 19, 59, 7)},
#  (951, 3): {'request_id': 951,
#   'leg_id': 3,
#   'reason': 'KTCsbdnaABuPwlWoUaOLkBpkBbncGZSK',
#   'attempt_time': datetime.datetime(1999, 12, 31, 3, 59, 7)},
#  (951, 4): {'request_id': 951,
#   'leg_id': 4,
#   'reason': 'kSiPUshEJBSRPJElAFClGljhactjEHKK',
#   'attempt_time': datetime.datetime(1999, 12, 31, 13, 59, 7)},
#  (981, 1): {'request_id': 981,
#   'leg_id': 1,
#   'reason': 'RdlTCzwKnfjwWXbukhnAnvBwYmgLWXOJ',
#   'attempt_time': datetime.datetime(1986, 5, 7, 21, 31, 19)},
#  (981, 2): {'request_id': 981,
#   'leg_id': 2,
#   'reason': 'LzbEQEeUsoqTAeFMAfSlbJeEfcIylIVA',
#   'attempt_time': datetime.datetime(1986, 5, 8, 1, 31, 19)},
#  (1016, 1): {'request_id': 1016,
#   'leg_id': 1,
#   'reason': 'BstkgdszzYJVYyfITmjuHNfPbLMzVlHZ',
#   'attempt_time': datetime.datetime(2016, 9, 26, 1, 23, 32)},
#  (1016, 2): {'request_id': 1016,
#   'leg_id': 2,
#   'reason': 'admjXkAfkkBnhREAaFEstdkYDOGRArkT',
#   'attempt_time': datetime.datetime(2016, 9, 26, 5, 23, 32)},
#  (1016, 3): {'request_id': 1016,
#   'leg_id': 3,
#   'reason': 'yiXaYZBRMSwfLoSBsRcIOyVbqetaXtpX',
#   'attempt_time': datetime.datetime(2016, 9, 26, 10, 23, 32)},
#  (1192, 1): {'request_id': 1192,
#   'leg_id': 1,
#   'reason': 'KmjJQRANIVuroJFikEKRmCLpPPYltAKS',
#   'attempt_time': datetime.datetime(2009, 10, 21, 10, 43, 14)},
#  (1192, 2): {'request_id': 1192,
#   'leg_id': 2,
#   'reason': 'AnUAnSYvWJimCWXwkQVrxseVvgDkqtjp',
#   'attempt_time': datetime.datetime(2009, 10, 21, 14, 43, 14)},
#  (1227, 1): {'request_id': 1227,
#   'leg_id': 1,
#   'reason': 'YVapcSdffoHsaZCTTCyvWwGNNMJmftVs',
#   'attempt_time': datetime.datetime(1998, 4, 13, 2, 2, 7)},
#  (1227, 2): {'request_id': 1227,
#   'leg_id': 2,
#   'reason': 'pxJAYwrGROBCmtasoRxepkxQuPougnJc',
#   'attempt_time': datetime.datetime(1998, 4, 13, 9, 2, 7)},
#  (1227, 3): {'request_id': 1227,
#   'leg_id': 3,
#   'reason': 'ydnjQPhCjFKgcznnYJJdUdJRrIdJpEon',
#   'attempt_time': datetime.datetime(1998, 4, 13, 10, 2, 7)},
#  (1227, 4): {'request_id': 1227,
#   'leg_id': 4,
#   'reason': 'xTwlSdyfdKqomLlJHzXktAofkaegyQAA',
#   'attempt_time': datetime.datetime(1998, 4, 13, 11, 2, 7)},
#  (1228, 1): {'request_id': 1228,
#   'leg_id': 1,
#   'reason': 'kZMGdYMjlFdcyWiDHMsyZyZgygabOuSc',
#   'attempt_time': datetime.datetime(2001, 9, 22, 12, 5, 5)},
#  (1228, 2): {'request_id': 1228,
#   'leg_id': 2,
#   'reason': 'EVGoDpjxUthueqsdqLyFDaEVqrETvTCS',
#   'attempt_time': datetime.datetime(2001, 9, 23, 4, 5, 5)},
#  (1228, 3): {'request_id': 1228,
#   'leg_id': 3,
#   'reason': 'fvGodncvPhmtRiidBLkdXbOomDeHgjJX',
#   'attempt_time': datetime.datetime(2001, 9, 22, 23, 5, 5)},
#  (1305, 1): {'request_id': 1305,
#   'leg_id': 1,
#   'reason': 'cHVdkfgVGNCyxHQejnZphZaKxjccQqvO',
#   'attempt_time': datetime.datetime(1983, 11, 21, 2, 51, 19)},
#  (1305, 2): {'request_id': 1305,
#   'leg_id': 2,
#   'reason': 'vbVOfBzFzCoClOYdCYDFOmogeSqqMHnd',
#   'attempt_time': datetime.datetime(1983, 11, 21, 12, 51, 19)},
#  (1307, 1): {'request_id': 1307,
#   'leg_id': 1,
#   'reason': 'dDLvxgBiCOVkgQmEVgBBAqvcardowMJP',
#   'attempt_time': datetime.datetime(2022, 8, 11, 9, 9, 18)},
#  (1307, 2): {'request_id': 1307,
#   'leg_id': 2,
#   'reason': 'aJPlhkSryRTgsPVqaYYpwtPVuOoloZub',
#   'attempt_time': datetime.datetime(2022, 8, 11, 15, 9, 18)},
#  (1307, 3): {'request_id': 1307,
#   'leg_id': 3,
#   'reason': 'wTaqyoFPJYKySxERYvrLMsqsBYfCstfU',
#   'attempt_time': datetime.datetime(2022, 8, 12, 3, 9, 18)},
#  (1307, 4): {'request_id': 1307,
#   'leg_id': 4,
#   'reason': 'UpoMGGWbGgVJZkEKXNWBQyEonjoZSsNG',
#   'attempt_time': datetime.datetime(2022, 8, 12, 8, 9, 18)},
#  (1377, 1): {'request_id': 1377,
#   'leg_id': 1,
#   'reason': 'jQCSOUJbQeeUFovpUjyBvwEgTnfdUBGA',
#   'attempt_time': datetime.datetime(1999, 10, 24, 14, 32, 48)},
#  (1377, 2): {'request_id': 1377,
#   'leg_id': 2,
#   'reason': 'vRZpdjlCujsNFbkgWdyFbPSmxmpsQrhC',
#   'attempt_time': datetime.datetime(1999, 10, 24, 10, 32, 48)},
#  (1377, 3): {'request_id': 1377,
#   'leg_id': 3,
#   'reason': 'zYyuuNVnwzScEiHpYZlJcNUwygTPzMos',
#   'attempt_time': datetime.datetime(1999, 10, 25, 0, 32, 48)},
#  (1377, 4): {'request_id': 1377,
#   'leg_id': 4,
#   'reason': 'WHpMTvtZdfUsQLKJXPCsiesEPvTmIVcx',
#   'attempt_time': datetime.datetime(1999, 10, 25, 1, 32, 48)},
#  (1377, 5): {'request_id': 1377,
#   'leg_id': 5,
#   'reason': 'JeLnmZmDQaTzmbgxqGylsVCKKaejeCUv',
#   'attempt_time': datetime.datetime(1999, 10, 25, 23, 32, 48)},
#  (1398, 1): {'request_id': 1398,
#   'leg_id': 1,
#   'reason': 'vwnxvHyYCiPISrCKFWiZAZRVjSUysaBs',
#   'attempt_time': datetime.datetime(2000, 1, 25, 16, 35, 18)},
#  (1398, 2): {'request_id': 1398,
#   'leg_id': 2,
#   'reason': 'cQjEKDWPSCtYdMLLbYKSqeXBqkpCepXu',
#   'attempt_time': datetime.datetime(2000, 1, 26, 0, 35, 18)},
#  (1429, 1): {'request_id': 1429,
#   'leg_id': 1,
#   'reason': 'uYEISVpGkZYqyHJsXMpkPMDGpRADoIyr',
#   'attempt_time': datetime.datetime(2016, 3, 26, 4, 48, 42)},
#  (1429, 2): {'request_id': 1429,
#   'leg_id': 2,
#   'reason': 'HcwyYviQeDmqcwjXMIdtAEvTFybwJEia',
#   'attempt_time': datetime.datetime(2016, 3, 26, 19, 48, 42)},
#  (1429, 3): {'request_id': 1429,
#   'leg_id': 3,
#   'reason': 'CYDneBdxSemYGIbxGntrqcdjWrmOmnhe',
#   'attempt_time': datetime.datetime(2016, 3, 27, 4, 48, 42)},
#  (1429, 4): {'request_id': 1429,
#   'leg_id': 4,
#   'reason': 'ZziJFCzDMfuPvRYdqNrbKsJmEZspGgUw',
#   'attempt_time': datetime.datetime(2016, 3, 27, 2, 48, 42)},
#  (1490, 1): {'request_id': 1490,
#   'leg_id': 1,
#   'reason': 'eAIwDEqXJiYXioNgoBnHuLJeEXVrplfy',
#   'attempt_time': datetime.datetime(2011, 3, 3, 5, 12, 48)},
#  (1490, 2): {'request_id': 1490,
#   'leg_id': 2,
#   'reason': 'FwlQADgocSNeVpbrraMqiDsWCRqkEqPi',
#   'attempt_time': datetime.datetime(2011, 3, 3, 17, 12, 48)},
#  (1490, 3): {'request_id': 1490,
#   'leg_id': 3,
#   'reason': 'iLRtiXbxskyjOlesYFvnfkTnDieIAawh',
#   'attempt_time': datetime.datetime(2011, 3, 4, 12, 12, 48)},
#  (1490, 4): {'request_id': 1490,
#   'leg_id': 4,
#   'reason': 'MaNvrQBVgsjsSazMvQjPREOBUrDQUhoN',
#   'attempt_time': datetime.datetime(2011, 3, 4, 12, 12, 48)},
#  (1544, 1): {'request_id': 1544,
#   'leg_id': 1,
#   'reason': 'ydUcltdAXKSsyGQObbFrawrwANziiyix',
#   'attempt_time': datetime.datetime(1985, 8, 17, 18, 10, 7)},
#  (1558, 1): {'request_id': 1558,
#   'leg_id': 1,
#   'reason': 'HooGcqVMWBqUrvEppSGJHOVZxuhRyRCZ',
#   'attempt_time': datetime.datetime(1999, 5, 5, 3, 42, 41)},
#  (1586, 1): {'request_id': 1586,
#   'leg_id': 1,
#   'reason': 'ovtQYPuVVMGICIEjdhZEaVnQxQAJUHLw',
#   'attempt_time': datetime.datetime(2007, 6, 24, 12, 28, 7)},
#  (1586, 2): {'request_id': 1586,
#   'leg_id': 2,
#   'reason': 'PaubLSkIbqYebQHQNMHWPMfFtomCgMHw',
#   'attempt_time': datetime.datetime(2007, 6, 24, 16, 28, 7)},
#  (1586, 3): {'request_id': 1586,
#   'leg_id': 3,
#   'reason': 'gDHrWFBRslsVbmBbuIbGfjnTmSLsJhJy',
#   'attempt_time': datetime.datetime(2007, 6, 24, 15, 28, 7)},
#  (1624, 1): {'request_id': 1624,
#   'leg_id': 1,
#   'reason': 'fiSjRcUDSBjxNUSyldbrrRGdrUUBPpdv',
#   'attempt_time': datetime.datetime(2010, 11, 3, 5, 26, 46)},
#  (1675, 1): {'request_id': 1675,
#   'leg_id': 1,
#   'reason': 'YspBhIDRewzxnZUTeoPqUguSmESTfSUf',
#   'attempt_time': datetime.datetime(1991, 12, 6, 11, 43, 5)},
#  (1675, 2): {'request_id': 1675,
#   'leg_id': 2,
#   'reason': 'zRSGyKZGgizKKTFMlwzVagwoaHVRFoWB',
#   'attempt_time': datetime.datetime(1991, 12, 6, 8, 43, 5)},
#  (1675, 3): {'request_id': 1675,
#   'leg_id': 3,
#   'reason': 'pwgZyTkRwddQNwqTGpbcqCdFrNTTTRAf',
#   'attempt_time': datetime.datetime(1991, 12, 6, 18, 43, 5)},
#  (1904, 1): {'request_id': 1904,
#   'leg_id': 1,
#   'reason': 'OszwyhkCakjBFdEOtoYYxZCWzLGBOfUY',
#   'attempt_time': datetime.datetime(1988, 11, 14, 15, 45, 52)},
#  (1917, 1): {'request_id': 1917,
#   'leg_id': 1,
#   'reason': 'aHRzhhVXuiIskjDdKvfyWTLZPcazJWMw',
#   'attempt_time': datetime.datetime(1992, 12, 18, 8, 22, 5)},
#  (1917, 2): {'request_id': 1917,
#   'leg_id': 2,
#   'reason': 'UfSNmHdEgdaclzUjXdCEvKErcEyltEKv',
#   'attempt_time': datetime.datetime(1992, 12, 18, 11, 22, 5)}}

# %%
have_inserted = {
    "customers": False,
    "employees": False,
    "d_staff": False,
    "d_req": False,
    "packages": False,
    "facilities": False,
    "unsuccessful_pickups": False,
    "legs": False,
    "unsuccessful_deliveries": False,
    "return_legs": False,
    "unsuccessful_return_deliveries": False,
    "accepted_requests": False,
    "c_or_u_requests": False,
    "c_requests": False,
}

# %%
conn = connect__to_database()

# %%
# Insert these shit

def insert_table(query, t_name, record):
    try:
        conn = connect__to_database()
        cur = conn.cursor()
        cur.execute(query, record)
        conn.commit()
        count = cur.rowcount
        print(f"{count} record(s) inserted successfully into {t_name} table")
    except (Exception, psycopg2.DatabaseError) as error:
        print(error)
    finally:
        cur.close()
        if conn is not None:
            conn.close()
def insert_M_table(query, t_name, recordS):
    has_error = False
    try:
        conn = connect__to_database()
        cur = conn.cursor()
        cur.executemany(query, recordS)
        conn.commit()
        count = cur.rowcount
        print(f"{count} record(s) inserted successfully into {t_name} table")
    except (Exception, psycopg2.DatabaseError) as error:
        print(f"ERROR WHILE INSERTING INTO {t_name}: {error}")
        has_error = True
    finally:
        cur.close()
        if conn is not None:
            conn.close()
        return has_error
    
def insert_M_table_no_commit(query, t_name, recordS, conn):
    
    has_error = False
    try:
        cur = conn.cursor()
        cur.executemany(query, recordS)
#         count = cur.rowcount
#         print(f"{count} record(s) inserted successfully into {t_name} table")
#     except (Exception, psycopg2.DatabaseError) as error:
#         print(f"ERROR WHILE INSERTING INTO {t_name}: {error}")
#         has_error = True
#         if conn is not None:
#             conn.close()
    finally:
        cur.close()
        return has_error
    
# 0: {'name': 'QlIDmJDlCOKjgvLf', 'gender': 'M', 'mobile': '12942917'}
def insert_customers(rows):
    rows = [(row['name'], row['gender'], row['mobile']) for row in rows]
    sql = """INSERT INTO customers(name, gender, mobile) VALUES(%s,%s,%s)"""
#     record_to_insert = (row['name'], row['gender'], row['mobile'])
    to_ret = insert_M_table_no_commit(sql, "customers", rows, conn)
    return to_ret
def insert_employees(rows):
    rows = [(row['name'], row['gender'], row['dob'], row['title'], row['salary']) for row in rows]
    sql = """INSERT INTO employees(name, gender, dob, title, salary) VALUES(%s,%s,%s,%s,%s)"""
    to_ret = insert_M_table_no_commit(sql, "employees", rows, conn)
    return to_ret

def insert_delivery_staff(ids):
    rows = [(str(employee_id),) for employee_id in ids]
    sql = """INSERT INTO delivery_staff(id) VALUES(%s)"""
    to_ret = insert_M_table_no_commit(sql, "delivery_staff", rows, conn)
    return to_ret
def insert_delivery_requests(rows):
    rows = [(
        row["customer_id"], 
        row["evaluater_id"], 
        row["status"], 
        row["pickup_addr"], 
        row["pickup_postal"], 
        row["recipient_name"], 
        row["recipient_addr"], 
        row['recipient_postal'], 
        row["submission_time"], 
        row["pickup_date"], 
        row["num_days_needed"], 
        row["price"]
    ) 
            for row in rows]
    sql = """INSERT INTO delivery_requests(customer_id, evaluater_id, status, pickup_addr, pickup_postal, recipient_name, recipient_addr, recipient_postal, submission_time, pickup_date, num_days_needed, price) VALUES(%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s)"""
    to_ret = insert_M_table_no_commit(sql, "delivery_requests", rows, conn)
    return to_ret
def insert_packages(rows):
    sql = """INSERT INTO packages(
            request_id,
            package_id,
            reported_height, 
            reported_width, 
            reported_depth, 
            reported_weight, 
            actual_height, 
            actual_width, 
            actual_depth, 
            actual_weight, 
            content, 
            estimated_value
        ) VALUES(%s,%s, %s,%s,%s,%s,%s,%s,%s,%s,%s,%s)"""
    rows = [
        (
            row["request_id"], 
            row["package_id"], 
            row["reported_height"], 
            row["reported_width"], 
            row["reported_depth"], 
            row["reported_weight"], 
            row["actual_height"], 
            row["actual_width"], 
            row["actual_depth"], 
            row['actual_weight'], 
            row["content"], 
            row["estimated_value"]
        ) for row in rows
    ]
    to_ret = insert_M_table_no_commit(sql, "packages", rows, conn)
    return to_ret

def insert_facilities(rows):
    sql = """INSERT INTO facilities(
            address,
            postal
        ) VALUES(%s,%s)"""
    rows = [
        (
            row["address"], 
            row["postal"]
        ) for row in rows
    ]
    to_ret = insert_M_table_no_commit(sql, "facilities", rows, conn)
    return to_ret

def insert_failed_pickups(rows):
    sql = """INSERT INTO unsuccessful_pickups(
            request_id,
            pickup_id,
            handler_id,
            pickup_time,
            reason
        ) VALUES(%s,%s,%s,%s,%s)"""
    rows = [
        (
            row["request_id"], 
            row["pickup_id"], 
            row["handler_id"], 
            row["pickup_time"], 
            row["reason"]
        ) for row in rows
    ]
    to_ret = insert_M_table_no_commit(sql, "unsuccessful_pickups", rows, conn)
    return to_ret

def insert_legs(rows):
    sql = """INSERT INTO legs(
            request_id,
            leg_id,
            handler_id,
            start_time,
            end_time,
            destination_facility
        ) VALUES(%s,%s,%s,%s,%s,%s)"""
    rows = [
        (
            row["request_id"], 
            str(row["leg_id"]), 
            row["handler_id"], 
            row["start_time"], 
            row["end_time"], 
            row["destination_facility"]
        ) for row in rows
    ]
    to_ret = insert_M_table_no_commit(sql, "legs", rows, conn)
    return to_ret
    
def insert_unsuccessful_deliveries(rows):
    sql = """INSERT INTO unsuccessful_deliveries(
            request_id,
            leg_id,
            attempt_time,
            reason
        ) VALUES(%s,%s,%s,%s)"""
    rows = [
        (
            row["request_id"], 
            row["leg_id"], 
            row["attempt_time"], 
            row["reason"]
        ) for row in rows
    ]
    to_ret = insert_M_table_no_commit(sql, "unsuccessful_deliveries", rows, conn)
    
def insert_return_legs(rows):
    sql = """INSERT INTO return_legs(
            request_id,
            leg_id,
            handler_id,
            start_time,
            end_time,
            source_facility
        ) VALUES(%s,%s,%s,%s,%s,%s)"""
    rows = [
        (
            str(row["request_id"]), 
            str(row["leg_id"]), 
            str(row["handler_id"]), 
            row["start_time"], 
            row["end_time"], 
            row["source_facility"]
        ) for row in rows
    ]
    to_ret = insert_M_table_no_commit(sql, "legs", rows, conn)
    return to_ret
    
def insert_u_return_deliveries(rows):
    sql = """INSERT INTO unsuccessful_return_deliveries(
            request_id,
            leg_id,
            attempt_time,
            reason
        ) VALUES(%s,%s,%s,%s)"""
    rows = [
        (
            str(row["request_id"]), 
            str(row["leg_id"]), 
            row["attempt_time"], 
            row["reason"]
        ) for row in rows
    ]
    to_ret = insert_M_table_no_commit(sql, "unsuccessful_return_deliveries", rows, conn)
    return to_ret

def insert_accepeted_requests(rows):
    sql = """INSERT INTO accepted_requests(
            id,
            card_number,
            payment_time,
            monitor_id
        ) VALUES(%s,%s,%s,%s)"""
    rows = [
        (
            str(row["id"]), 
            row["card_number"], 
            row["payment_time"], 
            row["monitor_id"]
        ) for row in rows
    ]
    to_ret = insert_M_table_no_commit(sql, "accepted_requests", rows, conn)
    return to_ret
    
def insert_c_or_u_requests(ids):
    sql = """INSERT INTO cancelled_or_unsuccessful_requests(
            id
        ) VALUES(%s)"""
    rows = [
        (
            str(c_u_id),
        ) for c_u_id in ids
    ]
    to_ret = insert_M_table_no_commit(sql, "cancelled_or_unsuccessful_requests", rows, conn)
    return to_ret

def insert_c_requests(rows):
    sql = """INSERT INTO cancelled_requests(
            id,
            cancel_time
        ) VALUES(%s,%s)"""
    rows = [
        (
            str(row["id"]), 
            row["cancel_time"]
        ) for row in rows
    ]
    to_ret = insert_M_table_no_commit(sql, "cancelled_requests", rows, conn)
    return to_ret

def test_inserts():
    if not have_inserted['customers']:
        have_inserted['customers'] = not insert_customers(customers.values())
    if not have_inserted['employees']:
        have_inserted['employees'] = not insert_employees(employee.values())
    if not have_inserted['d_staff']:
        to_insert = [k for k,v in employee.items() if v['is_delivery']]
        have_inserted['d_staff'] = not insert_delivery_staff(to_insert)
        
    if not have_inserted['d_req']:
        have_inserted['d_req'] = not insert_delivery_requests(delivery_requests.values())
    if not have_inserted['accepted_requests']:
        accepted_req_id
        have_inserted['accepted_requests'] = not insert_accepeted_requests([
          {
            "id":k,
            **v
          }  for k,v in delivery_requests.items() if k in accepted_req_id
        ])
    
    if not have_inserted['c_or_u_requests']:
        accepted_req_id
        have_inserted['c_or_u_requests'] = not insert_c_or_u_requests(list(cancelled_or_unsuccessful_requests_id))
        
    if not have_inserted['c_requests']:
        accepted_req_id
        have_inserted['c_requests'] = not insert_c_requests([
          {
            "id":k,
            "cancel_time": v['cancel_time']
          }  for k,v in delivery_requests.items() if 'cancel_time' in v
        ])
    if not have_inserted['packages']:
        have_inserted['packages'] = not insert_packages(packages.values())
    if not have_inserted['facilities']:
        have_inserted['facilities'] = not insert_facilities(facilities.values())
    if not have_inserted['unsuccessful_pickups']:
        have_inserted['unsuccessful_pickups'] = not insert_failed_pickups(failed_pickups.values())
        
    if not have_inserted['legs']:
        have_inserted['legs'] = not insert_legs([
            {
                "leg_id":k,
                **v
            } for k,v in legs.items()
        ])
        
    if not have_inserted['unsuccessful_deliveries']:
        have_inserted['unsuccessful_deliveries'] = not insert_unsuccessful_deliveries(unsuccessful_deliveries.values())
        
    if not have_inserted['return_legs']:
        have_inserted['return_legs'] = not insert_return_legs(return_legs.values())
        
    if not have_inserted['unsuccessful_return_deliveries']:
        have_inserted['unsuccessful_return_deliveries'] = not insert_u_return_deliveries(unsuccessful_return_deliveries.values())

# %%
test_inserts()
# Rmb to clear the database after runnign this

# %%
conn.commit()

# %%
conn.close()

# %%
# Unsuccessful_deliveries

"""
(11, 1): {'request_id': 11,
  'leg_id': 1,
  'reason': 'asdTWDciwEreMSQfvopmFOsbwgEtLndb',
  'attempt_time': datetime.datetime(1982, 8, 28, 23, 1, 49)}

"""

# Test Q4

pos_count = 2
neg_count = 2

conn = connect__to_database()

first = list(unsuccessful_deliveries.keys())[0]

cur_request = first[0]
cur_leg = first[1]
cur_test = False

for k in unsuccessful_deliveries.keys():
    if pos_count == 0 and neg_count == 0:
        break
    print(k)
    req = k[0]
    leg = k[1]
    if (cur_request != req):
        try:
            u_del = unsuccessful_deliveries[k]
            # Check if can violate
            if cur_leg == 3:
                continue
            else:
                old_leg_end_time = legs[(cur_request, cur_leg)]["end_time"]
                if old_leg_end_time == None:
                    continue
                new_leg = cur_leg + 1
                new_leg_start = old_leg_end_time + timedelta(hours=get_random_int_to(3,24))
                new_leg_end = new_leg_start + timedelta(hours=get_random_int_to(3,24))
                insert_legs([
                    {
                        "request_id": cur_request,
                        "leg_id": new_leg,
                        "handler_id": random.choice(list(delivery_staff_id)) ,
                        "start_time": new_leg_start ,
                        "end_time": old_leg_start ,
                        "destination_facility": random.choice(list(facilities.keys())) ,
                    }
                ])
                if cur_test:
                    # positive
                    insert_unsuccessful_deliveries([
                        {
                            "request_id": cur_request,
                            "leg_id": new_leg,
                            "attempt_time": new_leg_end + timedelta(hours=get_random_int_to(3,24)),
                            "reason": f"POS_test_{pos_count}"
                        }
                    ])
                    pos_count -= 1
                else:
                    # negative
                    insert_unsuccessful_deliveries([
                        {
                            "request_id": cur_request,
                            "leg_id": new_leg,
                            "attempt_time": new_leg_start,
                            "reason": f"POS_test_{pos_count}"
                        }
                    ])
                    neg_count -= 1
            conn.commit()
            cur_request = req
        except (Exception, psycopg2.DatabaseError) as error:
            print("Met error!")
            assert(cur_test == False) # Ideally shouldnt crash
            print("Cleared error~")
            cur_test = True
        
    cur_leg = leg
    cur_test = not cur_test
conn.close()
# Out:
# (11, 1)
# (11, 2)
# (11, 3)
# (13, 1)
# (13, 2)
# (13, 3)
# (15, 1)
# (19, 1)
# (19, 2)
# (19, 3)
# (23, 1)
# (23, 2)
# (23, 3)
# (24, 1)
# (24, 2)
# (24, 3)
# (27, 1)
# (27, 2)
# (27, 3)
# (28, 1)
# (28, 2)
# (28, 3)
# (30, 1)
# (30, 2)
# (31, 1)
# (31, 2)
# (31, 3)

# %%
# Unsuccessful_deliveries

"""
(11, 1): {'request_id': 11,
  'leg_id': 1,
  'reason': 'asdTWDciwEreMSQfvopmFOsbwgEtLndb',
  'attempt_time': datetime.datetime(1982, 8, 28, 23, 1, 49)}

"""

# Test Q5

pos_count = 2
neg_count = 2

conn = connect__to_database()

first = list(unsuccessful_deliveries.keys())[0]

cur_request = first[0]
cur_leg = first[1]

for k in unsuccessful_deliveries.keys():
    if pos_count == 0 and neg_count == 0:
        break
    print(k)
    req = k[0]
    leg = k[1]
    if (cur_request != req):
        cur_test = False
        try:
            u_del = unsuccessful_deliveries[k]
            # Check if can violate
            if cur_leg == 3:
                neg_count -= 1
                status = insert_unsuccessful_deliveries([
                    {
                        "request_id": cur_request,
                        "leg_id": cur_leg + 1,
                        "attempt_time": u_del["attempt_time"] + timedelta(hours=get_random_int_to(3,24)),
                        "reason": f"NEG_test_{neg_count}"
                    }
                ])
            else:
                old_leg_end_time = legs[(cur_request, cur_leg)]["end_time"]
                if old_leg_end_time == None:
                    #  skip null ones first
                    continue
#                     old_leg_end_time = legs[(cur_request, cur_leg)]["start_time"]
                new_leg = cur_leg + 1
                new_leg_start = old_leg_end_time + timedelta(hours=get_random_int_to(3,24))
                new_leg_end = new_leg_start + timedelta(hours=get_random_int_to(3,24))
                insert_legs([
                    {
                        "request_id": cur_request,
                        "leg_id": new_leg,
                        "handler_id": random.choice(list(delivery_staff_id)) ,
                        "start_time": new_leg_start ,
                        "end_time": new_leg_end ,
                        "destination_facility": random.choice(list(facilities.keys())) ,
                    }
                ])
                insert_unsuccessful_deliveries([
                    {
                        "request_id": cur_request,
                        "leg_id": new_leg,
                        "attempt_time": new_leg_end + timedelta(hours=get_random_int_to(3,24)),
                        "reason": f"POS_test_{pos_count}"
                    }
                ])
                cur_test = True
                pos_count -= 1
            conn.commit()
            cur_request = req
        except (Exception, psycopg2.DatabaseError) as error:
            print("Met error!")
            assert(cur_test == False) # Ideally shouldnt crash
            print("Cleared error~")
            cur_test = True
        
    cur_leg = leg
    
conn.close()
# Out:
# (11, 1)
# (11, 2)
# (11, 3)
# (13, 1)
# (13, 2)
# (13, 3)
# (15, 1)
# (19, 1)
# (19, 2)
# (19, 3)
# (23, 1)
# (23, 2)
# (23, 3)
# (24, 1)
# (24, 2)
# (24, 3)
# (27, 1)
# (27, 2)
# (27, 3)
# (28, 1)
# (28, 2)
# (28, 3)
# (30, 1)
# (30, 2)
# (31, 1)
# Met error!
# (31, 2)
# Met error!
# (31, 3)
# Met error!

# %%
len(accepted_req_id)
# Out:
# 1174

# %%
# Cancelled_requests

# Test Q6

pos_count = 2
neg_count = 2

cur_test = False

conn = connect__to_database()

reqs_to_cancel = [k for k in accepted_req_id if not is_cancelled(delivery_requests[k]["status"])]
print(len(reqs_to_cancel))

for req_id in reqs_to_cancel:
    print(f"req_id: {req_id}")
    try:
        
        if pos_count == 0 and neg_count == 0:
            break
        insert_c_or_u_requests([
            req_id
        ])
        sub_time = delivery_requests[req_id]["submission_time"]
        print(f"sub_time: {sub_time}")
        
        cancel_time = sub_time
        if cur_test:
            pos_count -= 1
            cancel_time += timedelta(hours=get_random_int_to(3,24))
        else:
            neg_count -= 1
        print(f"cancel_time: {cancel_time}")
        
            
        insert_c_requests([
          {
            "id":req_id,
            "cancel_time": cancel_time
          }  
        ])
        conn.commit()
        cur_test = not cur_test
    except (Exception, psycopg2.DatabaseError) as error:
        print("Met error!")
        assert(cur_test == False) # Ideally shouldnt crash
        print("Cleared error~")
        cur_test = True
        
# cur_request = first[0]

conn.close()
# Out:
# 878
# req_id: 9
# sub_time: 1970-06-21 08:31:56
# cancel_time: 1970-06-21 08:31:56
# req_id: 11
# sub_time: 1982-08-28 11:01:49
# cancel_time: 1982-08-29 02:01:49
# req_id: 12
# sub_time: 1988-11-06 20:41:05
# cancel_time: 1988-11-06 20:41:05
# req_id: 23
# sub_time: 1991-05-11 23:31:53
# cancel_time: 1991-05-12 05:31:53
# req_id: 24

# %%
conn.close()

# %%
if not have_inserted['c_or_u_requests']:
        accepted_req_id
        have_inserted['c_or_u_requests'] = not insert_c_or_u_requests(list(cancelled_or_unsuccessful_requests_id))
        
    if not have_inserted['c_requests']:
        accepted_req_id
        have_inserted['c_requests'] = not insert_c_requests([
          {
            "id":k,
            "cancel_time": v['cancel_time']
          }  for k,v in delivery_requests.items() if 'cancel_time' in v
        ])
