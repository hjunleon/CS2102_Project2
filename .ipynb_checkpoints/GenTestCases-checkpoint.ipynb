# %%
# !pip install psycopg2
# Out:
# /bin/bash: /home/randell-crapy/miniconda3/envs/base_py39/lib/libtinfo.so.6: no version information available (required by /bin/bash)
# Requirement already satisfied: psycopg2 in /home/randell-crapy/miniconda3/envs/finance/lib/python3.10/site-packages (2.9.3)

# %%
import psycopg2 
import random
import string
# from datetime import time
from datetime import datetime, timedelta
import time
from enum import Enum
import math

# %%
def connect__to_database():
    conn = None
    try:
        conn = psycopg2.connect(database="cs2102_project2",
                        host="localhost",
                        user="postgres",
                        password="burnoutx123",
                        port="5432")
        return conn 
    except (Exception, psycopg2.DatabaseError) as error:
        print(error)
    return False

# %%
conn = connect__to_database()

# %%
cursor = conn.cursor()

# %%
cursor.execute("SELECT * FROM accepted_requests")

# %%
cursor.execute("SELECT datname FROM pg_database")
for table in cursor.fetchall():
    print(table)
# Out:
# ('postgres',)
# ('template1',)
# ('template0',)
# ('golang_gin_db',)
# ('nus_mods',)
# ('cs2102_project2',)
# ('uv3_autocompound',)
# ('cs2102_as_01',)
# ('wonderland',)

# %%
cursor.close()
conn.close()

# %%
# random_seed = 20
# random.seed(random_seed)

# %%
def get_random_string(length):
    # choose from all lowercase letter
    letters = string.ascii_letters
    return ''.join(random.choice(letters) for i in range(length))

def get_random_number(length):
    choices = [str(x) for x in range(10)]
    return ''.join(random.choice(choices) for i in range(length))

def get_random_int_to(start = 2, upto = 9):
    return random.randint(start, upto)

def get_random_float_from_to(start = 1, mul = 9):
    return round(random.random() * mul, 2) + start

def random_plus_minus(num, mag = 5):
    return num + random.random() * 5 - random.random() * 5 

def get_random_price():
    return round(random.random() * 100, 2)

def random_date():
    d = random.randint(1, int(time.time()))
    return datetime.fromtimestamp(d).strftime('%Y-%m-%d')
def random_timestamp():
    d = random.randint(1, int(time.time()))
    return datetime.fromtimestamp(d)#.strftime('%Y-%m-%d')

# %%
def is_cancelled(status):
    return status == 'cancelled'

def is_accepted(status):
    return status == 'accepted'

def is_unsuccessful(status):
    return status == 'unsuccessful'

# %%
NUM_EMPLOYEES = 50
NUM_FACILITIES = 10
NUM_CUSTOMERS = 1000
NUM_DEL_REQ = NUM_CUSTOMERS * 2
NUM_PACKAGES = math.floor(NUM_DEL_REQ * 1.5)
NUM_LEGS = NUM_DEL_REQ * 3
NUM_UNSUCCESSFUL_PICKUP = NUM_DEL_REQ // 100 + 5
# class delivery_status(Enum):
#     submitted = 1
#     evaluated = 2
#     withdrawn = 3
#     accepted = 4
#     completed = 5
#     cancelled = 6
#     unsuccessful = 7
    
all_d_status = ['submitted', 'evaluated', 'withdrawn', 'accepted', 'completed', 'cancelled', 'unsuccessful']
accepted_statuses = set(['accepted', 'completed', 'cancelled', 'unsuccessful'])

# %%
employee = {}
delivery_staff_id = set()
for i in range(NUM_EMPLOYEES):
    this_id = i + 1
    to_add = {}
    to_add['gender'] = random.choice( ['male', 'female'] )
    to_add['name'] = get_random_string(16)
    to_add["dob"] = random_date()
    to_add["title"] = random.choice(['Mr', 'Ser']) if to_add['gender'] == 'male' else random.choice(['Mrs', 'Miss', "Mdm"])
    to_add["salary"] = round(random.random() * 15000, 2)
    to_add["is_delivery"] = False
    employee[this_id] = to_add
for i in range(min(NUM_EMPLOYEES,10)):
    this_id = i + 1
    employee[this_id]["is_delivery"] = True
    delivery_staff_id.add(this_id)
employee
# Out:
# {1: {'gender': 'female',
#   'name': 'BzdYRqNDRvBIQOFM',
#   'dob': '1985-10-26',
#   'title': 'Mrs',
#   'salary': 7591.46,
#   'is_delivery': True},
#  2: {'gender': 'male',
#   'name': 'WrzMGIoTylLafYOj',
#   'dob': '2013-05-05',
#   'title': 'Ser',
#   'salary': 13272.64,
#   'is_delivery': True},
#  3: {'gender': 'male',
#   'name': 'VBZXLnUkySakbfsC',
#   'dob': '2011-06-21',
#   'title': 'Mr',
#   'salary': 13120.95,
#   'is_delivery': True},
#  4: {'gender': 'male',
#   'name': 'AyEEfFaAykxLjLRH',
#   'dob': '1993-05-16',
#   'title': 'Ser',
#   'salary': 9800.06,
#   'is_delivery': True},
#  5: {'gender': 'male',
#   'name': 'iQJjVzJoHwOYaRLS',
#   'dob': '1998-03-18',
#   'title': 'Mr',
#   'salary': 3198.45,
#   'is_delivery': True},
#  6: {'gender': 'male',
#   'name': 'wUkkXYPIibqeZsUB',
#   'dob': '1994-05-04',
#   'title': 'Mr',
#   'salary': 7830.49,
#   'is_delivery': True},
#  7: {'gender': 'male',
#   'name': 'HjxKQoqZAIoZwOfW',
#   'dob': '2016-04-12',
#   'title': 'Mr',
#   'salary': 4130.15,
#   'is_delivery': True},
#  8: {'gender': 'male',
#   'name': 'HtOacwEvIltTWPJc',
#   'dob': '2010-08-09',
#   'title': 'Mr',
#   'salary': 10464.9,
#   'is_delivery': True},
#  9: {'gender': 'male',
#   'name': 'UzDIfLevpPmdvqvX',
#   'dob': '1995-05-31',
#   'title': 'Ser',
#   'salary': 11137.01,
#   'is_delivery': True},
#  10: {'gender': 'female',
#   'name': 'SItAiwtwDbeBhPSB',
#   'dob': '2000-05-29',
#   'title': 'Miss',
#   'salary': 6184.91,
#   'is_delivery': True},
#  11: {'gender': 'female',
#   'name': 'UDltVxwpQPPwuMMb',
#   'dob': '1988-08-26',
#   'title': 'Mrs',
#   'salary': 12302.88,
#   'is_delivery': False},
#  12: {'gender': 'female',
#   'name': 'qDtWIoLzxPMbEYwO',
#   'dob': '1994-11-25',
#   'title': 'Mrs',
#   'salary': 793.59,
#   'is_delivery': False},
#  13: {'gender': 'male',
#   'name': 'gppxnVLeQWFGrRQW',
#   'dob': '1998-10-05',
#   'title': 'Mr',
#   'salary': 13598.24,
#   'is_delivery': False},
#  14: {'gender': 'female',
#   'name': 'aVfnbIKQmvbdtiwH',
#   'dob': '2001-03-13',
#   'title': 'Mrs',
#   'salary': 11303.57,
#   'is_delivery': False},
#  15: {'gender': 'female',
#   'name': 'QYnrmyHalTqHRLyg',
#   'dob': '2001-03-16',
#   'title': 'Mrs',
#   'salary': 3339.69,
#   'is_delivery': False},
#  16: {'gender': 'female',
#   'name': 'uxjpxffZGyQnFmaB',
#   'dob': '2012-09-03',
#   'title': 'Mdm',
#   'salary': 1866.49,
#   'is_delivery': False},
#  17: {'gender': 'male',
#   'name': 'ufMWxhloLqbqktZB',
#   'dob': '1972-04-28',
#   'title': 'Mr',
#   'salary': 5306.11,
#   'is_delivery': False},
#  18: {'gender': 'male',
#   'name': 'ljzfbOYIbmKRtaVU',
#   'dob': '1992-07-30',
#   'title': 'Ser',
#   'salary': 2118.17,
#   'is_delivery': False},
#  19: {'gender': 'male',
#   'name': 'oXFdybBlnDEOBEvc',
#   'dob': '2004-11-15',
#   'title': 'Ser',
#   'salary': 9674.87,
#   'is_delivery': False},
#  20: {'gender': 'male',
#   'name': 'ugDETGaqwZzhPcYx',
#   'dob': '1987-10-28',
#   'title': 'Mr',
#   'salary': 3013.43,
#   'is_delivery': False},
#  21: {'gender': 'male',
#   'name': 'bdBPPjaQakWmytkY',
#   'dob': '2022-02-02',
#   'title': 'Mr',
#   'salary': 8070.02,
#   'is_delivery': False},
#  22: {'gender': 'female',
#   'name': 'zCgfyIXpghzncTGN',
#   'dob': '1974-07-12',
#   'title': 'Miss',
#   'salary': 2396.57,
#   'is_delivery': False},
#  23: {'gender': 'female',
#   'name': 'QoSIjrGKyGGNDgXY',
#   'dob': '1998-12-04',
#   'title': 'Mdm',
#   'salary': 6464.18,
#   'is_delivery': False},
#  24: {'gender': 'male',
#   'name': 'dfCuzzUYLlVoHpaQ',
#   'dob': '2007-07-25',
#   'title': 'Ser',
#   'salary': 6729.98,
#   'is_delivery': False},
#  25: {'gender': 'female',
#   'name': 'jAqAhwVVnyZLfEMg',
#   'dob': '1990-05-05',
#   'title': 'Mdm',
#   'salary': 7648.71,
#   'is_delivery': False},
#  26: {'gender': 'female',
#   'name': 'sjbuRSbQwLhZABsW',
#   'dob': '1970-10-20',
#   'title': 'Mrs',
#   'salary': 12390.99,
#   'is_delivery': False},
#  27: {'gender': 'female',
#   'name': 'tXswueOQBGNNWywO',
#   'dob': '1971-01-09',
#   'title': 'Mrs',
#   'salary': 6273.81,
#   'is_delivery': False},
#  28: {'gender': 'male',
#   'name': 'ctYyWEAkAGBzCmmE',
#   'dob': '2004-11-27',
#   'title': 'Ser',
#   'salary': 11463.96,
#   'is_delivery': False},
#  29: {'gender': 'female',
#   'name': 'tGtqFbpjesMkBBLv',
#   'dob': '1996-09-07',
#   'title': 'Miss',
#   'salary': 9355.8,
#   'is_delivery': False},
#  30: {'gender': 'male',
#   'name': 'rDvFgKIOGYAcwqpF',
#   'dob': '2017-03-28',
#   'title': 'Mr',
#   'salary': 2494.47,
#   'is_delivery': False},
#  31: {'gender': 'female',
#   'name': 'pDVOPorJYwYflyUa',
#   'dob': '1996-04-07',
#   'title': 'Miss',
#   'salary': 13888.03,
#   'is_delivery': False},
#  32: {'gender': 'male',
#   'name': 'bAlaDMIOMolyieGW',
#   'dob': '2016-07-03',
#   'title': 'Mr',
#   'salary': 10510.26,
#   'is_delivery': False},
#  33: {'gender': 'female',
#   'name': 'ByfEfygwwAoVkVRg',
#   'dob': '1993-11-04',
#   'title': 'Mdm',
#   'salary': 4139.75,
#   'is_delivery': False},
#  34: {'gender': 'female',
#   'name': 'QGLmIPWhTNJbHfBf',
#   'dob': '2017-09-20',
#   'title': 'Miss',
#   'salary': 7496.26,
#   'is_delivery': False},
#  35: {'gender': 'female',
#   'name': 'nBkQZfeHirWlyZtj',
#   'dob': '1973-12-08',
#   'title': 'Mrs',
#   'salary': 7197.64,
#   'is_delivery': False},
#  36: {'gender': 'female',
#   'name': 'qmsfnXmmzDXhLqnN',
#   'dob': '1999-08-31',
#   'title': 'Miss',
#   'salary': 8091.08,
#   'is_delivery': False},
#  37: {'gender': 'female',
#   'name': 'OTHNkALSLkYbatdj',
#   'dob': '2008-08-27',
#   'title': 'Mdm',
#   'salary': 9834.48,
#   'is_delivery': False},
#  38: {'gender': 'male',
#   'name': 'XHJyVbkZVkYyuMkY',
#   'dob': '2020-01-03',
#   'title': 'Ser',
#   'salary': 5054.27,
#   'is_delivery': False},
#  39: {'gender': 'male',
#   'name': 'PMJcIYxItUPDSHeG',
#   'dob': '2007-05-31',
#   'title': 'Mr',
#   'salary': 12549.99,
#   'is_delivery': False},
#  40: {'gender': 'male',
#   'name': 'gGzXmpSAyMFGSEGK',
#   'dob': '2001-01-27',
#   'title': 'Ser',
#   'salary': 4351.62,
#   'is_delivery': False},
#  41: {'gender': 'male',
#   'name': 'LjXDMligcwhKKAmP',
#   'dob': '2014-12-28',
#   'title': 'Mr',
#   'salary': 13438.15,
#   'is_delivery': False},
#  42: {'gender': 'female',
#   'name': 'dePdkchWHNbZKhbt',
#   'dob': '1975-04-18',
#   'title': 'Mdm',
#   'salary': 3495.15,
#   'is_delivery': False},
#  43: {'gender': 'female',
#   'name': 'XJPSqMiJOLYHawKn',
#   'dob': '2006-03-26',
#   'title': 'Miss',
#   'salary': 5244.81,
#   'is_delivery': False},
#  44: {'gender': 'male',
#   'name': 'mEvudVOCiAVkesUR',
#   'dob': '1971-10-22',
#   'title': 'Mr',
#   'salary': 6551.49,
#   'is_delivery': False},
#  45: {'gender': 'male',
#   'name': 'EuWPPeCGRBPHuznB',
#   'dob': '2018-02-13',
#   'title': 'Ser',
#   'salary': 12115.85,
#   'is_delivery': False},
#  46: {'gender': 'male',
#   'name': 'tptzcKcbGbigSSnx',
#   'dob': '2016-11-10',
#   'title': 'Mr',
#   'salary': 3078.95,
#   'is_delivery': False},
#  47: {'gender': 'male',
#   'name': 'RhwMXAijoQYqeCVX',
#   'dob': '2006-07-07',
#   'title': 'Ser',
#   'salary': 4695.88,
#   'is_delivery': False},
#  48: {'gender': 'male',
#   'name': 'vYudeEbeBArSBmbo',
#   'dob': '1986-10-04',
#   'title': 'Mr',
#   'salary': 5656.88,
#   'is_delivery': False},
#  49: {'gender': 'female',
#   'name': 'LBktaKChgXcNBqnb',
#   'dob': '1994-09-11',
#   'title': 'Miss',
#   'salary': 9010.79,
#   'is_delivery': False},
#  50: {'gender': 'male',
#   'name': 'UHFwPvgcadvWxXEw',
#   'dob': '1983-01-08',
#   'title': 'Mr',
#   'salary': 12312.17,
#   'is_delivery': False}}

# %%
customers = {}
for i in range(NUM_CUSTOMERS):
    this_id = i + 1
    to_add = {}
    to_add['name'] = get_random_string(16)
    to_add['gender'] = random.choice( ['male', 'female'] )
    to_add['mobile'] = get_random_number(8)
    customers[this_id] = to_add
customers
# Out:
# {1: {'name': 'pfIEDXYfDLUnChdI', 'gender': 'male', 'mobile': '87697447'},
#  2: {'name': 'nZlrkIQgGyhFAhNq', 'gender': 'male', 'mobile': '77580228'},
#  3: {'name': 'lkxnVYnJRntZChbP', 'gender': 'female', 'mobile': '62443756'},
#  4: {'name': 'ldqfUeuYreUzwiMM', 'gender': 'female', 'mobile': '59549191'},
#  5: {'name': 'WTpNrSWGJyjdzEzs', 'gender': 'male', 'mobile': '76008528'},
#  6: {'name': 'HyQhQYxTVOggsSwA', 'gender': 'female', 'mobile': '14776154'},
#  7: {'name': 'ckUgBmXlsgnizIRI', 'gender': 'female', 'mobile': '63701147'},
#  8: {'name': 'kLyDEdhKvTwvgWtL', 'gender': 'female', 'mobile': '73945272'},
#  9: {'name': 'IGZBxdPuAwPJCINF', 'gender': 'male', 'mobile': '92134213'},
#  10: {'name': 'uIDzdkEvWxCchouN', 'gender': 'male', 'mobile': '94891205'},
#  11: {'name': 'IyplJIpBjIhVlyhC', 'gender': 'male', 'mobile': '44762223'},
#  12: {'name': 'rwmLmOCONDByVLLI', 'gender': 'male', 'mobile': '47409695'},
#  13: {'name': 'CFMtwvPTdRQxonrz', 'gender': 'male', 'mobile': '18838822'},
#  14: {'name': 'YlKFhJLwsTItrZSu', 'gender': 'female', 'mobile': '61505182'},
#  15: {'name': 'UvgicQSzbRgOrfyC', 'gender': 'female', 'mobile': '89138000'},
#  16: {'name': 'zGmfigLREYIeeIZw', 'gender': 'female', 'mobile': '28983351'},
#  17: {'name': 'vimnZfoAajEAzLDr', 'gender': 'male', 'mobile': '27391307'},
#  18: {'name': 'VoKQzFabrydtOYTm', 'gender': 'male', 'mobile': '79301842'},
#  19: {'name': 'BMHAsXSzTCvCOoMF', 'gender': 'male', 'mobile': '88054526'},
#  20: {'name': 'tSVDCYZqCrLWXiVf', 'gender': 'male', 'mobile': '62517435'},
#  21: {'name': 'OXgVxPMgojuDbdGm', 'gender': 'female', 'mobile': '10757929'},
#  22: {'name': 'sDJetimIHbiYQXms', 'gender': 'male', 'mobile': '91031351'},
#  23: {'name': 'dOgeEUZjbpPgadCS', 'gender': 'male', 'mobile': '90901801'},
#  24: {'name': 'ZMxMuFlhlKhcpuRc', 'gender': 'male', 'mobile': '24258734'},
#  25: {'name': 'UnvXInSImkwuPkpE', 'gender': 'male', 'mobile': '24730525'},
#  26: {'name': 'CrkvpImAonczexqu', 'gender': 'female', 'mobile': '52958325'},
#  27: {'name': 'uSlLXdGCmEdsqeqh', 'gender': 'female', 'mobile': '59428426'},
#  28: {'name': 'pajuYXiqcSfpIdOq', 'gender': 'female', 'mobile': '72621963'},
#  29: {'name': 'pxANhgsacEJZjOAs', 'gender': 'male', 'mobile': '37710793'},
#  30: {'name': 'nusQrghUNuwnrYsL', 'gender': 'male', 'mobile': '38082445'},
for i in range(NUM_DEL_REQ):
    this_id = i + 1
    to_add = {}
    to_add['recipient_name'] = get_random_string(16)
    to_add['recipient_addr'] = get_random_string(32)
    to_add['recipient_postal'] = get_random_number(6)
    to_add['pickup_addr'] = get_random_string(32)
    to_add['pickup_postal'] = get_random_number(6)
    to_add['pickup_date'] = random_date()
    current_timestamp = random_timestamp()
    to_add['submission_time'] = current_timestamp
    to_add['num_days_needed'] = get_random_int_to(2, 16)
    to_add['price'] = get_random_price()
    
    to_add['customer_id'] = random.choice(list(customers.keys()))
    to_add['evaluater_id'] = random.choice(list(employee.keys()))
    to_add['status'] = random.choice(all_d_status)
    
    if (to_add['status'] in accepted_statuses):
        to_add['card_number'] = get_random_number(12)
        to_add['payment_time'] = random_timestamp()
        to_add['monitor_id'] = random.choice(list(employee.keys()))
#         if(is_accepted(to_add['status'])):
        accepted_req_id.add(this_id)
        
    if (is_cancelled(to_add['status'])):
        current_timestamp += timedelta(hours=get_random_int_to(1,12))
        to_add['cancel_time'] = current_timestamp
        cancelled_or_unsuccessful_requests_id.add(this_id)
    
    if (is_unsuccessful(to_add['status'])):
        cancelled_or_unsuccessful_requests_id.add(this_id)
    
    delivery_requests[this_id] = to_add
    
delivery_requests
# Out:
# {1: {'recipient_name': 'vUbbSRWYEidpXOlM',
#   'recipient_addr': 'PJXNwYwHNkbylakuQYBTOfNBnZeREZVY',
#   'recipient_postal': '835294',
#   'pickup_addr': 'aBogsojfISeKaTnxqrvSzSPOxRzgJafV',
#   'pickup_postal': '907745',
#   'pickup_date': '1972-12-08',
#   'submission_time': datetime.datetime(1974, 7, 16, 14, 51, 6),
#   'num_days_needed': 8,
#   'price': 3.92,
#   'customer_id': 514,
#   'evaluater_id': 7,
#   'status': 'withdrawn'},
#  2: {'recipient_name': 'TGhIjbitgvSGHljb',
#   'recipient_addr': 'gJMYhypMvNNrnUIBTXuIfSMgPnvKXNCO',
#   'recipient_postal': '107854',
#   'pickup_addr': 'PCWjJUoCzJPJJzcXpSuWjUtCgPQBXzvk',
#   'pickup_postal': '387916',
#   'pickup_date': '1983-07-14',
#   'submission_time': datetime.datetime(2005, 10, 26, 16, 36, 41),
#   'num_days_needed': 4,
#   'price': 4.54,
#   'customer_id': 311,
#   'evaluater_id': 13,
#   'status': 'unsuccessful',
#   'card_number': '855329584771',
#   'payment_time': datetime.datetime(1991, 5, 25, 23, 54, 22),
#   'monitor_id': 46},
#  3: {'recipient_name': 'RZXHDrZdrCMfxXEQ',
#   'recipient_addr': 'kCwWuGMcPBBxulaRqNLqSqAdmXVlfecH',
#   'recipient_postal': '888765',
#   'pickup_addr': 'KIezIqOlNIfTjkUXlpPjwEkSlaHHslsQ',
#   'pickup_postal': '668213',
#   'pickup_date': '2011-02-16',
#   'submission_time': datetime.datetime(1979, 11, 2, 10, 55, 59),
#   'num_days_needed': 13,
#   'price': 31.68,
#   'customer_id': 733,
#   'evaluater_id': 40,
#   'status': 'accepted',
#   'card_number': '378809092296',
#   'payment_time': datetime.datetime(1988, 3, 27, 3, 0, 34),
#   'monitor_id': 32},
#  4: {'recipient_name': 'jGkAgQgIlAelMSZi',
#   'recipient_addr': 'NbjaFIZkvFxXQYyLgnCJsnMQUcTLKacl',
#   'recipient_postal': '081569',
#   'pickup_addr': 'fmOYkoVtkNroXKUONxSxshOPJvlAxWBP',
#   'pickup_postal': '697858',
#   'pickup_date': '1998-02-04',
#   'submission_time': datetime.datetime(2010, 9, 12, 0, 45, 33),
#   'num_days_needed': 6,
#   'price': 20.46,
#   'customer_id': 10,
#   'evaluater_id': 50,
#   'status': 'withdrawn'},
#  5: {'recipient_name': 'vmKbBxAVywCafdqb',
#   'recipient_addr': 'SrZviEszGKyTQkgjVfTlUeavFnTzcJKI',
#   'recipient_postal': '963537',
#   'pickup_addr': 'CNPunmdrfKPkAtjQosTvpFIdhpcMwETm',
#   'pickup_postal': '394824',
#   'pickup_date': '1975-05-06',
#   'submission_time': datetime.datetime(2001, 12, 20, 23, 23, 24),
#   'num_days_needed': 5,
#   'price': 22.08,
#   'customer_id': 608,
#   'evaluater_id': 7,
#   'status': 'cancelled',
#   'card_number': '426307411166',
#   'payment_time': datetime.datetime(1979, 8, 27, 4, 3, 31),
#   'monitor_id': 14,
#   'cancel_time': datetime.datetime(2001, 12, 21, 11, 23, 24)},
#  6: {'recipient_name': 'yrbUzdNKEwdozoGN',
#   'recipient_addr': 'qIcRoGITeBbZTXusCxgSacjeEqlWHGks',
#   'recipient_postal': '533230',
#   'pickup_addr': 'UAeSPjPRiSdfxSMSGSCKkZMMQHCumrQW',
#   'pickup_postal': '438211',
#   'pickup_date': '2020-02-26',
#   'submission_time': datetime.datetime(1983, 12, 18, 5, 36, 43),
#   'num_days_needed': 14,
#   'price': 25.69,
#   'customer_id': 283,
#   'evaluater_id': 22,
#   'status': 'submitted'},
#  7: {'recipient_name': 'VbvWFPimypzjiSuE',
#   'recipient_addr': 'tdvoagRFlaWxpjSawAJdmhSTsMqSUHKM',
#   'recipient_postal': '511118',
#   'pickup_addr': 'BkOHZipzTnTakQPvRkfWNRUSmRWmwGsM',
#   'pickup_postal': '873443',
#   'pickup_date': '2012-05-24',
#   'submission_time': datetime.datetime(1997, 1, 4, 7, 5, 25),
#   'num_days_needed': 9,
#   'price': 81.06,
#   'customer_id': 40,
#   'evaluater_id': 23,
#   'status': 'cancelled',
#   'card_number': '554944382466',
#   'payment_time': datetime.datetime(2016, 6, 2, 2, 59, 7),
#   'monitor_id': 14,
#   'cancel_time': datetime.datetime(1997, 1, 4, 8, 5, 25)},
#  8: {'recipient_name': 'OtOsZGCOLFkwfmdi',
#   'recipient_addr': 'PehvdakThSoTMnxdomWDVVjGyjcIVXmi',
#   'recipient_postal': '058275',
#   'pickup_addr': 'NADklsVydBbqahvCougfemJJwyznNhse',
#   'pickup_postal': '591971',
#   'pickup_date': '1988-08-18',
#   'submission_time': datetime.datetime(1970, 8, 18, 2, 4, 45),
#   'num_days_needed': 7,
#   'price': 14.22,
#   'customer_id': 818,
#   'evaluater_id': 5,
#   'status': 'completed',
#   'card_number': '125475547062',
#   'payment_time': datetime.datetime(1980, 7, 21, 19, 26, 5),
#   'monitor_id': 26},
#  9: {'recipient_name': 'SjJJMpwcrrHpuMwY',
#   'recipient_addr': 'dYFMqgVDRqvxqvRHrtogBUOtgjZAmwBo',
#   'recipient_postal': '505669',
#   'pickup_addr': 'KMSNpCmYQKnXtrgSdAfXSXmVSOQuSgvp',
#   'pickup_postal': '981061',
#   'pickup_date': '2011-11-27',
#   'submission_time': datetime.datetime(1984, 10, 19, 16, 37, 27),
#   'num_days_needed': 6,
#   'price': 26.3,
#   'customer_id': 290,
#   'evaluater_id': 11,
#   'status': 'submitted'},
#  10: {'recipient_name': 'LVTFbLFwNWdENdgX',
#   'recipient_addr': 'bPgpelEHiyvxOzXrgDVwPaiBRpkLGKTs',
#   'recipient_postal': '102244',
#   'pickup_addr': 'EnPyeCAwmSJsPhguiXIwlDiBnVNJjQny',
#   'pickup_postal': '517500',
#   'pickup_date': '1993-12-16',
#   'submission_time': datetime.datetime(1990, 10, 24, 18, 35, 26),
#   'num_days_needed': 5,
#   'price': 18.28,
#   'customer_id': 495,
#   'evaluater_id': 17,
#   'status': 'withdrawn'},
#  11: {'recipient_name': 'qiWiYWmTGdFQLTjj',
#   'recipient_addr': 'jFNJihfucXBMrHzNbotZigmTllWPEjzf',
#   'recipient_postal': '538523',
#   'pickup_addr': 'RMQHOvCUmscDKRFqezyusAcXrfniZxzo',
#   'pickup_postal': '202299',
#   'pickup_date': '2002-06-21',
#   'submission_time': datetime.datetime(1983, 5, 20, 13, 24, 9),
#   'num_days_needed': 16,
#   'price': 74.21,
#   'customer_id': 593,
#   'evaluater_id': 3,
#   'status': 'withdrawn'},
#  12: {'recipient_name': 'cNqYiWuTDKNrAuSm',
#   'recipient_addr': 'amECEnTMbdRgePLXgCLxgvkgzhQWHyPA',
#   'recipient_postal': '262182',
#   'pickup_addr': 'hmPdBYZDOdGAnTDeBMgzqkayqkbImenn',
#   'pickup_postal': '196595',
#   'pickup_date': '2008-11-28',
#   'submission_time': datetime.datetime(1989, 8, 29, 15, 6, 50),
#   'num_days_needed': 6,
#   'price': 54.4,
#   'customer_id': 72,
#   'evaluater_id': 22,
#   'status': 'unsuccessful',
#   'card_number': '329971081554',
#   'payment_time': datetime.datetime(2019, 9, 18, 13, 27, 32),
#   'monitor_id': 9},
#  13: {'recipient_name': 'jcqYjdSNNcelgPuS',
#   'recipient_addr': 'qEfSeVDgOgPRgezoBWRRFgzQAhamVIBh',
#   'recipient_postal': '395674',
#   'pickup_addr': 'aEAPzFaLxTqEMyxCSpOSTPUsIMttNjrc',
#   'pickup_postal': '631858',
#   'pickup_date': '1977-06-05',
#   'submission_time': datetime.datetime(2005, 7, 24, 0, 58, 56),
#   'num_days_needed': 6,
#   'price': 26.1,
#   'customer_id': 920,
#   'evaluater_id': 42,
#   'status': 'completed',
#   'card_number': '327991306491',
#   'payment_time': datetime.datetime(2002, 9, 17, 14, 24, 27),
#   'monitor_id': 49},
#  14: {'recipient_name': 'bbgZztTTybgEUGMO',
#   'recipient_addr': 'CMUIbfInstzMMarfQeopRmvhUeTESHsQ',
#   'recipient_postal': '359939',
#   'pickup_addr': 'aMKPCZClYisqAQjQZKVhVwekuArQazNQ',
#   'pickup_postal': '701363',
#   'pickup_date': '1980-03-04',
#   'submission_time': datetime.datetime(1988, 11, 14, 23, 16, 31),
#   'num_days_needed': 2,
#   'price': 44.22,
#   'customer_id': 819,
#   'evaluater_id': 36,
#   'status': 'completed',
#   'card_number': '451704053534',
#   'payment_time': datetime.datetime(1994, 4, 17, 11, 54, 10),
#   'monitor_id': 28},
#  15: {'recipient_name': 'FRuoYZOMCDirNsul',
#   'recipient_addr': 'QxaHWTueOoGbkSzWIpBSnHqrgWngKWaa',
#   'recipient_postal': '878368',
#   'pickup_addr': 'DYrxZzLOlNWWdgPYPqveOdHAGJvZpgIn',
#   'pickup_postal': '592833',
#   'pickup_date': '1986-04-13',
#   'submission_time': datetime.datetime(1998, 2, 10, 5, 37, 59),
#   'num_days_needed': 14,
#   'price': 7.59,
#   'customer_id': 591,
#   'evaluater_id': 30,
#   'status': 'unsuccessful',
#   'card_number': '352170862841',
#   'payment_time': datetime.datetime(2016, 6, 10, 15, 35, 10),
#   'monitor_id': 17},
#  16: {'recipient_name': 'tlWJHOxFaMKydCIM',
#   'recipient_addr': 'pKDJUqadWTkhsxZqpPZJpcDHwQnPnCVD',
#   'recipient_postal': '936286',
#   'pickup_addr': 'qUIYMapEXxGuqNPWAkunVUcEqMvFHVaQ',
#   'pickup_postal': '440782',
#   'pickup_date': '1989-04-12',
#   'submission_time': datetime.datetime(2022, 1, 16, 8, 14, 37),
#   'num_days_needed': 13,
#   'price': 27.63,
#   'customer_id': 627,
#   'evaluater_id': 22,
#   'status': 'evaluated'},
#  17: {'recipient_name': 'nbWiFWxZgJRMegjv',
#   'recipient_addr': 'EzQCKoSHjdTKbYrwZRNTFPTsRTnYcPPa',
#   'recipient_postal': '863771',
#   'pickup_addr': 'bYYUGExyNhEDUuyVHTUFlFvdKFYsfgjk',
#   'pickup_postal': '195346',
#   'pickup_date': '2020-07-09',
#   'submission_time': datetime.datetime(1982, 1, 22, 11, 12, 58),
#   'num_days_needed': 4,
#   'price': 71.06,
#   'customer_id': 750,
#   'evaluater_id': 28,
#   'status': 'unsuccessful',
#   'card_number': '121727451499',
#   'payment_time': datetime.datetime(1979, 12, 25, 6, 56, 52),
#   'monitor_id': 2},
#  18: {'recipient_name': 'WGVmciNUCtYDhmqy',
#   'recipient_addr': 'TwgItzChXQndVRfrzwZhVwtwGPXNWEOD',
#   'recipient_postal': '006344',
#   'pickup_addr': 'dWNbFCwDeBuAWQeiMUHlTxHWuYDuBukD',
#   'pickup_postal': '843559',
#   'pickup_date': '2000-01-27',
#   'submission_time': datetime.datetime(2007, 11, 21, 12, 51, 10),
#   'num_days_needed': 10,
#   'price': 46.83,
#   'customer_id': 550,
#   'evaluater_id': 50,
#   'status': 'unsuccessful',
#   'card_number': '289126664523',
#   'payment_time': datetime.datetime(2008, 8, 3, 9, 34, 14),
#   'monitor_id': 40},
#  19: {'recipient_name': 'IzDEbQrgCsxDhizl',
#   'recipient_addr': 'immHUGuPFUDFjQcJMaRgJNWApTYFMpvc',
#   'recipient_postal': '540047',
#   'pickup_addr': 'YnQTCEZzIwqfTFAWLqJcuFLYkiwBbuaA',
#   'pickup_postal': '307957',
#   'pickup_date': '1999-03-20',
#   'submission_time': datetime.datetime(2021, 8, 10, 10, 44, 1),
#   'num_days_needed': 3,
#   'price': 72.76,
#   'customer_id': 880,
#   'evaluater_id': 12,
#   'status': 'evaluated'},
#  20: {'recipient_name': 'RQWaQqjQFTRQndgs',
#   'recipient_addr': 'OZyTQLFqeHOobBGtMfNrzqgQOWsoTxIw',
#   'recipient_postal': '135967',
#   'pickup_addr': 'YICUWmwRTXoiPEsvXKtdxpqRIvxxNatP',
#   'pickup_postal': '230789',
#   'pickup_date': '1995-04-23',
#   'submission_time': datetime.datetime(2011, 10, 25, 15, 18, 27),
#   'num_days_needed': 15,
#   'price': 96.7,
#   'customer_id': 111,
#   'evaluater_id': 11,
#   'status': 'accepted',
#   'card_number': '408216528778',
#   'payment_time': datetime.datetime(1998, 1, 4, 10, 54, 22),
#   'monitor_id': 23},
#  21: {'recipient_name': 'guEtgEvknNymGyFB',
#   'recipient_addr': 'PUcGKzdQZfZlgpjfrwghgLKkytTkBvTs',
#   'recipient_postal': '007065',
#   'pickup_addr': 'XFyYdlKEtfWtctVnSVsrOnxqZRJovBvi',
#   'pickup_postal': '372595',
#   'pickup_date': '2017-07-27',
#   'submission_time': datetime.datetime(2012, 10, 29, 6, 56, 56),
#   'num_days_needed': 6,
#   'price': 18.75,
#   'customer_id': 769,
#   'evaluater_id': 16,
#   'status': 'withdrawn'},
#  22: {'recipient_name': 'rIHlYzeIsTauMDBT',
#   'recipient_addr': 'VEQAqiqKPQdysKMxWlvSRyVmCoGAtofo',
#   'recipient_postal': '388683',
#   'pickup_addr': 'TVXbDissOilXGFqOJAdqTKjTjCHksDce',
#   'pickup_postal': '325706',
#   'pickup_date': '2004-06-16',
#   'submission_time': datetime.datetime(2005, 3, 10, 9, 42, 9),
#   'num_days_needed': 3,
#   'price': 37.71,
#   'customer_id': 77,
#   'evaluater_id': 37,
#   'status': 'unsuccessful',
#   'card_number': '138315900371',
#   'payment_time': datetime.datetime(1987, 6, 24, 6, 42, 6),
#   'monitor_id': 30},
#  23: {'recipient_name': 'jlwlLldHOFWuRvAt',
#   'recipient_addr': 'RnHeBeMbWGwrgpeXcmuOpVOVgmpnaHhW',
#   'recipient_postal': '425399',
#   'pickup_addr': 'AjLxzFUVplqZHgRCfvOsutOtHwEauZZc',
#   'pickup_postal': '002823',
#   'pickup_date': '2006-10-23',
#   'submission_time': datetime.datetime(2008, 1, 2, 22, 28, 19),
#   'num_days_needed': 11,
#   'price': 2.46,
#   'customer_id': 699,
#   'evaluater_id': 6,
#   'status': 'submitted'},
#  24: {'recipient_name': 'YEfHVRTmAXMkVtuI',
#   'recipient_addr': 'DdvcDdmDNkQiGcoRgLqxseksxujDpSRF',
#   'recipient_postal': '845123',
#   'pickup_addr': 'pQdOMgmeVHyAuscYlJOeKcCUQhkxybOn',
#   'pickup_postal': '239995',
#   'pickup_date': '1972-05-28',
#   'submission_time': datetime.datetime(2003, 2, 25, 0, 20, 19),
#   'num_days_needed': 11,
#   'price': 22.67,
#   'customer_id': 282,
#   'evaluater_id': 4,
#   'status': 'accepted',
#   'card_number': '237870216084',
#   'payment_time': datetime.datetime(2008, 3, 6, 19, 12, 44),
#   'monitor_id': 20},
#  25: {'recipient_name': 'YBtvrNBIamKlAEnO',
#   'recipient_addr': 'aVkeZzjffQIikULeQAFZMZgtoJYexMtJ',
#   'recipient_postal': '247052',
#   'pickup_addr': 'nZdpgzpcgfSRvdhimoCDBTwLiXnYqURx',
#   'pickup_postal': '469791',
#   'pickup_date': '1983-04-06',
#   'submission_time': datetime.datetime(1994, 5, 22, 0, 35, 8),
#   'num_days_needed': 7,
#   'price': 93.13,
#   'customer_id': 650,
#   'evaluater_id': 7,
#   'status': 'cancelled',
#   'card_number': '166702923262',
#   'payment_time': datetime.datetime(2003, 1, 29, 0, 40, 12),
#   'monitor_id': 11,
#   'cancel_time': datetime.datetime(1994, 5, 22, 6, 35, 8)},
#  26: {'recipient_name': 'PjfTjRycrmWqfqHt',
#   'recipient_addr': 'AkxZYxRcBlyDIpfqYeYcANOiaozLPwGR',
#   'recipient_postal': '576101',
#   'pickup_addr': 'vdkmVXWqTKGhaKAENRoNAyjTZfzcaOxo',
#   'pickup_postal': '040574',
#   'pickup_date': '2021-05-06',
#   'submission_time': datetime.datetime(2020, 9, 19, 23, 17, 3),
#   'num_days_needed': 8,
#   'price': 1.21,
#   'customer_id': 347,
#   'evaluater_id': 15,
#   'status': 'evaluated'},
#  27: {'recipient_name': 'uaQSeIqQGExWeQnV',
#   'recipient_addr': 'sbgZGIcXloORbHIrCZcHVbSQmuKABuos',
#   'recipient_postal': '941445',
#   'pickup_addr': 'SJTGOCaWXPUjktUtOtamDFhypzwgjRwi',
#   'pickup_postal': '776528',
#   'pickup_date': '1971-01-14',
#   'submission_time': datetime.datetime(1982, 1, 14, 18, 31, 30),
#   'num_days_needed': 10,
#   'price': 30.9,
#   'customer_id': 981,
#   'evaluater_id': 24,
#   'status': 'accepted',
#   'card_number': '292524698006',
#   'payment_time': datetime.datetime(1993, 6, 1, 16, 36, 8),
#   'monitor_id': 18},
#  28: {'recipient_name': 'KUENGkrYUDsxIPEF',
#   'recipient_addr': 'ZWyumEfegMoXfnozjpDQlQdfynwtSarR',
#   'recipient_postal': '859896',
#   'pickup_addr': 'KaWYPyAirsJUynypvHLOyVVIIGTFqCWP',
#   'pickup_postal': '446183',
#   'pickup_date': '1981-08-11',
#   'submission_time': datetime.datetime(1994, 7, 28, 4, 17, 23),
#   'num_days_needed': 2,
#   'price': 18.63,
#   'customer_id': 73,
#   'evaluater_id': 48,
#   'status': 'submitted'},
#  29: {'recipient_name': 'WanJFxVHFMRqggZj',
#   'recipient_addr': 'iXwOKjuFfTPbbtSxjGGgBoZrORXQFEVG',
#   'recipient_postal': '922623',
#   'pickup_addr': 'zUyIxaRZSYIXpAPIfjtNzOeXWdlVEzac',
#   'pickup_postal': '548032',
#   'pickup_date': '2016-11-28',
#   'submission_time': datetime.datetime(1978, 12, 29, 5, 0, 56),
#   'num_days_needed': 6,
#   'price': 58.81,
#   'customer_id': 920,
#   'evaluater_id': 40,
#   'status': 'unsuccessful',
#   'card_number': '863413088833',
#   'payment_time': datetime.datetime(2017, 5, 1, 22, 21, 11),
#   'monitor_id': 33},
#  30: {'recipient_name': 'szkpuSaAJCrCNVKJ',
#   'recipient_addr': 'wiTOBKarUKsylySWKgzLcpXhcXECavuT',
#   'recipient_postal': '698286',
#   'pickup_addr': 'panfSEFeYKPrybJLvEFFGdrXTgeDRNeQ',
#   'pickup_postal': '302658',
#   'pickup_date': '1972-01-05',
#   'submission_time': datetime.datetime(1972, 3, 31, 0, 18, 33),
#   'num_days_needed': 15,
#   'price': 68.81,
#   'customer_id': 303,
#   'evaluater_id': 21,
#   'status': 'withdrawn'},
#  31: {'recipient_name': 'tAQmhqmIZpqhoGrF',
#   'recipient_addr': 'bUoRhIddpYCtlppjUAkduPEsqEvoJNtH',
#   'recipient_postal': '626276',
#   'pickup_addr': 'NHzWAIAbGkNZfRrUipCnIixTtmMULapW',
#   'pickup_postal': '684820',
#   'pickup_date': '2020-05-25',
#   'submission_time': datetime.datetime(2009, 6, 8, 3, 17, 29),
#   'num_days_needed': 15,
#   'price': 27.43,
#   'customer_id': 389,
#   'evaluater_id': 44,
#   'status': 'completed',
#   'card_number': '554298207854',
#   'payment_time': datetime.datetime(2018, 8, 5, 17, 2, 8),
#   'monitor_id': 2},
#  32: {'recipient_name': 'wLrDjUzrnIwxAAUa',
#   'recipient_addr': 'EDTpbJaFRBIfqleZwflHLdxYUiUlMfct',
#   'recipient_postal': '089078',
#   'pickup_addr': 'rnsEobBwHszAUnLJcMezNcnrcKKOJHEJ',
#   'pickup_postal': '349049',
#   'pickup_date': '2002-05-31',
#   'submission_time': datetime.datetime(1974, 3, 24, 11, 11, 35),
#   'num_days_needed': 3,
#   'price': 92.57,
#   'customer_id': 265,
#   'evaluater_id': 27,
#   'status': 'cancelled',
#   'card_number': '623159540657',
#   'payment_time': datetime.datetime(1978, 9, 22, 1, 43, 30),
#   'monitor_id': 4,
#   'cancel_time': datetime.datetime(1974, 3, 24, 21, 11, 35)},
#  33: {'recipient_name': 'iUqdfVnbnfddzSgi',
#   'recipient_addr': 'iYHblMNUOyUwmPwbSgDigIGjsuJtJyYw',
#   'recipient_postal': '894467',
#   'pickup_addr': 'VgtBoDIRqyZsjNhxUTbaEkYvoxIILPEZ',
#   'pickup_postal': '964981',
#   'pickup_date': '2020-09-19',
#   'submission_time': datetime.datetime(1983, 6, 30, 12, 46, 11),
#   'num_days_needed': 14,
#   'price': 80.56,
#   'customer_id': 611,
#   'evaluater_id': 42,
#   'status': 'withdrawn'},
#  34: {'recipient_name': 'VZnKyHqceIoBwnIa',
#   'recipient_addr': 'okAPBZgxhilyIsSVmrXfqPVAjFLZcVBo',
#   'recipient_postal': '631265',
#   'pickup_addr': 'aRlqmiQrTocCZAPfolJItBMThdXOmNwp',
#   'pickup_postal': '514085',
#   'pickup_date': '1990-03-31',
#   'submission_time': datetime.datetime(1988, 4, 24, 5, 16, 47),
#   'num_days_needed': 4,
#   'price': 70.17,
#   'customer_id': 615,
#   'evaluater_id': 11,
#   'status': 'accepted',
#   'card_number': '478563073001',
#   'payment_time': datetime.datetime(1974, 4, 11, 22, 9, 52),
#   'monitor_id': 20},
#  35: {'recipient_name': 'hOYfdTYUvOvLPrZs',
#   'recipient_addr': 'eWqctNEXfpUIZTPwNcTUQEPrxHjCajiq',
#   'recipient_postal': '484857',
#   'pickup_addr': 'FaopEkaHTpJuYPXUuwAHyhDKthuoxqRt',
#   'pickup_postal': '319489',
#   'pickup_date': '1971-02-23',
#   'submission_time': datetime.datetime(1998, 5, 21, 11, 42, 1),
#   'num_days_needed': 5,
#   'price': 88.19,
#   'customer_id': 438,
#   'evaluater_id': 33,
#   'status': 'evaluated'},
#  36: {'recipient_name': 'cxoziwDJaocrgAUW',
#   'recipient_addr': 'AZUdcoIHNGcqhFaLKiFRJcuNOvaKxlAU',
#   'recipient_postal': '314180',
#   'pickup_addr': 'XizYYEGmCPAMMNWntRWhyDWEEpdDrYnA',
#   'pickup_postal': '407021',
#   'pickup_date': '2010-07-13',
#   'submission_time': datetime.datetime(2022, 2, 25, 13, 15, 9),
#   'num_days_needed': 8,
#   'price': 71.06,
#   'customer_id': 572,
#   'evaluater_id': 7,
#   'status': 'completed',
#   'card_number': '051418747991',
#   'payment_time': datetime.datetime(1973, 12, 29, 0, 57, 40),
#   'monitor_id': 18},
#  37: {'recipient_name': 'rATAslmYZLUSHBeH',
#   'recipient_addr': 'kyavZRklVHrxSuJXkylzYfUyfJCMBima',
#   'recipient_postal': '863862',
#   'pickup_addr': 'aAMocUDSQCaXBIvcFoOWzLZIWXunKfxI',
#   'pickup_postal': '954816',
#   'pickup_date': '1982-03-25',
#   'submission_time': datetime.datetime(2023, 3, 22, 5, 0, 42),
#   'num_days_needed': 7,
#   'price': 44.82,
#   'customer_id': 973,
#   'evaluater_id': 11,
#   'status': 'submitted'},
#  38: {'recipient_name': 'YrmCrvpfOYVQIigu',
#   'recipient_addr': 'RpqlTNeMzFusApsIPSDLTftFjneWthel',
#   'recipient_postal': '141498',
#   'pickup_addr': 'PRQpLqoHTHIpSgGgjcsWPCAQmgoFzOhz',
#   'pickup_postal': '111344',
#   'pickup_date': '1994-01-20',
#   'submission_time': datetime.datetime(2021, 1, 17, 20, 36, 29),
#   'num_days_needed': 9,
#   'price': 62.27,
#   'customer_id': 771,
#   'evaluater_id': 33,
#   'status': 'accepted',
#   'card_number': '932423181796',
#   'payment_time': datetime.datetime(1994, 2, 5, 5, 33, 12),
#   'monitor_id': 47},
#  39: {'recipient_name': 'VQkdKcIQGpNipJNd',
#   'recipient_addr': 'OFyYRYUeZuNtWcArpcivPMbrmjuDDqLo',
#   'recipient_postal': '033837',
#   'pickup_addr': 'JEowylYbYUiWCrwhVQPvcWFDaprahzgx',
#   'pickup_postal': '625054',
#   'pickup_date': '2012-04-16',
#   'submission_time': datetime.datetime(2004, 5, 16, 22, 55, 47),
#   'num_days_needed': 15,
#   'price': 97.05,
#   'customer_id': 712,
#   'evaluater_id': 4,
#   'status': 'withdrawn'},
#  40: {'recipient_name': 'LkZwZWssjKNXulTL',
#   'recipient_addr': 'JKZwLNIpBPjkudnRSgfngkfOrcUVodIx',
#   'recipient_postal': '522776',
#   'pickup_addr': 'dHjFcnbRwdkiZyKIyRMbOsKTptRiabEB',
#   'pickup_postal': '633645',
#   'pickup_date': '2019-06-06',
#   'submission_time': datetime.datetime(2011, 12, 12, 3, 9, 14),
#   'num_days_needed': 15,
#   'price': 64.89,
#   'customer_id': 97,
#   'evaluater_id': 20,
#   'status': 'unsuccessful',
#   'card_number': '341981915542',
#   'payment_time': datetime.datetime(1970, 2, 7, 17, 9, 42),
#   'monitor_id': 34},
#  41: {'recipient_name': 'NKjTKbZcOzFfcKWY',
#   'recipient_addr': 'wTpECUdXlXfIbxZHFOPCIaODbVxudJzs',
#   'recipient_postal': '540821',
#   'pickup_addr': 'pOzOTSkIksdYHyNzDtKgaPrxGpwbGktm',
#   'pickup_postal': '119334',
#   'pickup_date': '2014-09-12',
#   'submission_time': datetime.datetime(2011, 8, 28, 6, 37, 52),
#   'num_days_needed': 2,
#   'price': 53.35,
#   'customer_id': 489,
#   'evaluater_id': 38,
#   'status': 'accepted',
#   'card_number': '534604096463',
#   'payment_time': datetime.datetime(2001, 8, 30, 10, 56, 34),
#   'monitor_id': 14},
#  42: {'recipient_name': 'GIgwYpNZQXUePKBt',
#   'recipient_addr': 'GSkcXgLGObyPKdBjrKfVPJGiUfDMCYOd',
#   'recipient_postal': '851639',
#   'pickup_addr': 'annzrJrqpindXGPspzgNKIRHuzNbyNOz',
#   'pickup_postal': '055101',
#   'pickup_date': '1986-06-13',
#   'submission_time': datetime.datetime(2015, 11, 4, 8, 48, 2),
#   'num_days_needed': 6,
#   'price': 39.13,
#   'customer_id': 754,
#   'evaluater_id': 2,
#   'status': 'completed',
#   'card_number': '828816779332',
#   'payment_time': datetime.datetime(1997, 7, 13, 14, 32, 14),
#   'monitor_id': 16},
#  43: {'recipient_name': 'tTnQXoMAIPXuAgLC',
#   'recipient_addr': 'NMQErABHVEZIsrswvNDCsyawgVDhtNPw',
#   'recipient_postal': '630237',
#   'pickup_addr': 'XVvCuUlCBoxtcjAhqpWZczZdvRYGHdUC',
#   'pickup_postal': '682606',
#   'pickup_date': '1990-07-24',
#   'submission_time': datetime.datetime(2009, 12, 5, 9, 14, 52),
#   'num_days_needed': 4,
#   'price': 69.53,
#   'customer_id': 231,
#   'evaluater_id': 38,
#   'status': 'evaluated'},
#  44: {'recipient_name': 'IuvmlmaNsCrAwMPO',
#   'recipient_addr': 'BVfcVzHSFVxCurHEkcKjfKSkihUHASYM',
#   'recipient_postal': '932737',
#   'pickup_addr': 'kICTOhxjAoSAMcNgQGhSIEbLycpZFqIr',
#   'pickup_postal': '039493',
#   'pickup_date': '2006-10-27',
#   'submission_time': datetime.datetime(1996, 11, 29, 3, 33, 59),
#   'num_days_needed': 11,
#   'price': 44.48,
#   'customer_id': 279,
#   'evaluater_id': 1,
#   'status': 'submitted'},
#  45: {'recipient_name': 'UkgguuTGnnoutytq',
#   'recipient_addr': 'nXQqfYqJvMaXdwUrTSVzLwJTeoVyvqfC',
#   'recipient_postal': '311495',
#   'pickup_addr': 'lrcOapdCzJZqwPQQAPIEobedWrrqIhkc',
#   'pickup_postal': '780981',
#   'pickup_date': '2016-09-23',
#   'submission_time': datetime.datetime(1974, 1, 9, 6, 40, 20),
#   'num_days_needed': 5,
#   'price': 36.53,
#   'customer_id': 981,
#   'evaluater_id': 15,
#   'status': 'evaluated'},
#  46: {'recipient_name': 'OUOIwQZmHsvbFuSo',
#   'recipient_addr': 'iMLHbVBbTrOMbIfsNTQOqIXWiFFymhPI',
#   'recipient_postal': '033757',
#   'pickup_addr': 'QHWsmhazvStzOJoWotKeCJzXSndwkaVS',
#   'pickup_postal': '174076',
#   'pickup_date': '2006-09-15',
#   'submission_time': datetime.datetime(2014, 5, 25, 8, 14, 51),
#   'num_days_needed': 11,
#   'price': 5.93,
#   'customer_id': 823,
#   'evaluater_id': 41,
#   'status': 'evaluated'},
#  47: {'recipient_name': 'HBIYxDCDrJTWdWax',
#   'recipient_addr': 'vjZfXxDzQfNHQrZUqfYyisWHOxVYPFoL',
#   'recipient_postal': '882872',
#   'pickup_addr': 'lPReKcOUQTkJzGmjSCIiatBznfXIurqD',
#   'pickup_postal': '165828',
#   'pickup_date': '2009-08-06',
#   'submission_time': datetime.datetime(1980, 11, 26, 9, 5, 12),
#   'num_days_needed': 6,
#   'price': 4.27,
#   'customer_id': 859,
#   'evaluater_id': 14,
#   'status': 'accepted',
#   'card_number': '840168507870',
#   'payment_time': datetime.datetime(1991, 6, 27, 10, 57, 58),
#   'monitor_id': 2},
#  48: {'recipient_name': 'jYgnhKsFoZlgKkGQ',
#   'recipient_addr': 'chTRaRsABhAjDUAMSkbupIxcpYuxFrkB',
#   'recipient_postal': '259186',
#   'pickup_addr': 'iRWtJitijZxXKJJLgUuvNUZtqLlxupHl',
#   'pickup_postal': '136113',
#   'pickup_date': '1973-10-08',
#   'submission_time': datetime.datetime(1978, 8, 28, 2, 46, 32),
#   'num_days_needed': 8,
#   'price': 13.49,
#   'customer_id': 990,
#   'evaluater_id': 48,
#   'status': 'unsuccessful',
#   'card_number': '781551674113',
#   'payment_time': datetime.datetime(1978, 11, 2, 0, 55, 39),
#   'monitor_id': 28},
#  49: {'recipient_name': 'mtjIkBsXBZGKSaAW',
#   'recipient_addr': 'bbHauWbISraQOzgMgOcNVDDLtPHVdPEV',
#   'recipient_postal': '753254',
#   'pickup_addr': 'LBzFVupCweXnDXHJWWHsJpjSwxdxAZyY',
#   'pickup_postal': '003209',
#   'pickup_date': '1998-04-27',
#   'submission_time': datetime.datetime(1994, 1, 19, 15, 47, 40),
#   'num_days_needed': 2,
#   'price': 78.62,
#   'customer_id': 48,
#   'evaluater_id': 43,
#   'status': 'withdrawn'},
#  50: {'recipient_name': 'APfPqkGMaJSpPqkK',
#   'recipient_addr': 'CJNghjAOrzbTpOWpMCRyBSzBhCoPsarB',
#   'recipient_postal': '968806',
#   'pickup_addr': 'KDOMNRKyusxboDndIYtvJMnSEfUhScSf',
#   'pickup_postal': '108502',
#   'pickup_date': '1976-07-12',
#   'submission_time': datetime.datetime(1981, 12, 18, 22, 31, 4),
#   'num_days_needed': 8,
#   'price': 95.62,
#   'customer_id': 968,
#   'evaluater_id': 31,
#   'status': 'evaluated'},
#  51: {'recipient_name': 'zRhDzLvlUKLXFYUh',
#   'recipient_addr': 'GVDEGxhnrZkkbPxJDcxsRdihNMqkMBWr',
#   'recipient_postal': '597061',
#   'pickup_addr': 'OJqsEPzbbAMwEQJFhgYKiXBBtXCTVUwF',
#   'pickup_postal': '540312',
#   'pickup_date': '1980-08-28',
#   'submission_time': datetime.datetime(1989, 7, 4, 9, 30, 35),
#   'num_days_needed': 7,
#   'price': 43.19,
#   'customer_id': 27,
#   'evaluater_id': 39,
#   'status': 'withdrawn'},
#  52: {'recipient_name': 'lKGYzBOOLvmbEJEN',
#   'recipient_addr': 'mTARziislujMXcThAAvhKWPSQYpWCYEF',
#   'recipient_postal': '269800',
#   'pickup_addr': 'fLnpgNiTKbWdXyFGRSsXqvaWIDfijtcr',
#   'pickup_postal': '806125',
#   'pickup_date': '1978-11-26',
#   'submission_time': datetime.datetime(2000, 3, 16, 1, 20, 33),
#   'num_days_needed': 8,
#   'price': 46.37,
#   'customer_id': 590,
#   'evaluater_id': 20,
#   'status': 'evaluated'},
#  53: {'recipient_name': 'XPAbavPAUElMOLMi',
#   'recipient_addr': 'pYofSOZmYgbguoARskiyEBCspLTxVGTX',
#   'recipient_postal': '100812',
#   'pickup_addr': 'eYtRamSVCSGCJiEdfgQlCLNhHSXuKRCs',
#   'pickup_postal': '060404',
#   'pickup_date': '2009-02-10',
#   'submission_time': datetime.datetime(2010, 10, 20, 2, 20, 47),
#   'num_days_needed': 13,
#   'price': 4.51,
#   'customer_id': 948,
#   'evaluater_id': 15,
#   'status': 'accepted',
#   'card_number': '764357444510',
#   'payment_time': datetime.datetime(1978, 6, 16, 22, 27),
#   'monitor_id': 7},
#  54: {'recipient_name': 'dUthLVEvjsSMUYxO',
#   'recipient_addr': 'OovQhYRlAutKsaXiDOKVywvRRyPaEVer',
#   'recipient_postal': '521788',
#   'pickup_addr': 'pYkjePDdpOlPMhTUFtggFbtUbdZIOCCF',
#   'pickup_postal': '962562',
#   'pickup_date': '2000-03-22',
#   'submission_time': datetime.datetime(2001, 8, 16, 20, 17, 59),
#   'num_days_needed': 15,
#   'price': 65.78,
#   'customer_id': 391,
#   'evaluater_id': 8,
#   'status': 'withdrawn'},
#  55: {'recipient_name': 'ZoAXXMEPFyTEZjzu',
#   'recipient_addr': 'AUpFGcdePqpUHfHZGBgqkicrJNWERDRX',
#   'recipient_postal': '734522',
#   'pickup_addr': 'NlrgXfMBEvrTdyPNzDlXUfBdEROkkhAd',
#   'pickup_postal': '706173',
#   'pickup_date': '1992-07-12',
#   'submission_time': datetime.datetime(2006, 12, 14, 18, 22, 34),
#   'num_days_needed': 6,
#   'price': 28.21,
#   'customer_id': 89,
#   'evaluater_id': 11,
#   'status': 'submitted'},
#  56: {'recipient_name': 'GHvRTMBfOYtcEPnn',
#   'recipient_addr': 'ZCrYbednfmwhYaUIczpzkDDoVOECNfIJ',
#   'recipient_postal': '739433',
#   'pickup_addr': 'VtPodMNGwghzHxyVtjVimSEpLvHSbTid',
#   'pickup_postal': '042703',
#   'pickup_date': '1972-08-25',
#   'submission_time': datetime.datetime(2011, 8, 20, 3, 17, 19),
#   'num_days_needed': 8,
#   'price': 17.15,
#   'customer_id': 460,
#   'evaluater_id': 12,
#   'status': 'unsuccessful',
#   'card_number': '391980558356',
#   'payment_time': datetime.datetime(2013, 4, 20, 0, 32, 39),
#   'monitor_id': 20},
#  57: {'recipient_name': 'CUeTVhKuEZQRrWKs',
#   'recipient_addr': 'clUZFGxcXQGGPMHxfRuDcytkqmqyBjZr',
#   'recipient_postal': '639816',
#   'pickup_addr': 'ZpzKrHEfVfTDbcguvtlKDnwcTawPhRNs',
#   'pickup_postal': '027810',
#   'pickup_date': '1985-07-09',
#   'submission_time': datetime.datetime(2016, 6, 10, 23, 54, 28),
#   'num_days_needed': 3,
#   'price': 52.98,
#   'customer_id': 708,
#   'evaluater_id': 1,
#   'status': 'accepted',
#   'card_number': '319545680642',
#   'payment_time': datetime.datetime(2005, 6, 19, 6, 56, 31),
#   'monitor_id': 23},
#  58: {'recipient_name': 'FcawZtQUOPaUAJPL',
#   'recipient_addr': 'eIhLTeZpeUzKhiiTEgwvnyPnCyQBXUJt',
#   'recipient_postal': '879266',
#   'pickup_addr': 'jZpBvCZFfVfFEsuynJPwnPKTRgRPFaRh',
#   'pickup_postal': '300035',
#   'pickup_date': '2015-12-16',
#   'submission_time': datetime.datetime(1978, 3, 13, 21, 30, 19),
#   'num_days_needed': 15,
#   'price': 6.75,
#   'customer_id': 630,
#   'evaluater_id': 15,
#   'status': 'accepted',
#   'card_number': '259685093527',
#   'payment_time': datetime.datetime(2007, 9, 17, 8, 2, 17),
#   'monitor_id': 9},
#  59: {'recipient_name': 'hDkzyEuOGMNiJYBr',
#   'recipient_addr': 'lYihJGaMWmHyXrwPNWTTejauktKGnEEC',
#   'recipient_postal': '197728',
#   'pickup_addr': 'rpNMqYgsKrODjkIaWJdjHJOzVuchjQFV',
#   'pickup_postal': '536620',
#   'pickup_date': '2019-10-08',
#   'submission_time': datetime.datetime(1983, 12, 2, 22, 18, 2),
#   'num_days_needed': 6,
#   'price': 60.03,
#   'customer_id': 140,
#   'evaluater_id': 13,
#   'status': 'evaluated'},
#  60: {'recipient_name': 'PNGRDooqNsQmVjcB',
#   'recipient_addr': 'olQxHpOcMzPmndQYrVgKAqcwbvbCjbQC',
#   'recipient_postal': '799024',
#   'pickup_addr': 'uGUfomoMMgPYJDQcvQCICQESzrJxHQOm',
#   'pickup_postal': '408341',
#   'pickup_date': '1984-10-04',
#   'submission_time': datetime.datetime(1974, 10, 26, 4, 25, 31),
#   'num_days_needed': 6,
#   'price': 40.06,
#   'customer_id': 500,
#   'evaluater_id': 27,
#   'status': 'accepted',
#   'card_number': '356597060244',
#   'payment_time': datetime.datetime(1973, 7, 2, 4, 29, 23),
#   'monitor_id': 13},
#  61: {'recipient_name': 'JUIFkCIQrlGLsrqj',
#   'recipient_addr': 'LbLckbdcbASEzDjkhzGnBkUKSrwxKkvF',
#   'recipient_postal': '234276',
#   'pickup_addr': 'qxawgzrcdQxRadcZthVHybsfaMCxrWKd',
#   'pickup_postal': '461433',
#   'pickup_date': '2001-12-14',
#   'submission_time': datetime.datetime(1996, 12, 8, 4, 29, 25),
#   'num_days_needed': 10,
#   'price': 92.43,
#   'customer_id': 934,
#   'evaluater_id': 16,
#   'status': 'completed',
#   'card_number': '629234652180',
#   'payment_time': datetime.datetime(2014, 5, 25, 8, 19, 29),
#   'monitor_id': 21},
#  62: {'recipient_name': 'ZTVRhEAAFDNQIPqI',
#   'recipient_addr': 'uKULpxZmdVYAgRndtBOYgyFrPVTvLAsQ',
#   'recipient_postal': '863580',
#   'pickup_addr': 'BQYrDzSauQqeWDyIEXZDpnQkyoiLSTrn',
#   'pickup_postal': '188669',
#   'pickup_date': '2005-02-27',
#   'submission_time': datetime.datetime(1996, 9, 14, 2, 29, 42),
#   'num_days_needed': 5,
#   'price': 84.93,
#   'customer_id': 752,
#   'evaluater_id': 1,
#   'status': 'withdrawn'},
#  63: {'recipient_name': 'xVOtQlFcjgZPGaBu',
#   'recipient_addr': 'XfjjhofynGmxIKTpEJBltWlsWCFETgJN',
#   'recipient_postal': '542907',
#   'pickup_addr': 'oyQQnckTAZwEtiWKLrRmdrTuKCMiyYNX',
#   'pickup_postal': '518719',
#   'pickup_date': '1990-12-01',
#   'submission_time': datetime.datetime(1999, 6, 5, 14, 38, 30),
#   'num_days_needed': 7,
#   'price': 60.75,
#   'customer_id': 488,
#   'evaluater_id': 25,
#   'status': 'unsuccessful',
#   'card_number': '937855630349',
#   'payment_time': datetime.datetime(1976, 11, 3, 16, 58, 20),
#   'monitor_id': 19},
#  64: {'recipient_name': 'biiylrMVygMTDJiT',
#   'recipient_addr': 'HCRcXMDoKeZdaiEdcCyzfPDKLKHYCgpi',
#   'recipient_postal': '981689',
#   'pickup_addr': 'NjDlotBCaAAKJPAIrfrcvPuoOItnaEir',
#   'pickup_postal': '008786',
#   'pickup_date': '2020-03-26',
#   'submission_time': datetime.datetime(1979, 10, 11, 11, 21),
#   'num_days_needed': 6,
#   'price': 65.66,
#   'customer_id': 183,
#   'evaluater_id': 12,
#   'status': 'withdrawn'},
#  65: {'recipient_name': 'FtCQEPHEHpYdDHHQ',
#   'recipient_addr': 'KjZiqHGlDVlMGzKmNCBEnTRciUIjCJkc',
#   'recipient_postal': '402134',
#   'pickup_addr': 'muDhQmMJMBpIFWsmrKdCwxVftSvULpPZ',
#   'pickup_postal': '750844',
#   'pickup_date': '1973-01-03',
#   'submission_time': datetime.datetime(2001, 5, 8, 23, 17, 55),
#   'num_days_needed': 2,
#   'price': 43.27,
#   'customer_id': 565,
#   'evaluater_id': 8,
#   'status': 'cancelled',
#   'card_number': '211249576359',
#   'payment_time': datetime.datetime(1970, 11, 4, 7, 41, 26),
#   'monitor_id': 7,
#   'cancel_time': datetime.datetime(2001, 5, 9, 6, 17, 55)},
#  66: {'recipient_name': 'qEJzIkqixLpzbXtI',
#   'recipient_addr': 'vLpVNlKtTXostDETxIgBjxTayNbJhjWB',
#   'recipient_postal': '200649',
#   'pickup_addr': 'NdGnxiJAqmrTTyQxNFNpSDKznyPQhkTW',
#   'pickup_postal': '123003',
#   'pickup_date': '2017-10-06',
#   'submission_time': datetime.datetime(1980, 1, 31, 16, 51, 38),
#   'num_days_needed': 6,
#   'price': 9.09,
#   'customer_id': 542,
#   'evaluater_id': 19,
#   'status': 'evaluated'},
#  67: {'recipient_name': 'AwyQOQNFdCTValbP',
#   'recipient_addr': 'cMjYKhHklUeWivLoVeWOlyPajFOawNPt',
#   'recipient_postal': '588183',
#   'pickup_addr': 'tDErhaHsxwJNHxSFVqljsqhTlnrGeFcZ',
#   'pickup_postal': '964465',
#   'pickup_date': '2004-01-10',
#   'submission_time': datetime.datetime(2001, 9, 18, 19, 19, 6),
#   'num_days_needed': 16,
#   'price': 50.94,
#   'customer_id': 998,
#   'evaluater_id': 15,
#   'status': 'completed',
#   'card_number': '283186786977',
#   'payment_time': datetime.datetime(1971, 2, 2, 2, 50, 15),
#   'monitor_id': 44},
#  68: {'recipient_name': 'wZJQtQKSJvKSdCys',
#   'recipient_addr': 'UbUBvFqyLOTaCqCMuRYQckGgLsRfctKY',
#   'recipient_postal': '760018',
#   'pickup_addr': 'CXcFDZSWMRwgdWLfovpeyssfiWlSIFRc',
#   'pickup_postal': '926978',
#   'pickup_date': '1980-01-20',
#   'submission_time': datetime.datetime(1993, 8, 8, 3, 50, 9),
#   'num_days_needed': 8,
#   'price': 17.0,
#   'customer_id': 551,
#   'evaluater_id': 33,
#   'status': 'completed',
#   'card_number': '468689785755',
#   'payment_time': datetime.datetime(2006, 3, 15, 14, 20, 25),
#   'monitor_id': 29},
#  69: {'recipient_name': 'WRfPVKvcKUUFANrZ',
#   'recipient_addr': 'mVoFQRqLqYMeauQGlDGcEUBhCQeFhENe',
#   'recipient_postal': '156956',
#   'pickup_addr': 'UebcAVdoGyXfLtAcwRUDixaHCohXHJGG',
#   'pickup_postal': '268717',
#   'pickup_date': '1982-07-05',
#   'submission_time': datetime.datetime(1987, 6, 13, 14, 43, 34),
#   'num_days_needed': 13,
#   'price': 17.59,
#   'customer_id': 703,
#   'evaluater_id': 8,
#   'status': 'unsuccessful',
#   'card_number': '450405902398',
#   'payment_time': datetime.datetime(2012, 10, 7, 11, 29, 42),
#   'monitor_id': 20},
#  70: {'recipient_name': 'SEWLtKQzQqpaBXDh',
#   'recipient_addr': 'yJFxyiFSJkNwyEKCJTEBiNSJpalTGJrQ',
#   'recipient_postal': '227877',
#   'pickup_addr': 'sbrqhhzuGQohXRmTlscVRrmykWMAQkgu',
#   'pickup_postal': '559304',
#   'pickup_date': '2022-08-31',
#   'submission_time': datetime.datetime(1970, 2, 20, 19, 0, 46),
#   'num_days_needed': 4,
#   'price': 77.37,
#   'customer_id': 253,
#   'evaluater_id': 27,
#   'status': 'unsuccessful',
#   'card_number': '773989821316',
#   'payment_time': datetime.datetime(2007, 2, 4, 13, 5, 4),
#   'monitor_id': 47},
#  71: {'recipient_name': 'pjucrQSdWrKLnbPl',
#   'recipient_addr': 'VouGqqpobbjivEVnPnheOorrPqTTGbeq',
#   'recipient_postal': '342809',
#   'pickup_addr': 'PYXfYEZXVQjqkDANxrfsTnlWCOvmKDqV',
#   'pickup_postal': '151805',
#   'pickup_date': '1987-09-06',
#   'submission_time': datetime.datetime(2013, 7, 18, 2, 6, 17),
#   'num_days_needed': 15,
#   'price': 76.78,
#   'customer_id': 554,
#   'evaluater_id': 35,
#   'status': 'completed',
#   'card_number': '233458441056',
#   'payment_time': datetime.datetime(1998, 9, 15, 15, 42, 13),
#   'monitor_id': 37},
#  72: {'recipient_name': 'wjznxmIRqDuChLLC',
#   'recipient_addr': 'UXmETOZVDpiAgsLAqCDRmtIzohAJeavG',
#   'recipient_postal': '956704',
#   'pickup_addr': 'pRHeRDrrXghIfgvCbKhLsKZXxnwaDkeD',
#   'pickup_postal': '343310',
#   'pickup_date': '2021-11-27',
#   'submission_time': datetime.datetime(2017, 10, 14, 5, 51, 3),
#   'num_days_needed': 8,
#   'price': 96.93,
#   'customer_id': 696,
#   'evaluater_id': 18,
#   'status': 'completed',
#   'card_number': '631577677512',
#   'payment_time': datetime.datetime(1997, 2, 16, 13, 7, 32),
#   'monitor_id': 4},
#  73: {'recipient_name': 'MiVfYNbldnEiYOFG',
#   'recipient_addr': 'ryqTSbyLzgKhJchuGbIIecmvNuNYZZkj',
#   'recipient_postal': '604295',
#   'pickup_addr': 'ZNnBeDmCDNLzGkPRYZzJFbYLCkUftBzY',
#   'pickup_postal': '806283',
#   'pickup_date': '1984-04-21',
#   'submission_time': datetime.datetime(2019, 8, 30, 15, 42, 8),
#   'num_days_needed': 6,
#   'price': 90.74,
#   'customer_id': 893,
#   'evaluater_id': 42,
#   'status': 'withdrawn'},
#  74: {'recipient_name': 'FGqJrKlIfXauTWsY',
#   'recipient_addr': 'sbYyEaKMgqxAIAJLBmHTLpnoTExpYCmh',
#   'recipient_postal': '165398',
#   'pickup_addr': 'rVfTtOgUNxvmEbITuJDxNVWrzcxeHKQC',
#   'pickup_postal': '224721',
#   'pickup_date': '2014-08-03',
#   'submission_time': datetime.datetime(1976, 2, 29, 6, 9, 19),
#   'num_days_needed': 14,
#   'price': 39.57,
#   'customer_id': 635,
#   'evaluater_id': 8,
#   'status': 'evaluated'},
#  75: {'recipient_name': 'DHgaTGgQLymMuwQR',
#   'recipient_addr': 'jMyGddFNjzJbpKjgBoELxcIzIegwTYoF',
#   'recipient_postal': '128263',
#   'pickup_addr': 'aGUTIcXvBGSJupQLHjGscHOlOIVbBQll',
#   'pickup_postal': '751532',
#   'pickup_date': '2016-03-10',
#   'submission_time': datetime.datetime(1975, 7, 17, 10, 54, 15),
#   'num_days_needed': 11,
#   'price': 21.87,
#   'customer_id': 536,
#   'evaluater_id': 44,
#   'status': 'completed',
#   'card_number': '777467603793',
#   'payment_time': datetime.datetime(1987, 11, 25, 18, 30, 42),
#   'monitor_id': 11},
#  76: {'recipient_name': 'PQoOGfiwHOjUUhKN',
#   'recipient_addr': 'qxIlphxopuWYnmtYFazDASLsgJzEYiSq',
#   'recipient_postal': '395748',
#   'pickup_addr': 'fenpfJlYjoVJOJXEywwslSyHkTsJJapS',
#   'pickup_postal': '641449',
#   'pickup_date': '1976-07-23',
#   'submission_time': datetime.datetime(1976, 11, 10, 12, 35, 18),
#   'num_days_needed': 4,
#   'price': 86.16,
#   'customer_id': 967,
#   'evaluater_id': 15,
#   'status': 'unsuccessful',
#   'card_number': '661524322287',
#   'payment_time': datetime.datetime(1990, 9, 30, 4, 32, 34),
#   'monitor_id': 3},
#  77: {'recipient_name': 'dtbPRAwOgmtelWGv',
#   'recipient_addr': 'wYzDSsxNJDeuCBqJHtKSnDuOQleaeyQp',
#   'recipient_postal': '857302',
#   'pickup_addr': 'YocrkvTexbrkqRMIQFlmHggqTZafOgKF',
#   'pickup_postal': '329110',
#   'pickup_date': '1983-03-13',
#   'submission_time': datetime.datetime(1970, 10, 25, 17, 57, 54),
#   'num_days_needed': 15,
#   'price': 34.36,
#   'customer_id': 790,
#   'evaluater_id': 29,
#   'status': 'withdrawn'},
#  78: {'recipient_name': 'sxbBCGYeTPApNeIh',
#   'recipient_addr': 'hBOIlpaneLDyMIhZcPIvDEutXXHGecyt',
#   'recipient_postal': '893794',
#   'pickup_addr': 'XsVAAHmXviTwJMGrDersfEMTHeUcbPLh',
#   'pickup_postal': '292411',
#   'pickup_date': '2010-04-11',
#   'submission_time': datetime.datetime(1978, 1, 6, 1, 37, 16),
#   'num_days_needed': 8,
#   'price': 5.02,
#   'customer_id': 643,
#   'evaluater_id': 30,
#   'status': 'evaluated'},
#  79: {'recipient_name': 'fSgXgXEqpDTOlzAg',
#   'recipient_addr': 'GsBcKlSUhNiUAzSBUNprKzDwXcYdmSEM',
#   'recipient_postal': '544555',
#   'pickup_addr': 'axpdQhsbKqGqdiHtCJyGrhgqCYvhOpbm',
#   'pickup_postal': '623998',
#   'pickup_date': '1995-05-29',
#   'submission_time': datetime.datetime(2013, 9, 15, 9, 23, 20),
#   'num_days_needed': 4,
#   'price': 57.09,
#   'customer_id': 806,
#   'evaluater_id': 5,
#   'status': 'cancelled',
#   'card_number': '950658709187',
#   'payment_time': datetime.datetime(2019, 5, 30, 11, 52, 46),
#   'monitor_id': 41,
#   'cancel_time': datetime.datetime(2013, 9, 15, 11, 23, 20)},
#  80: {'recipient_name': 'QVcdbCtepvLjkVEa',
#   'recipient_addr': 'wjfpBZRsxPTzJuwjOCNCHxhQjzbLrjUD',
#   'recipient_postal': '504870',
#   'pickup_addr': 'yUIrHLLeYjXDrgXZDnSGnADqSltyBnCg',
#   'pickup_postal': '770134',
#   'pickup_date': '1979-03-28',
#   'submission_time': datetime.datetime(2022, 3, 28, 10, 41, 16),
#   'num_days_needed': 16,
#   'price': 2.35,
#   'customer_id': 986,
#   'evaluater_id': 31,
#   'status': 'evaluated'},
#  81: {'recipient_name': 'krKNGUDayNFxSDNa',
#   'recipient_addr': 'pqRrogBZlpGAJgdthjwHXZaqCtHXztqu',
#   'recipient_postal': '374543',
#   'pickup_addr': 'eOBXwcLbBggkkcSohtlBvRVPGfrYRLCk',
#   'pickup_postal': '392859',
#   'pickup_date': '1987-09-16',
#   'submission_time': datetime.datetime(1981, 7, 14, 7, 43, 15),
#   'num_days_needed': 2,
#   'price': 26.97,
#   'customer_id': 801,
#   'evaluater_id': 24,
#   'status': 'withdrawn'},
#  82: {'recipient_name': 'NVneCWljOCMgvanH',
#   'recipient_addr': 'CwuKoWBuyNtDDfFlfwrXJCynXewhaDTQ',
#   'recipient_postal': '458268',
#   'pickup_addr': 'BVvWteLVZjhYHmUoyQXXiznWvIGhtCJD',
#   'pickup_postal': '972444',
#   'pickup_date': '2016-10-06',
#   'submission_time': datetime.datetime(1989, 10, 1, 9, 28, 7),
#   'num_days_needed': 10,
#   'price': 86.6,
#   'customer_id': 760,
#   'evaluater_id': 30,
#   'status': 'unsuccessful',
#   'card_number': '015057561850',
#   'payment_time': datetime.datetime(1995, 5, 9, 23, 36, 22),
#   'monitor_id': 11},
#  83: {'recipient_name': 'FfpzhVZwACNuSCDI',
#   'recipient_addr': 'AqhcHCbPFZfqsPGaQCxrSgTvyrZBLDxn',
#   'recipient_postal': '637734',
#   'pickup_addr': 'KCupKZLbzUUTtRJKXrjkoHUGukNPdFgc',
#   'pickup_postal': '128879',
#   'pickup_date': '2012-02-13',
#   'submission_time': datetime.datetime(2017, 5, 4, 8, 5, 7),
#   'num_days_needed': 6,
#   'price': 92.2,
#   'customer_id': 709,
#   'evaluater_id': 21,
#   'status': 'withdrawn'},
#  84: {'recipient_name': 'xDesHwpSYhPHvpyY',
#   'recipient_addr': 'abzuUXOPquqfozEgnqTzPTbMddUlfrYP',
#   'recipient_postal': '077596',
#   'pickup_addr': 'TmoYOktQVizLSbVpVTmlhWerUpbPSTiI',
#   'pickup_postal': '312900',
#   'pickup_date': '2022-07-01',
#   'submission_time': datetime.datetime(2016, 7, 18, 1, 51, 25),
#   'num_days_needed': 12,
#   'price': 95.8,
#   'customer_id': 193,
#   'evaluater_id': 26,
#   'status': 'submitted'},
#  85: {'recipient_name': 'cXJRdgbzVfdANCfJ',
#   'recipient_addr': 'sugGCQefewAshFxjoRMEHCwvZRkMEsQL',
#   'recipient_postal': '426047',
#   'pickup_addr': 'TxvhmcmVIFIgBYXkRzSJeQVQVJcRWwCk',
#   'pickup_postal': '731619',
#   'pickup_date': '2017-05-28',
#   'submission_time': datetime.datetime(1990, 10, 27, 19, 40, 45),
#   'num_days_needed': 16,
#   'price': 52.28,
#   'customer_id': 966,
#   'evaluater_id': 38,
#   'status': 'completed',
#   'card_number': '965172960587',
#   'payment_time': datetime.datetime(2023, 3, 21, 21, 17, 45),
#   'monitor_id': 40},
#  86: {'recipient_name': 'QzqvcHWrhCqOEXMg',
#   'recipient_addr': 'zxKZNQCfHrnAJEPTIBDQiZNRWdcEDzfW',
#   'recipient_postal': '091738',
#   'pickup_addr': 'ctRBrvNQbAKLxXHBTpJvEXEjRzPERArK',
#   'pickup_postal': '074666',
#   'pickup_date': '1988-04-05',
#   'submission_time': datetime.datetime(2017, 9, 26, 6, 10, 22),
#   'num_days_needed': 15,
#   'price': 8.2,
#   'customer_id': 374,
#   'evaluater_id': 44,
#   'status': 'completed',
#   'card_number': '643907833399',
#   'payment_time': datetime.datetime(2018, 9, 10, 5, 0, 17),
#   'monitor_id': 15},
#  87: {'recipient_name': 'gvIumsvmoTecPqbP',
#   'recipient_addr': 'RLMhnEqkWnrDEwTrlHUhEtBFjhEDifCu',
#   'recipient_postal': '413751',
#   'pickup_addr': 'HkbpHaQUtIhOpwdzAglmkkPTYBpYUXNA',
#   'pickup_postal': '435221',
#   'pickup_date': '1994-08-01',
#   'submission_time': datetime.datetime(1994, 4, 19, 22, 59, 25),
#   'num_days_needed': 15,
#   'price': 70.89,
#   'customer_id': 316,
#   'evaluater_id': 41,
#   'status': 'cancelled',
#   'card_number': '931173172541',
#   'payment_time': datetime.datetime(1986, 1, 3, 5, 57, 18),
#   'monitor_id': 3,
#   'cancel_time': datetime.datetime(1994, 4, 19, 23, 59, 25)},
#  88: {'recipient_name': 'niDyhUIhalqRtEff',
#   'recipient_addr': 'fVycOIOSamqZvGQaoCZZEoxkwYYaBQhR',
#   'recipient_postal': '960034',
#   'pickup_addr': 'TxNyjIAUpCoKalMMItunpFgpZApVJzUz',
#   'pickup_postal': '869523',
#   'pickup_date': '2018-05-05',
#   'submission_time': datetime.datetime(1990, 1, 10, 13, 4, 18),
#   'num_days_needed': 6,
#   'price': 16.09,
#   'customer_id': 526,
#   'evaluater_id': 25,
#   'status': 'cancelled',
#   'card_number': '215189303481',
#   'payment_time': datetime.datetime(2019, 3, 18, 16, 53, 46),
#   'monitor_id': 39,
#   'cancel_time': datetime.datetime(1990, 1, 10, 20, 4, 18)},
#  89: {'recipient_name': 'vuZBCcicmqfbjLaH',
#   'recipient_addr': 'sKWXfNtvobAdZQWsAUJhkBGVZMGhDOfn',
#   'recipient_postal': '974063',
#   'pickup_addr': 'WquoDSSnUCbZLKxtiIySWYdLDLfofmMR',
#   'pickup_postal': '426989',
#   'pickup_date': '1995-04-18',
#   'submission_time': datetime.datetime(1990, 4, 18, 20, 49, 17),
#   'num_days_needed': 14,
#   'price': 22.14,
#   'customer_id': 243,
#   'evaluater_id': 5,
#   'status': 'submitted'},
#  90: {'recipient_name': 'QhubnJEOAKloIWza',
#   'recipient_addr': 'DgRfTtMjdosiKSbUrrRXkhrbbajUvXuz',
#   'recipient_postal': '347102',
#   'pickup_addr': 'vOpPcYrRXGfLCBsCTlmdyXnnCWxTktgf',
#   'pickup_postal': '132617',
#   'pickup_date': '1973-08-24',
#   'submission_time': datetime.datetime(1981, 5, 6, 15, 45, 56),
#   'num_days_needed': 15,
#   'price': 70.36,
#   'customer_id': 367,
#   'evaluater_id': 12,
#   'status': 'evaluated'},
#  91: {'recipient_name': 'TsbYJoywtYqGxCaf',
#   'recipient_addr': 'xGlpojfbyEJtwHfHGywauvVehIvnwKeA',
#   'recipient_postal': '454667',
#   'pickup_addr': 'jCefaivtMmWgLAbhyRWJCiypvEJkmrca',
#   'pickup_postal': '415992',
#   'pickup_date': '2015-01-18',
#   'submission_time': datetime.datetime(2011, 10, 10, 1, 29, 53),
#   'num_days_needed': 8,
#   'price': 31.83,
#   'customer_id': 155,
#   'evaluater_id': 11,
#   'status': 'completed',
#   'card_number': '559613225606',
#   'payment_time': datetime.datetime(2007, 9, 24, 6, 44, 48),
#   'monitor_id': 11},
#  92: {'recipient_name': 'tBrZPULWrbNVulJa',
#   'recipient_addr': 'HtgMvGQIilnVmbvJXrrVggKcfdhjCQJs',
#   'recipient_postal': '424270',
#   'pickup_addr': 'HRzUhjAXLATkRiBlsiaVSRLSGDxXrmwH',
#   'pickup_postal': '209839',
#   'pickup_date': '1986-07-20',
#   'submission_time': datetime.datetime(2021, 10, 5, 18, 35, 52),
#   'num_days_needed': 13,
#   'price': 13.89,
#   'customer_id': 85,
#   'evaluater_id': 36,
#   'status': 'completed',
#   'card_number': '395206748263',
#   'payment_time': datetime.datetime(2013, 6, 14, 2, 47, 7),
#   'monitor_id': 25},
#  93: {'recipient_name': 'KKKdFMsTMLPEvGtj',
#   'recipient_addr': 'DoZXOCHfQXOQgoyQlraSMYKKKtfzXVbF',
#   'recipient_postal': '637845',
#   'pickup_addr': 'KPcblygEsVdaTqCHZhsOgIRjAyilVkNe',
#   'pickup_postal': '841133',
#   'pickup_date': '1984-02-26',
#   'submission_time': datetime.datetime(1986, 12, 20, 7, 32, 59),
#   'num_days_needed': 5,
#   'price': 47.91,
#   'customer_id': 378,
#   'evaluater_id': 33,
#   'status': 'accepted',
#   'card_number': '065143086370',
#   'payment_time': datetime.datetime(1987, 7, 29, 16, 1, 55),
#   'monitor_id': 19},
#  94: {'recipient_name': 'UhDDxoGIKVHjdody',
#   'recipient_addr': 'ZKTapYhvMbvizssAljGedvktRocOaFZQ',
#   'recipient_postal': '111213',
#   'pickup_addr': 'AStInqSpytiVMtAOcGvPwvMkqExDUIAm',
#   'pickup_postal': '552536',
#   'pickup_date': '1992-12-20',
#   'submission_time': datetime.datetime(2009, 3, 15, 7, 7, 41),
#   'num_days_needed': 15,
#   'price': 99.2,
#   'customer_id': 777,
#   'evaluater_id': 17,
#   'status': 'submitted'},
#  95: {'recipient_name': 'kVuBvTdJrPtKDVKK',
#   'recipient_addr': 'DtQPkQEFKuyiLvBIfBHscFCIEFMdVTSX',
#   'recipient_postal': '851746',
#   'pickup_addr': 'BzDjnhLehmIhxlGzgAMnZRbDcVoNcHvj',
#   'pickup_postal': '614980',
#   'pickup_date': '2011-04-13',
#   'submission_time': datetime.datetime(1991, 6, 16, 0, 4, 8),
#   'num_days_needed': 3,
#   'price': 26.06,
#   'customer_id': 704,
#   'evaluater_id': 20,
#   'status': 'unsuccessful',
#   'card_number': '516902529403',
#   'payment_time': datetime.datetime(1974, 5, 12, 4, 3, 35),
#   'monitor_id': 3},
#  96: {'recipient_name': 'nvkgEQNOoZqlOEdC',
#   'recipient_addr': 'GCXHdENgmbMKdEtAWqYCuxMMxVPJBteN',
#   'recipient_postal': '684965',
#   'pickup_addr': 'lsxCBajQbNTbDxFNtpwMDLGUgpgCTKDg',
#   'pickup_postal': '556061',
#   'pickup_date': '2001-02-27',
#   'submission_time': datetime.datetime(1988, 3, 26, 20, 32, 19),
#   'num_days_needed': 15,
#   'price': 81.53,
#   'customer_id': 986,
#   'evaluater_id': 4,
#   'status': 'withdrawn'},
#  97: {'recipient_name': 'lWAugryUnSRiWeWy',
#   'recipient_addr': 'xjYtgdBFcHCjlcWyOGRVlmfpxvlItfVY',
#   'recipient_postal': '392597',
#   'pickup_addr': 'avCYkoHzcxknvoNcIteEKuXLKLqxsHTR',
#   'pickup_postal': '892047',
#   'pickup_date': '1992-08-06',
#   'submission_time': datetime.datetime(2000, 10, 26, 9, 14, 5),
#   'num_days_needed': 8,
#   'price': 1.15,
#   'customer_id': 649,
#   'evaluater_id': 5,
#   'status': 'submitted'},
#  98: {'recipient_name': 'BOtflosNhPjrezJu',
#   'recipient_addr': 'pYPCcclFUIAkvZuHJkjAwQXaagkdZTzX',
#   'recipient_postal': '633985',
#   'pickup_addr': 'xzlhwtxdmQpclcqMXGfkGyJSKoRvFqSU',
#   'pickup_postal': '633090',
#   'pickup_date': '1971-09-26',
#   'submission_time': datetime.datetime(1991, 2, 16, 2, 9, 24),
#   'num_days_needed': 5,
#   'price': 70.34,
#   'customer_id': 273,
#   'evaluater_id': 24,
#   'status': 'cancelled',
#   'card_number': '828792752960',
#   'payment_time': datetime.datetime(2009, 3, 12, 2, 9, 54),
#   'monitor_id': 40,
#   'cancel_time': datetime.datetime(1991, 2, 16, 8, 9, 24)},
# ...
#   'monitor_id': 21},
#  968: {'recipient_name': 'abbmEtGcgjFwINlI',
#   'recipient_addr': 'XzMmwWXGqNondlUuBNrXGtUKHNauYWbz',
#   'recipient_postal': '450641',
#   'pickup_addr': 'GGLxXSYaOvpRFiXbGQOrrrCXrDNxFAvR',
#   'pickup_postal': '304094',
#   'pickup_date': '2011-06-27',
#   'submission_time': datetime.datetime(1979, 3, 14, 21, 36, 55),
#   'num_days_needed': 8,
#   'price': 90.16,
#   'customer_id': 644,
#   'evaluater_id': 11,
#   'status': 'withdrawn'},
#  969: {'recipient_name': 'ypxIAORrNPnURoNr',
#   'recipient_addr': 'XJbAKKkIejJZWsGSpYgSMbylsOrSPNiQ',
#   'recipient_postal': '278188',
#   'pickup_addr': 'yknpyVvcUIlbLlwCgWkAUWZMTaHOsfHi',
#   'pickup_postal': '952856',
#   'pickup_date': '1970-10-05',
#   'submission_time': datetime.datetime(2008, 2, 20, 22, 42, 31),
#   'num_days_needed': 15,
#   'price': 68.97,
#   'customer_id': 317,
#   'evaluater_id': 44,
#   'status': 'withdrawn'},
#  970: {'recipient_name': 'WvTClmcLmZRizbpx',
#   'recipient_addr': 'MbWzvkbjbrmgQmnPdemTEsCZezHukYHJ',
#   'recipient_postal': '737049',
#   'pickup_addr': 'zsWfAWcbNeopoZfZWLxcCqWQXIHwCyxT',
#   'pickup_postal': '891439',
#   'pickup_date': '1979-12-11',
#   'submission_time': datetime.datetime(1986, 12, 5, 15, 55, 17),
#   'num_days_needed': 15,
#   'price': 19.31,
#   'customer_id': 901,
#   'evaluater_id': 41,
#   'status': 'unsuccessful',
#   'card_number': '737690862674',
#   'payment_time': datetime.datetime(1978, 7, 20, 12, 45, 51),
#   'monitor_id': 28},
#  971: {'recipient_name': 'RrwJJGjBYWaKiFxP',
#   'recipient_addr': 'uFJqjHniggqCTgxtDrcBOSqSZHyxNNal',
#   'recipient_postal': '424635',
#   'pickup_addr': 'gtowlltVHpbQHGMTcNPzwlDkfcoqalmd',
#   'pickup_postal': '985587',
#   'pickup_date': '1976-10-27',
#   'submission_time': datetime.datetime(1978, 10, 7, 6, 18, 35),
#   'num_days_needed': 10,
#   'price': 83.82,
#   'customer_id': 82,
#   'evaluater_id': 50,
#   'status': 'evaluated'},
#  972: {'recipient_name': 'DKYlLLwMTmKOUFLf',
#   'recipient_addr': 'BgHKXdKBbrLAmhvDWVLljkXdUljyHkgO',
#   'recipient_postal': '089670',
#   'pickup_addr': 'otZAcAPAGEDjHnYXhzPjplOMvUJIbSrY',
#   'pickup_postal': '984999',
#   'pickup_date': '2006-07-18',
#   'submission_time': datetime.datetime(1989, 8, 28, 14, 4, 38),
#   'num_days_needed': 6,
#   'price': 1.43,
#   'customer_id': 94,
#   'evaluater_id': 25,
#   'status': 'unsuccessful',
#   'card_number': '932789844983',
#   'payment_time': datetime.datetime(1993, 1, 17, 9, 43, 36),
#   'monitor_id': 38},
#  973: {'recipient_name': 'tKQbHCVXWQsaNvBT',
#   'recipient_addr': 'YJaVmjmnzeMJNEwAWDCEfSvLRUvXJsFT',
#   'recipient_postal': '431053',
#   'pickup_addr': 'VwoIheTAWrFiNMFOAwyjPJfpvdfibIAn',
#   'pickup_postal': '073068',
#   'pickup_date': '1973-01-24',
#   'submission_time': datetime.datetime(1989, 12, 12, 7, 17, 14),
#   'num_days_needed': 16,
#   'price': 17.82,
#   'customer_id': 689,
#   'evaluater_id': 30,
#   'status': 'completed',
#   'card_number': '297257518704',
#   'payment_time': datetime.datetime(2005, 10, 2, 6, 28, 56),
#   'monitor_id': 48},
#  974: {'recipient_name': 'KjQSiFKIWEPOLvpT',
#   'recipient_addr': 'hXtyvJJZhQzPmqzYDJBzEySyiAbjLjMm',
#   'recipient_postal': '182145',
#   'pickup_addr': 'tHtdJZdRBogIbbHtWXtajJoWNHKehuae',
#   'pickup_postal': '817861',
#   'pickup_date': '1982-06-14',
#   'submission_time': datetime.datetime(1996, 10, 19, 6, 32, 6),
#   'num_days_needed': 9,
#   'price': 96.66,
#   'customer_id': 999,
#   'evaluater_id': 8,
#   'status': 'accepted',
#   'card_number': '248732294361',
#   'payment_time': datetime.datetime(2014, 2, 26, 18, 34, 3),
#   'monitor_id': 26},
#  975: {'recipient_name': 'tGCgFMVUbjxsrYZC',
#   'recipient_addr': 'kqrJJeRtagWhLnvIHYPowwtLhtUGHMcy',
#   'recipient_postal': '958142',
#   'pickup_addr': 'wNHCMmveuAhGOLxZmtLcerOvkxXNMlUR',
#   'pickup_postal': '739524',
#   'pickup_date': '1983-04-11',
#   'submission_time': datetime.datetime(1990, 1, 3, 1, 33, 20),
#   'num_days_needed': 16,
#   'price': 57.12,
#   'customer_id': 652,
#   'evaluater_id': 30,
#   'status': 'cancelled',
#   'card_number': '139482475748',
#   'payment_time': datetime.datetime(2020, 11, 27, 3, 18, 36),
#   'monitor_id': 40,
#   'cancel_time': datetime.datetime(1990, 1, 3, 5, 33, 20)},
#  976: {'recipient_name': 'UtrkjUJcfwSwMakM',
#   'recipient_addr': 'qnaIXOndBsRqFsNzVPMZDkMSdtqCVCwi',
#   'recipient_postal': '207683',
#   'pickup_addr': 'HpsYeSkdKofvfdncDnsMFNNCtRmgaVkM',
#   'pickup_postal': '951362',
#   'pickup_date': '2018-10-01',
#   'submission_time': datetime.datetime(1982, 8, 9, 13, 12, 20),
#   'num_days_needed': 13,
#   'price': 96.55,
#   'customer_id': 469,
#   'evaluater_id': 50,
#   'status': 'evaluated'},
#  977: {'recipient_name': 'KyojgWlkCUvxEhfd',
#   'recipient_addr': 'kTMClWdmHJZsRDXdBIJTbzSjfzfbjUig',
#   'recipient_postal': '850908',
#   'pickup_addr': 'bfWiWCWOozcvENupUULCrcuGbCxdzlNa',
#   'pickup_postal': '919162',
#   'pickup_date': '1982-06-29',
#   'submission_time': datetime.datetime(1980, 4, 8, 21, 16, 20),
#   'num_days_needed': 15,
#   'price': 67.57,
#   'customer_id': 138,
#   'evaluater_id': 39,
#   'status': 'submitted'},
#  978: {'recipient_name': 'WUGLUhkHXuruDCAl',
#   'recipient_addr': 'WVgqSKsAoNKMWppSBClINVmqaCMtrAof',
#   'recipient_postal': '670813',
#   'pickup_addr': 'ErJUrHezPXfiNkHkbNBHWejWflwkysAq',
#   'pickup_postal': '403023',
#   'pickup_date': '1988-07-19',
#   'submission_time': datetime.datetime(1974, 5, 30, 2, 16, 49),
#   'num_days_needed': 7,
#   'price': 89.11,
#   'customer_id': 807,
#   'evaluater_id': 10,
#   'status': 'withdrawn'},
#  979: {'recipient_name': 'dOoEfMrrTjDiaUSv',
#   'recipient_addr': 'ZncUfYmriGHkdSJcFKhwChPQPRQzSzOs',
#   'recipient_postal': '772031',
#   'pickup_addr': 'QKHyhBLKyTYdKCPukcvquwLQbunfawVu',
#   'pickup_postal': '016805',
#   'pickup_date': '2004-03-14',
#   'submission_time': datetime.datetime(1982, 7, 1, 14, 2, 14),
#   'num_days_needed': 12,
#   'price': 73.65,
#   'customer_id': 738,
#   'evaluater_id': 1,
#   'status': 'submitted'},
#  980: {'recipient_name': 'aqniKaAyTPZvHplA',
#   'recipient_addr': 'extHKOEqPiwXbczGrrABPLPwVmJDNZNH',
#   'recipient_postal': '334434',
#   'pickup_addr': 'dQWkOmdHJuSikRyttYOEaXIQJaIIHDgG',
#   'pickup_postal': '461874',
#   'pickup_date': '2019-03-19',
#   'submission_time': datetime.datetime(1980, 12, 15, 1, 34, 48),
#   'num_days_needed': 15,
#   'price': 82.63,
#   'customer_id': 528,
#   'evaluater_id': 31,
#   'status': 'cancelled',
#   'card_number': '913109934970',
#   'payment_time': datetime.datetime(1997, 5, 20, 7, 19, 58),
#   'monitor_id': 9,
#   'cancel_time': datetime.datetime(1980, 12, 15, 13, 34, 48)},
#  981: {'recipient_name': 'owrlYVBJoozUgSsB',
#   'recipient_addr': 'WCgdPooWhCrZeLGCTaQWtcjyLkstJXgS',
#   'recipient_postal': '427047',
#   'pickup_addr': 'DaecFhhRWxjwmLLbvxhiagruZbEQsCce',
#   'pickup_postal': '379081',
#   'pickup_date': '1976-07-09',
#   'submission_time': datetime.datetime(1998, 3, 27, 18, 10, 22),
#   'num_days_needed': 2,
#   'price': 41.24,
#   'customer_id': 964,
#   'evaluater_id': 13,
#   'status': 'completed',
#   'card_number': '123761562037',
#   'payment_time': datetime.datetime(1995, 7, 16, 16, 58, 24),
#   'monitor_id': 11},
#  982: {'recipient_name': 'PjJctawofMuQBqPD',
#   'recipient_addr': 'HGDJgcHTuhjzQACXZmaKPhWZiJmjBwOQ',
#   'recipient_postal': '470966',
#   'pickup_addr': 'AImkqdwUyegbFLfurDoCaFANcVUuIBRJ',
#   'pickup_postal': '263585',
#   'pickup_date': '1994-02-15',
#   'submission_time': datetime.datetime(2010, 7, 11, 8, 57, 44),
#   'num_days_needed': 4,
#   'price': 84.85,
#   'customer_id': 260,
#   'evaluater_id': 2,
#   'status': 'accepted',
#   'card_number': '891839719976',
#   'payment_time': datetime.datetime(2003, 6, 27, 13, 48, 32),
#   'monitor_id': 3},
#  983: {'recipient_name': 'xXGDDPWOIJZuwXzL',
#   'recipient_addr': 'sVtZJGxESfHMHxHeVkeSBatBiLQzYpCW',
#   'recipient_postal': '132988',
#   'pickup_addr': 'TfznxXZfWoWtWVHmnTGLpcdwGYNfnZRI',
#   'pickup_postal': '615258',
#   'pickup_date': '2012-08-01',
#   'submission_time': datetime.datetime(1973, 1, 14, 18, 59),
#   'num_days_needed': 10,
#   'price': 54.55,
#   'customer_id': 689,
#   'evaluater_id': 12,
#   'status': 'withdrawn'},
#  984: {'recipient_name': 'nuhNIHcVfprfBjDb',
#   'recipient_addr': 'DblmAIbGTRlJOgeFKiYXGimqyCCHpMCf',
#   'recipient_postal': '948121',
#   'pickup_addr': 'wijhlVZGmrcdBnelVxLhhaWUhlxqOpbo',
#   'pickup_postal': '715934',
#   'pickup_date': '1990-07-11',
#   'submission_time': datetime.datetime(1975, 7, 4, 14, 29, 53),
#   'num_days_needed': 5,
#   'price': 29.44,
#   'customer_id': 673,
#   'evaluater_id': 3,
#   'status': 'completed',
#   'card_number': '167694040824',
#   'payment_time': datetime.datetime(2007, 10, 13, 0, 40, 1),
#   'monitor_id': 44},
#  985: {'recipient_name': 'iIhEhEcKIklEovCt',
#   'recipient_addr': 'LqYBOFUOgXFqeuroTMcUNVZbfDRJBPoI',
#   'recipient_postal': '048108',
#   'pickup_addr': 'RcnDkWUfEsuKxssMDzWXgGtEDTodGjEF',
#   'pickup_postal': '685700',
#   'pickup_date': '1982-11-24',
#   'submission_time': datetime.datetime(2009, 8, 11, 1, 3, 2),
#   'num_days_needed': 3,
#   'price': 28.85,
#   'customer_id': 214,
#   'evaluater_id': 13,
#   'status': 'unsuccessful',
#   'card_number': '616342944042',
#   'payment_time': datetime.datetime(1996, 4, 5, 9, 54, 12),
#   'monitor_id': 37},
#  986: {'recipient_name': 'bxFloWfafKODPend',
#   'recipient_addr': 'dndrpIlmaFhevIcNkHTrmRzVlloZumgC',
#   'recipient_postal': '194288',
#   'pickup_addr': 'mXammpjLIhItBHDTONeAPTkcROPBYvpZ',
#   'pickup_postal': '661449',
#   'pickup_date': '1975-07-13',
#   'submission_time': datetime.datetime(1998, 1, 13, 18, 51, 49),
#   'num_days_needed': 4,
#   'price': 74.18,
#   'customer_id': 3,
#   'evaluater_id': 15,
#   'status': 'evaluated'},
#  987: {'recipient_name': 'rLQKSFiIMZFaCIfr',
#   'recipient_addr': 'VnWtpkAcYmXAzkuHYulLbtlefvxZqSWJ',
#   'recipient_postal': '110429',
#   'pickup_addr': 'PjZGlfrtKBrbdXlUMelflVHOjBNEzazP',
#   'pickup_postal': '661739',
#   'pickup_date': '1975-10-18',
#   'submission_time': datetime.datetime(1983, 1, 26, 14, 11, 27),
#   'num_days_needed': 13,
#   'price': 67.73,
#   'customer_id': 722,
#   'evaluater_id': 6,
#   'status': 'submitted'},
#  988: {'recipient_name': 'kRalnlDLOYhaXloY',
#   'recipient_addr': 'kQiusngJxDCGbmRhjLkIraEOyKCWgoRV',
#   'recipient_postal': '989016',
#   'pickup_addr': 'YzEsMqrxkVIJhYxAFSOJYcVmXQtjXHpf',
#   'pickup_postal': '621080',
#   'pickup_date': '1996-03-24',
#   'submission_time': datetime.datetime(1990, 12, 6, 10, 18, 32),
#   'num_days_needed': 13,
#   'price': 53.93,
#   'customer_id': 870,
#   'evaluater_id': 49,
#   'status': 'accepted',
#   'card_number': '490263557073',
#   'payment_time': datetime.datetime(1984, 6, 24, 13, 25, 19),
#   'monitor_id': 43},
#  989: {'recipient_name': 'vScMYrlzORxflDbO',
#   'recipient_addr': 'OrhtUWkCmdwgGsoKVVcSfTBkIVVXwbZo',
#   'recipient_postal': '136471',
#   'pickup_addr': 'ALAGqGdPueTMfQDtSCymmsLyAcbmuKkg',
#   'pickup_postal': '469790',
#   'pickup_date': '2010-09-22',
#   'submission_time': datetime.datetime(1972, 3, 1, 19, 3, 49),
#   'num_days_needed': 8,
#   'price': 75.88,
#   'customer_id': 145,
#   'evaluater_id': 15,
#   'status': 'evaluated'},
#  990: {'recipient_name': 'YCyiiQhrOFOPbJqP',
#   'recipient_addr': 'CezBilTwkQqmuVtJAaTTXTKqkwMhLrBH',
#   'recipient_postal': '784190',
#   'pickup_addr': 'nJnXZuFEDXarCyahRPOZXUCjcyVogRZi',
#   'pickup_postal': '158975',
#   'pickup_date': '2000-01-29',
#   'submission_time': datetime.datetime(1988, 7, 20, 9, 15, 58),
#   'num_days_needed': 9,
#   'price': 27.12,
#   'customer_id': 505,
#   'evaluater_id': 20,
#   'status': 'submitted'},
#  991: {'recipient_name': 'opReQiVaDXsrWtzJ',
#   'recipient_addr': 'jdQBKorzHWbSivwnQTzwDkVlMzKNrnqO',
#   'recipient_postal': '294741',
#   'pickup_addr': 'mstkCQSOFbckJUKllpSqLcQsaIGCPVcJ',
#   'pickup_postal': '474441',
#   'pickup_date': '2015-02-01',
#   'submission_time': datetime.datetime(1975, 7, 1, 16, 57, 34),
#   'num_days_needed': 10,
#   'price': 79.53,
#   'customer_id': 617,
#   'evaluater_id': 10,
#   'status': 'withdrawn'},
#  992: {'recipient_name': 'RntSJcxBkPJMRHdG',
#   'recipient_addr': 'jjqjDdwbvFavGdbbXfCJTiFBFDBOXHag',
#   'recipient_postal': '072212',
#   'pickup_addr': 'ayhFXlcLauukxOZtjkGraTkQZRyAHDTj',
#   'pickup_postal': '324290',
#   'pickup_date': '2017-02-28',
#   'submission_time': datetime.datetime(2020, 12, 29, 13, 48, 50),
#   'num_days_needed': 13,
#   'price': 77.33,
#   'customer_id': 387,
#   'evaluater_id': 41,
#   'status': 'accepted',
#   'card_number': '524479182492',
#   'payment_time': datetime.datetime(2014, 9, 16, 9, 24, 43),
#   'monitor_id': 19},
#  993: {'recipient_name': 'KaDFUZwTBaNpOngE',
#   'recipient_addr': 'ZNTwHYZESvEEuIMxdgItQMywjUCAwPMR',
#   'recipient_postal': '183170',
#   'pickup_addr': 'LzbSTIbYQPFdBNsGrfTgztGjYjKVrMtb',
#   'pickup_postal': '965034',
#   'pickup_date': '1973-07-26',
#   'submission_time': datetime.datetime(2001, 6, 19, 10, 12, 26),
#   'num_days_needed': 14,
#   'price': 19.04,
#   'customer_id': 107,
#   'evaluater_id': 33,
#   'status': 'completed',
#   'card_number': '893319428290',
#   'payment_time': datetime.datetime(2010, 4, 30, 17, 51, 26),
#   'monitor_id': 37},
#  994: {'recipient_name': 'ZrHJqMBMSkniCaRA',
#   'recipient_addr': 'mYSSMaCCuVxwRoQJYkBWfcDKHmMgXlzc',
#   'recipient_postal': '035082',
#   'pickup_addr': 'odLTBmVkZgREnsQbwivVGinrdyceebUF',
#   'pickup_postal': '170097',
#   'pickup_date': '2006-01-20',
#   'submission_time': datetime.datetime(2012, 10, 6, 4, 9, 26),
#   'num_days_needed': 8,
#   'price': 30.65,
#   'customer_id': 259,
#   'evaluater_id': 1,
#   'status': 'evaluated'},
#  995: {'recipient_name': 'OdoYzzvqinOjYXme',
#   'recipient_addr': 'jyPWZXhZjyXnSvSXCWdJcaMZlIMQvInB',
#   'recipient_postal': '056624',
#   'pickup_addr': 'dKNJJauaitIfgRNuQqTQqEqFUugHitbF',
#   'pickup_postal': '915666',
#   'pickup_date': '1997-07-26',
#   'submission_time': datetime.datetime(2023, 1, 2, 9, 18, 38),
#   'num_days_needed': 12,
#   'price': 74.26,
#   'customer_id': 18,
#   'evaluater_id': 6,
#   'status': 'submitted'},
#  996: {'recipient_name': 'LFBUKIRJijyOMhHs',
#   'recipient_addr': 'lMTCOcVAKLJtPslKnTAdqQAQuIrMHKhQ',
#   'recipient_postal': '360419',
#   'pickup_addr': 'GRLUQAJicCHfYumbzULscENadFVlIKNx',
#   'pickup_postal': '127739',
#   'pickup_date': '2009-10-09',
#   'submission_time': datetime.datetime(1975, 1, 8, 1, 51, 10),
#   'num_days_needed': 15,
#   'price': 93.37,
#   'customer_id': 924,
#   'evaluater_id': 47,
#   'status': 'withdrawn'},
#  997: {'recipient_name': 'OHNRUuEJIjRhczDF',
#   'recipient_addr': 'eWzvpNJtiWtQfdEPQuvhENIwOHUgzsqJ',
#   'recipient_postal': '783493',
#   'pickup_addr': 'LwKFuGyUDiBnUgxAZggHodNytSKOLdgI',
#   'pickup_postal': '939970',
#   'pickup_date': '1972-05-29',
#   'submission_time': datetime.datetime(1991, 7, 22, 3, 11, 21),
#   'num_days_needed': 8,
#   'price': 36.3,
#   'customer_id': 73,
#   'evaluater_id': 38,
#   'status': 'unsuccessful',
#   'card_number': '658347061032',
#   'payment_time': datetime.datetime(2016, 12, 16, 12, 52, 31),
#   'monitor_id': 13},
#  998: {'recipient_name': 'PVVQxLfaicbyxwqT',
#   'recipient_addr': 'VYAFADbxtGgfvoVBNZNVHzSUNKvqkLXx',
#   'recipient_postal': '276449',
#   'pickup_addr': 'OcFAStzQaiWHwZxBjeijaqbrNDZQtvoM',
#   'pickup_postal': '719659',
#   'pickup_date': '2012-02-12',
#   'submission_time': datetime.datetime(1992, 3, 13, 1, 52, 2),
#   'num_days_needed': 2,
#   'price': 61.24,
#   'customer_id': 640,
#   'evaluater_id': 27,
#   'status': 'accepted',
#   'card_number': '507645834204',
#   'payment_time': datetime.datetime(2022, 4, 16, 21, 58, 26),
#   'monitor_id': 29},
#  999: {'recipient_name': 'xgVottPOkybznjGF',
#   'recipient_addr': 'rcMffGamDzyUvJjiimhkblusctoAZRik',
#   'recipient_postal': '194650',
#   'pickup_addr': 'iRrwrAADnDcuYLDamdFiTDFeKNCTuHqj',
#   'pickup_postal': '549242',
#   'pickup_date': '1994-09-30',
#   'submission_time': datetime.datetime(1989, 4, 2, 22, 1, 47),
#   'num_days_needed': 15,
#   'price': 90.63,
#   'customer_id': 137,
#   'evaluater_id': 38,
#   'status': 'cancelled',
#   'card_number': '364918309285',
#   'payment_time': datetime.datetime(2022, 9, 8, 22, 17, 52),
#   'monitor_id': 44,
#   'cancel_time': datetime.datetime(1989, 4, 3, 2, 1, 47)},
#  1000: {'recipient_name': 'ncSeTKQXypbCbGwE',
#   'recipient_addr': 'UHwdhxmQoixfdJRLtqVGebVUveXadpbM',
#   'recipient_postal': '487427',
#   'pickup_addr': 'ZLLEEBKQrAoplsxHLONdbebXECGzeyuw',
#   'pickup_postal': '137842',
#   'pickup_date': '1988-09-15',
#   'submission_time': datetime.datetime(1984, 11, 18, 22, 4, 57),
#   'num_days_needed': 10,
#   'price': 77.73,
#   'customer_id': 420,
#   'evaluater_id': 39,
#   'status': 'submitted'},
#  ...}

# %%
accepted_req_id
# Out:
# {2,
#  3,
#  5,
#  7,
#  8,
#  12,
#  13,
#  14,
#  15,
#  17,
#  18,
#  20,
#  22,
#  24,
#  25,
#  27,
#  29,
#  31,
#  32,
#  34,
#  36,
#  38,
#  40,
#  41,
#  42,
#  47,
#  48,
#  53,
#  56,
#  57,
#  58,
#  60,
#  61,
#  63,
#  65,
#  67,
#  68,
#  69,
#  70,
#  71,
#  72,
#  75,
#  76,
#  79,
#  82,
#  85,
#  86,
#  87,
#  88,
#  91,
#  92,
#  93,
#  95,
#  98,
#  100,
#  101,
#  104,
#  105,
#  106,
#  107,
#  109,
#  110,
#  112,
#  113,
#  114,
#  115,
#  116,
#  118,
#  120,
#  123,
#  127,
#  128,
#  129,
#  130,
#  131,
#  132,
#  133,
#  134,
#  136,
#  137,
#  139,
#  140,
#  143,
#  144,
#  145,
#  146,
#  149,
#  154,
#  155,
#  158,
#  160,
#  161,
#  162,
#  164,
#  168,
#  169,
#  170,
#  171,
#  173,
#  174,
#  175,
#  177,
#  178,
#  180,
#  182,
#  183,
#  185,
#  188,
#  189,
#  193,
#  194,
#  195,
#  198,
#  201,
#  204,
#  206,
#  212,
#  214,
#  218,
#  219,
#  220,
#  221,
#  222,
#  227,
#  230,
#  233,
#  234,
#  235,
#  236,
#  238,
#  240,
#  241,
#  242,
#  243,
#  245,
#  246,
#  248,
#  249,
#  251,
#  252,
#  254,
#  255,
#  259,
#  260,
#  262,
#  267,
#  268,
#  271,
#  273,
#  274,
#  275,
#  279,
#  281,
#  282,
#  283,
#  285,
#  286,
#  287,
#  288,
#  289,
#  290,
#  291,
#  292,
#  294,
#  295,
#  296,
#  303,
#  304,
#  305,
#  307,
#  308,
#  309,
#  310,
#  311,
#  312,
#  313,
#  314,
#  316,
#  317,
#  320,
#  321,
#  323,
#  324,
#  326,
#  327,
#  329,
#  331,
#  333,
#  339,
#  342,
#  343,
#  344,
#  346,
#  348,
#  349,
#  350,
#  351,
#  352,
#  353,
#  356,
#  357,
#  358,
#  359,
#  364,
#  366,
#  368,
#  370,
#  371,
#  372,
#  373,
#  374,
#  375,
#  376,
#  377,
#  379,
#  380,
#  381,
#  383,
#  384,
#  385,
#  388,
#  389,
#  390,
#  391,
#  392,
#  393,
#  394,
#  395,
#  396,
#  398,
#  402,
#  404,
#  405,
#  406,
#  410,
#  411,
#  413,
#  415,
#  416,
#  419,
#  420,
#  421,
#  422,
#  425,
#  426,
#  427,
#  428,
#  430,
#  433,
#  434,
#  435,
#  438,
#  439,
#  440,
#  443,
#  444,
#  448,
#  450,
#  451,
#  453,
#  454,
#  457,
#  458,
#  460,
#  461,
#  464,
#  465,
#  466,
#  468,
#  469,
#  470,
#  473,
#  474,
#  475,
#  477,
#  478,
#  485,
#  486,
#  487,
#  490,
#  493,
#  495,
#  497,
#  500,
#  501,
#  504,
#  505,
#  506,
#  507,
#  510,
#  512,
#  513,
#  514,
#  516,
#  517,
#  518,
#  519,
#  520,
#  523,
#  525,
#  528,
#  530,
#  531,
#  533,
#  537,
#  540,
#  542,
#  543,
#  544,
#  547,
#  548,
#  549,
#  550,
#  551,
#  554,
#  556,
#  559,
#  560,
#  561,
#  562,
#  563,
#  565,
#  569,
#  572,
#  573,
#  574,
#  575,
#  576,
#  577,
#  578,
#  585,
#  587,
#  589,
#  590,
#  591,
#  592,
#  593,
#  594,
#  596,
#  599,
#  600,
#  604,
#  605,
#  611,
#  612,
#  616,
#  618,
#  623,
#  624,
#  625,
#  628,
#  629,
#  634,
#  638,
#  640,
#  641,
#  643,
#  644,
#  645,
#  646,
#  649,
#  651,
#  652,
#  654,
#  658,
#  659,
#  661,
#  662,
#  665,
#  667,
#  669,
#  670,
#  671,
#  672,
#  673,
#  674,
#  675,
#  676,
#  678,
#  679,
#  680,
#  685,
#  687,
#  689,
#  690,
#  691,
#  692,
#  694,
#  695,
#  696,
#  700,
#  701,
#  703,
#  704,
#  705,
#  706,
#  708,
#  710,
#  711,
#  712,
#  714,
#  715,
#  716,
#  717,
#  718,
#  719,
#  720,
#  722,
#  723,
#  724,
#  725,
#  726,
#  728,
#  729,
#  731,
#  733,
#  734,
#  738,
#  739,
#  743,
#  746,
#  753,
#  754,
#  756,
#  757,
#  758,
#  759,
#  760,
#  762,
#  767,
#  769,
#  772,
#  773,
#  774,
#  775,
#  776,
#  777,
#  778,
#  780,
#  781,
#  783,
#  784,
#  785,
#  786,
#  788,
#  789,
#  790,
#  793,
#  794,
#  795,
#  796,
#  798,
#  799,
#  800,
#  803,
#  804,
#  806,
#  808,
#  809,
#  810,
#  811,
#  812,
#  813,
#  815,
#  816,
#  817,
#  818,
#  823,
#  824,
#  825,
#  828,
#  831,
#  833,
#  834,
#  835,
#  836,
#  837,
#  839,
#  841,
#  842,
#  843,
#  846,
#  848,
#  850,
#  852,
#  853,
#  854,
#  857,
#  858,
#  860,
#  862,
#  863,
#  866,
#  867,
#  868,
#  871,
#  872,
#  875,
#  877,
#  878,
#  879,
#  880,
#  881,
#  882,
#  883,
#  884,
#  885,
#  886,
#  889,
#  890,
#  891,
#  893,
#  894,
#  896,
#  897,
#  899,
#  900,
#  901,
#  902,
#  904,
#  905,
#  906,
#  907,
#  908,
#  910,
#  913,
#  914,
#  915,
#  918,
#  919,
#  920,
#  921,
#  922,
#  923,
#  925,
#  928,
#  929,
#  930,
#  931,
#  932,
#  933,
#  936,
#  937,
#  940,
#  942,
#  944,
#  946,
#  948,
#  949,
#  952,
#  953,
#  954,
#  955,
#  961,
#  962,
#  965,
#  966,
#  967,
#  970,
#  972,
#  973,
#  974,
#  975,
#  980,
#  981,
#  982,
#  984,
#  985,
#  988,
#  992,
#  993,
#  997,
#  998,
#  999,
#  1001,
#  1003,
#  1004,
#  1005,
#  1006,
#  1008,
#  1011,
#  1014,
#  1015,
#  1018,
#  1022,
#  1023,
#  1025,
#  1026,
#  1027,
#  1028,
#  1032,
#  1033,
#  1034,
#  1035,
#  1036,
#  1037,
#  1038,
#  1041,
#  1042,
#  1043,
#  1044,
#  1047,
#  1048,
#  1051,
#  1052,
#  1053,
#  1054,
#  1056,
#  1057,
#  1058,
#  1061,
#  1062,
#  1065,
#  1066,
#  1069,
#  1071,
#  1072,
#  1074,
#  1075,
#  1081,
#  1082,
#  1084,
#  1088,
#  1092,
#  1093,
#  1095,
#  1096,
#  1097,
#  1099,
#  1100,
#  1102,
#  1103,
#  1105,
#  1106,
#  1109,
#  1110,
#  1112,
#  1113,
#  1114,
#  1117,
#  1118,
#  1119,
#  1121,
#  1122,
#  1124,
#  1128,
#  1129,
#  1130,
#  1132,
#  1134,
#  1135,
#  1137,
#  1141,
#  1143,
#  1144,
#  1145,
#  1146,
#  1149,
#  1150,
#  1153,
#  1154,
#  1156,
#  1160,
#  1162,
#  1164,
#  1165,
#  1168,
#  1169,
#  1174,
#  1175,
#  1177,
#  1180,
#  1181,
#  1183,
#  1184,
#  1185,
#  1187,
#  1188,
#  1190,
#  1191,
#  1193,
#  1194,
#  1196,
#  1198,
#  1200,
#  1202,
#  1204,
#  1206,
#  1208,
#  1209,
#  1213,
#  1218,
#  1219,
#  1224,
#  1226,
#  1232,
#  1233,
#  1234,
#  1235,
#  1236,
#  1237,
#  1239,
#  1240,
#  1241,
#  1242,
#  1244,
#  1246,
#  1247,
#  1250,
#  1252,
#  1254,
#  1258,
#  1259,
#  1261,
#  1262,
#  1263,
#  1264,
#  1266,
#  1267,
#  1268,
#  1270,
#  1271,
#  1272,
#  1273,
#  1274,
#  1276,
#  1277,
#  1278,
#  1279,
#  1281,
#  1284,
#  1287,
#  1288,
#  1290,
#  1292,
#  1294,
#  1296,
#  1298,
#  1299,
#  1300,
#  1302,
#  1303,
#  1305,
#  1306,
#  1307,
#  1308,
#  1309,
#  1312,
#  1315,
#  1318,
#  1320,
#  1321,
#  1322,
#  1323,
#  1324,
#  1327,
#  1328,
#  1329,
#  1330,
#  1332,
#  1334,
#  1336,
#  1339,
#  1340,
#  1344,
#  1345,
#  1346,
#  1347,
#  1348,
#  1349,
#  1351,
#  1356,
#  1357,
#  1358,
#  1359,
#  1361,
#  1366,
#  1368,
#  1369,
#  1370,
#  1371,
#  1373,
#  1374,
#  1375,
#  1376,
#  1377,
#  1378,
#  1379,
#  1383,
#  1384,
#  1385,
#  1386,
#  1388,
#  1391,
#  1394,
#  1396,
#  1397,
#  1399,
#  1400,
#  1401,
#  1404,
#  1405,
#  1411,
#  1413,
#  1414,
#  1415,
#  1419,
#  1422,
#  1423,
#  1424,
#  1426,
#  1428,
#  1429,
#  1431,
#  1432,
#  1434,
#  1436,
#  1437,
#  1439,
#  1441,
#  1442,
#  1443,
#  1444,
#  1445,
#  1446,
#  1447,
#  1449,
#  1451,
#  1453,
#  1457,
#  1458,
#  1460,
#  1461,
#  1463,
#  1465,
#  1467,
#  1469,
#  1470,
#  1472,
#  1473,
#  1474,
#  1475,
#  1476,
#  1477,
#  1478,
#  1479,
#  1480,
#  1484,
#  1485,
#  1486,
#  1490,
#  1493,
#  1495,
#  1496,
#  1497,
#  1498,
#  1501,
#  1502,
#  1504,
#  1505,
#  1507,
#  1509,
#  1510,
#  1511,
#  1512,
#  1513,
#  1516,
#  1521,
#  1522,
#  1524,
#  1528,
#  1530,
#  1535,
#  1539,
#  1540,
#  1541,
#  1542,
#  1543,
#  1545,
#  1547,
#  1548,
#  1551,
#  1552,
#  1554,
#  1556,
#  1557,
#  1558,
#  1559,
#  1561,
#  1562,
#  1563,
#  1564,
#  1566,
#  1567,
#  1569,
#  1570,
#  1572,
#  1575,
#  1577,
#  1579,
#  1580,
#  1581,
#  1582,
#  1585,
#  1586,
#  1588,
#  1590,
#  1592,
#  1594,
#  1595,
#  1602,
#  1603,
#  1604,
#  1608,
#  1609,
#  1610,
#  1615,
#  1617,
#  1619,
#  1622,
#  1627,
#  1629,
#  1630,
#  1632,
#  1634,
#  1639,
#  1640,
#  1641,
#  1642,
#  1644,
#  1645,
#  1646,
#  1647,
#  1649,
#  1650,
#  1653,
#  1654,
#  1656,
#  1657,
#  1660,
#  1661,
#  1664,
#  1668,
#  1670,
#  1671,
#  1672,
#  1673,
#  1674,
#  1675,
#  1677,
#  1678,
#  1679,
#  1680,
#  1682,
#  1683,
#  1686,
#  1687,
#  1689,
#  1690,
#  1691,
#  1692,
#  1693,
#  1694,
#  1695,
#  1696,
#  1697,
#  1699,
#  1702,
#  1703,
#  1706,
#  1708,
#  1709,
#  1710,
#  1711,
#  1712,
#  1714,
#  1719,
#  1721,
#  1723,
#  1724,
#  1726,
#  1727,
#  1728,
#  1729,
#  1730,
#  1731,
#  1732,
#  1733,
#  1734,
#  1735,
#  1738,
#  1740,
#  1741,
#  1742,
#  1744,
#  1747,
#  1748,
#  1749,
#  1753,
#  1756,
#  ...}

# %%
packages = {}
for request_id in delivery_requests.keys():
    current_timestamp = random_timestamp()
    for package_id in range(1, get_random_int_to(2, 6)):
        to_add = {}
        to_add['request_id'] = request_id
        to_add['package_id'] = package_id
        this_id = (to_add['request_id'], to_add['package_id'])
        to_add['reported_height'] = get_random_float_from_to(2, 1000)
        to_add['reported_width'] = get_random_float_from_to(2, 1000)
        to_add['reported_depth'] = get_random_float_from_to(2, 1000)
        to_add['reported_weight'] = get_random_float_from_to(2, 1000)
        to_add['actual_height'] = random_plus_minus(to_add['reported_height'])
        to_add['actual_width'] = random_plus_minus(to_add['reported_width'])
        to_add['actual_depth'] = random_plus_minus(to_add['reported_depth'])
        to_add['actual_weight'] = random_plus_minus(to_add['reported_weight'])
        to_add['content'] = get_random_string(12)
        to_add['estimated_value'] = get_random_price()   
        packages[this_id] = to_add
    
packages
# Out:
# {(1, 1): {'request_id': 1,
#   'package_id': 1,
#   'reported_height': 133.44,
#   'reported_width': 171.38,
#   'reported_depth': 387.94,
#   'reported_weight': 345.63,
#   'actual_height': 134.2474433891623,
#   'actual_width': 170.0472165885122,
#   'actual_depth': 387.31782271889557,
#   'actual_weight': 345.40043157967875,
#   'content': 'nzkKQCAEYjOf',
#   'estimated_value': 37.03},
#  (1, 2): {'request_id': 1,
#   'package_id': 2,
#   'reported_height': 180.54,
#   'reported_width': 148.78,
#   'reported_depth': 964.78,
#   'reported_weight': 488.14,
#   'actual_height': 180.3944450067496,
#   'actual_width': 151.18161770502027,
#   'actual_depth': 965.4642849356039,
#   'actual_weight': 484.72781234205996,
#   'content': 'DibAwmyQnnxh',
#   'estimated_value': 67.76},
#  (1, 3): {'request_id': 1,
#   'package_id': 3,
#   'reported_height': 564.42,
#   'reported_width': 394.5,
#   'reported_depth': 832.69,
#   'reported_weight': 190.33,
#   'actual_height': 567.1572786036988,
#   'actual_width': 396.1076762782784,
#   'actual_depth': 835.0548166730379,
#   'actual_weight': 191.41248959032146,
#   'content': 'tkspIaexDjzn',
#   'estimated_value': 58.49},
#  (1, 4): {'request_id': 1,
#   'package_id': 4,
#   'reported_height': 507.87,
#   'reported_width': 242.21,
#   'reported_depth': 387.81,
#   'reported_weight': 20.98,
#   'actual_height': 509.80388571901534,
#   'actual_width': 243.19739650782574,
#   'actual_depth': 384.24854491826534,
#   'actual_weight': 23.085375105687035,
#   'content': 'zBFjkrAFbNvB',
#   'estimated_value': 28.37},
#  (2, 1): {'request_id': 2,
#   'package_id': 1,
#   'reported_height': 948.75,
#   'reported_width': 710.93,
#   'reported_depth': 975.81,
#   'reported_weight': 882.24,
#   'actual_height': 951.431772688502,
#   'actual_width': 711.522884301272,
#   'actual_depth': 973.6922832243343,
#   'actual_weight': 880.9912432694827,
#   'content': 'xPKthaBVbPGx',
#   'estimated_value': 65.05},
#  (2, 2): {'request_id': 2,
#   'package_id': 2,
#   'reported_height': 784.65,
#   'reported_width': 540.16,
#   'reported_depth': 666.7,
#   'reported_weight': 771.32,
#   'actual_height': 784.3176301140362,
#   'actual_width': 539.9414722913332,
#   'actual_depth': 663.9786144870117,
#   'actual_weight': 769.8243801771891,
#   'content': 'GZLuVyNsbNIy',
#   'estimated_value': 70.32},
#  (3, 1): {'request_id': 3,
#   'package_id': 1,
#   'reported_height': 839.6,
#   'reported_width': 78.55,
#   'reported_depth': 807.58,
#   'reported_weight': 873.42,
#   'actual_height': 841.4524558972059,
#   'actual_width': 82.64792349142151,
#   'actual_depth': 804.1873384255982,
#   'actual_weight': 872.3260548183655,
#   'content': 'ibLElDPoeMWa',
#   'estimated_value': 83.63},
#  (3, 2): {'request_id': 3,
#   'package_id': 2,
#   'reported_height': 384.61,
#   'reported_width': 412.95,
#   'reported_depth': 489.03,
#   'reported_weight': 401.92,
#   'actual_height': 386.6152183910313,
#   'actual_width': 411.2026924516536,
#   'actual_depth': 486.66380443643305,
#   'actual_weight': 401.0839487797065,
#   'content': 'iqLEPRuAduQK',
#   'estimated_value': 91.26},
#  (3, 3): {'request_id': 3,
#   'package_id': 3,
#   'reported_height': 328.22,
#   'reported_width': 481.13,
#   'reported_depth': 266.58,
#   'reported_weight': 236.5,
#   'actual_height': 328.5857476187454,
#   'actual_width': 480.40390393867295,
#   'actual_depth': 269.5377302569764,
#   'actual_weight': 234.98538653865987,
#   'content': 'vNJrTSXrhxEj',
#   'estimated_value': 71.95},
#  (3, 4): {'request_id': 3,
#   'package_id': 4,
#   'reported_height': 598.81,
#   'reported_width': 204.55,
#   'reported_depth': 864.59,
#   'reported_weight': 662.08,
#   'actual_height': 598.4156699116751,
#   'actual_width': 203.97728684273602,
#   'actual_depth': 863.4868244110706,
#   'actual_weight': 665.5176543920256,
#   'content': 'BnRNpTOkKaFM',
#   'estimated_value': 13.76},
#  (3, 5): {'request_id': 3,
#   'package_id': 5,
#   'reported_height': 36.86,
#   'reported_width': 767.61,
#   'reported_depth': 273.17,
#   'reported_weight': 657.07,
#   'actual_height': 35.98120545831104,
#   'actual_width': 767.7605927272821,
#   'actual_depth': 271.949521160218,
#   'actual_weight': 658.5552932730674,
#   'content': 'sHUBcNqkiKXV',
#   'estimated_value': 23.75},
#  (4, 1): {'request_id': 4,
#   'package_id': 1,
#   'reported_height': 619.58,
#   'reported_width': 289.62,
#   'reported_depth': 240.74,
#   'reported_weight': 602.35,
#   'actual_height': 617.4021628876042,
#   'actual_width': 291.71762590639685,
#   'actual_depth': 244.13049368242054,
#   'actual_weight': 603.4994975693913,
#   'content': 'OysIuBNDQUvq',
#   'estimated_value': 95.0},
#  (4, 2): {'request_id': 4,
#   'package_id': 2,
#   'reported_height': 612.54,
#   'reported_width': 537.16,
#   'reported_depth': 360.38,
#   'reported_weight': 118.67,
#   'actual_height': 609.9047310977307,
#   'actual_width': 537.397670927235,
#   'actual_depth': 356.7825456948295,
#   'actual_weight': 119.4845585270235,
#   'content': 'MbFYkVADLRmp',
#   'estimated_value': 10.49},
#  (5, 1): {'request_id': 5,
#   'package_id': 1,
#   'reported_height': 913.39,
#   'reported_width': 500.43,
#   'reported_depth': 955.55,
#   'reported_weight': 837.58,
#   'actual_height': 913.0589589471557,
#   'actual_width': 501.35078758218316,
#   'actual_depth': 956.495155912273,
#   'actual_weight': 836.3763678694032,
#   'content': 'CLOtSruHgRAC',
#   'estimated_value': 49.75},
#  (6, 1): {'request_id': 6,
#   'package_id': 1,
#   'reported_height': 979.34,
#   'reported_width': 922.58,
#   'reported_depth': 861.94,
#   'reported_weight': 242.21,
#   'actual_height': 982.0731028852321,
#   'actual_width': 922.8493454474134,
#   'actual_depth': 861.5151025378843,
#   'actual_weight': 241.89479783800994,
#   'content': 'TirnglgVMZvw',
#   'estimated_value': 30.85},
#  (7, 1): {'request_id': 7,
#   'package_id': 1,
#   'reported_height': 911.87,
#   'reported_width': 836.57,
#   'reported_depth': 186.53,
#   'reported_weight': 468.22,
#   'actual_height': 910.5547295746323,
#   'actual_width': 838.9091541558172,
#   'actual_depth': 186.91581802468434,
#   'actual_weight': 465.57441230163977,
#   'content': 'ylxKfhCvoaVH',
#   'estimated_value': 63.2},
#  (8, 1): {'request_id': 8,
#   'package_id': 1,
#   'reported_height': 110.85,
#   'reported_width': 934.08,
#   'reported_depth': 327.41,
#   'reported_weight': 662.84,
#   'actual_height': 112.52159888058218,
#   'actual_width': 936.0303131171695,
#   'actual_depth': 332.1304403529875,
#   'actual_weight': 665.8960410868757,
#   'content': 'xqDPaqVDmzBN',
#   'estimated_value': 24.85},
#  (8, 2): {'request_id': 8,
#   'package_id': 2,
#   'reported_height': 991.72,
#   'reported_width': 254.9,
#   'reported_depth': 850.95,
#   'reported_weight': 324.54,
#   'actual_height': 988.4411203819676,
#   'actual_width': 254.68493770724703,
#   'actual_depth': 848.6967490097044,
#   'actual_weight': 326.2324649788043,
#   'content': 'vJkrsqVSAAfK',
#   'estimated_value': 17.28},
#  (8, 3): {'request_id': 8,
#   'package_id': 3,
#   'reported_height': 379.56,
#   'reported_width': 374.43,
#   'reported_depth': 265.6,
#   'reported_weight': 571.27,
#   'actual_height': 379.53025035611336,
#   'actual_width': 375.57098843124436,
#   'actual_depth': 264.15490814063116,
#   'actual_weight': 574.4005331362021,
#   'content': 'XAfXDAWMRKvP',
#   'estimated_value': 36.66},
#  (9, 1): {'request_id': 9,
#   'package_id': 1,
#   'reported_height': 987.88,
#   'reported_width': 916.49,
#   'reported_depth': 746.6,
#   'reported_weight': 79.29,
#   'actual_height': 987.4221335349704,
#   'actual_width': 918.0906921539523,
#   'actual_depth': 744.6991010984515,
#   'actual_weight': 78.33933491321892,
#   'content': 'UsHFEKtGsOsv',
#   'estimated_value': 11.64},
#  (9, 2): {'request_id': 9,
#   'package_id': 2,
#   'reported_height': 348.84,
#   'reported_width': 877.54,
#   'reported_depth': 335.37,
#   'reported_weight': 974.14,
#   'actual_height': 347.6806191806654,
#   'actual_width': 879.300796920974,
#   'actual_depth': 332.28182119774607,
#   'actual_weight': 972.7778420412603,
#   'content': 'OEDLPPtFqWQi',
#   'estimated_value': 46.1},
#  (9, 3): {'request_id': 9,
#   'package_id': 3,
#   'reported_height': 779.84,
#   'reported_width': 124.7,
#   'reported_depth': 894.99,
#   'reported_weight': 514.72,
#   'actual_height': 779.3133022214481,
#   'actual_width': 127.35598434288106,
#   'actual_depth': 894.030874464934,
#   'actual_weight': 515.0169227395477,
#   'content': 'OqlCgbzeWBeQ',
#   'estimated_value': 43.27},
#  (9, 4): {'request_id': 9,
#   'package_id': 4,
#   'reported_height': 980.03,
#   'reported_width': 814.16,
#   'reported_depth': 345.29,
#   'reported_weight': 311.18,
#   'actual_height': 979.842877311224,
#   'actual_width': 814.1221436322861,
#   'actual_depth': 345.9584275153218,
#   'actual_weight': 311.03504041187017,
#   'content': 'PpaXQDyNQenI',
#   'estimated_value': 28.41},
#  (9, 5): {'request_id': 9,
#   'package_id': 5,
#   'reported_height': 298.89,
#   'reported_width': 13.39,
#   'reported_depth': 167.31,
#   'reported_weight': 477.01,
#   'actual_height': 300.4979202301729,
#   'actual_width': 14.638085534307608,
#   'actual_depth': 168.8498549213957,
#   'actual_weight': 479.4758090769442,
#   'content': 'eaAfBtafFRoK',
#   'estimated_value': 2.61},
#  (10, 1): {'request_id': 10,
#   'package_id': 1,
#   'reported_height': 772.44,
#   'reported_width': 870.59,
#   'reported_depth': 258.24,
#   'reported_weight': 219.95,
#   'actual_height': 769.9848197086869,
#   'actual_width': 870.3632521904289,
#   'actual_depth': 261.6432319347831,
#   'actual_weight': 219.25053662582414,
#   'content': 'SzhzcJeeVupP',
#   'estimated_value': 24.6},
#  (10, 2): {'request_id': 10,
#   'package_id': 2,
#   'reported_height': 684.06,
#   'reported_width': 879.57,
#   'reported_depth': 136.94,
#   'reported_weight': 284.46,
#   'actual_height': 683.913291745663,
#   'actual_width': 876.1301872759809,
#   'actual_depth': 135.5993998335366,
#   'actual_weight': 282.84377462656624,
#   'content': 'nWSiLqmHXEdA',
#   'estimated_value': 41.78},
#  (10, 3): {'request_id': 10,
#   'package_id': 3,
#   'reported_height': 911.69,
#   'reported_width': 365.29,
#   'reported_depth': 81.63,
#   'reported_weight': 496.8,
#   'actual_height': 913.0212232120546,
#   'actual_width': 361.63617615709035,
#   'actual_depth': 82.04609382267171,
#   'actual_weight': 496.2814633866564,
#   'content': 'AhuVMFWbmmcD',
#   'estimated_value': 55.57},
#  (10, 4): {'request_id': 10,
#   'package_id': 4,
#   'reported_height': 427.63,
#   'reported_width': 118.05,
#   'reported_depth': 646.85,
#   'reported_weight': 833.68,
#   'actual_height': 427.35223557934256,
#   'actual_width': 114.17086885193682,
#   'actual_depth': 648.2246881331052,
#   'actual_weight': 833.7312009341605,
#   'content': 'FBeaYUDKNfbv',
#   'estimated_value': 50.93},
#  (10, 5): {'request_id': 10,
#   'package_id': 5,
#   'reported_height': 85.91,
#   'reported_width': 540.29,
#   'reported_depth': 918.87,
#   'reported_weight': 297.26,
#   'actual_height': 87.56299417205979,
#   'actual_width': 541.9630997296427,
#   'actual_depth': 920.0546208449551,
#   'actual_weight': 298.14107563102584,
#   'content': 'TWIFVdsDgTVr',
#   'estimated_value': 14.73},
#  (11, 1): {'request_id': 11,
#   'package_id': 1,
#   'reported_height': 478.34,
#   'reported_width': 121.14,
#   'reported_depth': 538.03,
#   'reported_weight': 842.24,
#   'actual_height': 479.22474445312366,
#   'actual_width': 121.41761705947582,
#   'actual_depth': 540.8747654701721,
#   'actual_weight': 840.4444055450997,
#   'content': 'nyjyUOhxHCCw',
#   'estimated_value': 65.56},
#  (11, 2): {'request_id': 11,
#   'package_id': 2,
#   'reported_height': 668.4,
#   'reported_width': 976.59,
#   'reported_depth': 906.93,
#   'reported_weight': 237.76,
#   'actual_height': 671.0376881205991,
#   'actual_width': 977.2212074447293,
#   'actual_depth': 909.2517070342452,
#   'actual_weight': 240.81668844188584,
#   'content': 'OHFfZVBPUcEG',
#   'estimated_value': 66.97},
#  (11, 3): {'request_id': 11,
#   'package_id': 3,
#   'reported_height': 819.52,
#   'reported_width': 113.35,
#   'reported_depth': 671.23,
#   'reported_weight': 793.17,
#   'actual_height': 818.8376043414512,
#   'actual_width': 115.57485029155603,
#   'actual_depth': 670.1689918424937,
#   'actual_weight': 793.0336535293017,
#   'content': 'BYQiwFJTOFhz',
#   'estimated_value': 42.77},
#  (12, 1): {'request_id': 12,
#   'package_id': 1,
#   'reported_height': 485.31,
#   'reported_width': 580.97,
#   'reported_depth': 452.28,
#   'reported_weight': 140.93,
#   'actual_height': 486.40818339292935,
#   'actual_width': 578.8958285615097,
#   'actual_depth': 456.45397988103093,
#   'actual_weight': 136.9790161084436,
#   'content': 'nuRHAdEpiDsz',
#   'estimated_value': 64.95},
#  (12, 2): {'request_id': 12,
#   'package_id': 2,
#   'reported_height': 621.54,
#   'reported_width': 773.03,
#   'reported_depth': 718.96,
#   'reported_weight': 139.02,
#   'actual_height': 622.5060700796521,
#   'actual_width': 772.9169767678485,
#   'actual_depth': 719.6642742223022,
#   'actual_weight': 138.66655882279548,
#   'content': 'JrLRNSJltArL',
#   'estimated_value': 82.2},
#  (12, 3): {'request_id': 12,
#   'package_id': 3,
#   'reported_height': 696.67,
#   'reported_width': 534.35,
#   'reported_depth': 941.76,
#   'reported_weight': 798.93,
#   'actual_height': 696.3377111500815,
#   'actual_width': 537.7325129781193,
#   'actual_depth': 937.4659075856329,
#   'actual_weight': 798.0072441230013,
#   'content': 'BBQwCZDmWnQz',
#   'estimated_value': 91.15},
#  (12, 4): {'request_id': 12,
#   'package_id': 4,
#   'reported_height': 615.07,
#   'reported_width': 85.63,
#   'reported_depth': 141.01,
#   'reported_weight': 881.26,
#   'actual_height': 614.7263018261843,
#   'actual_width': 87.89201615398689,
#   'actual_depth': 141.51335617708625,
#   'actual_weight': 884.6069077892479,
#   'content': 'iIkrAqwUffyE',
#   'estimated_value': 5.67},
#  (13, 1): {'request_id': 13,
#   'package_id': 1,
#   'reported_height': 568.9,
#   'reported_width': 155.92,
#   'reported_depth': 349.21,
#   'reported_weight': 702.92,
#   'actual_height': 567.9296441935767,
#   'actual_width': 157.0779960568791,
#   'actual_depth': 348.7992044011055,
#   'actual_weight': 702.1541610771163,
#   'content': 'DTSQHGyKLQGs',
#   'estimated_value': 83.29},
#  (13, 2): {'request_id': 13,
#   'package_id': 2,
#   'reported_height': 855.28,
#   'reported_width': 167.33,
#   'reported_depth': 837.72,
#   'reported_weight': 338.41,
#   'actual_height': 853.9628863440305,
#   'actual_width': 166.89237341608353,
#   'actual_depth': 835.1165280703631,
#   'actual_weight': 337.10858021612097,
#   'content': 'BKwjggWhEYyz',
#   'estimated_value': 62.89},
#  (13, 3): {'request_id': 13,
#   'package_id': 3,
#   'reported_height': 227.51,
#   'reported_width': 380.08,
#   'reported_depth': 744.99,
#   'reported_weight': 330.86,
#   'actual_height': 226.6010225768091,
#   'actual_width': 376.2515256620302,
#   'actual_depth': 747.3274868452804,
#   'actual_weight': 329.64713995261883,
#   'content': 'qYXoaZNqmxCN',
#   'estimated_value': 99.61},
#  (13, 4): {'request_id': 13,
#   'package_id': 4,
#   'reported_height': 789.2,
#   'reported_width': 903.08,
#   'reported_depth': 815.4,
#   'reported_weight': 874.16,
#   'actual_height': 788.6942612859007,
#   'actual_width': 901.3842873476592,
#   'actual_depth': 818.1633655077774,
#   'actual_weight': 872.8670973721898,
#   'content': 'qUpOzkeEsyrW',
#   'estimated_value': 69.63},
#  (13, 5): {'request_id': 13,
#   'package_id': 5,
#   'reported_height': 499.55,
#   'reported_width': 742.69,
#   'reported_depth': 430.96,
#   'reported_weight': 395.95,
#   'actual_height': 499.9786655109682,
#   'actual_width': 742.9542164346997,
#   'actual_depth': 434.9267158300015,
#   'actual_weight': 396.60870655997996,
#   'content': 'pXvuSviEdWCH',
#   'estimated_value': 85.41},
#  (14, 1): {'request_id': 14,
#   'package_id': 1,
#   'reported_height': 840.23,
#   'reported_width': 104.35,
#   'reported_depth': 905.23,
#   'reported_weight': 680.02,
#   'actual_height': 840.4823176236519,
#   'actual_width': 105.47181168859063,
#   'actual_depth': 903.3280453182851,
#   'actual_weight': 681.280846655581,
#   'content': 'KRsDIGfrzkux',
#   'estimated_value': 1.61},
#  (14, 2): {'request_id': 14,
#   'package_id': 2,
#   'reported_height': 352.47,
#   'reported_width': 914.24,
#   'reported_depth': 396.92,
#   'reported_weight': 17.08,
#   'actual_height': 353.77031688950626,
#   'actual_width': 913.5030341089212,
#   'actual_depth': 396.026429770146,
#   'actual_weight': 18.17473609700064,
#   'content': 'URMJNUMhRTWs',
#   'estimated_value': 60.02},
#  (15, 1): {'request_id': 15,
#   'package_id': 1,
#   'reported_height': 170.77,
#   'reported_width': 718.23,
#   'reported_depth': 884.34,
#   'reported_weight': 573.64,
#   'actual_height': 171.14817472183435,
#   'actual_width': 714.2690964512461,
#   'actual_depth': 882.1395441914349,
#   'actual_weight': 570.4047095232595,
#   'content': 'lKXLglfGdbIy',
#   'estimated_value': 34.13},
#  (15, 2): {'request_id': 15,
#   'package_id': 2,
#   'reported_height': 898.48,
#   'reported_width': 11.65,
#   'reported_depth': 326.54,
#   'reported_weight': 145.43,
#   'actual_height': 899.093156506246,
#   'actual_width': 13.27248261552987,
#   'actual_depth': 329.08554181784416,
#   'actual_weight': 148.361793388317,
#   'content': 'HMjyehhJyrbX',
#   'estimated_value': 43.56},
#  (15, 3): {'request_id': 15,
#   'package_id': 3,
#   'reported_height': 356.53,
#   'reported_width': 485.26,
#   'reported_depth': 876.62,
#   'reported_weight': 540.38,
#   'actual_height': 356.95916059974974,
#   'actual_width': 484.8901664506233,
#   'actual_depth': 876.7122398158357,
#   'actual_weight': 541.417025737162,
#   'content': 'aukiISuOKCBn',
#   'estimated_value': 83.88},
#  (15, 4): {'request_id': 15,
#   'package_id': 4,
#   'reported_height': 766.9,
#   'reported_width': 478.53,
#   'reported_depth': 343.58,
#   'reported_weight': 799.49,
#   'actual_height': 767.0358098230198,
#   'actual_width': 478.12685467745206,
#   'actual_depth': 339.30278750034216,
#   'actual_weight': 796.6227355311471,
#   'content': 'CpcXVfyxIXAN',
#   'estimated_value': 37.53},
#  (16, 1): {'request_id': 16,
#   'package_id': 1,
#   'reported_height': 611.78,
#   'reported_width': 82.96,
#   'reported_depth': 804.02,
#   'reported_weight': 543.63,
#   'actual_height': 611.666575906992,
#   'actual_width': 80.92888413930358,
#   'actual_depth': 801.004417781245,
#   'actual_weight': 547.3541828223225,
#   'content': 'pqDHZbUxqHDs',
#   'estimated_value': 98.83},
#  (17, 1): {'request_id': 17,
#   'package_id': 1,
#   'reported_height': 29.33,
#   'reported_width': 967.26,
#   'reported_depth': 833.25,
#   'reported_weight': 828.35,
#   'actual_height': 32.81640458502118,
#   'actual_width': 965.3826769080514,
#   'actual_depth': 830.4082448743342,
#   'actual_weight': 829.6142251991243,
#   'content': 'irUdcetiiIaN',
#   'estimated_value': 73.16},
#  (17, 2): {'request_id': 17,
#   'package_id': 2,
#   'reported_height': 523.88,
#   'reported_width': 348.29,
#   'reported_depth': 400.12,
#   'reported_weight': 160.2,
#   'actual_height': 523.2799334606782,
#   'actual_width': 346.6970799384218,
#   'actual_depth': 401.4057011598378,
#   'actual_weight': 162.44748569872633,
#   'content': 'giTtAqoAZtUc',
#   'estimated_value': 12.77},
#  (17, 3): {'request_id': 17,
#   'package_id': 3,
#   'reported_height': 357.58,
#   'reported_width': 876.97,
#   'reported_depth': 97.8,
#   'reported_weight': 467.15,
#   'actual_height': 358.39531141076685,
#   'actual_width': 877.6447141728542,
#   'actual_depth': 97.72368534524553,
#   'actual_weight': 463.3832933828067,
#   'content': 'QwmhddwbLALi',
#   'estimated_value': 87.72},
#  (17, 4): {'request_id': 17,
#   'package_id': 4,
#   'reported_height': 807.09,
#   'reported_width': 844.02,
#   'reported_depth': 25.62,
#   'reported_weight': 841.41,
#   'actual_height': 810.9041748508732,
#   'actual_width': 841.4440683806854,
#   'actual_depth': 25.927643834440364,
#   'actual_weight': 839.1942493561905,
#   'content': 'ghWnPwVEDeAB',
#   'estimated_value': 83.95},
#  (18, 1): {'request_id': 18,
#   'package_id': 1,
#   'reported_height': 325.56,
#   'reported_width': 865.42,
#   'reported_depth': 328.24,
#   'reported_weight': 19.82,
#   'actual_height': 327.8184037307051,
#   'actual_width': 864.5973987383456,
#   'actual_depth': 326.70815705673624,
#   'actual_weight': 20.76710440081632,
#   'content': 'zGgWZRNZmlkW',
#   'estimated_value': 71.66},
#  (18, 2): {'request_id': 18,
#   'package_id': 2,
#   'reported_height': 592.46,
#   'reported_width': 20.46,
#   'reported_depth': 306.75,
#   'reported_weight': 16.02,
#   'actual_height': 589.9159155032685,
#   'actual_width': 19.860182011230883,
#   'actual_depth': 306.9726135193466,
#   'actual_weight': 19.461652111579994,
#   'content': 'boqLJnPgEKmx',
#   'estimated_value': 28.57},
#  (18, 3): {'request_id': 18,
#   'package_id': 3,
#   'reported_height': 514.0,
#   'reported_width': 1001.58,
#   'reported_depth': 421.47,
#   'reported_weight': 578.54,
#   'actual_height': 514.0234384106623,
#   'actual_width': 1000.3370514941167,
#   'actual_depth': 422.50586650623643,
#   'actual_weight': 576.3130420525257,
#   'content': 'FArzpjTnaPPZ',
#   'estimated_value': 27.7},
#  (18, 4): {'request_id': 18,
#   'package_id': 4,
#   'reported_height': 364.41,
#   'reported_width': 881.99,
#   'reported_depth': 9.14,
#   'reported_weight': 152.0,
#   'actual_height': 366.34510373501695,
#   'actual_width': 883.3518945910507,
#   'actual_depth': 11.887073498973653,
#   'actual_weight': 150.78905198407676,
#   'content': 'LyEVShYpdtAX',
#   'estimated_value': 44.05},
#  (18, 5): {'request_id': 18,
#   'package_id': 5,
#   'reported_height': 207.31,
#   'reported_width': 930.07,
#   'reported_depth': 19.94,
#   'reported_weight': 510.03,
#   'actual_height': 203.73778145180094,
#   'actual_width': 931.1269820433522,
#   'actual_depth': 21.175082241037106,
#   'actual_weight': 506.6792808729478,
#   'content': 'NzPJkKMMcooK',
#   'estimated_value': 97.5},
#  (19, 1): {'request_id': 19,
#   'package_id': 1,
#   'reported_height': 279.27,
#   'reported_width': 358.28,
#   'reported_depth': 757.41,
#   'reported_weight': 175.48,
#   'actual_height': 277.0327347321072,
#   'actual_width': 359.51312110057376,
#   'actual_depth': 757.4163416099614,
#   'actual_weight': 173.1153567013106,
#   'content': 'QbQFXLLqdUnp',
#   'estimated_value': 68.29},
#  (20, 1): {'request_id': 20,
#   'package_id': 1,
#   'reported_height': 333.8,
#   'reported_width': 37.37,
#   'reported_depth': 113.94,
#   'reported_weight': 138.15,
#   'actual_height': 334.6040865165005,
#   'actual_width': 40.07136003253394,
#   'actual_depth': 114.16127943194739,
#   'actual_weight': 136.8960093683587,
#   'content': 'zOxgaBTMdQUq',
#   'estimated_value': 40.47},
#  (20, 2): {'request_id': 20,
#   'package_id': 2,
#   'reported_height': 679.2,
#   'reported_width': 914.65,
#   'reported_depth': 534.02,
#   'reported_weight': 212.95,
#   'actual_height': 681.0614405328528,
#   'actual_width': 913.3439252577675,
#   'actual_depth': 534.8555254493798,
#   'actual_weight': 214.73500235330835,
#   'content': 'pwlUlocdbIhP',
#   'estimated_value': 29.06},
#  (20, 3): {'request_id': 20,
#   'package_id': 3,
#   'reported_height': 915.94,
#   'reported_width': 167.26,
#   'reported_depth': 369.65,
#   'reported_weight': 85.84,
#   'actual_height': 918.5678886015319,
#   'actual_width': 163.71065968749093,
#   'actual_depth': 370.9101671933377,
#   'actual_weight': 86.32404169043008,
#   'content': 'IseMBjaZSkJb',
#   'estimated_value': 93.19},
#  (20, 4): {'request_id': 20,
#   'package_id': 4,
#   'reported_height': 595.09,
#   'reported_width': 246.62,
#   'reported_depth': 138.46,
#   'reported_weight': 803.78,
#   'actual_height': 592.6410666068821,
#   'actual_width': 245.7946894965487,
#   'actual_depth': 139.4164445238624,
#   'actual_weight': 804.5888312112402,
#   'content': 'KvgrzNXVoAYs',
#   'estimated_value': 91.54},
#  (20, 5): {'request_id': 20,
#   'package_id': 5,
#   'reported_height': 93.02,
#   'reported_width': 96.96,
#   'reported_depth': 205.58,
#   'reported_weight': 183.85,
#   'actual_height': 93.0339132185312,
#   'actual_width': 99.10749237347476,
#   'actual_depth': 206.52660988574365,
#   'actual_weight': 182.51805644492833,
#   'content': 'RrDHuOpRZpZt',
#   'estimated_value': 84.74},
#  (21, 1): {'request_id': 21,
#   'package_id': 1,
#   'reported_height': 544.98,
#   'reported_width': 433.4,
#   'reported_depth': 537.85,
#   'reported_weight': 786.01,
#   'actual_height': 547.0755233443377,
#   'actual_width': 432.1096364745016,
#   'actual_depth': 536.5637898028685,
#   'actual_weight': 789.1911726051865,
#   'content': 'LtoBAPBOWvya',
#   'estimated_value': 21.38},
#  (21, 2): {'request_id': 21,
#   'package_id': 2,
#   'reported_height': 612.59,
#   'reported_width': 127.74,
#   'reported_depth': 650.14,
#   'reported_weight': 211.95,
#   'actual_height': 615.3698241629843,
#   'actual_width': 123.99542625185151,
#   'actual_depth': 650.475650173731,
#   'actual_weight': 212.4765322550196,
#   'content': 'HzrFiPwrLYYG',
#   'estimated_value': 16.4},
#  (21, 3): {'request_id': 21,
#   'package_id': 3,
#   'reported_height': 127.62,
#   'reported_width': 275.2,
#   'reported_depth': 509.45,
#   'reported_weight': 577.21,
#   'actual_height': 126.63899227093071,
#   'actual_width': 273.2841710897841,
#   'actual_depth': 508.39072853762667,
#   'actual_weight': 579.0179126121279,
#   'content': 'AjPrUmraOUlM',
#   'estimated_value': 75.63},
#  (21, 4): {'request_id': 21,
#   'package_id': 4,
#   'reported_height': 288.68,
#   'reported_width': 360.4,
#   'reported_depth': 703.36,
#   'reported_weight': 498.73,
#   'actual_height': 289.7975199173989,
#   'actual_width': 356.57466191539396,
#   'actual_depth': 701.4838578954926,
#   'actual_weight': 498.39966240857433,
#   'content': 'fiUvXssQThSW',
#   'estimated_value': 93.36},
#  (21, 5): {'request_id': 21,
#   'package_id': 5,
#   'reported_height': 234.74,
#   'reported_width': 749.87,
#   'reported_depth': 417.54,
#   'reported_weight': 837.13,
#   'actual_height': 233.1927367733402,
#   'actual_width': 749.9172171761709,
#   'actual_depth': 418.1199643904877,
#   'actual_weight': 837.0802631196142,
#   'content': 'yGrbZWbrfZCR',
#   'estimated_value': 50.03},
#  (22, 1): {'request_id': 22,
#   'package_id': 1,
#   'reported_height': 637.75,
#   'reported_width': 866.15,
#   'reported_depth': 129.04000000000002,
#   'reported_weight': 991.82,
#   'actual_height': 634.0279921579149,
#   'actual_width': 867.0574740432689,
#   'actual_depth': 126.4984326997817,
#   'actual_weight': 990.7787040888361,
#   'content': 'IoIBepSNaNhr',
#   'estimated_value': 50.09},
#  (22, 2): {'request_id': 22,
#   'package_id': 2,
#   'reported_height': 755.75,
#   'reported_width': 278.08,
#   'reported_depth': 16.28,
#   'reported_weight': 299.79,
#   'actual_height': 754.5303396141193,
#   'actual_width': 280.5328375488855,
#   'actual_depth': 16.633978886128176,
#   'actual_weight': 299.8096142321722,
#   'content': 'IEZhiWtZGKXj',
#   'estimated_value': 9.33},
#  (22, 3): {'request_id': 22,
#   'package_id': 3,
#   'reported_height': 626.15,
#   'reported_width': 181.67,
#   'reported_depth': 940.13,
#   'reported_weight': 592.21,
#   'actual_height': 628.1640948757888,
#   'actual_width': 184.07406525663967,
#   'actual_depth': 939.5815706417342,
#   'actual_weight': 591.3916488681981,
#   'content': 'YIiWgNqUULuD',
#   'estimated_value': 76.48},
#  (23, 1): {'request_id': 23,
#   'package_id': 1,
#   'reported_height': 261.58,
#   'reported_width': 127.72,
#   'reported_depth': 597.46,
#   'reported_weight': 328.38,
#   'actual_height': 265.39621842300863,
#   'actual_width': 130.4972643445257,
#   'actual_depth': 595.5814924201081,
#   'actual_weight': 330.2613763913611,
#   'content': 'mbSIKqapLBUn',
#   'estimated_value': 30.02},
#  (23, 2): {'request_id': 23,
#   'package_id': 2,
#   'reported_height': 468.1,
#   'reported_width': 242.58,
#   'reported_depth': 980.17,
#   'reported_weight': 557.64,
#   'actual_height': 468.9688287616876,
#   'actual_width': 242.5347326315357,
#   'actual_depth': 984.1174772189994,
#   'actual_weight': 562.0153175099217,
#   'content': 'KBGVUkjzyKLP',
#   'estimated_value': 81.85},
#  (23, 3): {'request_id': 23,
#   'package_id': 3,
#   'reported_height': 842.96,
#   'reported_width': 225.93,
#   'reported_depth': 421.61,
#   'reported_weight': 316.49,
#   'actual_height': 842.1011855056195,
#   'actual_width': 227.59858468370544,
#   'actual_depth': 421.82793093119216,
#   'actual_weight': 315.5937042372568,
#   'content': 'EbibyOsHBLMC',
#   'estimated_value': 8.52},
#  (23, 4): {'request_id': 23,
#   'package_id': 4,
#   'reported_height': 877.39,
#   'reported_width': 81.87,
#   'reported_depth': 958.34,
#   'reported_weight': 994.47,
#   'actual_height': 874.8605020910021,
#   'actual_width': 85.36094311552789,
#   'actual_depth': 957.3874633156483,
#   'actual_weight': 996.2410383439844,
#   'content': 'QrXmzOgrUzUz',
#   'estimated_value': 32.06},
#  (23, 5): {'request_id': 23,
#   'package_id': 5,
#   'reported_height': 262.7,
#   'reported_width': 210.49,
#   'reported_depth': 948.99,
#   'reported_weight': 895.96,
#   'actual_height': 260.1689536511706,
#   'actual_width': 209.472387828918,
#   'actual_depth': 948.4030984710884,
#   'actual_weight': 897.5001660579569,
#   'content': 'DqtDKHLgtiVj',
#   'estimated_value': 37.83},
#  (24, 1): {'request_id': 24,
#   'package_id': 1,
#   'reported_height': 753.59,
#   'reported_width': 41.11,
#   'reported_depth': 729.07,
#   'reported_weight': 215.1,
#   'actual_height': 753.6264358065781,
#   'actual_width': 40.814373776390624,
#   'actual_depth': 730.0369497023963,
#   'actual_weight': 215.16225438533593,
#   'content': 'tJKbFDZWdfng',
#   'estimated_value': 31.97},
#  (24, 2): {'request_id': 24,
#   'package_id': 2,
#   'reported_height': 343.79,
#   'reported_width': 845.82,
#   'reported_depth': 786.1,
#   'reported_weight': 987.95,
#   'actual_height': 344.04211161486484,
#   'actual_width': 842.4096429422938,
#   'actual_depth': 784.9100348908535,
#   'actual_weight': 987.9692884425971,
#   'content': 'tZvoCjqkuvnz',
#   'estimated_value': 54.71},
#  (24, 3): {'request_id': 24,
#   'package_id': 3,
#   'reported_height': 217.99,
#   'reported_width': 775.34,
#   'reported_depth': 307.14,
#   'reported_weight': 995.62,
#   'actual_height': 216.5861263616186,
#   'actual_width': 777.4692429606118,
#   'actual_depth': 306.8925241115514,
#   'actual_weight': 991.6906050909103,
#   'content': 'nwDhgqqxxLMv',
#   'estimated_value': 32.67},
#  (24, 4): {'request_id': 24,
#   'package_id': 4,
#   'reported_height': 7.79,
#   'reported_width': 681.56,
#   'reported_depth': 777.99,
#   'reported_weight': 22.14,
#   'actual_height': 5.555974495865664,
#   'actual_width': 681.1810557119076,
#   'actual_depth': 777.5453047500953,
#   'actual_weight': 23.677042181357447,
#   'content': 'HUaanqBzesQH',
#   'estimated_value': 27.12},
#  (25, 1): {'request_id': 25,
#   'package_id': 1,
#   'reported_height': 203.54,
#   'reported_width': 995.7,
#   'reported_depth': 658.78,
#   'reported_weight': 330.26,
#   'actual_height': 203.44938414576987,
#   'actual_width': 994.4994546421503,
#   'actual_depth': 655.6990876590733,
#   'actual_weight': 328.1242439960109,
#   'content': 'GiIWeTWiLygf',
#   'estimated_value': 71.01},
#  (25, 2): {'request_id': 25,
#   'package_id': 2,
#   'reported_height': 944.13,
#   'reported_width': 90.51,
#   'reported_depth': 821.66,
#   'reported_weight': 158.12,
#   'actual_height': 945.7903941178228,
#   'actual_width': 89.1177317193647,
#   'actual_depth': 819.7622551995121,
#   'actual_weight': 158.86704889689406,
#   'content': 'YXmbCPLHETnL',
#   'estimated_value': 91.84},
#  (25, 3): {'request_id': 25,
#   'package_id': 3,
#   'reported_height': 477.33,
#   'reported_width': 433.29,
#   'reported_depth': 989.85,
#   'reported_weight': 397.52,
#   'actual_height': 477.64154048484875,
#   'actual_width': 432.97665674170446,
#   'actual_depth': 990.4055231327277,
#   'actual_weight': 400.1371082133278,
#   'content': 'AGUvFMROzkeQ',
#   'estimated_value': 65.86},
#  (25, 4): {'request_id': 25,
#   'package_id': 4,
#   'reported_height': 26.52,
#   'reported_width': 700.14,
#   'reported_depth': 124.3,
#   'reported_weight': 654.67,
#   'actual_height': 25.919409847965344,
#   'actual_width': 702.165913869289,
#   'actual_depth': 124.66578285087473,
#   'actual_weight': 655.3538997762715,
#   'content': 'EcNhuKDmyTPw',
#   'estimated_value': 48.13},
#  (25, 5): {'request_id': 25,
#   'package_id': 5,
#   'reported_height': 407.3,
#   'reported_width': 300.75,
#   'reported_depth': 150.02,
#   'reported_weight': 220.32,
#   'actual_height': 410.47995163484774,
#   'actual_width': 300.34611491362796,
#   'actual_depth': 149.39441590192828,
#   'actual_weight': 217.05072033304222,
#   'content': 'HyivXmLfeSLN',
#   'estimated_value': 68.84},
#  (26, 1): {'request_id': 26,
#   'package_id': 1,
#   'reported_height': 520.41,
#   'reported_width': 851.68,
#   'reported_depth': 390.91,
#   'reported_weight': 169.6,
#   'actual_height': 518.1012538130067,
#   'actual_width': 854.1225290638356,
#   'actual_depth': 389.6769035423334,
#   'actual_weight': 169.27889015531906,
#   'content': 'fDPSsnSMUhyS',
#   'estimated_value': 79.31},
#  (27, 1): {'request_id': 27,
#   'package_id': 1,
#   'reported_height': 689.6,
#   'reported_width': 646.66,
#   'reported_depth': 973.34,
#   'reported_weight': 378.0,
#   'actual_height': 689.1927238597333,
#   'actual_width': 643.2993080195743,
#   'actual_depth': 973.2880153283403,
#   'actual_weight': 378.7888072001778,
#   'content': 'noNozOPXmWaa',
#   'estimated_value': 34.99},
#  (27, 2): {'request_id': 27,
#   'package_id': 2,
#   'reported_height': 974.84,
#   'reported_width': 83.64,
#   'reported_depth': 598.62,
#   'reported_weight': 190.74,
#   'actual_height': 975.4765630375397,
#   'actual_width': 85.0419632937951,
#   'actual_depth': 596.348727586097,
#   'actual_weight': 188.08516445240645,
#   'content': 'ldlXLwcyqtGR',
#   'estimated_value': 60.09},
#  (28, 1): {'request_id': 28,
#   'package_id': 1,
#   'reported_height': 725.74,
#   'reported_width': 441.41,
#   'reported_depth': 96.41,
#   'reported_weight': 92.07,
#   'actual_height': 724.0403858682216,
#   'actual_width': 441.74412814250985,
#   'actual_depth': 93.76768622905114,
#   'actual_weight': 91.4093862952169,
#   'content': 'lhFHgaFfVpMt',
#   'estimated_value': 44.05},
#  (28, 2): {'request_id': 28,
#   'package_id': 2,
#   'reported_height': 144.52,
#   'reported_width': 401.22,
#   'reported_depth': 610.26,
#   'reported_weight': 370.32,
#   'actual_height': 145.36026963284075,
#   'actual_width': 403.2072386201926,
#   'actual_depth': 607.9856425274606,
#   'actual_weight': 369.59364683215296,
#   'content': 'SIZBBFCLhxKf',
#   'estimated_value': 36.68},
#  (28, 3): {'request_id': 28,
#   'package_id': 3,
#   'reported_height': 542.48,
#   'reported_width': 953.11,
#   'reported_depth': 320.35,
#   'reported_weight': 49.08,
#   'actual_height': 544.0634116083113,
#   'actual_width': 951.59252937746,
#   'actual_depth': 316.82357404644443,
#   'actual_weight': 51.72759964287266,
#   'content': 'aurvAKLFvRrl',
#   'estimated_value': 34.08},
#  (29, 1): {'request_id': 29,
#   'package_id': 1,
#   'reported_height': 402.91,
#   'reported_width': 748.25,
#   'reported_depth': 259.3,
#   'reported_weight': 117.66,
#   'actual_height': 402.88828010431985,
#   'actual_width': 744.5588944786515,
#   'actual_depth': 258.3028955310468,
#   'actual_weight': 115.28961248937576,
#   'content': 'ncqcocaBVQEf',
#   'estimated_value': 29.43},
#  (30, 1): {'request_id': 30,
#   'package_id': 1,
#   'reported_height': 792.72,
#   'reported_width': 351.07,
#   'reported_depth': 328.33,
#   'reported_weight': 872.09,
#   'actual_height': 793.6728733719717,
#   'actual_width': 353.1986287026049,
#   'actual_depth': 328.26290773872915,
#   'actual_weight': 871.1297081043359,
#   'content': 'hwiGQGgwAACs',
#   'estimated_value': 73.59},
#  (30, 2): {'request_id': 30,
#   'package_id': 2,
#   'reported_height': 827.62,
#   'reported_width': 8.55,
#   'reported_depth': 402.2,
#   'reported_weight': 811.27,
#   'actual_height': 826.2557327067411,
#   'actual_width': 9.677675465394783,
#   'actual_depth': 402.96747230724014,
#   'actual_weight': 808.7659811557853,
#   'content': 'rKItUbgNRPMN',
#   'estimated_value': 1.11},
#  (31, 1): {'request_id': 31,
#   'package_id': 1,
#   'reported_height': 992.16,
#   'reported_width': 405.4,
#   'reported_depth': 864.64,
#   'reported_weight': 199.15,
#   'actual_height': 991.4484521626873,
#   'actual_width': 404.06104109247104,
#   'actual_depth': 866.2996576181603,
#   'actual_weight': 199.80336264143634,
#   'content': 'OuQiXkXJGvKy',
#   'estimated_value': 93.13},
#  (31, 2): {'request_id': 31,
#   'package_id': 2,
#   'reported_height': 556.05,
#   'reported_width': 881.77,
#   'reported_depth': 448.79,
#   'reported_weight': 732.49,
#   'actual_height': 557.3576852803283,
#   'actual_width': 883.4932924228224,
#   'actual_depth': 449.2298858119813,
#   'actual_weight': 732.5955496255166,
#   'content': 'wKwBGUvzPWlF',
#   'estimated_value': 8.26},
#  (31, 3): {'request_id': 31,
#   'package_id': 3,
#   'reported_height': 706.76,
#   'reported_width': 270.76,
#   'reported_depth': 300.23,
#   'reported_weight': 404.61,
#   'actual_height': 704.787188913232,
#   'actual_width': 267.822519000229,
#   'actual_depth': 299.65400114901877,
#   'actual_weight': 401.51834953017266,
#   'content': 'kcVeKuXxboVC',
#   'estimated_value': 73.58},
#  (31, 4): {'request_id': 31,
#   'package_id': 4,
#   'reported_height': 782.57,
#   'reported_width': 125.85,
#   'reported_depth': 594.23,
#   'reported_weight': 662.37,
#   'actual_height': 781.8462809220738,
#   'actual_width': 123.66826489882017,
#   'actual_depth': 594.5122615131934,
#   'actual_weight': 661.1157770828844,
#   'content': 'pFbEdMpvyvzw',
#   'estimated_value': 73.03},
#  (31, 5): {'request_id': 31,
#   'package_id': 5,
#   'reported_height': 984.59,
#   'reported_width': 22.11,
#   'reported_depth': 356.16,
#   'reported_weight': 535.23,
#   'actual_height': 984.7916085367968,
#   'actual_width': 20.092310412824915,
#   'actual_depth': 357.20636283703254,
#   'actual_weight': 537.4976719044248,
#   'content': 'FqgFEAwlyije',
#   'estimated_value': 67.55},
#  (32, 1): {'request_id': 32,
#   'package_id': 1,
#   'reported_height': 482.36,
#   'reported_width': 248.59,
#   'reported_depth': 515.53,
#   'reported_weight': 198.08,
#   'actual_height': 482.6104105619674,
#   'actual_width': 248.4109631541168,
#   'actual_depth': 514.6674505484857,
#   'actual_weight': 201.10393029167432,
#   'content': 'dKNimWdLvSuy',
#   'estimated_value': 38.65},
#  (32, 2): {'request_id': 32,
#   'package_id': 2,
#   'reported_height': 131.03,
#   'reported_width': 32.58,
#   'reported_depth': 558.75,
#   'reported_weight': 578.08,
#   'actual_height': 129.47550752513078,
#   'actual_width': 30.93274210489075,
#   'actual_depth': 559.4106971742691,
#   'actual_weight': 576.9266486711559,
#   'content': 'LJLnWpvmJlMW',
#   'estimated_value': 77.11},
#  (33, 1): {'request_id': 33,
#   'package_id': 1,
#   'reported_height': 294.88,
#   'reported_width': 820.51,
#   'reported_depth': 466.56,
#   'reported_weight': 945.01,
#   'actual_height': 293.93343245070844,
#   'actual_width': 816.5299199580851,
#   'actual_depth': 467.5653178969815,
#   'actual_weight': 944.352656331015,
#   'content': 'umwRJtxAtQDf',
#   'estimated_value': 54.31},
#  (34, 1): {'request_id': 34,
#   'package_id': 1,
#   'reported_height': 956.77,
#   'reported_width': 54.01,
#   'reported_depth': 254.75,
#   'reported_weight': 137.42,
#   'actual_height': 955.0485299284906,
#   'actual_width': 55.085742775122256,
#   'actual_depth': 259.32606554897677,
#   'actual_weight': 136.87614183252953,
#   'content': 'RrtfaZyFNnNG',
#   'estimated_value': 44.53},
#  (34, 2): {'request_id': 34,
#   'package_id': 2,
#   'reported_height': 645.63,
#   'reported_width': 268.01,
#   'reported_depth': 630.27,
#   'reported_weight': 9.809999999999999,
#   'actual_height': 646.095939806024,
#   'actual_width': 268.50141702153303,
#   'actual_depth': 628.9770370369292,
#   'actual_weight': 10.030929012368714,
#   'content': 'ykCFrysGocym',
#   'estimated_value': 67.63},
#  (34, 3): {'request_id': 34,
#   'package_id': 3,
#   'reported_height': 912.91,
#   'reported_width': 160.72,
#   'reported_depth': 464.83,
#   'reported_weight': 714.77,
#   'actual_height': 914.3021968952733,
#   'actual_width': 161.21693505464472,
#   'actual_depth': 467.4625938171158,
#   'actual_weight': 715.2856474681244,
#   'content': 'EZgxbWXwhhsy',
#   'estimated_value': 39.44},
#  (35, 1): {'request_id': 35,
#   'package_id': 1,
#   'reported_height': 76.37,
#   'reported_width': 607.78,
#   'reported_depth': 125.98,
#   'reported_weight': 461.67,
#   'actual_height': 76.1168897749173,
#   'actual_width': 607.7366117237931,
#   'actual_depth': 122.61650322179892,
#   'actual_weight': 460.370539891984,
#   'content': 'GVOFGYCqWgRj',
#   'estimated_value': 42.09},
#  (35, 2): {'request_id': 35,
#   'package_id': 2,
#   'reported_height': 80.56,
#   'reported_width': 135.05,
#   'reported_depth': 208.03,
#   'reported_weight': 707.57,
#   'actual_height': 81.89286125454501,
#   'actual_width': 134.15625438076805,
#   'actual_depth': 209.96710360231742,
#   'actual_weight': 708.6225467489381,
#   'content': 'eMOGnfryFBPJ',
#   'estimated_value': 38.33},
#  (35, 3): {'request_id': 35,
#   'package_id': 3,
#   'reported_height': 515.22,
#   'reported_width': 312.3,
#   'reported_depth': 791.7,
#   'reported_weight': 790.42,
#   'actual_height': 514.060751915502,
#   'actual_width': 311.5449125421065,
#   'actual_depth': 791.5727285178862,
#   'actual_weight': 791.0722724904276,
#   'content': 'udctimeyQhUT',
#   'estimated_value': 7.41},
#  (35, 4): {'request_id': 35,
#   'package_id': 4,
#   'reported_height': 746.86,
#   'reported_width': 312.45,
#   'reported_depth': 650.78,
#   'reported_weight': 528.32,
#   'actual_height': 746.5900559649841,
#   'actual_width': 311.3157877837648,
#   'actual_depth': 650.6647840385106,
#   'actual_weight': 530.6790641490954,
#   'content': 'YTkchzhkuhyo',
#   'estimated_value': 57.18},
#  (36, 1): {'request_id': 36,
#   'package_id': 1,
#   'reported_height': 640.56,
#   'reported_width': 881.31,
#   'reported_depth': 2.2,
#   'reported_weight': 487.25,
#   'actual_height': 640.8818900815661,
#   'actual_width': 883.7957382535917,
#   'actual_depth': 0.19087377192779487,
#   'actual_weight': 486.33202601927223,
#   'content': 'uvVgfyUQKImW',
#   'estimated_value': 59.76},
#  (36, 2): {'request_id': 36,
#   'package_id': 2,
#   'reported_height': 129.55,
#   'reported_width': 359.33,
#   'reported_depth': 832.24,
#   'reported_weight': 851.28,
#   'actual_height': 126.53039497186042,
#   'actual_width': 360.84773243125466,
#   'actual_depth': 832.035377204454,
#   'actual_weight': 854.93178816181,
#   'content': 'idDXZErXbXoa',
#   'estimated_value': 91.19},
#  (36, 3): {'request_id': 36,
#   'package_id': 3,
#   'reported_height': 763.11,
#   'reported_width': 609.07,
#   'reported_depth': 582.43,
#   'reported_weight': 728.28,
#   'actual_height': 761.6228465265997,
#   'actual_width': 608.6392531272435,
#   'actual_depth': 581.7998522021674,
#   'actual_weight': 727.5975351796545,
#   'content': 'ntogVqpjyqGc',
#   'estimated_value': 60.21},
#  (36, 4): {'request_id': 36,
#   'package_id': 4,
#   'reported_height': 267.98,
#   'reported_width': 974.92,
#   'reported_depth': 553.55,
#   'reported_weight': 586.92,
#   'actual_height': 267.4060857430832,
#   'actual_width': 974.0197237938066,
#   'actual_depth': 553.1274213563821,
#   'actual_weight': 585.4106894507877,
#   'content': 'GVCeqLUwPsxN',
#   'estimated_value': 60.68},
#  (36, 5): {'request_id': 36,
#   'package_id': 5,
#   'reported_height': 571.56,
#   'reported_width': 112.94,
#   'reported_depth': 471.18,
#   'reported_weight': 952.09,
#   'actual_height': 574.3875174650818,
#   'actual_width': 109.52965356009891,
#   'actual_depth': 473.0881885704958,
#   'actual_weight': 948.6136945087309,
#   'content': 'EEhBGryiLegl',
#   'estimated_value': 94.81},
#  (37, 1): {'request_id': 37,
#   'package_id': 1,
#   'reported_height': 26.32,
#   'reported_width': 970.47,
#   'reported_depth': 791.91,
#   'reported_weight': 451.53,
#   'actual_height': 28.66155959633202,
#   'actual_width': 972.1737587920736,
#   'actual_depth': 790.9358170949139,
#   'actual_weight': 449.8574717979891,
#   'content': 'msrwbHBBdMhk',
#   'estimated_value': 73.77},
#  (37, 2): {'request_id': 37,
#   'package_id': 2,
#   'reported_height': 6.0,
#   'reported_width': 133.92,
#   'reported_depth': 396.06,
#   'reported_weight': 695.06,
#   'actual_height': 9.30392106225928,
#   'actual_width': 135.6584975432698,
#   'actual_depth': 393.56559362436116,
#   'actual_weight': 696.299394634977,
#   'content': 'fTmKGnOQJbNG',
#   'estimated_value': 17.46},
#  (37, 3): {'request_id': 37,
#   'package_id': 3,
#   'reported_height': 172.22,
#   'reported_width': 78.3,
#   'reported_depth': 665.66,
#   'reported_weight': 579.48,
#   'actual_height': 173.21447738253434,
#   'actual_width': 82.23492803501823,
#   'actual_depth': 662.7939552570334,
#   'actual_weight': 579.5929850490533,
#   'content': 'jyxWAszpsgkA',
#   'estimated_value': 22.01},
#  (37, 4): {'request_id': 37,
#   'package_id': 4,
#   'reported_height': 851.07,
#   'reported_width': 657.04,
#   'reported_depth': 435.02,
#   'reported_weight': 264.11,
#   'actual_height': 848.9524471300292,
#   'actual_width': 657.7059802555336,
#   'actual_depth': 437.38991395722604,
#   'actual_weight': 265.35292048194026,
#   'content': 'ZKKCVTozIDtB',
#   'estimated_value': 43.64},
#  (38, 1): {'request_id': 38,
#   'package_id': 1,
#   'reported_height': 190.29,
#   'reported_width': 214.4,
#   'reported_depth': 221.82,
#   'reported_weight': 437.54,
#   'actual_height': 191.24729377824346,
#   'actual_width': 212.71474987111682,
#   'actual_depth': 221.27122524007692,
#   'actual_weight': 439.47317388225775,
#   'content': 'bSTgZXrmOErg',
#   'estimated_value': 39.89},
#  (38, 2): {'request_id': 38,
#   'package_id': 2,
#   'reported_height': 434.0,
#   'reported_width': 242.36,
#   'reported_depth': 488.73,
#   'reported_weight': 103.33,
#   'actual_height': 437.99979602526435,
#   'actual_width': 242.45176730997503,
#   'actual_depth': 485.91879672768937,
#   'actual_weight': 106.13830155958203,
#   'content': 'ILwLdxMuAzAG',
#   'estimated_value': 67.98},
#  (38, 3): {'request_id': 38,
#   'package_id': 3,
#   'reported_height': 16.810000000000002,
#   'reported_width': 350.62,
#   'reported_depth': 600.43,
#   'reported_weight': 399.63,
#   'actual_height': 19.33807040052907,
#   'actual_width': 349.94180133169397,
#   'actual_depth': 601.1480478492497,
#   'actual_weight': 400.3446020190842,
#   'content': 'lPnVujZHfMmQ',
#   'estimated_value': 16.86},
#  (38, 4): {'request_id': 38,
#   'package_id': 4,
#   'reported_height': 184.24,
#   'reported_width': 982.18,
#   'reported_depth': 129.23000000000002,
#   'reported_weight': 731.56,
#   'actual_height': 184.17944203491888,
#   'actual_width': 984.8578997165247,
#   'actual_depth': 129.62731522612532,
#   'actual_weight': 730.4238513341877,
#   'content': 'KVaZBhatSuBK',
#   'estimated_value': 54.39},
#  (39, 1): {'request_id': 39,
#   'package_id': 1,
#   'reported_height': 486.25,
#   'reported_width': 291.81,
#   'reported_depth': 368.72,
#   'reported_weight': 63.51,
#   'actual_height': 487.58848803809605,
#   'actual_width': 293.5694167817143,
#   'actual_depth': 366.3131392793105,
#   'actual_weight': 61.044787284037625,
#   'content': 'lhzqDqwyupcK',
#   'estimated_value': 56.01},
#  (39, 2): {'request_id': 39,
#   'package_id': 2,
#   'reported_height': 734.16,
#   'reported_width': 200.18,
#   'reported_depth': 959.28,
#   'reported_weight': 162.14,
#   'actual_height': 733.0402152068468,
#   'actual_width': 203.93859346675887,
#   'actual_depth': 960.5520059970983,
#   'actual_weight': 157.44480674534555,
#   'content': 'cLAooijwfFqF',
#   'estimated_value': 79.81},
#  (39, 3): {'request_id': 39,
#   'package_id': 3,
#   'reported_height': 31.27,
#   'reported_width': 850.34,
#   'reported_depth': 153.43,
#   'reported_weight': 781.45,
#   'actual_height': 30.82996708723334,
#   'actual_width': 853.3681650275902,
#   'actual_depth': 150.7194811044143,
#   'actual_weight': 778.5168393470194,
#   'content': 'orXPOnxpkoyh',
#   'estimated_value': 90.22},
#  (40, 1): {'request_id': 40,
#   'package_id': 1,
#   'reported_height': 885.88,
#   'reported_width': 333.68,
#   'reported_depth': 656.02,
#   'reported_weight': 440.64,
#   'actual_height': 885.9427605784749,
#   'actual_width': 330.295970413892,
#   'actual_depth': 654.1006929416761,
#   'actual_weight': 438.3800447425202,
#   'content': 'LXSFznaSnUPS',
#   'estimated_value': 45.31},
#  (40, 2): {'request_id': 40,
#   'package_id': 2,
#   'reported_height': 680.53,
#   'reported_width': 419.06,
#   'reported_depth': 344.71,
#   'reported_weight': 19.01,
#   'actual_height': 679.8005837812337,
#   'actual_width': 420.18414578885114,
#   'actual_depth': 342.5839625522936,
#   'actual_weight': 18.51025398673703,
#   'content': 'alZfBCWbfwuX',
#   'estimated_value': 72.16},
#  (40, 3): {'request_id': 40,
#   'package_id': 3,
#   'reported_height': 868.18,
#   'reported_width': 422.78,
#   'reported_depth': 528.57,
#   'reported_weight': 459.59,
#   'actual_height': 868.6018225043251,
#   'actual_width': 423.75201407665804,
#   'actual_depth': 528.8325357101118,
#   'actual_weight': 456.21007158797136,
#   'content': 'wHvzBKSbXTNT',
#   'estimated_value': 30.35},
#  (40, 4): {'request_id': 40,
#   'package_id': 4,
#   'reported_height': 501.06,
#   'reported_width': 207.13,
#   'reported_depth': 557.91,
#   'reported_weight': 268.5,
#   'actual_height': 501.66996785143897,
#   'actual_width': 210.12228584262044,
#   'actual_depth': 555.46622679527,
#   'actual_weight': 267.0709955574355,
#   'content': 'tdUpoKslBkmF',
#   'estimated_value': 55.2},
#  (41, 1): {'request_id': 41,
#   'package_id': 1,
#   'reported_height': 968.86,
#   'reported_width': 652.57,
#   'reported_depth': 65.72,
#   'reported_weight': 420.35,
#   'actual_height': 971.584894068368,
#   'actual_width': 651.3197255466788,
# ...
#  (326, 1): {'request_id': 326,
#   'package_id': 1,
#   'reported_height': 778.55,
#   'reported_width': 141.04,
#   'reported_depth': 515.52,
#   'reported_weight': 527.69,
#   'actual_height': 779.4950906566844,
#   'actual_width': 140.282194522102,
#   'actual_depth': 517.1866229250268,
#   'actual_weight': 528.1636075546776,
#   'content': 'xWgjaLGNemsx',
#   'estimated_value': 6.03},
#  (326, 2): {'request_id': 326,
#   'package_id': 2,
#   'reported_height': 223.62,
#   'reported_width': 774.79,
#   'reported_depth': 865.9,
#   'reported_weight': 769.34,
#   'actual_height': 223.6658036870689,
#   'actual_width': 772.9531561952591,
#   'actual_depth': 866.4531902312733,
#   'actual_weight': 771.631765366737,
#   'content': 'PjNPIObQixRY',
#   'estimated_value': 27.84},
#  (326, 3): {'request_id': 326,
#   'package_id': 3,
#   'reported_height': 571.55,
#   'reported_width': 480.34,
#   'reported_depth': 962.6,
#   'reported_weight': 842.79,
#   'actual_height': 572.7940354501247,
#   'actual_width': 478.86534062854105,
#   'actual_depth': 962.5531884500093,
#   'actual_weight': 844.679980640145,
#   'content': 'SPlOsoydiDzg',
#   'estimated_value': 77.4},
#  (327, 1): {'request_id': 327,
#   'package_id': 1,
#   'reported_height': 548.85,
#   'reported_width': 128.97,
#   'reported_depth': 833.02,
#   'reported_weight': 421.98,
#   'actual_height': 546.5990296278541,
#   'actual_width': 129.48520308914055,
#   'actual_depth': 834.4327540567485,
#   'actual_weight': 425.59428631709727,
#   'content': 'WVfmEldJZzDr',
#   'estimated_value': 81.98},
#  (327, 2): {'request_id': 327,
#   'package_id': 2,
#   'reported_height': 111.49,
#   'reported_width': 609.22,
#   'reported_depth': 532.54,
#   'reported_weight': 52.18,
#   'actual_height': 114.55809106292052,
#   'actual_width': 611.2327021346671,
#   'actual_depth': 536.5372022794961,
#   'actual_weight': 50.815548021987205,
#   'content': 'fUEvDmoOukLI',
#   'estimated_value': 78.76},
#  (327, 3): {'request_id': 327,
#   'package_id': 3,
#   'reported_height': 234.97,
#   'reported_width': 472.96,
#   'reported_depth': 621.86,
#   'reported_weight': 579.23,
#   'actual_height': 238.5884973452376,
#   'actual_width': 471.36635421284274,
#   'actual_depth': 619.3071543534994,
#   'actual_weight': 580.4696220319017,
#   'content': 'BxEQkFpHTtCf',
#   'estimated_value': 44.53},
#  (327, 4): {'request_id': 327,
#   'package_id': 4,
#   'reported_height': 178.01,
#   'reported_width': 75.66,
#   'reported_depth': 782.68,
#   'reported_weight': 117.34,
#   'actual_height': 174.13962946600265,
#   'actual_width': 77.58619272928141,
#   'actual_depth': 785.1470164760356,
#   'actual_weight': 119.32327049360985,
#   'content': 'SzoWmZemzdbm',
#   'estimated_value': 97.93},
#  (327, 5): {'request_id': 327,
#   'package_id': 5,
#   'reported_height': 823.24,
#   'reported_width': 537.66,
#   'reported_depth': 17.05,
#   'reported_weight': 816.41,
#   'actual_height': 826.6832780147763,
#   'actual_width': 540.0674439347741,
#   'actual_depth': 14.212149526417278,
#   'actual_weight': 817.1920226867849,
#   'content': 'ShtuwHZsWReX',
#   'estimated_value': 1.48},
#  (328, 1): {'request_id': 328,
#   'package_id': 1,
#   'reported_height': 245.32,
#   'reported_width': 132.57,
#   'reported_depth': 103.98,
#   'reported_weight': 992.75,
#   'actual_height': 242.0209864914709,
#   'actual_width': 131.867957588841,
#   'actual_depth': 104.4159145379112,
#   'actual_weight': 991.5007178695912,
#   'content': 'kClYGBqQDEFR',
#   'estimated_value': 4.7},
#  (328, 2): {'request_id': 328,
#   'package_id': 2,
#   'reported_height': 813.67,
#   'reported_width': 626.35,
#   'reported_depth': 112.13,
#   'reported_weight': 895.87,
#   'actual_height': 815.229954422518,
#   'actual_width': 628.8367261564836,
#   'actual_depth': 113.63906744713941,
#   'actual_weight': 896.2797358439072,
#   'content': 'URyERDBlHnWb',
#   'estimated_value': 60.57},
#  (328, 3): {'request_id': 328,
#   'package_id': 3,
#   'reported_height': 227.14,
#   'reported_width': 837.74,
#   'reported_depth': 861.87,
#   'reported_weight': 928.49,
#   'actual_height': 226.4559498250916,
#   'actual_width': 840.1569122948423,
#   'actual_depth': 864.5543992886413,
#   'actual_weight': 930.1787669664412,
#   'content': 'GEJopyLwoBrR',
#   'estimated_value': 98.25},
#  (329, 1): {'request_id': 329,
#   'package_id': 1,
#   'reported_height': 69.95,
#   'reported_width': 965.66,
#   'reported_depth': 580.82,
#   'reported_weight': 192.92,
#   'actual_height': 70.1253044848633,
#   'actual_width': 965.436693570433,
#   'actual_depth': 577.2418468113,
#   'actual_weight': 190.70929990391667,
#   'content': 'WOcGzmGOMwRc',
#   'estimated_value': 49.15},
#  (329, 2): {'request_id': 329,
#   'package_id': 2,
#   'reported_height': 173.27,
#   'reported_width': 868.4,
#   'reported_depth': 350.14,
#   'reported_weight': 683.9,
#   'actual_height': 172.93623847392942,
#   'actual_width': 866.2214883032932,
#   'actual_depth': 348.24311368385816,
#   'actual_weight': 682.5802675109363,
#   'content': 'sgQbyvAhSBKR',
#   'estimated_value': 58.67},
#  (329, 3): {'request_id': 329,
#   'package_id': 3,
#   'reported_height': 906.45,
#   'reported_width': 571.92,
#   'reported_depth': 28.26,
#   'reported_weight': 112.35,
#   'actual_height': 903.2866489536264,
#   'actual_width': 570.3654437833691,
#   'actual_depth': 31.185378049618983,
#   'actual_weight': 109.61671860765597,
#   'content': 'JQMsIDlJMyDG',
#   'estimated_value': 79.94},
#  (329, 4): {'request_id': 329,
#   'package_id': 4,
#   'reported_height': 964.82,
#   'reported_width': 85.18,
#   'reported_depth': 446.41,
#   'reported_weight': 88.01,
#   'actual_height': 964.1785196258967,
#   'actual_width': 87.2925614736445,
#   'actual_depth': 447.0536733506208,
#   'actual_weight': 84.83390913983956,
#   'content': 'XeaxRhQlWWbp',
#   'estimated_value': 56.79},
#  (330, 1): {'request_id': 330,
#   'package_id': 1,
#   'reported_height': 753.57,
#   'reported_width': 928.66,
#   'reported_depth': 499.62,
#   'reported_weight': 617.5,
#   'actual_height': 751.8565763218985,
#   'actual_width': 931.26532128854,
#   'actual_depth': 497.07158392953806,
#   'actual_weight': 617.1695737454235,
#   'content': 'RIKPAhEMNZax',
#   'estimated_value': 71.82},
#  (330, 2): {'request_id': 330,
#   'package_id': 2,
#   'reported_height': 937.13,
#   'reported_width': 525.61,
#   'reported_depth': 785.36,
#   'reported_weight': 892.17,
#   'actual_height': 935.9088225707052,
#   'actual_width': 524.0383560410861,
#   'actual_depth': 787.9954687615505,
#   'actual_weight': 889.4196332765134,
#   'content': 'cjsdqdsyeAQv',
#   'estimated_value': 7.13},
#  (330, 3): {'request_id': 330,
#   'package_id': 3,
#   'reported_height': 399.14,
#   'reported_width': 268.41,
#   'reported_depth': 309.02,
#   'reported_weight': 980.96,
#   'actual_height': 401.7918916949894,
#   'actual_width': 270.0649915827861,
#   'actual_depth': 306.427876348192,
#   'actual_weight': 981.6858780522466,
#   'content': 'gNesdxCGvkVR',
#   'estimated_value': 29.7},
#  (331, 1): {'request_id': 331,
#   'package_id': 1,
#   'reported_height': 809.73,
#   'reported_width': 786.03,
#   'reported_depth': 51.61,
#   'reported_weight': 601.99,
#   'actual_height': 806.4423638443517,
#   'actual_width': 786.9204146558677,
#   'actual_depth': 48.22828214077585,
#   'actual_weight': 602.1406995689603,
#   'content': 'OzuAzxLseflN',
#   'estimated_value': 57.6},
#  (331, 2): {'request_id': 331,
#   'package_id': 2,
#   'reported_height': 530.81,
#   'reported_width': 794.46,
#   'reported_depth': 73.06,
#   'reported_weight': 318.49,
#   'actual_height': 533.5125651428716,
#   'actual_width': 793.7875207755466,
#   'actual_depth': 72.37634871280105,
#   'actual_weight': 316.4564659690645,
#   'content': 'tmqsrmUIQmct',
#   'estimated_value': 78.83},
#  (331, 3): {'request_id': 331,
#   'package_id': 3,
#   'reported_height': 282.06,
#   'reported_width': 338.05,
#   'reported_depth': 470.74,
#   'reported_weight': 677.61,
#   'actual_height': 283.0865094307627,
#   'actual_width': 337.9681756356619,
#   'actual_depth': 469.470065157837,
#   'actual_weight': 677.9895665491532,
#   'content': 'HoHyBIGrUjbJ',
#   'estimated_value': 90.35},
#  (331, 4): {'request_id': 331,
#   'package_id': 4,
#   'reported_height': 853.58,
#   'reported_width': 144.63,
#   'reported_depth': 109.53,
#   'reported_weight': 834.75,
#   'actual_height': 856.455686142212,
#   'actual_width': 147.93999056022545,
#   'actual_depth': 106.1325111596953,
#   'actual_weight': 834.7295638150014,
#   'content': 'EtjFlinKtoNG',
#   'estimated_value': 87.51},
#  (332, 1): {'request_id': 332,
#   'package_id': 1,
#   'reported_height': 1000.76,
#   'reported_width': 9.93,
#   'reported_depth': 80.64,
#   'reported_weight': 440.18,
#   'actual_height': 1002.520561450953,
#   'actual_width': 10.882143117059467,
#   'actual_depth': 80.1649055814275,
#   'actual_weight': 439.62732759728465,
#   'content': 'HzGOnbNtfCXM',
#   'estimated_value': 40.12},
#  (332, 2): {'request_id': 332,
#   'package_id': 2,
#   'reported_height': 389.56,
#   'reported_width': 12.46,
#   'reported_depth': 193.3,
#   'reported_weight': 6.45,
#   'actual_height': 389.78632476961496,
#   'actual_width': 12.574593449090091,
#   'actual_depth': 191.4486886633635,
#   'actual_weight': 5.820678774762945,
#   'content': 'rlZIEtaaClwT',
#   'estimated_value': 71.91},
#  (332, 3): {'request_id': 332,
#   'package_id': 3,
#   'reported_height': 706.14,
#   'reported_width': 503.53,
#   'reported_depth': 93.56,
#   'reported_weight': 662.51,
#   'actual_height': 706.5951741556099,
#   'actual_width': 503.0295412079351,
#   'actual_depth': 96.58239020204203,
#   'actual_weight': 663.6672379440506,
#   'content': 'BayseuBXeahY',
#   'estimated_value': 48.27},
#  (333, 1): {'request_id': 333,
#   'package_id': 1,
#   'reported_height': 142.26,
#   'reported_width': 403.84,
#   'reported_depth': 367.11,
#   'reported_weight': 545.76,
#   'actual_height': 141.83551789799117,
#   'actual_width': 405.6483892248133,
#   'actual_depth': 365.79929661810223,
#   'actual_weight': 548.3976575674551,
#   'content': 'vXYiTyKcYUHb',
#   'estimated_value': 74.99},
#  (333, 2): {'request_id': 333,
#   'package_id': 2,
#   'reported_height': 281.83,
#   'reported_width': 487.46,
#   'reported_depth': 806.1,
#   'reported_weight': 514.24,
#   'actual_height': 285.80943252297817,
#   'actual_width': 487.8524577388528,
#   'actual_depth': 805.7474588049857,
#   'actual_weight': 511.4916781811484,
#   'content': 'NKjACTZyajbb',
#   'estimated_value': 80.37},
#  (334, 1): {'request_id': 334,
#   'package_id': 1,
#   'reported_height': 88.85,
#   'reported_width': 34.91,
#   'reported_depth': 527.55,
#   'reported_weight': 935.02,
#   'actual_height': 91.98461234832394,
#   'actual_width': 36.605226945194154,
#   'actual_depth': 524.8926912240013,
#   'actual_weight': 934.0690170411283,
#   'content': 'JIpuRnJoKhaA',
#   'estimated_value': 17.95},
#  (334, 2): {'request_id': 334,
#   'package_id': 2,
#   'reported_height': 73.23,
#   'reported_width': 517.94,
#   'reported_depth': 384.78,
#   'reported_weight': 959.11,
#   'actual_height': 71.54159150974003,
#   'actual_width': 518.2786484029627,
#   'actual_depth': 384.62528467075157,
#   'actual_weight': 961.8223505185708,
#   'content': 'QRrmctbBimOd',
#   'estimated_value': 73.99},
#  (334, 3): {'request_id': 334,
#   'package_id': 3,
#   'reported_height': 744.95,
#   'reported_width': 103.56,
#   'reported_depth': 205.84,
#   'reported_weight': 460.6,
#   'actual_height': 744.332848498249,
#   'actual_width': 105.27888408164935,
#   'actual_depth': 203.77982175420829,
#   'actual_weight': 459.906929947177,
#   'content': 'UTWUvuzvrdOJ',
#   'estimated_value': 83.94},
#  (335, 1): {'request_id': 335,
#   'package_id': 1,
#   'reported_height': 562.43,
#   'reported_width': 223.2,
#   'reported_depth': 835.34,
#   'reported_weight': 841.38,
#   'actual_height': 565.605649703311,
#   'actual_width': 224.54335591962288,
#   'actual_depth': 834.238544537838,
#   'actual_weight': 840.8442824020708,
#   'content': 'uoZxLujdpECl',
#   'estimated_value': 89.46},
#  (335, 2): {'request_id': 335,
#   'package_id': 2,
#   'reported_height': 260.98,
#   'reported_width': 403.28,
#   'reported_depth': 552.43,
#   'reported_weight': 721.14,
#   'actual_height': 261.6859709334285,
#   'actual_width': 404.2164702169057,
#   'actual_depth': 552.9491054779614,
#   'actual_weight': 722.1615888115255,
#   'content': 'QTzNGSrJfiBK',
#   'estimated_value': 34.67},
#  (335, 3): {'request_id': 335,
#   'package_id': 3,
#   'reported_height': 220.91,
#   'reported_width': 448.37,
#   'reported_depth': 388.39,
#   'reported_weight': 627.49,
#   'actual_height': 220.40703375743033,
#   'actual_width': 450.0343372459619,
#   'actual_depth': 385.7895239606474,
#   'actual_weight': 626.9402027695731,
#   'content': 'SQimdWHuxQto',
#   'estimated_value': 30.01},
#  (335, 4): {'request_id': 335,
#   'package_id': 4,
#   'reported_height': 868.01,
#   'reported_width': 44.35,
#   'reported_depth': 480.31,
#   'reported_weight': 234.31,
#   'actual_height': 866.1885285037854,
#   'actual_width': 47.669252977890594,
#   'actual_depth': 480.4717001300746,
#   'actual_weight': 231.96036145309378,
#   'content': 'htKeHxigpFFU',
#   'estimated_value': 38.42},
#  (335, 5): {'request_id': 335,
#   'package_id': 5,
#   'reported_height': 158.32,
#   'reported_width': 365.5,
#   'reported_depth': 31.59,
#   'reported_weight': 970.54,
#   'actual_height': 154.90431961380526,
#   'actual_width': 366.4930150841149,
#   'actual_depth': 28.439614154934098,
#   'actual_weight': 974.6391602792232,
#   'content': 'GntZDyMOBYCG',
#   'estimated_value': 2.94},
#  (336, 1): {'request_id': 336,
#   'package_id': 1,
#   'reported_height': 693.06,
#   'reported_width': 642.84,
#   'reported_depth': 899.71,
#   'reported_weight': 830.21,
#   'actual_height': 693.0065608588465,
#   'actual_width': 644.2108870669043,
#   'actual_depth': 901.2680541024788,
#   'actual_weight': 826.5357823864291,
#   'content': 'SeuzwQdPvqiA',
#   'estimated_value': 15.33},
#  (337, 1): {'request_id': 337,
#   'package_id': 1,
#   'reported_height': 936.93,
#   'reported_width': 600.38,
#   'reported_depth': 761.08,
#   'reported_weight': 456.1,
#   'actual_height': 939.7338110575669,
#   'actual_width': 599.5585824469237,
#   'actual_depth': 757.6453204641457,
#   'actual_weight': 456.82502672897124,
#   'content': 'jMxOIKbRHQwM',
#   'estimated_value': 85.26},
#  (337, 2): {'request_id': 337,
#   'package_id': 2,
#   'reported_height': 318.36,
#   'reported_width': 20.43,
#   'reported_depth': 534.88,
#   'reported_weight': 327.24,
#   'actual_height': 314.3839800331351,
#   'actual_width': 19.540662181081263,
#   'actual_depth': 536.3193386408963,
#   'actual_weight': 327.2084973290993,
#   'content': 'hvqGnadkZmRd',
#   'estimated_value': 85.42},
#  (337, 3): {'request_id': 337,
#   'package_id': 3,
#   'reported_height': 262.25,
#   'reported_width': 549.95,
#   'reported_depth': 90.37,
#   'reported_weight': 136.69,
#   'actual_height': 263.70506587939366,
#   'actual_width': 552.529109602514,
#   'actual_depth': 92.30903484116814,
#   'actual_weight': 137.81930437504568,
#   'content': 'MgPDGPjlSdJP',
#   'estimated_value': 41.71},
#  (338, 1): {'request_id': 338,
#   'package_id': 1,
#   'reported_height': 650.73,
#   'reported_width': 477.98,
#   'reported_depth': 504.43,
#   'reported_weight': 759.62,
#   'actual_height': 650.2894175608925,
#   'actual_width': 475.7445483404883,
#   'actual_depth': 504.19526326846176,
#   'actual_weight': 761.0636624453891,
#   'content': 'uJsDOkoOqkjx',
#   'estimated_value': 41.21},
#  (339, 1): {'request_id': 339,
#   'package_id': 1,
#   'reported_height': 638.35,
#   'reported_width': 932.06,
#   'reported_depth': 24.01,
#   'reported_weight': 168.58,
#   'actual_height': 642.3163682527728,
#   'actual_width': 930.3711083531784,
#   'actual_depth': 22.070388652504967,
#   'actual_weight': 167.01031068484778,
#   'content': 'OULXEgtIGwxU',
#   'estimated_value': 17.17},
#  (339, 2): {'request_id': 339,
#   'package_id': 2,
#   'reported_height': 587.14,
#   'reported_width': 631.35,
#   'reported_depth': 214.95,
#   'reported_weight': 346.84,
#   'actual_height': 587.1758800259984,
#   'actual_width': 628.7874114800574,
#   'actual_depth': 215.13799648097384,
#   'actual_weight': 345.9226475226601,
#   'content': 'pFHZalscBold',
#   'estimated_value': 22.26},
#  (339, 3): {'request_id': 339,
#   'package_id': 3,
#   'reported_height': 858.14,
#   'reported_width': 155.83,
#   'reported_depth': 359.11,
#   'reported_weight': 454.92,
#   'actual_height': 856.0078429724089,
#   'actual_width': 155.9529389469142,
#   'actual_depth': 357.6951019655934,
#   'actual_weight': 457.17486727280857,
#   'content': 'ezfsKBgXZnmJ',
#   'estimated_value': 34.79},
#  ...}

# %%
facilities = {}

for i in range(NUM_FACILITIES):
    this_id = i + 1
    to_add = {}
    to_add['address'] = get_random_string(32)
    to_add['postal'] = get_random_string(6)
    facilities[this_id] = to_add
    
facilities
# Out:
# {1: {'address': 'uswHjotDyuDYoyLsGCHJZvPLpqhkFtrm', 'postal': 'qHlndk'},
#  2: {'address': 'RVGmdnAtYfIDEJHqbMPRbAHJJbJuXHhI', 'postal': 'DpREIi'},
#  3: {'address': 'AMHwyEXKyOKBRvmvJELiZknPAMmoJRVU', 'postal': 'NmcrFk'},
#  4: {'address': 'vLnfjKKClcKKgBMfmiQUhKVuqkXSHnLC', 'postal': 'UmTBYI'},
#  5: {'address': 'GbSqvLRNoqbJDenDZgemgPqPQSFgcBgy', 'postal': 'eEgqjF'},
#  6: {'address': 'SrLfShqidjJxScmbNfWrJYYJDeQHyIaP', 'postal': 'MAyPfg'},
#  7: {'address': 'YKxNoMEsnBBwngzsjOGbicoOtozBJTQD', 'postal': 'fYMrPE'},
#  8: {'address': 'eNlEyGcvnleUVKbMzbrFCmOrkkyguHNu', 'postal': 'iacvcI'},
#  9: {'address': 'RUeAUDypsEkorTZJsYcogrBqVDzLPvXa', 'postal': 'nPSESX'},
#  10: {'address': 'RtozVOYxcybSDCOErqFlpCaDjQSXugGx', 'postal': 'TdoKBp'}}

# %%
failed_pickups = {}
req_to_failed_pickup = {}
for accepted_id in accepted_req_id:
    if (random.choice([True,False])):
        cur_time = delivery_requests[accepted_id]['submission_time']
        last_pickup_id = 1
        for pickup_id in range(1, get_random_int_to(2, 4)):
            to_add = {}
            to_add["reason"] =  get_random_string(32)
            to_add['request_id'] = accepted_id
            to_add['handler_id'] = random.choice(list(delivery_staff_id))
            to_add['pickup_id'] = pickup_id
            this_id = (to_add['request_id'], to_add['pickup_id'])
            # Double check if this needs to be strictly after any other time
            cur_time += timedelta(hours=get_random_int_to(1,12))
            to_add["pickup_time"] = cur_time

            failed_pickups[this_id] = to_add
            last_pickup_id = pickup_id
        
        req_to_failed_pickup[accepted_id] = last_pickup_id
        
failed_pickups
# Out:
# {(2, 1): {'reason': 'qODbxaOTqIRVDMTnDycgFeaMhGNqBKlW',
#   'request_id': 2,
#   'handler_id': 10,
#   'pickup_id': 1,
#   'pickup_time': datetime.datetime(2005, 10, 26, 20, 36, 41)},
#  (3, 1): {'reason': 'beEReoAwMJXnRIvRQXZlHsmEBTvvxxHZ',
#   'request_id': 3,
#   'handler_id': 1,
#   'pickup_id': 1,
#   'pickup_time': datetime.datetime(1979, 11, 2, 21, 55, 59)},
#  (3, 2): {'reason': 'vURhUlnFybqDQzzCevZkPOAsBgFLOLeW',
#   'request_id': 3,
#   'handler_id': 3,
#   'pickup_id': 2,
#   'pickup_time': datetime.datetime(1979, 11, 3, 4, 55, 59)},
#  (5, 1): {'reason': 'pQHsuyyVGoffFEkdUMwtvPTgWAFzQswe',
#   'request_id': 5,
#   'handler_id': 7,
#   'pickup_id': 1,
#   'pickup_time': datetime.datetime(2001, 12, 21, 0, 23, 24)},
#  (8, 1): {'reason': 'CFeDyInJFDUUTZxSVDxNjuSlixOnxykF',
#   'request_id': 8,
#   'handler_id': 9,
#   'pickup_id': 1,
#   'pickup_time': datetime.datetime(1970, 8, 18, 4, 4, 45)},
#  (12, 1): {'reason': 'quuxvdraRQqCDwClRneExORYLnvBWLTu',
#   'request_id': 12,
#   'handler_id': 8,
#   'pickup_id': 1,
#   'pickup_time': datetime.datetime(1989, 8, 30, 1, 6, 50)},
#  (14, 1): {'reason': 'KAHbfTQgBlTSQLgrEwUEEJoUkKHmFFlM',
#   'request_id': 14,
#   'handler_id': 8,
#   'pickup_id': 1,
#   'pickup_time': datetime.datetime(1988, 11, 15, 6, 16, 31)},
#  (14, 2): {'reason': 'eNRWusAGEAyiqAtUscoQowJFtcJdGMQN',
#   'request_id': 14,
#   'handler_id': 8,
#   'pickup_id': 2,
#   'pickup_time': datetime.datetime(1988, 11, 15, 15, 16, 31)},
#  (14, 3): {'reason': 'XsgjlWYRVBNTPvzwlrrTCvLYrcCMmgFP',
#   'request_id': 14,
#   'handler_id': 9,
#   'pickup_id': 3,
#   'pickup_time': datetime.datetime(1988, 11, 15, 21, 16, 31)},
#  (15, 1): {'reason': 'cidsiuxAfkzMcmOeGljHsusnPMBENIAE',
#   'request_id': 15,
#   'handler_id': 10,
#   'pickup_id': 1,
#   'pickup_time': datetime.datetime(1998, 2, 10, 7, 37, 59)},
#  (15, 2): {'reason': 'dxSTDCvmBSRrklrdaAjdrBJliPixFgNc',
#   'request_id': 15,
#   'handler_id': 2,
#   'pickup_id': 2,
#   'pickup_time': datetime.datetime(1998, 2, 10, 19, 37, 59)},
#  (15, 3): {'reason': 'kUwKqGHKtavNQeXXUlvkgtzTiaubuxyQ',
#   'request_id': 15,
#   'handler_id': 7,
#   'pickup_id': 3,
#   'pickup_time': datetime.datetime(1998, 2, 11, 6, 37, 59)},
#  (17, 1): {'reason': 'VmKdVhHRitIAjfuCGYYtqMrQbJBSbskC',
#   'request_id': 17,
#   'handler_id': 8,
#   'pickup_id': 1,
#   'pickup_time': datetime.datetime(1982, 1, 22, 12, 12, 58)},
#  (17, 2): {'reason': 'AXoXfYOWmEqIQekIWIiflUPmktzinLfi',
#   'request_id': 17,
#   'handler_id': 1,
#   'pickup_id': 2,
#   'pickup_time': datetime.datetime(1982, 1, 22, 14, 12, 58)},
#  (17, 3): {'reason': 'dxtMKiBvkkjsJVuoUomZnaVrFUNuSmqc',
#   'request_id': 17,
#   'handler_id': 1,
#   'pickup_id': 3,
#   'pickup_time': datetime.datetime(1982, 1, 22, 23, 12, 58)},
#  (18, 1): {'reason': 'FAepixwEwsWNPpacRplJpGhyQFTFBCJY',
#   'request_id': 18,
#   'handler_id': 3,
#   'pickup_id': 1,
#   'pickup_time': datetime.datetime(

#   'handler_id': 7,
#   'pickup_id': 2,
#   'pickup_time': datetime.datetime(1985, 1, 16, 15, 31, 30)},
#  ...}

# %%
req_to_failed_pickup
# Out:
# {2: 1,
#  3: 2,
#  5: 1,
#  8: 1,
#  12: 1,
#  14: 3,
#  15: 3,
#  17: 3,
#  18: 2,
#  20: 2,
#  22: 2,
#  24: 2,
#  25: 1,
#  27: 3,
#  29: 2,
#  34: 2,
#  41: 3,
#  42: 2,
#  56: 1,
#  57: 2,
#  58: 3,
#  60: 2,
#  65: 2,
#  69: 1,
#  72: 2,
#  75: 2,
#  82: 2,
#  88: 1,
#  95: 3,
#  98: 2,
#  100: 2,
#  105: 3,
#  106: 1,
#  110: 3,
#  113: 3,
#  114: 3,
#  116: 1,
#  118: 3,
#  123: 3,
#  127: 2,
#  129: 1,
#  130: 2,
#  131: 2,
#  133: 1,
#  134: 2,
#  145: 2,
#  149: 3,
#  158: 3,
#  162: 1,
#  164: 3,
#  169: 3,
#  178: 2,
#  180: 2,
#  182: 3,
#  183: 1,
#  188: 3,
#  201: 2,
#  206: 3,
#  219: 3,
#  221: 3,
#  222: 1,
#  227: 2,
#  235: 3,
#  236: 1,
#  238: 1,
#  245: 1,
#  246: 3,
#  252: 3,
#  259: 1,
#  267: 1,
#  271: 1,
#  273: 2,
#  283: 2,
#  285: 3,
#  286: 1,
#  287: 1,
#  289: 1,
#  292: 3,
#  295: 3,
#  303: 3,
#  305: 3,
#  307: 1,
#  309: 2,
#  311: 3,
#  312: 3,
#  313: 1,
#  314: 1,
#  317: 3,
#  321: 1,
#  324: 3,
#  327: 1,
#  331: 2,
#  333: 2,
#  339: 3,
#  343: 3,
#  344: 2,
#  349: 1,
#  350: 1,
#  351: 1,
#  353: 2,
#  357: 2,
#  358: 3,
#  371: 2,
#  373: 1,
#  374: 2,
#  376: 1,
#  377: 1,
#  380: 2,
#  385: 1,
#  388: 3,
#  389: 3,
#  390: 2,
#  392: 3,
#  393: 2,
#  402: 1,
#  405: 3,
#  416: 1,
#  419: 3,
#  420: 1,
#  422: 1,
#  425: 3,
#  426: 3,
#  428: 1,
#  430: 2,
#  433: 3,
#  434: 2,
#  443: 1,
#  444: 2,
#  448: 2,
#  451: 3,
#  454: 3,
#  458: 1,
#  461: 2,
#  464: 3,
#  465: 3,
#  468: 1,
#  470: 1,
#  473: 3,
#  493: 3,
#  497: 2,
#  505: 2,
#  507: 1,
#  510: 2,
#  514: 2,
#  523: 3,
#  525: 1,
#  547: 3,
#  549: 1,
#  550: 3,
#  554: 2,
#  563: 2,
#  565: 2,
#  573: 2,
#  576: 3,
#  578: 3,
#  585: 2,
#  587: 1,
#  589: 2,
#  591: 2,
#  594: 2,
#  596: 2,
#  599: 2,
#  600: 2,
#  604: 2,
#  605: 2,
#  624: 2,
#  640: 1,
#  645: 2,
#  651: 3,
#  661: 3,
#  662: 1,
#  667: 2,
#  676: 1,
#  678: 2,
#  679: 2,
#  680: 2,
#  689: 1,
#  690: 2,
#  691: 2,
#  695: 3,
#  701: 2,
#  704: 3,
#  706: 1,
#  710: 3,
#  711: 1,
#  714: 3,
#  715: 2,
#  717: 1,
#  719: 2,
#  720: 2,
#  723: 1,
#  726: 2,
#  729: 2,
#  733: 1,
#  738: 1,
#  739: 2,
#  743: 2,
#  746: 3,
#  757: 3,
#  758: 2,
#  767: 2,
#  772: 1,
#  773: 2,
#  774: 1,
#  775: 1,
#  776: 1,
#  778: 1,
#  780: 2,
#  781: 2,
#  783: 2,
#  788: 2,
#  790: 2,
#  793: 1,
#  794: 2,
#  798: 3,
#  799: 1,
#  800: 2,
#  803: 2,
#  804: 3,
#  808: 2,
#  810: 3,
#  811: 1,
#  813: 2,
#  815: 3,
#  816: 2,
#  817: 2,
#  824: 1,
#  825: 1,
#  831: 1,
#  833: 1,
#  834: 2,
#  835: 2,
#  837: 2,
#  841: 3,
#  843: 1,
#  848: 3,
#  853: 2,
#  857: 1,
#  858: 3,
#  866: 3,
#  867: 3,
#  868: 2,
#  872: 2,
#  875: 1,
#  878: 2,
#  879: 1,
#  880: 3,
#  882: 2,
#  883: 1,
#  884: 1,
#  885: 2,
#  886: 2,
#  889: 3,
#  893: 1,
#  896: 2,
#  902: 3,
#  904: 2,
#  905: 2,
#  907: 3,
#  910: 3,
#  914: 1,
#  919: 2,
#  920: 3,
#  921: 1,
#  923: 2,
#  925: 3,
#  931: 1,
#  932: 1,
#  933: 1,
#  937: 1,
#  940: 1,
#  946: 1,
#  948: 2,
#  949: 3,
#  952: 1,
#  961: 1,
#  962: 1,
#  970: 1,
#  980: 3,
#  981: 1,
#  984: 3,
#  988: 3,
#  992: 2,
#  997: 2,
#  998: 3,
#  1001: 3,
#  1004: 2,
#  1005: 3,
#  1006: 2,
#  1008: 2,
#  1015: 2,
#  1018: 3,
#  1022: 1,
#  1025: 2,
#  1028: 3,
#  1034: 3,
#  1035: 3,
#  1038: 3,
#  1041: 1,
#  1042: 3,
#  1043: 3,
#  1047: 3,
#  1051: 1,
#  1052: 2,
#  1054: 2,
#  1056: 1,
#  1061: 3,
#  1071: 1,
#  1075: 2,
#  1095: 1,
#  1100: 1,
#  1109: 2,
#  1110: 1,
#  1113: 2,
#  1114: 1,
#  1117: 1,
#  1124: 2,
#  1129: 1,
#  1132: 2,
#  1144: 2,
#  1145: 2,
#  1153: 3,
#  1160: 3,
#  1162: 1,
#  1164: 3,
#  1165: 3,
#  1168: 1,
#  1174: 3,
#  1175: 1,
#  1184: 1,
#  1191: 3,
#  1193: 3,
#  1194: 3,
#  1200: 3,
#  1206: 3,
#  1213: 3,
#  1219: 3,
#  1226: 1,
#  1233: 2,
#  1234: 3,
#  1235: 1,
#  1236: 2,
#  1239: 3,
#  1263: 2,
#  1268: 1,
#  1271: 2,
#  1272: 2,
#  1276: 2,
#  1281: 3,
#  1284: 2,
#  1288: 2,
#  1292: 2,
#  1294: 1,
#  1306: 3,
#  1309: 1,
#  1315: 1,
#  1323: 3,
#  1328: 2,
#  1329: 2,
#  1330: 2,
#  1332: 3,
#  1336: 1,
#  1339: 1,
#  1344: 1,
#  1345: 2,
#  1347: 2,
#  1348: 1,
#  1349: 1,
#  1356: 2,
#  1357: 1,
#  1368: 1,
#  1369: 2,
#  1370: 1,
#  1371: 3,
#  1374: 2,
#  1375: 1,
#  1384: 3,
#  1386: 3,
#  1391: 2,
#  1397: 3,
#  1400: 3,
#  1401: 1,
#  1404: 3,
#  1405: 1,
#  1411: 2,
#  1415: 2,
#  1419: 2,
#  1424: 1,
#  1426: 3,
#  1431: 2,
#  1443: 2,
#  1446: 1,
#  1447: 2,
#  1449: 3,
#  1453: 2,
#  1457: 1,
#  1458: 2,
#  1460: 2,
#  1470: 2,
#  1472: 2,
#  1475: 3,
#  1476: 3,
#  1478: 3,
#  1479: 1,
#  1480: 3,
#  1490: 1,
#  1493: 1,
#  1495: 3,
#  1498: 2,
#  1501: 3,
#  1510: 2,
#  1511: 3,
#  1513: 3,
#  1516: 2,
#  1522: 3,
#  1528: 1,
#  1540: 2,
#  1541: 1,
#  1543: 2,
#  1545: 3,
#  1548: 1,
#  1551: 2,
#  1552: 1,
#  1554: 3,
#  1556: 3,
#  1557: 1,
#  1558: 1,
#  1559: 2,
#  1561: 1,
#  1562: 1,
#  1563: 2,
#  1564: 3,
#  1566: 1,
#  1569: 1,
#  1570: 1,
#  1572: 3,
#  1577: 1,
#  1581: 1,
#  1582: 1,
#  1585: 3,
#  1588: 1,
#  1590: 3,
#  1602: 3,
#  1604: 3,
#  1608: 3,
#  1610: 2,
#  1615: 1,
#  1617: 3,
#  1622: 3,
#  1627: 3,
#  1629: 2,
#  1630: 3,
#  1634: 2,
#  1642: 2,
#  1644: 2,
#  1650: 1,
#  1653: 1,
#  1660: 1,
#  1664: 3,
#  1668: 1,
#  1670: 2,
#  1675: 3,
#  1678: 3,
#  1680: 2,
#  1683: 2,
#  1686: 2,
#  1687: 3,
#  1689: 1,
#  1693: 3,
#  1697: 3,
#  1699: 3,
#  1709: 3,
#  1710: 1,
#  1711: 3,
#  1712: 2,
#  1719: 1,
#  1721: 1,
#  1726: 3,
#  1728: 2,
#  1729: 1,
#  1732: 3,
#  1733: 2,
#  1740: 1,
#  1742: 1,
#  1744: 2,
#  1748: 1,
#  1749: 2,
#  1753: 2,
#  1760: 1,
#  1765: 2,
#  1766: 3,
#  1768: 1,
#  1769: 1,
#  1773: 1,
#  1774: 1,
#  1775: 3,
#  1776: 2,
#  1777: 2,
#  1779: 2,
#  1782: 3,
#  1783: 1,
#  1785: 2,
#  1788: 2,
#  1792: 3,
#  1796: 1,
#  1798: 1,
#  1799: 3,
#  1801: 1,
#  1803: 3,
#  1808: 3,
#  1809: 1,
#  1817: 1,
#  1818: 1,
#  1825: 1,
#  1831: 2,
#  1832: 3,
#  1835: 2,
#  1837: 2,
#  1842: 2,
#  1845: 2,
#  1852: 3,
#  1856: 2,
#  1866: 3,
#  1867: 3,
#  1870: 3,
#  1872: 3,
#  1873: 2,
#  1875: 3,
#  1878: 1,
#  1880: 2,
#  1882: 1,
#  1883: 2,
#  1885: 3,
#  1886: 2,
#  1887: 2,
#  1893: 2,
#  1897: 1,
#  1901: 1,
#  1906: 3,
#  1912: 2,
#  1913: 2,
#  1916: 1,
#  1917: 1,
#  1919: 1,
#  1924: 2,
#  1927: 3,
#  1931: 3,
#  1937: 3,
#  1938: 3,
#  1941: 3,
#  1943: 2,
#  1947: 1,
#  1950: 3,
#  1952: 2,
#  1955: 1,
#  1960: 2,
#  1961: 3,
#  1963: 2,
#  1964: 2,
#  1965: 1,
#  1969: 3,
#  1975: 1,
#  1977: 3,
#  1987: 3,
#  1988: 2,
#  1996: 3}

# %%
legs = {}
# NUM_LEGS
req_to_last_leg = {}
    
potential_unsuccessful = set()
    
for accepted_id in accepted_req_id:
#     print(f"accepted_id: {accepted_id}")
    if (random.choice([True,False])):
        cur_time = delivery_requests[accepted_id]['submission_time']
        if accepted_id in req_to_failed_pickup:
            k = (accepted_id, req_to_failed_pickup[accepted_id])
            cur_time = failed_pickups[k]['pickup_time']
        leg_id  = 1
        up_to = get_random_int_to(2, 7)
        while(leg_id < up_to):
            to_add = {}
            this_id = (accepted_id, leg_id)
            # Check if need to match the pickup handler's id
            to_add['request_id'] = accepted_id
            to_add['leg_id'] = leg_id
            to_add['handler_id'] = random.choice(list(delivery_staff_id))
            cur_time += timedelta(hours=get_random_int_to(1,12))
            to_add['start_time'] = cur_time
            cur_time += timedelta(hours=get_random_int_to(1,12))
            to_add['destination_facility'] = random.choice(list(facilities.keys()))
            if leg_id < (up_to - 1):
                to_add['end_time'] = cur_time
            else:
                # None means mid way, a timestamp means complete
                to_add['end_time'] = random.choice([None, cur_time])
            legs[this_id] = to_add
            leg_id += 1
        if up_to <= 4:
            potential_unsuccessful.add(accepted_id)
        req_to_last_leg[accepted_id] = up_to - 1 
legs
# Out:
# {(5, 1): {'request_id': 5,
#   'leg_id': 1,
#   'handler_id': 1,
#   'start_time': datetime.datetime(2001, 12, 21, 6, 23, 24),
#   'destination_facility': 2,
#   'end_time': None},
#  (8, 1): {'request_id': 8,
#   'leg_id': 1,
#   'handler_id': 2,
#   'start_time': datetime.datetime(1970, 8, 18, 11, 4, 45),
#   'destination_facility': 9,
#   'end_time': datetime.datetime(1970, 8, 18, 20, 4, 45)},
#  (14, 1): {'request_id': 14,
#   'leg_id': 1,
#   'handler_id': 2,
#   'start_time': datetime.datetime(1988, 11, 16, 2, 16, 31),
#   'destination_facility': 7,
#   'end_time': datetime.datetime(1988, 11, 16, 5, 16, 31)},
#  (14, 2): {'request_id': 14,
#   'leg_id': 2,
#   'handler_id': 6,
#   'start_time': datetime.datetime(1988, 11, 16, 10, 16, 31),
#   'destination_facility': 8,
#   'end_time': datetime.datetime(1988, 11, 16, 20, 16, 31)},
#  (14, 3): {'request_id': 14,
#   'leg_id': 3,
#   'handler_id': 9,
#   'start_time': datetime.datetime(1988, 11, 16, 22, 16, 31),
#   'destination_facility': 10,
#   'end_time': datetime.datetime(1988, 11, 17, 3, 16, 31)},
#  (14, 4): {'request_id': 14,
#   'leg_id': 4,
#   'handler_id': 10,
#   'start_time': datetime.datetime(1988, 11, 17, 6, 16, 31),
#   'destination_facility': 5,
#   'end_time': datetime.datetime(1988, 11, 17, 18, 16, 31)},
#  (14, 5): {'request_id': 14,
#   'leg_id': 5,
#   'handler_id': 10,
#   'start_time': datetime.datetime(1988, 11, 18, 5, 16, 31),
#   'destination_facility': 3,
#   'end_time': datetime.datetime(1988, 11, 18, 13, 16, 31)},
#  (17, 1): {'request_id': 17,
#   'leg_id': 1,
#   'handler_id': 7,
#   'start_time': datetime.datetime(1982, 1, 23, 7, 12, 58),
#   'destination_facility': 7,
#   'end_time': datetime.datetime(1982, 1, 23, 9, 12, 58)},
#  (17, 2): {'request_id': 17,
#   'leg_id': 2,
#   'handler_id': 3,
#   'start_time': datetime.datetime(1982, 1, 23, 13, 12, 58),
#   'destination_facility': 8,
#   'end_time': datetime.datetime(1982, 1, 23, 15, 12, 58)},
#  (17, 3): {'request_id': 17,
#   'leg_id': 3,
#   'handler_id': 4,
#   'start_time': datetime.datetime(1982, 1, 23, 18, 12, 58),
#   'destination_facility': 1,
#   'end_time': datetime.datetime(1982, 1, 23, 20, 12, 58)},
#  (18, 1): {'request_id': 18,
#   'leg_id': 1,
#   'handler_id': 9,
#   'start_time': datetime.datetime(2007, 11, 22, 15, 51, 10),
#   'destination_facility': 9,
#   'end_time': datetime.datetime(2007, 11, 22, 20, 51, 10)},
#  (18, 2): {'request_id': 18,
#   'leg_id': 2,
#   'handler_id': 6,
#   'start_time': datetime.datetime(2007, 11, 23, 3, 51, 10),
#   'destination_facility': 5,
#   'end_time': datetime.datetime(2007, 11, 23, 4, 51, 10)},
#  (20, 1): {'request_id': 20,
#   'leg_id': 1,
#   'handler_id': 5,
#   'start_time': datetime.datetime(2011, 10, 26, 1, 18, 27),
#   'destination_facility': 4,
#   'end_time': datetime.datetime(2011, 10, 26, 7, 18, 27)},
#  (20, 2): {'request_id': 20,
#   'leg_id': 2,
#   'handler_id': 8,
#   'start_time': datetime.datetime(2011, 10, 26, 9, 18, 27),
#   'destination_facility': 1,
#   'end_time': datetime.datetime(2011, 10, 26, 21, 18, 27)},
#  (20, 3): {'request_id': 20,
#   'leg_id': 3,
#   'handler_id': 2,
#   'start_time': datetime.datetime(

#   'handler_id': 7,
#   'start_time': datetime.datetime(2013, 8, 18, 19, 7, 4),
#   'destination_facility': 5,
#   'end_time': datetime.datetime(2013, 8, 19, 5, 7, 4)},
#  (931, 1): {'request_id': 931,
#   'leg_id': 1,
#   'handler_id': 8,
#   'start_time': datetime.datetime(1980, 11, 30, 6, 24, 46),
#   'destination_facility': 10,
#   'end_time': datetime.datetime(1980, 11, 30, 12, 24, 46)},
#  (931, 2): {'request_id': 931,
#   'leg_id': 2,
#   'handler_id': 6,
#   'start_time': datetime.datetime(1980, 11, 30, 15, 24, 46),
#   'destination_facility': 10,
#   'end_time': datetime.datetime(1980, 11, 30, 19, 24, 46)},
#  (931, 3): {'request_id': 931,
#   'leg_id': 3,
#   'handler_id': 1,
#   'start_time': datetime.datetime(1980, 11, 30, 20, 24, 46),
#   'destination_facility': 3,
#   'end_time': datetime.datetime(1980, 12, 1, 0, 24, 46)},
#  (931, 4): {'request_id': 931,
#   'leg_id': 4,
#   'handler_id': 6,
#   'start_time': datetime.datetime(1980, 12, 1, 12, 24, 46),
#   'destination_facility': 2,
#   'end_time': datetime.datetime(1980, 12, 1, 21, 24, 46)},
#  (933, 1): {'request_id': 933,
#   'leg_id': 1,
#   'handler_id': 9,
#   'start_time': datetime.datetime(2016, 7, 23, 15, 1, 23),
#   'destination_facility': 9,
#   'end_time': datetime.datetime(2016, 7, 24, 3, 1, 23)},
#  (933, 2): {'request_id': 933,
#   'leg_id': 2,
#   'handler_id': 4,
#   'start_time': datetime.datetime(2016, 7, 24, 8, 1, 23),
#   'destination_facility': 1,
#   'end_time': None},
#  (937, 1): {'request_id': 937,
#   'leg_id': 1,
#   'handler_id': 6,
#   'start_time': datetime.datetime(1994, 7, 17, 1, 1, 17),
#   'destination_facility': 5,
#   'end_time': datetime.datetime(1994, 7, 17, 12, 1, 17)},
#  (937, 2): {'request_id': 937,
#   'leg_id': 2,
#   'handler_id': 2,
#   'start_time': datetime.datetime(1994, 7, 17, 18, 1, 17),
#   'destination_facility': 4,
#   'end_time': datetime.datetime(1994, 7, 18, 6, 1, 17)},
#  (937, 3): {'request_id': 937,
#   'leg_id': 3,
#   'handler_id': 1,
#   'start_time': datetime.datetime(1994, 7, 18, 14, 1, 17),
#   'destination_facility': 9,
#   'end_time': datetime.datetime(1994, 7, 18, 15, 1, 17)},
#  (937, 4): {'request_id': 937,
#   'leg_id': 4,
#   'handler_id': 5,
#   'start_time': datetime.datetime(1994, 7, 18, 17, 1, 17),
#   'destination_facility': 6,
#   'end_time': datetime.datetime(1994, 7, 19, 5, 1, 17)},
#  (937, 5): {'request_id': 937,
#   'leg_id': 5,
#   'handler_id': 4,
#   'start_time': datetime.datetime(1994, 7, 19, 8, 1, 17),
#   'destination_facility': 1,
#   'end_time': datetime.datetime(1994, 7, 19, 9, 1, 17)},
#  (940, 1): {'request_id': 940,
#   'leg_id': 1,
#   'handler_id': 5,
#   'start_time': datetime.datetime(2011, 4, 19, 7, 38, 33),
#   'destination_facility': 10,
#   'end_time': datetime.datetime(2011, 4, 19, 9, 38, 33)},
#  (940, 2): {'request_id': 940,
#   'leg_id': 2,
#   'handler_id': 5,
#   'start_time': datetime.datetime(2011, 4, 19, 13, 38, 33),
#   'destination_facility': 3,
#   'end_time': datetime.datetime(2011, 4, 19, 14, 38, 33)},
#  (940, 3): {'request_id': 940,
#   'leg_id': 3,
#   'handler_id': 10,
#   'start_time': datetime.datetime(2011, 4, 19, 22, 38, 33),
#   'destination_facility': 7,
#   'end_time': datetime.datetime(2011, 4, 20, 2, 38, 33)},
#  (940, 4): {'request_id': 940,
#   'leg_id': 4,
#   'handler_id': 8,
#   'start_time': datetime.datetime(2011, 4, 20, 9, 38, 33),
#   'destination_facility': 8,
#   'end_time': datetime.datetime(2011, 4, 20, 15, 38, 33)},
#  (940, 5): {'request_id': 940,
#   'leg_id': 5,
#   'handler_id': 7,
#   'start_time': datetime.datetime(2011, 4, 20, 17, 38, 33),
#   'destination_facility': 6,
#   'end_time': datetime.datetime(2011, 4, 20, 19, 38, 33)},
#  (942, 1): {'request_id': 942,
#   'leg_id': 1,
#   'handler_id': 8,
#   'start_time': datetime.datetime(1985, 2, 23, 22, 50, 31),
#   'destination_facility': 4,
#   'end_time': None},
#  ...}

# %%
unsuccessful_deliveries = {}
fail_cnt = 10

cur_req = 0
cur_fail_reqs = 0

for k, v in legs.items():
    to_ret = {}
    to_ret['request_id'] = k[0]
    
    to_ret['leg_id'] = k[1]
    if cur_req == to_ret['request_id']:
        cur_fail_reqs += 1
    else:
        if fail_cnt == 0:
            break
        fail_cnt -= 1
        cur_req = to_ret['request_id']
        cur_fail_reqs = 0
    
    if cur_fail_reqs >= 3:
        continue
    
    to_ret["reason"] = get_random_string(32)
    
    # Are there any constraints?
    to_ret["attempt_time"] = v['start_time'] + timedelta(hours=get_random_int_to(1,12))
    
    unsuccessful_deliveries[k] = to_ret
    

unsuccessful_deliveries
# Out:
# {(5, 1): {'request_id': 5,
#   'leg_id': 1,
#   'reason': 'oMXKVUJPVwHkBptlDsrdWTvYPLpICVmD',
#   'attempt_time': datetime.datetime(2001, 12, 21, 13, 23, 24)},
#  (8, 1): {'request_id': 8,
#   'leg_id': 1,
#   'reason': 'vIetOytWSoBzARqxkgrKAJTplMejFBLh',
#   'attempt_time': datetime.datetime(1970, 8, 18, 16, 4, 45)},
#  (14, 1): {'request_id': 14,
#   'leg_id': 1,
#   'reason': 'SpIZAQFBlWlOPnsbTcRcJDbCBtYDesZu',
#   'attempt_time': datetime.datetime(1988, 11, 16, 14, 16, 31)},
#  (14, 2): {'request_id': 14,
#   'leg_id': 2,
#   'reason': 'wCWmOJrbgVpUQDocMccsaHvlmbGXqKOJ',
#   'attempt_time': datetime.datetime(1988, 11, 16, 17, 16, 31)},
#  (14, 3): {'request_id': 14,
#   'leg_id': 3,
#   'reason': 'VuPltUipmbAbBaBvrvtKiWlefJTKawKL',
#   'attempt_time': datetime.datetime(1988, 11, 16, 23, 16, 31)},
#  (17, 1): {'request_id': 17,
#   'leg_id': 1,
#   'reason': 'uWMzQxshNondLpeIVlbKDHdPTLkpBGpI',
#   'attempt_time': datetime.datetime(1982, 1, 23, 9, 12, 58)},
#  (17, 2): {'request_id': 17,
#   'leg_id': 2,
#   'reason': 'GVTTLsyEHhhWBOzszJXvasbuBOpISPOk',
#   'attempt_time': datetime.datetime(1982, 1, 24, 1, 12, 58)},
#  (17, 3): {'request_id': 17,
#   'leg_id': 3,
#   'reason': 'CEtWltFgwddegfFVwNkWiIAgoiZIEUWl',
#   'attempt_time': datetime.datetime(1982, 1, 23, 21, 12, 58)},
#  (18, 1): {'request_id': 18,
#   'leg_id': 1,
#   'reason': 'PKnYuEzxvGHWvuJGaWkFZeslZvfCIKup',
#   'attempt_time': datetime.datetime(2007, 11, 22, 21, 51, 10)},
#  (18, 2): {'request_id': 18,
#   'leg_id': 2,
#   'reason': 'ZUOfCXbfAIbmesLAxJzItNShMkDNFZCO',
#   'attempt_time': datetime.datetime(2007, 11, 23, 11, 51, 10)},
#  (20, 1): {'request_id': 20,
#   'leg_id': 1,
#   'reason': 'vSAYMvkLfZykrzjNQilaEwdNCccAgqEf',
#   'attempt_time': datetime.datetime(2011, 10, 26, 5, 18, 27)},
#  (20, 2): {'request_id': 20,
#   'leg_id': 2,
#   'reason': 'gKRasJCDjUbSajMlqzvWcqVkmygCRygX',
#   'attempt_time': datetime.datetime(2011, 10, 26, 10, 18, 27)},
#  (20, 3): {'request_id': 20,
#   'leg_id': 3,
#   'reason': 'MIDbbLJtUUvkmhwqiTRicMgvarGAxuwV',
#   'attempt_time': datetime.datetime(2011, 10, 27, 3, 18, 27)},
#  (24, 1): {'request_id': 24,
#   'leg_id': 1,
#   'reason': 'tbGgmSeRYlcwWFEsFxGXXTQWgViaLQHD',
#   'attempt_time': datetime.datetime(2003, 2, 26, 5, 20, 19)},
#  (24, 2): {'request_id': 24,
#   'leg_id': 2,
#   'reason': 'QJizmnlHlUgXulPbvvMnokYZluKKwvWj',
#   'attempt_time': datetime.datetime(2003, 2, 26, 13, 20, 19)},
#  (24, 3): {'request_id': 24,
#   'leg_id': 3,
#   'reason': 'spofFRFHoZzrHNYRxvMchpNnyWEIEEgI',
#   'attempt_time': datetime.datetime(2003, 2, 27, 2, 20, 19)},
#  (25, 1): {'request_id': 25,
#   'leg_id': 1,
#   'reason': 'oXTNlpEmpRlppwIPthZvheEcUgXzuuvh',
#   'attempt_time': datetime.datetime(1994, 5, 23, 0, 35, 8)},
#  (25, 2): {'request_id': 25,
#   'leg_id': 2,
#   'reason': 'hZBSxEJQogIpKQYvCydBVjsIPzRKhJrx',
#   'attempt_time': datetime.datetime(1994, 5, 23, 2, 35, 8)},
#  (25, 3): {'request_id': 25,
#   'leg_id': 3,
#   'reason': 'FnfltmISeJxYtyPccWGWNCmQTuAZTIXF',
#   'attempt_time': datetime.datetime(1994, 5, 24, 2, 35, 8)},
#  (29, 1): {'request_id': 29,
#   'leg_id': 1,
#   'reason': 'RzPCLdNwcStHxHQqJcDkmmJLjkWBmvll',
#   'attempt_time': datetime.datetime(1978, 12, 30, 8, 0, 56)},
#  (29, 2): {'request_id': 29,
#   'leg_id': 2,
#   'reason': 'CXyZeOiZNIFgGZcIYwArbWGjfKCulrhE',
#   'attempt_time': datetime.datetime(1978, 12, 30, 19, 0, 56)},
#  (29, 3): {'request_id': 29,
#   'leg_id': 3,
#   'reason': 'JxSqHuoOFcxyChwFxFJtncJdLLXUScdR',
#   'attempt_time': datetime.datetime(1978, 12, 31, 16, 0, 56)},
#  (32, 1): {'request_id': 32,
#   'leg_id': 1,
#   'reason': 'YFiEPuTxZrxHKfdBRPQsQFAleOFbGcQB',
#   'attempt_time': datetime.datetime(1974, 3, 24, 19, 11, 35)},
#  (32, 2): {'request_id': 32,
#   'leg_id': 2,
#   'reason': 'IfrnomClgzudMoakEXdQGcINLANjvGdX',
#   'attempt_time': datetime.datetime(1974, 3, 25, 6, 11, 35)},
#  (32, 3): {'request_id': 32,
#   'leg_id': 3,
#   'reason': 'NqItsfNyzOObzaSSxOfwZVwoObBJjEOf',
#   'attempt_time': datetime.datetime(1974, 3, 26, 3, 11, 35)}}

# %%
unsuccessful_deliveries.keys()
# Out:
# dict_keys([(5, 1), (8, 1), (14, 1), (14, 2), (14, 3), (17, 1), (17, 2), (17, 3), (18, 1), (18, 2), (20, 1), (20, 2), (20, 3), (24, 1), (24, 2), (24, 3), (25, 1), (25, 2), (25, 3), (29, 1), (29, 2), (29, 3), (32, 1), (32, 2), (32, 3)])

# %%
req_to_last_leg.keys()
# Out:
# dict_keys([5, 8, 14, 17, 18, 20, 24, 25, 29, 32, 36, 38, 42, 47, 53, 56, 58, 61, 63, 65, 67, 68, 69, 70, 72, 79, 86, 88, 92, 95, 100, 105, 107, 109, 110, 112, 114, 115, 120, 127, 131, 132, 133, 134, 136, 140, 143, 149, 154, 155, 160, 161, 162, 164, 168, 170, 173, 180, 183, 188, 189, 198, 236, 238, 241, 242, 245, 246, 251, 255, 259, 260, 267, 268, 271, 275, 279, 282, 285, 287, 288, 290, 291, 292, 294, 295, 303, 305, 309, 310, 311, 312, 320, 321, 323, 324, 327, 331, 333, 342, 343, 344, 346, 348, 349, 351, 352, 364, 366, 368, 
809, 1810, 1812, 1817, 1818, 1819, 1832, 1837, 1839, 1841, 1844, 1849, 1852, 1856, 1862, 1863, 1867, 1870, 1872, 1873, 1875, 1886, 1887, 1890, 1895, 1896, 1901, 1906, 1912, 1917, 1918, 1919, 1920, 1921, 1923, 1924, 1928, 1930, 1932, 1934, 1938, 1943, 1946, 1960, 1967, 1969, 1971, 1973, 1974, 1975, 1978, 1979, 1981, 1987, 1988, 1992, 1994, 1996, 1999])

# %%
return_legs = {}
for request_id in cancelled_or_unsuccessful_requests_id:
    print(f"request_id: {request_id}")
    if (random.choice([True,False]) and request_id in req_to_last_leg):
        current_timestamp = random_timestamp()
        status = delivery_requests[request_id]['status']
        if (is_cancelled(status)):
            current_timestamp = delivery_requests[request_id]['cancel_time']
            current_timestamp += timedelta(hours=get_random_int_to(1,12))
            
        last_leg = req_to_last_leg[request_id]
#         print(legs[(request_id, last_leg)])
        last_end_time = legs[(request_id, last_leg)]['end_time']
#         print(f"last_end_time: {last_end_time}")
        if last_end_time == None:
            continue
            
        for leg_id in range(1, get_random_int_to(2, 6)):
#             print(f"current_timestamp: {current_timestamp}")
            if (last_end_time >= current_timestamp):
                break
            to_add = {}
            this_id = (request_id, leg_id)
            # Check if need to match the pickup handler's id
            to_add['request_id'] = request_id
            to_add['leg_id'] = leg_id
            to_add['handler_id'] = random.choice(list(delivery_staff_id))
            to_add['start_time'] = current_timestamp
            current_timestamp += timedelta(hours=get_random_int_to(1,12))
            to_add['end_time'] = current_timestamp
            to_add['source_facility'] = random.choice(list(facilities.keys()))
            return_legs[this_id] = to_add
            
return_legs
# Out:
# request_id: 2
# request_id: 5
# request_id: 7
# request_id: 12
# request_id: 15
# request_id: 17
# request_id: 18
# request_id: 22
# request_id: 25
# request_id: 29
# request_id: 32
# request_id: 40
# request_id: 48
# request_id: 56
# request_id: 63
# request_id: 65
# request_id: 69
# request_id: 70
# request_id: 76
# request_id: 79
# request_id: 82
# request_id: 87
# request_id: 88
# request_id: 95
# request_id: 98
# request_id: 100
# request_id: 101
# request_id: 105
# request_id: 106
# request_id: 107
# request_id: 112
# request_id: 114
# request_id: 115
# request_id: 116
# request_id: 118
# request_id: 129
# request_id: 130
# request_id: 132
# request_id: 143
# request_id: 144
# request_id: 146
# request_id: 158
# request_id: 161
# request_id: 162
# request_id: 164
# request_id: 168
# request_id: 170
# request_id: 173
# request_id: 177
# request_id: 180
# request_id: 183
# request_id: 185
# request_id: 193
# request_id: 194
# request_id: 195
# request_id: 198
# request_id: 201
# request_id: 204
# request_id: 212
# request_id: 218
# request_id: 219
# request_id: 220
# request_id: 222
# request_id: 227
# request_id: 230
# request_id: 233
# request_id: 234
# request_id: 235
# request_id: 236
# request_id: 238
# request_id: 242
# request_id: 248
# request_id: 249
# request_id: 252
# request_id: 254
# request_id: 260
# request_id: 262
# request_id: 267
# request_id: 271
# request_id: 275
# request_id: 279
# request_id: 281
# request_id: 285
# request_id: 286
# request_id: 289
# request_id: 291
# request_id: 292
# request_id: 294
# request_id: 295
# request_id: 296

#   'handler_id': 4,
#   'start_time': datetime.datetime(1988, 7, 24, 12, 34, 10),
#   'end_time': datetime.datetime(1988, 7, 24, 17, 34, 10),
#   'source_facility': 3},
#  (236, 1): {'request_id': 236,
#   'leg_id': 1,
#   'handler_id': 2,
#   'start_time': datetime.datetime(1978, 11, 27, 4, 0, 8),
#   'end_time': datetime.datetime(1978, 11, 27, 13, 0, 8),
#   'source_facility': 1},
#  (236, 2): {'request_id': 236,
#   'leg_id': 2,
#   'handler_id': 9,
#   'start_time': datetime.datetime(1978, 11, 27, 13, 0, 8),
#   'end_time': datetime.datetime(1978, 11, 28, 1, 0, 8),
#   'source_facility': 7},
#  (236, 3): {'request_id': 236,
#   'leg_id': 3,
#   'handler_id': 4,
#   'start_time': datetime.datetime(1978, 11, 28, 1, 0, 8),
#   'end_time': datetime.datetime(1978, 11, 28, 3, 0, 8),
#   'source_facility': 7},
#  (236, 4): {'request_id': 236,
#   'leg_id': 4,
#   'handler_id': 9,
#   'start_time': datetime.datetime(1978, 11, 28, 3, 0, 8),
#   'end_time': datetime.datetime(1978, 11, 28, 9, 0, 8),
#   'source_facility': 4},
#  (267, 1): {'request_id': 267,
#   'leg_id': 1,
#   'handler_id': 3,
#   'start_time': datetime.datetime(1993, 7, 19, 12, 0, 54),
#   'end_time': datetime.datetime(1993, 7, 19, 16, 0, 54),
#   'source_facility': 4},
#  (267, 2): {'request_id': 267,
#   'leg_id': 2,
#   'handler_id': 9,
#   'start_time': datetime.datetime(1993, 7, 19, 16, 0, 54),
#   'end_time': datetime.datetime(1993, 7, 20, 4, 0, 54),
#   'source_facility': 4},
#  (311, 1): {'request_id': 311,
#   'leg_id': 1,
#   'handler_id': 7,
#   'start_time': datetime.datetime(2000, 4, 1, 4, 48, 19),
#   'end_time': datetime.datetime(2000, 4, 1, 14, 48, 19),
#   'source_facility': 1},
#  (311, 2): {'request_id': 311,
#   'leg_id': 2,
#   'handler_id': 7,
#   'start_time': datetime.datetime(2000, 4, 1, 14, 48, 19),
#   'end_time': datetime.datetime(2000, 4, 1, 22, 48, 19),
#   'source_facility': 9},
#  (311, 3): {'request_id': 311,
#   'leg_id': 3,
#   'handler_id': 5,
#   'start_time': datetime.datetime(2000, 4, 1, 22, 48, 19),
#   'end_time': datetime.datetime(2000, 4, 2, 0, 48, 19),
#   'source_facility': 10},
#  (311, 4): {'request_id': 311,
#   'leg_id': 4,
#   'handler_id': 1,
#   'start_time': datetime.datetime(2000, 4, 2, 0, 48, 19),
#   'end_time': datetime.datetime(2000, 4, 2, 7, 48, 19),
#   'source_facility': 5},
#  (364, 1): {'request_id': 364,
#   'leg_id': 1,
#   'handler_id': 3,
#   'start_time': datetime.datetime(1990, 7, 13, 8, 44, 9),
#   'end_time': datetime.datetime(1990, 7, 13, 12, 44, 9),
#   'source_facility': 5},
#  (364, 2): {'request_id': 364,
#   'leg_id': 2,
#   'handler_id': 10,
#   'start_time': datetime.datetime(1990, 7, 13, 12, 44, 9),
#   'end_time': datetime.datetime(1990, 7, 13, 22, 44, 9),
#   'source_facility': 5},
#  (364, 3): {'request_id': 364,
#   'leg_id': 3,
#   'handler_id': 8,
#   'start_time': datetime.datetime(1990, 7, 13, 22, 44, 9),
#   'end_time': datetime.datetime(1990, 7, 14, 6, 44, 9),
#   'source_facility': 6},
#  (364, 4): {'request_id': 364,
#   'leg_id': 4,
#   'handler_id': 5,
#   'start_time': datetime.datetime(1990, 7, 14, 6, 44, 9),
#   'end_time': datetime.datetime(1990, 7, 14, 9, 44, 9),
#   'source_facility': 4},
#  (425, 1): {'request_id': 425,
#   'leg_id': 1,
#   'handler_id': 7,
#   'start_time': datetime.datetime(2003, 7, 10, 22, 38, 41),
#   'end_time': datetime.datetime(2003, 7, 11, 6, 38, 41),
#   'source_facility': 7},
#  (425, 2): {'request_id': 425,
#   'leg_id': 2,
#   'handler_id': 5,
#   'start_time': datetime.datetime(2003, 7, 11, 6, 38, 41),
#   'end_time': datetime.datetime(2003, 7, 11, 8, 38, 41),
#   'source_facility': 6},
#  (425, 3): {'request_id': 425,
#   'leg_id': 3,
#   'handler_id': 8,
#   'start_time': datetime.datetime(2003, 7, 11, 8, 38, 41),
#   'end_time': datetime.datetime(2003, 7, 11, 15, 38, 41),
#   'source_facility': 2},
#  (425, 4): {'request_id': 425,
#   'leg_id': 4,
#   'handler_id': 2,
#   'start_time': datetime.datetime(2003, 7, 11, 15, 38, 41),
#   'end_time': datetime.datetime(2003, 7, 11, 23, 38, 41),
#   'source_facility': 6},
#  (548, 1): {'request_id': 548,
#   'leg_id': 1,
#   'handler_id': 8,
#   'start_time': datetime.datetime(2016, 10, 15, 4, 2, 30),
#   'end_time': datetime.datetime(2016, 10, 15, 10, 2, 30),
#   'source_facility': 4},
#  (548, 2): {'request_id': 548,
#   'leg_id': 2,
#   'handler_id': 6,
#   'start_time': datetime.datetime(2016, 10, 15, 10, 2, 30),
#   'end_time': datetime.datetime(2016, 10, 15, 15, 2, 30),
#   'source_facility': 3},
#  (548, 3): {'request_id': 548,
#   'leg_id': 3,
#   'handler_id': 4,
#   'start_time': datetime.datetime(2016, 10, 15, 15, 2, 30),
#   'end_time': datetime.datetime(2016, 10, 15, 20, 2, 30),
#   'source_facility': 7},
#  (573, 1): {'request_id': 573,
#   'leg_id': 1,
#   'handler_id': 10,
#   'start_time': datetime.datetime(1976, 11, 14, 8, 43, 56),
#   'end_time': datetime.datetime(1976, 11, 14, 20, 43, 56),
#   'source_facility': 2},
#  (573, 2): {'request_id': 573,
#   'leg_id': 2,
#   'handler_id': 10,
#   'start_time': datetime.datetime(1976, 11, 14, 20, 43, 56),
#   'end_time': datetime.datetime(1976, 11, 15, 8, 43, 56),
#   'source_facility': 4},
#  (573, 3): {'request_id': 573,
#   'leg_id': 3,
#   'handler_id': 7,
#   'start_time': datetime.datetime(1976, 11, 15, 8, 43, 56),
#   'end_time': datetime.datetime(1976, 11, 15, 12, 43, 56),
#   'source_facility': 2},
#  (573, 4): {'request_id': 573,
#   'leg_id': 4,
#   'handler_id': 9,
#   'start_time': datetime.datetime(1976, 11, 15, 12, 43, 56),
#   'end_time': datetime.datetime(1976, 11, 15, 23, 43, 56),
#   'source_facility': 6},
#  (573, 5): {'request_id': 573,
#   'leg_id': 5,
#   'handler_id': 6,
#   'start_time': datetime.datetime(1976, 11, 15, 23, 43, 56),
#   'end_time': datetime.datetime(1976, 11, 16, 4, 43, 56),
#   'source_facility': 9},
#  (690, 1): {'request_id': 690,
#   'leg_id': 1,
#   'handler_id': 9,
#   'start_time': datetime.datetime(1995, 8, 9, 12, 36, 17),
#   'end_time': datetime.datetime(1995, 8, 9, 23, 36, 17),
#   'source_facility': 2},
#  (690, 2): {'request_id': 690,
#   'leg_id': 2,
#   'handler_id': 8,
#   'start_time': datetime.datetime(1995, 8, 9, 23, 36, 17),
#   'end_time': datetime.datetime(1995, 8, 10, 8, 36, 17),
#   'source_facility': 10},
#  (690, 3): {'request_id': 690,
#   'leg_id': 3,
#   'handler_id': 9,
#   'start_time': datetime.datetime(1995, 8, 10, 8, 36, 17),
#   'end_time': datetime.datetime(1995, 8, 10, 13, 36, 17),
#   'source_facility': 2},
#  (690, 4): {'request_id': 690,
#   'leg_id': 4,
#   'handler_id': 2,
#   'start_time': datetime.datetime(1995, 8, 10, 13, 36, 17),
#   'end_time': datetime.datetime(1995, 8, 11, 0, 36, 17),
#   'source_facility': 8},
#  (690, 5): {'request_id': 690,
#   'leg_id': 5,
#   'handler_id': 6,
#   'start_time': datetime.datetime(1995, 8, 11, 0, 36, 17),
#   'end_time': datetime.datetime(1995, 8, 11, 3, 36, 17),
#   'source_facility': 6},
#  (743, 1): {'request_id': 743,
#   'leg_id': 1,
#   'handler_id': 7,
#   'start_time': datetime.datetime(2010, 9, 5, 16, 43, 52),
#   'end_time': datetime.datetime(2010, 9, 6, 2, 43, 52),
#   'source_facility': 1},
#  (812, 1): {'request_id': 812,
#   'leg_id': 1,
#   'handler_id': 8,
#   'start_time': datetime.datetime(2022, 2, 7, 15, 5, 30),
#   'end_time': datetime.datetime(2022, 2, 7, 21, 5, 30),
#   'source_facility': 6},
#  (812, 2): {'request_id': 812,
#   'leg_id': 2,
#   'handler_id': 9,
#   'start_time': datetime.datetime(2022, 2, 7, 21, 5, 30),
#   'end_time': datetime.datetime(2022, 2, 8, 8, 5, 30),
#   'source_facility': 6},
#  (970, 1): {'request_id': 970,
#   'leg_id': 1,
#   'handler_id': 6,
#   'start_time': datetime.datetime(2016, 9, 11, 15, 59, 53),
#   'end_time': datetime.datetime(2016, 9, 12, 1, 59, 53),
#   'source_facility': 10},
#  (970, 2): {'request_id': 970,
#   'leg_id': 2,
#   'handler_id': 5,
#   'start_time': datetime.datetime(

#   'leg_id': 1,
#   'handler_id': 6,
#   'start_time': datetime.datetime(1991, 2, 7, 10, 22, 27),
#   'end_time': datetime.datetime(1991, 2, 7, 16, 22, 27),
#   'source_facility': 1},
#  (1241, 2): {'request_id': 1241,
#   'leg_id': 2,
#   'handler_id': 10,
#   'start_time': datetime.datetime(1991, 2, 7, 16, 22, 27),
#   'end_time': datetime.datetime(1991, 2, 7, 22, 22, 27),
#   'source_facility': 9},
#  (1241, 3): {'request_id': 1241,
#   'leg_id': 3,
#   'handler_id': 7,
#   'start_time': datetime.datetime(1991, 2, 7, 22, 22, 27),
#   'end_time': datetime.datetime(1991, 2, 8, 2, 22, 27),
#   'source_facility': 8},
#  (1281, 1): {'request_id': 1281,
#   'leg_id': 1,
#   'handler_id': 4,
#   'start_time': datetime.datetime(1991, 10, 21, 2, 41, 19),
#   'end_time': datetime.datetime(1991, 10, 21, 3, 41, 19),
#   'source_facility': 5},
#  (1281, 2): {'request_id': 1281,
#   'leg_id': 2,
#   'handler_id': 8,
#   'start_time': datetime.datetime(1991, 10, 21, 3, 41, 19),
#   'end_time': datetime.datetime(1991, 10, 21, 9, 41, 19),
#   'source_facility': 7},
#  (1281, 3): {'request_id': 1281,
#   'leg_id': 3,
#   'handler_id': 8,
#   'start_time': datetime.datetime(1991, 10, 21, 9, 41, 19),
#   'end_time': datetime.datetime(1991, 10, 21, 20, 41, 19),
#   'source_facility': 5},
#  (1281, 4): {'request_id': 1281,
#   'leg_id': 4,
#   'handler_id': 4,
#   'start_time': datetime.datetime(1991, 10, 21, 20, 41, 19),
#   'end_time': datetime.datetime(1991, 10, 22, 1, 41, 19),
#   'source_facility': 8},
#  (1300, 1): {'request_id': 1300,
#   'leg_id': 1,
#   'handler_id': 4,
#   'start_time': datetime.datetime(1986, 7, 14, 9, 48, 47),
#   'end_time': datetime.datetime(1986, 7, 14, 16, 48, 47),
#   'source_facility': 8},
#  (1378, 1): {'request_id': 1378,
#   'leg_id': 1,
#   'handler_id': 7,
#   'start_time': datetime.datetime(1984, 9, 3, 3, 41, 40),
#   'end_time': datetime.datetime(1984, 9, 3, 12, 41, 40),
#   'source_facility': 4},
#  (1378, 2): {'request_id': 1378,
#   'leg_id': 2,
#   'handler_id': 4,
#   'start_time': datetime.datetime(1984, 9, 3, 12, 41, 40),
#   'end_time': datetime.datetime(1984, 9, 3, 17, 41, 40),
#   'source_facility': 7},
#  (1378, 3): {'request_id': 1378,
#   'leg_id': 3,
#   'handler_id': 7,
#   'start_time': datetime.datetime(1984, 9, 3, 17, 41, 40),
#   'end_time': datetime.datetime(1984, 9, 4, 0, 41, 40),
#   'source_facility': 1},
#  (1388, 1): {'request_id': 1388,
#   'leg_id': 1,
#   'handler_id': 10,
#   'start_time': datetime.datetime(2013, 4, 15, 2, 43, 8),
#   'end_time': datetime.datetime(2013, 4, 15, 10, 43, 8),
#   'source_facility': 5},
#  (1388, 2): {'request_id': 1388,
#   'leg_id': 2,
#   'handler_id': 4,
#   'start_time': datetime.datetime(2013, 4, 15, 10, 43, 8),
#   'end_time': datetime.datetime(2013, 4, 15, 16, 43, 8),
#   'source_facility': 4},
#  (1388, 3): {'request_id': 1388,
#   'leg_id': 3,
#   'handler_id': 6,
#   'start_time': datetime.datetime(2013, 4, 15, 16, 43, 8),
#   'end_time': datetime.datetime(2013, 4, 15, 21, 43, 8),
#   'source_facility': 5},
#  (1429, 1): {'request_id': 1429,
#   'leg_id': 1,
#   'handler_id': 3,
#   'start_time': datetime.datetime(2015, 8, 30, 12, 47, 34),
#   'end_time': datetime.datetime(2015, 8, 30, 16, 47, 34),
#   'source_facility': 8},
#  (1429, 2): {'request_id': 1429,
#   'leg_id': 2,
#   'handler_id': 8,
#   'start_time': datetime.datetime(2015, 8, 30, 16, 47, 34),
#   'end_time': datetime.datetime(2015, 8, 30, 21, 47, 34),
#   'source_facility': 10},
#  (1429, 3): {'request_id': 1429,
#   'leg_id': 3,
#   'handler_id': 8,
#   'start_time': datetime.datetime(2015, 8, 30, 21, 47, 34),
#   'end_time': datetime.datetime(2015, 8, 31, 2, 47, 34),
#   'source_facility': 6},
#  (1429, 4): {'request_id': 1429,
#   'leg_id': 4,
#   'handler_id': 10,
#   'start_time': datetime.datetime(2015, 8, 31, 2, 47, 34),
#   'end_time': datetime.datetime(2015, 8, 31, 13, 47, 34),
#   'source_facility': 10},
#  (1495, 1): {'request_id': 1495,
#   'leg_id': 1,
#   'handler_id': 2,
#   'start_time': datetime.datetime(1996, 2, 5, 21, 43, 52),
#   'end_time': datetime.datetime(1996, 2, 6, 4, 43, 52),
#   'source_facility': 3},
#  (1495, 2): {'request_id': 1495,
#   'leg_id': 2,
#   'handler_id': 6,
#   'start_time': datetime.datetime(1996, 2, 6, 4, 43, 52),
#   'end_time': datetime.datetime(1996, 2, 6, 15, 43, 52),
#   'source_facility': 4},
#  (1586, 1): {'request_id': 1586,
#   'leg_id': 1,
#   'handler_id': 10,
#   'start_time': datetime.datetime(2009, 9, 27, 17, 15, 43),
#   'end_time': datetime.datetime(2009, 9, 28, 4, 15, 43),
#   'source_facility': 7},
#  (1586, 2): {'request_id': 1586,
#   'leg_id': 2,
#   'handler_id': 4,
#   'start_time': datetime.datetime(2009, 9, 28, 4, 15, 43),
#   'end_time': datetime.datetime(2009, 9, 28, 5, 15, 43),
#   'source_facility': 7},
#  (1586, 3): {'request_id': 1586,
#   'leg_id': 3,
#   'handler_id': 8,
#   'start_time': datetime.datetime(2009, 9, 28, 5, 15, 43),
#   'end_time': datetime.datetime(2009, 9, 28, 11, 15, 43),
#   'source_facility': 3},
#  (1586, 4): {'request_id': 1586,
#   'leg_id': 4,
#   'handler_id': 7,
#   'start_time': datetime.datetime(2009, 9, 28, 11, 15, 43),
#   'end_time': datetime.datetime(2009, 9, 28, 13, 15, 43),
#   'source_facility': 6},
#  (1766, 1): {'request_id': 1766,
#   'leg_id': 1,
#   'handler_id': 1,
#   'start_time': datetime.datetime(1998, 3, 26, 6, 35, 36),
#   'end_time': datetime.datetime(1998, 3, 26, 8, 35, 36),
#   'source_facility': 6},
#  (1766, 2): {'request_id': 1766,
#   'leg_id': 2,
#   'handler_id': 3,
#   'start_time': datetime.datetime(1998, 3, 26, 8, 35, 36),
#   'end_time': datetime.datetime(1998, 3, 26, 18, 35, 36),
#   'source_facility': 8},
#  (1766, 3): {'request_id': 1766,
#   'leg_id': 3,
#   'handler_id': 9,
#   'start_time': datetime.datetime(1998, 3, 26, 18, 35, 36),
#   'end_time': datetime.datetime(1998, 3, 27, 1, 35, 36),
#   'source_facility': 8},
#  (1766, 4): {'request_id': 1766,
#   'leg_id': 4,
#   'handler_id': 7,
#   'start_time': datetime.datetime(1998, 3, 27, 1, 35, 36),
#   'end_time': datetime.datetime(1998, 3, 27, 9, 35, 36),
#   'source_facility': 8},
#  (1873, 1): {'request_id': 1873,
#   'leg_id': 1,
#   'handler_id': 5,
#   'start_time': datetime.datetime(1987, 7, 31, 13, 16, 31),
#   'end_time': datetime.datetime(1987, 7, 31, 23, 16, 31),
#   'source_facility': 6},
#  (1873, 2): {'request_id': 1873,
#   'leg_id': 2,
#   'handler_id': 3,
#   'start_time': datetime.datetime(1987, 7, 31, 23, 16, 31),
#   'end_time': datetime.datetime(1987, 8, 1, 9, 16, 31),
#   'source_facility': 2}}

# %%
unsuccessful_return_deliveries = {}

for k,v in return_legs.items():
    to_add={}
    to_add['request_id'] = k[0]
    to_add['leg_id'] = k[1]
    to_add["reason"] = get_random_string(32)
    
    # Are there any constraints?
    to_add["attempt_time"] = v['start_time'] + timedelta(hours=get_random_int_to(1,12))
    
    
    unsuccessful_return_deliveries[k] = to_add

unsuccessful_return_deliveries
# Out:
# {(180, 1): {'request_id': 180,
#   'leg_id': 1,
#   'reason': 'pmEgAYLzlfYjouPGhlVRadcDtlRLUPCR',
#   'attempt_time': datetime.datetime(1988, 7, 23, 11, 34, 10)},
#  (180, 2): {'request_id': 180,
#   'leg_id': 2,
#   'reason': 'XRRpDBoUrDeSfOdrbWkDlZdrDhPooDAR',
#   'attempt_time': datetime.datetime(1988, 7, 23, 21, 34, 10)},
#  (180, 3): {'request_id': 180,
#   'leg_id': 3,
#   'reason': 'GwyxMADbuJamQuZBOejXANgJrLPKpRND',
#   'attempt_time': datetime.datetime(1988, 7, 24, 1, 34, 10)},
#  (180, 4): {'request_id': 180,
#   'leg_id': 4,
#   'reason': 'AvLoommoIOYzLrjxhAYsJqzJLwelOYBv',
#   'attempt_time': datetime.datetime(1988, 7, 24, 7, 34, 10)},
#  (180, 5): {'request_id': 180,
#   'leg_id': 5,
#   'reason': 'ofUCQHGKCWxveXVbMzQYTmjEemmLfkWL',
#   'attempt_time': datetime.datetime(1988, 7, 24, 23, 34, 10)},
#  (236, 1): {'request_id': 236,
#   'leg_id': 1,
#   'reason': 'whVhClQZhdokYJgBEqNQjHqtnYETeofx',
#   'attempt_time': datetime.datetime(1978, 11, 27, 12, 0, 8)},
#  (236, 2): {'request_id': 236,
#   'leg_id': 2,
#   'reason': 'esHpxpDWleQnOIPoZJCorzhnvcuKwQEU',
#   'attempt_time': datetime.datetime(1978, 11, 27, 17, 0, 8)},
#  (236, 3): {'request_id': 236,
#   'leg_id': 3,
#   'reason': 'NRUpJYyoDnXZNbiJhdOSjgvsUCNwzdzT',
#   'attempt_time': datetime.datetime(1978, 11, 28, 2, 0, 8)},
#  (236, 4): {'request_id': 236,
#   'leg_id': 4,
#   'reason': 'ZoMBzOafcKxapQzUbXyHQLflVLPogeRx',
#   'attempt_time': datetime.datetime(1978, 11, 28, 5, 0, 8)},
#  (267, 1): {'request_id': 267,
#   'leg_id': 1,
#   'reason': 'pQhtGvJoTPYqMvZOFVfBrsDJWabMebMn',
#   'attempt_time': datetime.datetime(1993, 7, 19, 19, 0, 54)},
#  (267, 2): {'request_id': 267,
#   'leg_id': 2,
#   'reason': 'vVehMSHfDMOhxFovfUSfYfGDUebMyXUv',
#   'attempt_time': datetime.datetime(1993, 7, 20, 3, 0, 54)},
#  (311, 1): {'request_id': 311,
#   'leg_id': 1,
#   'reason': 'QOZyEOdxGkerhRxSXRKCQxJKAXCKnhfF',
#   'attempt_time': datetime.datetime(2000, 4, 1, 5, 48, 19)},
#  (311, 2): {'request_id': 311,
#   'leg_id': 2,
#   'reason': 'YCSnUNIJkQDQHJqzGnNgjXfLcGNWIMTm',
#   'attempt_time': datetime.datetime(2000, 4, 1, 15, 48, 19)},
#  (311, 3): {'request_id': 311,
#   'leg_id': 3,
#   'reason': 'XirprTrzOQjgHyONXgoNRCTmMhyPsYFg',
#   'attempt_time': datetime.datetime(2000, 4, 2, 1, 48, 19)},
#  (311, 4): {'request_id': 311,
#   'leg_id': 4,
#   'reason': 'poHAEfsyVJwxejKWrNOEBdLQODgmRVyB',
#   'attempt_time': datetime.datetime(2000, 4, 2, 4, 48, 19)},
#  (364, 1): {'request_id': 364,
#   'leg_id': 1,
#   'reason': 'LgyOBZobokCpjjZPrwoXCdaogQGOwuMY',
#   'attempt_time': datetime.datetime(1990, 7, 13, 17, 44, 9)},
#  (364, 2): {'request_id': 364,
#   'leg_id': 2,
#   'reason': 'mwQnsujSWrBdkrCHXyIjzxulOxhmETmC',
#   'attempt_time': datetime.datetime(1990, 7, 13, 13, 44, 9)},
#  (364, 3): {'request_id': 364,
#   'leg_id': 3,
#   'reason': 'pyjskKbvoIsCEwUUQCQxSVxwsKyXnDGm',
#   'attempt_time': datetime.datetime(1990, 7, 14, 9, 44, 9)},
#  (364, 4): {'request_id': 364,
#   'leg_id': 4,
#   'reason': 'WBorNtIIrHBgkWNlaVvkVHQYKFKqUhJd',
#   'attempt_time': datetime.datetime(1990, 7, 14, 7, 44, 9)},
#  (425, 1): {'request_id': 425,
#   'leg_id': 1,
#   'reason': 'qbBcFwxSHHAKbVriKDVkbpzANEdGztrX',
#   'attempt_time': datetime.datetime(2003, 7, 11, 1, 38, 41)},
#  (425, 2): {'request_id': 425,
#   'leg_id': 2,
#   'reason': 'tHmgxGqRZgffRxYuHBpNIWfaYqxWxrQw',
#   'attempt_time': datetime.datetime(2003, 7, 11, 10, 38, 41)},
#  (425, 3): {'request_id': 425,
#   'leg_id': 3,
#   'reason': 'yqXPVkiXOOwnQYSIOtnZyPaTwwaWYMfp',
#   'attempt_time': datetime.datetime(2003, 7, 11, 17, 38, 41)},
#  (425, 4): {'request_id': 425,
#   'leg_id': 4,
#   'reason': 'GSSnHjIhbBTVhASGVgijDSoZZdPwcojB',
#   'attempt_time': datetime.datetime(2003, 7, 11, 18, 38, 41)},
#  (548, 1): {'request_id': 548,
#   'leg_id': 1,
#   'reason': 'JzQaLtiMayhKIGCPKtjUVJILNJOGKLIu',
#   'attempt_time': datetime.datetime(2016, 10, 15, 7, 2, 30)},
#  (548, 2): {'request_id': 548,
#   'leg_id': 2,
#   'reason': 'PZwhDrrLhUXvwIpyotjFDTNNzYcGWmNU',
#   'attempt_time': datetime.datetime(2016, 10, 15, 12, 2, 30)},
#  (548, 3): {'request_id': 548,
#   'leg_id': 3,
#   'reason': 'aMFnPojpNAgjytSuGCWmcGLXTgfqIbpA',
#   'attempt_time': datetime.datetime(2016, 10, 15, 21, 2, 30)},
#  (573, 1): {'request_id': 573,
#   'leg_id': 1,
#   'reason': 'wxDHkrTaNFgViBHSyffnbZjuiDEJZulV',
#   'attempt_time': datetime.datetime(1976, 11, 14, 10, 43, 56)},
#  (573, 2): {'request_id': 573,
#   'leg_id': 2,
#   'reason': 'seSSSYjLFywyuvFxFYeSeSFEkRlitnej',
#   'attempt_time': datetime.datetime(1976, 11, 15, 1, 43, 56)},
#  (573, 3): {'request_id': 573,
#   'leg_id': 3,
#   'reason': 'iyLjWTAfFwEERkzNhrOQrdodiudriPJj',
#   'attempt_time': datetime.datetime(1976, 11, 15, 19, 43, 56)},
#  (573, 4): {'request_id': 573,
#   'leg_id': 4,
#   'reason': 'sndRXeDrcSjmVZVdFJcjRAkxdyUJfCBs',
#   'attempt_time': datetime.datetime(1976, 11, 15, 16, 43, 56)},
#  (573, 5): {'request_id': 573,
#   'leg_id': 5,
#   'reason': 'dwoGObUDulNOUDZBZhreIyPOLcIXQyMx',
#   'attempt_time': datetime.datetime(1976, 11, 16, 2, 43, 56)},
#  (690, 1): {'request_id': 690,
#   'leg_id': 1,
#   'reason': 'WTwfpGLUsBOcacGYDPPzjkPEGeADgAZp',
#   'attempt_time': datetime.datetime(1995, 8, 9, 18, 36, 17)},
#  (690, 2): {'request_id': 690,
#   'leg_id': 2,
#   'reason': 'uhGtjYOqYaLMXxIiNBxgjVsVEjoaVyUj',
#   'attempt_time': datetime.datetime(1995, 8, 10, 2, 36, 17)},
#  (690, 3): {'request_id': 690,
#   'leg_id': 3,
#   'reason': 'XxZFdRmTXYLzKSywoHDkMduqXaSnguTP',
#   'attempt_time': datetime.datetime(1995, 8, 10, 12, 36, 17)},
#  (690, 4): {'request_id': 690,
#   'leg_id': 4,
#   'reason': 'nnVDkYxnZnGVUErPAjLdfjGDtnlRbFXT',
#   'attempt_time': datetime.datetime(1995, 8, 10, 18, 36, 17)},
#  (690, 5): {'request_id': 690,
#   'leg_id': 5,
#   'reason': 'CEXePEDAHZwURfZAEgDDFtGySdApKFVY',
#   'attempt_time': datetime.datetime(1995, 8, 11, 5, 36, 17)},
#  (743, 1): {'request_id': 743,
#   'leg_id': 1,
#   'reason': 'eFgElcUXPayqhuAgBVWQYvykTEsGDBmV',
#   'attempt_time': datetime.datetime(2010, 9, 6, 4, 43, 52)},
#  (812, 1): {'request_id': 812,
#   'leg_id': 1,
#   'reason': 'HJJmEHpMULZwjpgBgowhiVdsManRUNLu',
#   'attempt_time': datetime.datetime(2022, 2, 7, 19, 5, 30)},
#  (812, 2): {'request_id': 812,
#   'leg_id': 2,
#   'reason': 'uXkYJOmITrbNVzMeVrZJXRQovkCKIqqv',
#   'attempt_time': datetime.datetime(2022, 2, 7, 22, 5, 30)},
#  (970, 1): {'request_id': 970,
#   'leg_id': 1,
#   'reason': 'MSuldnhjfvONTMfrrbZPVsQDwCVjUIFu',
#   'attempt_time': datetime.datetime(2016, 9, 11, 16, 59, 53)},
#  (970, 2): {'request_id': 970,
#   'leg_id': 2,
#   'reason': 'vLaaajJwwtUyXtWhNJbmrWpjRZghpQNG',
#   'attempt_time': datetime.datetime(2016, 9, 12, 6, 59, 53)},
#  (970, 3): {'request_id': 970,
#   'leg_id': 3,
#   'reason': 'CdiwITnSgYJHkHHexvVoajfBRrnqoVwh',
#   'attempt_time': datetime.datetime(2016, 9, 12, 19, 59, 53)},
#  (970, 4): {'request_id': 970,
#   'leg_id': 4,
#   'reason': 'mBUoAMqxkRnWZemkpYKaEpjeZNoZGClR',
#   'attempt_time': datetime.datetime(2016, 9, 13, 4, 59, 53)},
#  (970, 5): {'request_id': 970,
#   'leg_id': 5,
#   'reason': 'lCetiMnSAMHPQPCoGZMyiUdZzzdiEUul',
#   'attempt_time': datetime.datetime(2016, 9, 13, 2, 59, 53)},
#  (1005, 1): {'request_id': 1005,
#   'leg_id': 1,
#   'reason': 'hIbDpBWCDIlsRrPmHvPHMxgcAFbrSOSz',
#   'attempt_time': datetime.datetime(2019, 10, 5, 20, 27, 15)},
#  (1005, 2): {'request_id': 1005,
#   'leg_id': 2,
#   'reason': 'eZReNYVjnXKcSaxzZlyAlyRgxQAQYKfN',
#   'attempt_time': datetime.datetime(2019, 10, 6, 5, 27, 15)},
#  (1042, 1): {'request_id': 1042,
#   'leg_id': 1,
#   'reason': 'nWptUbmMhcPAwdwbKyVqiWaEbZLOYuKH',
#   'attempt_time': datetime.datetime(2022, 11, 19, 8, 28, 41)},
#  (1042, 2): {'request_id': 1042,
#   'leg_id': 2,
#   'reason': 'RtzaETYgmnWibBzwyncfQHixbppngMeI',
#   'attempt_time': datetime.datetime(2022, 11, 19, 9, 28, 41)},
#  (1042, 3): {'request_id': 1042,
#   'leg_id': 3,
#   'reason': 'asVInBgPASTJkPWYImKbNkkvdWMWQUVy',
#   'attempt_time': datetime.datetime(2022, 11, 20, 7, 28, 41)},
#  (1042, 4): {'request_id': 1042,
#   'leg_id': 4,
#   'reason': 'wIFeXKrPOtIhPIRVMZoDUznwSoRhjjwy',
#   'attempt_time': datetime.datetime(2022, 11, 20, 6, 28, 41)},
#  (1058, 1): {'request_id': 1058,
#   'leg_id': 1,
#   'reason': 'RUxuYdKOwnYRyZGAZqnpxNqOjgUNLMTH',
#   'attempt_time': datetime.datetime(2009, 7, 10, 6, 51, 19)},
#  (1058, 2): {'request_id': 1058,
#   'leg_id': 2,
#   'reason': 'iQGIPQVbUuaESsUtOztqOsHsCOiAnsJj',
#   'attempt_time': datetime.datetime(2009, 7, 10, 9, 51, 19)},
#  (1058, 3): {'request_id': 1058,
#   'leg_id': 3,
#   'reason': 'nuuVxHiWohBwgzoSSkJeoAyLAlMlCxvT',
#   'attempt_time': datetime.datetime(2009, 7, 10, 18, 51, 19)},
#  (1058, 4): {'request_id': 1058,
#   'leg_id': 4,
#   'reason': 'ATIkJczSeRcixcjUQSgSBrEiIMQRkReU',
#   'attempt_time': datetime.datetime(2009, 7, 10, 19, 51, 19)},
#  (1129, 1): {'request_id': 1129,
#   'leg_id': 1,
#   'reason': 'RrJjoGHofGwVtYwxUQNlsSKgkIeFrkRx',
#   'attempt_time': datetime.datetime(2015, 4, 22, 17, 5, 12)},
#  (1129, 2): {'request_id': 1129,
#   'leg_id': 2,
#   'reason': 'pJwjOeRkjcAZqvDPCyhoRjvaHUFHYuLC',
#   'attempt_time': datetime.datetime(2015, 4, 23, 4, 5, 12)},
#  (1129, 3): {'request_id': 1129,
#   'leg_id': 3,
#   'reason': 'axmbdykEVKoIwfTIKfFHYjaxPxsILVkC',
#   'attempt_time': datetime.datetime(2015, 4, 23, 8, 5, 12)},
#  (1241, 1): {'request_id': 1241,
#   'leg_id': 1,
#   'reason': 'qMkmnDsKtFBJYRGFRsBPMclPTHMINMMp',
#   'attempt_time': datetime.datetime(1991, 2, 7, 18, 22, 27)},
#  (1241, 2): {'request_id': 1241,
#   'leg_id': 2,
#   'reason': 'VkPlarspXBjuHJQTjrWsMHhZMBFWyKyh',
#   'attempt_time': datetime.datetime(1991, 2, 7, 18, 22, 27)},
#  (1241, 3): {'request_id': 1241,
#   'leg_id': 3,
#   'reason': 'isUEKTAatQFsCZqlqBnqWjbgLZZunaAR',
#   'attempt_time': datetime.datetime(1991, 2, 8, 1, 22, 27)},
#  (1281, 1): {'request_id': 1281,
#   'leg_id': 1,
#   'reason': 'bUkNLzrLZXXqLqNoPckyVpojOoexATkL',
#   'attempt_time': datetime.datetime(1991, 10, 21, 7, 41, 19)},
#  (1281, 2): {'request_id': 1281,
#   'leg_id': 2,
#   'reason': 'GDykGYSRywsVhjoUpiaglznZpnYBaGqm',
#   'attempt_time': datetime.datetime(1991, 10, 21, 8, 41, 19)},
#  (1281, 3): {'request_id': 1281,
#   'leg_id': 3,
#   'reason': 'dRUjpOayXEspqhTRDIgjwlRuVKtqOqhP',
#   'attempt_time': datetime.datetime(1991, 10, 21, 10, 41, 19)},
#  (1281, 4): {'request_id': 1281,
#   'leg_id': 4,
#   'reason': 'aGveNwqkGjsigHyKUxlFFFHTnduEJXci',
#   'attempt_time': datetime.datetime(1991, 10, 21, 22, 41, 19)},
#  (1300, 1): {'request_id': 1300,
#   'leg_id': 1,
#   'reason': 'yPhHadDGPjeoGbbRtTCZBCNKDoEwIcyx',
#   'attempt_time': datetime.datetime(1986, 7, 14, 19, 48, 47)},
#  (1378, 1): {'request_id': 1378,
#   'leg_id': 1,
#   'reason': 'vkZoahadBURHNkLbLQESjLDnfcJEutYT',
#   'attempt_time': datetime.datetime(1984, 9, 3, 8, 41, 40)},
#  (1378, 2): {'request_id': 1378,
#   'leg_id': 2,
#   'reason': 'gufyqJZWUeTRpHUMRqJvZzFAMwicNdHx',
#   'attempt_time': datetime.datetime(1984, 9, 3, 16, 41, 40)},
#  (1378, 3): {'request_id': 1378,
#   'leg_id': 3,
#   'reason': 'oSWAHmvwqdnhGdCFUjVAFHhztXAOOWIG',
#   'attempt_time': datetime.datetime(1984, 9, 4, 4, 41, 40)},
#  (1388, 1): {'request_id': 1388,
#   'leg_id': 1,
#   'reason': 'oDRCBbArBXymeudLHlDEkBiwBUicztWH',
#   'attempt_time': datetime.datetime(2013, 4, 15, 13, 43, 8)},
#  (1388, 2): {'request_id': 1388,
#   'leg_id': 2,
#   'reason': 'fdfPaIhwFMCPJwTwrcXlnnVCQGvkowcE',
#   'attempt_time': datetime.datetime(2013, 4, 15, 21, 43, 8)},
#  (1388, 3): {'request_id': 1388,
#   'leg_id': 3,
#   'reason': 'BrOHbZnJFcRSDtdzvewcOWMSFgkdyghO',
#   'attempt_time': datetime.datetime(2013, 4, 16, 1, 43, 8)},
#  (1429, 1): {'request_id': 1429,
#   'leg_id': 1,
#   'reason': 'QxIOEeuszapQdZpQLoCYDLcVfaAeSXIM',
#   'attempt_time': datetime.datetime(2015, 8, 31, 0, 47, 34)},
#  (1429, 2): {'request_id': 1429,
#   'leg_id': 2,
#   'reason': 'lcHzzrUdGsjsoTLvpjLyPBRlcyjsXSdH',
#   'attempt_time': datetime.datetime(2015, 8, 31, 1, 47, 34)},
#  (1429, 3): {'request_id': 1429,
#   'leg_id': 3,
#   'reason': 'lKIAYoCCRrxhLtuWXIQiYaMjStJBKOKD',
#   'attempt_time': datetime.datetime(2015, 8, 31, 7, 47, 34)},
#  (1429, 4): {'request_id': 1429,
#   'leg_id': 4,
#   'reason': 'PnHiVJlAaoyhbCOewrlvXqBDyzeWoFSg',
#   'attempt_time': datetime.datetime(2015, 8, 31, 11, 47, 34)},
#  (1495, 1): {'request_id': 1495,
#   'leg_id': 1,
#   'reason': 'BGgEGcAAKWRsGcqhrCnHTFSuJqsCOznG',
#   'attempt_time': datetime.datetime(1996, 2, 6, 9, 43, 52)},
#  (1495, 2): {'request_id': 1495,
#   'leg_id': 2,
#   'reason': 'IniTOKnwJQhskhRSCCtgWRrMYJdUQNqK',
#   'attempt_time': datetime.datetime(1996, 2, 6, 9, 43, 52)},
#  (1586, 1): {'request_id': 1586,
#   'leg_id': 1,
#   'reason': 'CmXAXgcYbmFzmPQxDDqzcykSwHYkzQob',
#   'attempt_time': datetime.datetime(2009, 9, 28, 5, 15, 43)},
#  (1586, 2): {'request_id': 1586,
#   'leg_id': 2,
#   'reason': 'wmgzBCiOugLIOvSpYUqhrMrIFyFsgxFL',
#   'attempt_time': datetime.datetime(2009, 9, 28, 12, 15, 43)},
#  (1586, 3): {'request_id': 1586,
#   'leg_id': 3,
#   'reason': 'DGFrjlFcAgTxtTGZilYTEIiMSdMcDlTh',
#   'attempt_time': datetime.datetime(2009, 9, 28, 15, 15, 43)},
#  (1586, 4): {'request_id': 1586,
#   'leg_id': 4,
#   'reason': 'hwREBBJVhhweEtsdWkACMirbSobicdBe',
#   'attempt_time': datetime.datetime(2009, 9, 28, 15, 15, 43)},
#  (1766, 1): {'request_id': 1766,
#   'leg_id': 1,
#   'reason': 'UXgJYsOtgfCaBsmZVuJMyhwBMpNOULAR',
#   'attempt_time': datetime.datetime(1998, 3, 26, 12, 35, 36)},
#  (1766, 2): {'request_id': 1766,
#   'leg_id': 2,
#   'reason': 'TDiwQNfCRnItqbmgFnsjaTNvJutpXNxB',
#   'attempt_time': datetime.datetime(1998, 3, 26, 19, 35, 36)},
#  (1766, 3): {'request_id': 1766,
#   'leg_id': 3,
#   'reason': 'CxBYkXIBVlQlQTjitwTgkFEAeUFCRbat',
#   'attempt_time': datetime.datetime(1998, 3, 27, 5, 35, 36)},
#  (1766, 4): {'request_id': 1766,
#   'leg_id': 4,
#   'reason': 'UYvpTjaMFnDuMBpdwlpRexuDsJaMXzlB',
#   'attempt_time': datetime.datetime(1998, 3, 27, 12, 35, 36)},
#  (1873, 1): {'request_id': 1873,
#   'leg_id': 1,
#   'reason': 'JHejKIGhbOaFRyGLJzjBoSfzqyiCAZML',
#   'attempt_time': datetime.datetime(1987, 7, 31, 23, 16, 31)},
#  (1873, 2): {'request_id': 1873,
#   'leg_id': 2,
#   'reason': 'qFFMDXWEsjpvNzoAOcWGsXnrtsDweBAt',
#   'attempt_time': datetime.datetime(1987, 8, 1, 10, 16, 31)}}

# %%
have_inserted = {
    "customers": False,
    "employees": False,
    "d_staff": False,
    "d_req": False,
    "packages": False,
    "facilities": False,
    "unsuccessful_pickups": False,
    "legs": False,
    "unsuccessful_deliveries": False,
    "return_legs": False,
    "unsuccessful_return_deliveries": False,
    "accepted_requests": False,
    "c_or_u_requests": False,
    "c_requests": False,
}

# %%
conn = connect__to_database()

# %%
# Insert these shit

def insert_table(query, t_name, record):
    try:
        conn = connect__to_database()
        cur = conn.cursor()
        cur.execute(query, record)
        conn.commit()
        count = cur.rowcount
        print(f"{count} record(s) inserted successfully into {t_name} table")
    except (Exception, psycopg2.DatabaseError) as error:
        print(error)
    finally:
        cur.close()
        if conn is not None:
            conn.close()
def insert_M_table(query, t_name, recordS):
    has_error = False
    try:
        conn = connect__to_database()
        cur = conn.cursor()
        cur.executemany(query, recordS)
        conn.commit()
        count = cur.rowcount
        print(f"{count} record(s) inserted successfully into {t_name} table")
    except (Exception, psycopg2.DatabaseError) as error:
        print(f"ERROR WHILE INSERTING INTO {t_name}: {error}")
        has_error = True
    finally:
        cur.close()
        if conn is not None:
            conn.close()
        return has_error
    
def insert_M_table_no_commit(query, t_name, recordS, conn):
    
    has_error = False
    try:
        cur = conn.cursor()
        cur.executemany(query, recordS)
#         count = cur.rowcount
#         print(f"{count} record(s) inserted successfully into {t_name} table")
#     except (Exception, psycopg2.DatabaseError) as error:
#         print(f"ERROR WHILE INSERTING INTO {t_name}: {error}")
#         has_error = True
#         if conn is not None:
#             conn.close()
    finally:
        cur.close()
        return has_error
    
# 0: {'name': 'QlIDmJDlCOKjgvLf', 'gender': 'M', 'mobile': '12942917'}
def insert_customers(rows):
    rows = [(row['name'], row['gender'], row['mobile']) for row in rows]
    sql = """INSERT INTO customers(name, gender, mobile) VALUES(%s,%s,%s)"""
#     record_to_insert = (row['name'], row['gender'], row['mobile'])
    to_ret = insert_M_table_no_commit(sql, "customers", rows, conn)
    return to_ret
def insert_employees(rows):
    rows = [(row['name'], row['gender'], row['dob'], row['title'], row['salary']) for row in rows]
    sql = """INSERT INTO employees(name, gender, dob, title, salary) VALUES(%s,%s,%s,%s,%s)"""
    to_ret = insert_M_table_no_commit(sql, "employees", rows, conn)
    return to_ret

def insert_delivery_staff(ids):
    rows = [(str(employee_id),) for employee_id in ids]
    sql = """INSERT INTO delivery_staff(id) VALUES(%s)"""
    to_ret = insert_M_table_no_commit(sql, "delivery_staff", rows, conn)
    return to_ret
def insert_delivery_requests(rows):
    rows = [(
        row["customer_id"], 
        row["evaluater_id"], 
        row["status"], 
        row["pickup_addr"], 
        row["pickup_postal"], 
        row["recipient_name"], 
        row["recipient_addr"], 
        row['recipient_postal'], 
        row["submission_time"], 
        row["pickup_date"], 
        row["num_days_needed"], 
        row["price"]
    ) 
            for row in rows]
    sql = """INSERT INTO delivery_requests(customer_id, evaluater_id, status, pickup_addr, pickup_postal, recipient_name, recipient_addr, recipient_postal, submission_time, pickup_date, num_days_needed, price) VALUES(%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s)"""
    to_ret = insert_M_table_no_commit(sql, "delivery_requests", rows, conn)
    return to_ret
def insert_packages(rows):
    sql = """INSERT INTO packages(
            request_id,
            package_id,
            reported_height, 
            reported_width, 
            reported_depth, 
            reported_weight, 
            actual_height, 
            actual_width, 
            actual_depth, 
            actual_weight, 
            content, 
            estimated_value
        ) VALUES(%s,%s, %s,%s,%s,%s,%s,%s,%s,%s,%s,%s)"""
    rows = [
        (
            row["request_id"], 
            row["package_id"], 
            row["reported_height"], 
            row["reported_width"], 
            row["reported_depth"], 
            row["reported_weight"], 
            row["actual_height"], 
            row["actual_width"], 
            row["actual_depth"], 
            row['actual_weight'], 
            row["content"], 
            row["estimated_value"]
        ) for row in rows
    ]
    to_ret = insert_M_table_no_commit(sql, "packages", rows, conn)
    return to_ret

def insert_facilities(rows):
    sql = """INSERT INTO facilities(
            address,
            postal
        ) VALUES(%s,%s)"""
    rows = [
        (
            row["address"], 
            row["postal"]
        ) for row in rows
    ]
    to_ret = insert_M_table_no_commit(sql, "facilities", rows, conn)
    return to_ret

def insert_failed_pickups(rows):
    sql = """INSERT INTO unsuccessful_pickups(
            request_id,
            pickup_id,
            handler_id,
            pickup_time,
            reason
        ) VALUES(%s,%s,%s,%s,%s)"""
    rows = [
        (
            row["request_id"], 
            row["pickup_id"], 
            row["handler_id"], 
            row["pickup_time"], 
            row["reason"]
        ) for row in rows
    ]
    to_ret = insert_M_table_no_commit(sql, "unsuccessful_pickups", rows, conn)
    return to_ret

def insert_legs(rows):
    sql = """INSERT INTO legs(
            request_id,
            leg_id,
            handler_id,
            start_time,
            end_time,
            destination_facility
        ) VALUES(%s,%s,%s,%s,%s,%s)"""
    rows = [
        (
            row["request_id"], 
            str(row["leg_id"]), 
            row["handler_id"], 
            row["start_time"], 
            row["end_time"], 
            row["destination_facility"]
        ) for row in rows
    ]
    to_ret = insert_M_table_no_commit(sql, "legs", rows, conn)
    return to_ret
    
def insert_unsuccessful_deliveries(rows):
    sql = """INSERT INTO unsuccessful_deliveries(
            request_id,
            leg_id,
            attempt_time,
            reason
        ) VALUES(%s,%s,%s,%s)"""
    rows = [
        (
            row["request_id"], 
            row["leg_id"], 
            row["attempt_time"], 
            row["reason"]
        ) for row in rows
    ]
    to_ret = insert_M_table_no_commit(sql, "unsuccessful_deliveries", rows, conn)
    
def insert_return_legs(rows):
    sql = """INSERT INTO return_legs(
            request_id,
            leg_id,
            handler_id,
            start_time,
            end_time,
            source_facility
        ) VALUES(%s,%s,%s,%s,%s,%s)"""
    rows = [
        (
            str(row["request_id"]), 
            str(row["leg_id"]), 
            str(row["handler_id"]), 
            row["start_time"], 
            row["end_time"], 
            row["source_facility"]
        ) for row in rows
    ]
    to_ret = insert_M_table_no_commit(sql, "legs", rows, conn)
    return to_ret
    
def insert_u_return_deliveries(rows):
    sql = """INSERT INTO unsuccessful_return_deliveries(
            request_id,
            leg_id,
            attempt_time,
            reason
        ) VALUES(%s,%s,%s,%s)"""
    rows = [
        (
            str(row["request_id"]), 
            str(row["leg_id"]), 
            row["attempt_time"], 
            row["reason"]
        ) for row in rows
    ]
    to_ret = insert_M_table_no_commit(sql, "unsuccessful_return_deliveries", rows, conn)
    return to_ret

def insert_accepeted_requests(rows):
    sql = """INSERT INTO accepted_requests(
            id,
            card_number,
            payment_time,
            monitor_id
        ) VALUES(%s,%s,%s,%s)"""
    rows = [
        (
            str(row["id"]), 
            row["card_number"], 
            row["payment_time"], 
            row["monitor_id"]
        ) for row in rows
    ]
    to_ret = insert_M_table_no_commit(sql, "accepted_requests", rows, conn)
    return to_ret
    
def insert_c_or_u_requests(ids):
    sql = """INSERT INTO cancelled_or_unsuccessful_requests(
            id
        ) VALUES(%s)"""
    rows = [
        (
            str(c_u_id),
        ) for c_u_id in ids
    ]
    to_ret = insert_M_table_no_commit(sql, "cancelled_or_unsuccessful_requests", rows, conn)
    return to_ret

def insert_c_requests(rows):
    sql = """INSERT INTO cancelled_requests(
            id,
            cancel_time
        ) VALUES(%s,%s)"""
    rows = [
        (
            str(row["id"]), 
            row["cancel_time"]
        ) for row in rows
    ]
    to_ret = insert_M_table_no_commit(sql, "cancelled_requests", rows, conn)
    return to_ret

def test_inserts():
    if not have_inserted['customers']:
        have_inserted['customers'] = not insert_customers(customers.values())
    if not have_inserted['employees']:
        have_inserted['employees'] = not insert_employees(employee.values())
    if not have_inserted['d_staff']:
        to_insert = [k for k,v in employee.items() if v['is_delivery']]
        have_inserted['d_staff'] = not insert_delivery_staff(to_insert)
        
    if not have_inserted['d_req']:
        have_inserted['d_req'] = not insert_delivery_requests(delivery_requests.values())
    if not have_inserted['accepted_requests']:
        accepted_req_id
        have_inserted['accepted_requests'] = not insert_accepeted_requests([
          {
            "id":k,
            **v
          }  for k,v in delivery_requests.items() if k in accepted_req_id
        ])
    
    if not have_inserted['c_or_u_requests']:
        accepted_req_id
        have_inserted['c_or_u_requests'] = not insert_c_or_u_requests(list(cancelled_or_unsuccessful_requests_id))
        
    if not have_inserted['c_requests']:
        accepted_req_id
        have_inserted['c_requests'] = not insert_c_requests([
          {
            "id":k,
            "cancel_time": v['cancel_time']
          }  for k,v in delivery_requests.items() if 'cancel_time' in v
        ])
    if not have_inserted['packages']:
        have_inserted['packages'] = not insert_packages(packages.values())
    if not have_inserted['facilities']:
        have_inserted['facilities'] = not insert_facilities(facilities.values())
    if not have_inserted['unsuccessful_pickups']:
        have_inserted['unsuccessful_pickups'] = not insert_failed_pickups(failed_pickups.values())
        
    if not have_inserted['legs']:
        have_inserted['legs'] = not insert_legs([
            {
                "leg_id":k,
                **v
            } for k,v in legs.items()
        ])
        
    if not have_inserted['unsuccessful_deliveries']:
        have_inserted['unsuccessful_deliveries'] = not insert_unsuccessful_deliveries(unsuccessful_deliveries.values())
        
    if not have_inserted['return_legs']:
        have_inserted['return_legs'] = not insert_return_legs(return_legs.values())
        
    if not have_inserted['unsuccessful_return_deliveries']:
        have_inserted['unsuccessful_return_deliveries'] = not insert_u_return_deliveries(unsuccessful_return_deliveries.values())

# %%
test_inserts()
# Rmb to clear the database after runnign this

# %%
conn.commit()

# %%
conn.close()

# %%
# Unsuccessful_deliveries

"""
(11, 1): {'request_id': 11,
  'leg_id': 1,
  'reason': 'asdTWDciwEreMSQfvopmFOsbwgEtLndb',
  'attempt_time': datetime.datetime(1982, 8, 28, 23, 1, 49)}

"""

# Test Q4

pos_count = 2
neg_count = 2

conn = connect__to_database()

first = list(unsuccessful_deliveries.keys())[0]

cur_request = first[0]
cur_leg = first[1]
cur_test = False

for k in unsuccessful_deliveries.keys():
    print(f"pos_count {pos_count}, neg_count {neg_count}")
    if pos_count == 0 and neg_count == 0:
        break
#     print(k)
    req = k[0]
    leg = k[1]
    if (cur_request != req):
        try:
            u_del = unsuccessful_deliveries[k]
            print(cur_request, cur_leg)
            print(f"cur_test: {cur_test}")
            if cur_leg == 3:
                continue
            else:
                old_leg_end_time = legs[(cur_request, cur_leg)]["end_time"]
                if old_leg_end_time == None:
                    continue
                new_leg = cur_leg + 1
                new_leg_start = old_leg_end_time + timedelta(hours=get_random_int_to(3,24))
                new_leg_end = new_leg_start + timedelta(hours=get_random_int_to(3,24))
                insert_legs([
                    {
                        "request_id": cur_request,
                        "leg_id": new_leg,
                        "handler_id": random.choice(list(delivery_staff_id)) ,
                        "start_time": new_leg_start ,
                        "end_time": new_leg_end ,
                        "destination_facility": random.choice(list(facilities.keys())) ,
                    }
                ])
                if cur_test:
                    # positive
                    insert_unsuccessful_deliveries([
                        {
                            "request_id": cur_request,
                            "leg_id": new_leg,
                            "attempt_time": new_leg_end + timedelta(hours=get_random_int_to(3,24)),
                            "reason": f"POS_test_{pos_count}"
                        }
                    ])
                    pos_count -= 1
                else:
                    # negative
                    insert_unsuccessful_deliveries([
                        {
                            "request_id": cur_request,
                            "leg_id": new_leg,
                            "attempt_time": new_leg_start,
                            "reason": f"POS_test_{pos_count}"
                        }
                    ])
                    neg_count -= 1
            conn.commit()
#             cur_request = req
        except (Exception, psycopg2.DatabaseError) as error:
            print("Met error!")
            assert(cur_test == False) # Ideally shouldnt crash
            print("Cleared error~")
#             cur_test = True
        print(f"Toggling values")
        cur_test = not cur_test
        cur_request = req
    cur_leg = leg
conn.close()
# Out:
# pos_count 2, neg_count 2
# pos_count 2, neg_count 2
# 5 1
# cur_test: False
# pos_count 2, neg_count 2
# 5 1
# cur_test: False
# pos_count 2, neg_count 2
# 5 1
# cur_test: False
# pos_count 2, neg_count 2
# 5 1
# cur_test: False
# pos_count 2, neg_count 2
# 5 1
# cur_test: False
# pos_count 2, neg_count 2
# 5 1
# cur_test: False
# pos_count 2, neg_count 2
# 5 1
# cur_test: False
# pos_count 2, neg_count 2
# 5 1
# cur_test: False
# pos_count 2, neg_count 2
# 5 1
# cur_test: False
# pos_count 2, neg_count 2
# 5 1
# cur_test: False
# pos_count 2, neg_count 2
# 5 1
# cur_test: False
# pos_count 2, neg_count 2
# 5 1
# cur_test: False
# pos_count 2, neg_count 2
# 5 1
# cur_test: False
# pos_count 2, neg_count 2
# 5 1
# cur_test: False
# pos_count 2, neg_count 2
# 5 1
# cur_test: False
# pos_count 2, neg_count 2
# 5 1
# cur_test: False
# pos_count 2, neg_count 2
# 5 1
# cur_test: False
# pos_count 2, neg_count 2
# 5 1
# cur_test: False
# pos_count 2, neg_count 2
# 5 1
# cur_test: False
# pos_count 2, neg_count 2
# 5 1
# cur_test: False
# pos_count 2, neg_count 2
# 5 1
# cur_test: False
# pos_count 2, neg_count 2
# 5 1
# cur_test: False
# pos_count 2, neg_count 2
# 5 1
# cur_test: False
# pos_count 2, neg_count 2
# 5 1
# cur_test: False

# %%
# Unsuccessful_deliveries

"""
(11, 1): {'request_id': 11,
  'leg_id': 1,
  'reason': 'asdTWDciwEreMSQfvopmFOsbwgEtLndb',
  'attempt_time': datetime.datetime(1982, 8, 28, 23, 1, 49)}

"""

# Test Q5

pos_count = 2
neg_count = 2

conn = connect__to_database()

first = list(unsuccessful_deliveries.keys())[0]

print(f"first: {first}")

cur_request = first[0]
cur_leg = first[1]

print(cur_request, cur_leg)

for k in unsuccessful_deliveries.keys():
    print(f"pos_count {pos_count}, neg_count {neg_count}")
    if pos_count == 0 and neg_count == 0:
        break
    req = k[0]
    leg = k[1]
#     print(f"req: {req}")
#     print(f"leg: {leg}")
    if (cur_request != req):
        cur_test = False
        try:
            u_del = unsuccessful_deliveries[k]
            print(k)
            print(f"cur_leg: {cur_leg}")
            # Check if can violate
            if cur_leg == 3:
                neg_count -= 1
                status = insert_unsuccessful_deliveries([
                    {
                        "request_id": cur_request,
                        "leg_id": cur_leg + 1,
                        "attempt_time": u_del["attempt_time"] + timedelta(hours=get_random_int_to(3,24)),
                        "reason": f"NEG_test_{neg_count}"
                    }
                ])
            else:
                old_leg_end_time = legs[(cur_request, cur_leg)]["end_time"]
                if old_leg_end_time == None:
                    #  skip null ones first
                    continue
                new_leg = cur_leg + 1
                new_leg_start = old_leg_end_time + timedelta(hours=get_random_int_to(3,24))
                new_leg_end = new_leg_start + timedelta(hours=get_random_int_to(3,24))
                insert_legs([
                    {
                        "request_id": cur_request,
                        "leg_id": new_leg,
                        "handler_id": random.choice(list(delivery_staff_id)) ,
                        "start_time": new_leg_start ,
                        "end_time": new_leg_end ,
                        "destination_facility": random.choice(list(facilities.keys())) ,
                    }
                ])
                insert_unsuccessful_deliveries([
                    {
                        "request_id": cur_request,
                        "leg_id": new_leg,
                        "attempt_time": new_leg_end + timedelta(hours=get_random_int_to(3,24)),
                        "reason": f"POS_test_{pos_count}"
                    }
                ])
                cur_test = True
                pos_count -= 1
            conn.commit()
            cur_request = req
        except (Exception, psycopg2.DatabaseError) as error:
            print("Met error!")
            assert(cur_test == False) # Ideally shouldnt crash
            print("Cleared error~")
            cur_test = True
        
    cur_leg = leg
    
conn.close()
# Out:
# first: (5, 1)
# 5 1
# pos_count 2, neg_count 2
# pos_count 2, neg_count 2
# (8, 1)
# cur_leg: 1
# pos_count 2, neg_count 2
# (14, 1)
# cur_leg: 1
# pos_count 2, neg_count 2
# (14, 2)
# cur_leg: 1
# pos_count 2, neg_count 2
# (14, 3)
# cur_leg: 1
# pos_count 2, neg_count 2
# (17, 1)
# cur_leg: 1
# pos_count 2, neg_count 2
# (17, 2)
# cur_leg: 1
# pos_count 2, neg_count 2
# (17, 3)
# cur_leg: 1
# pos_count 2, neg_count 2
# (18, 1)
# cur_leg: 1
# pos_count 2, neg_count 2
# (18, 2)
# cur_leg: 1
# pos_count 2, neg_count 2
# (20, 1)
# cur_leg: 1
# pos_count 2, neg_count 2
# (20, 2)
# cur_leg: 1
# pos_count 2, neg_count 2
# (20, 3)
# cur_leg: 1
# pos_count 2, neg_count 2
# (24, 1)
# cur_leg: 1
# pos_count 2, neg_count 2
# (24, 2)
# cur_leg: 1
# pos_count 2, neg_count 2
# (24, 3)
# cur_leg: 1
# pos_count 2, neg_count 2
# (25, 1)
# cur_leg: 1
# pos_count 2, neg_count 2
# (25, 2)
# cur_leg: 1
# pos_count 2, neg_count 2
# (25, 3)
# cur_leg: 1
# pos_count 2, neg_count 2
# (29, 1)
# cur_leg: 1
# pos_count 2, neg_count 2
# (29, 2)
# cur_leg: 1
# pos_count 2, neg_count 2
# (29, 3)
# cur_leg: 1
# pos_count 2, neg_count 2
# (32, 1)
# cur_leg: 1
# pos_count 2, neg_count 2
# (32, 2)
# cur_leg: 1
# pos_count 2, neg_count 2
# (32, 3)
# cur_leg: 1

# %%
len(accepted_req_id)
# Out:
# 1143

# %%
# Cancelled_requests

# Test Q6

pos_count = 2
neg_count = 2

cur_test = False

conn = connect__to_database()

reqs_to_cancel = [k for k in accepted_req_id if not is_cancelled(delivery_requests[k]["status"])]
print(len(reqs_to_cancel))

for req_id in reqs_to_cancel:
    print(f"req_id: {req_id}")
    try:
        
        if pos_count == 0 and neg_count == 0:
            break
        insert_c_or_u_requests([
            req_id
        ])
        sub_time = delivery_requests[req_id]["submission_time"]
        print(f"sub_time: {sub_time}")
        
        cancel_time = sub_time
        if cur_test:
            pos_count -= 1
            cancel_time += timedelta(hours=get_random_int_to(3,24))
        else:
            neg_count -= 1
        print(f"cancel_time: {cancel_time}")
        
            
        insert_c_requests([
          {
            "id":req_id,
            "cancel_time": cancel_time
          }  
        ])
        conn.commit()
        cur_test = not cur_test
    except (Exception, psycopg2.DatabaseError) as error:
        print("Met error!")
        assert(cur_test == False) # Ideally shouldnt crash
        print("Cleared error~")
        cur_test = True
        
# cur_request = first[0]

conn.close()
# Out:
# 852
# req_id: 2
# sub_time: 2005-10-26 16:36:41
# cancel_time: 2005-10-26 16:36:41
# req_id: 3
# sub_time: 1979-11-02 10:55:59
# cancel_time: 1979-11-03 02:55:59
# req_id: 8
# sub_time: 1970-08-18 02:04:45
# cancel_time: 1970-08-18 02:04:45
# req_id: 12
# sub_time: 1989-08-29 15:06:50
# cancel_time: 1989-08-30 02:06:50
# req_id: 13

# %%
conn.close()

# %%
k = 4
conn = connect__to_database()

cursor = conn.cursor()


cursor.callproc('get_top_connections',[k,])
print(f"Fetching top {k} connections")

result = cursor.fetchall()
print(result)
for row in result:
    print(row)

conn.close()
# Out:
# Fetching top 4 connections
# [(2, 2), (7, 4), (2, 8), (2, 3)]
# (2, 2)
# (7, 4)
# (2, 8)
# (2, 3)

# %%
src_dest_cnts = {} # (src, dest) -> int
rl_keys = list(legs.keys())
rl_values = list(legs.values())
for i in range(len(rl_keys)-1):
    prev_id = rl_keys[i]
    next_id = rl_keys[i + 1]
    prev_leg = legs[prev_id]
    next_leg = legs[next_id]
    pair = (prev_leg['destination_facility'],next_leg['destination_facility'])
    if pair not in src_dest_cnts:
        src_dest_cnts[pair] = 0
    src_dest_cnts[pair] += 1
rl_keys = list(return_legs.keys())
rl_values = list(return_legs.values())
for i in range(len(rl_keys)-1):
    prev_id = rl_keys[i]
    next_id = rl_keys[i + 1]
    prev_leg = return_legs[prev_id]
    next_leg = return_legs[next_id]
    pair = (prev_leg['source_facility'],next_leg['source_facility'])
    if pair not in src_dest_cnts:
        src_dest_cnts[pair] = 0
    src_dest_cnts[pair] += 1

# %%
src_dest_cnts.items()
# Out:
# dict_items([((2, 9), 23), ((9, 7), 13), ((7, 8), 16), ((8, 10), 18), ((10, 5), 27), ((5, 3), 19), ((3, 7), 22), ((8, 1), 22), ((1, 9), 23), ((9, 5), 23), ((5, 4), 35), ((4, 1), 28), ((9, 8), 24), ((10, 8), 22), ((8, 8), 27), ((8, 4), 28), ((4, 10), 28), ((10, 6), 26), ((6, 10), 20), ((10, 1), 18), ((1, 2), 24), ((2, 3), 31), ((3, 3), 18), ((3, 10), 28), ((6, 9), 19), ((4, 4), 21), ((4, 2), 24), ((2, 8), 33), ((9, 3), 16), ((3, 5), 18), ((4, 6), 22), ((6, 6), 22), ((6, 8), 24), ((10, 9), 20), ((9, 4), 16), ((1, 6), 27), ((6, 5), 17), ((6, 7), 22), ((7, 4), 34), ((7, 3), 21), ((3, 1), 20), ((1, 3), 18), ((3, 2), 25), ((1, 4), 20), ((4, 5), 30), ((5, 6), 23), ((5, 8), 22), ((8, 7), 28), ((7, 1), 22), ((10, 3), 24), ((2, 4), 27), ((2, 6), 20), ((6, 2), 30), ((2, 1), 26), ((4, 9), 18), ((9, 9), 22), ((7, 6), 23), ((3, 9), 18), ((9, 6), 22), ((6, 3), 19), ((10, 10), 22), ((1, 8), 13), ((3, 8), 21), ((8, 5), 23), ((5, 9), 17), ((2, 2), 26), ((2, 7), 20), ((3, 6), 16), ((10, 2), 32), ((2, 5), 17), ((9, 1), 20), ((1, 1), 20), ((7, 7), 29), ((4, 8), 24), ((8, 2), 19), ((9, 10), 24), ((5, 1), 11), ((3, 4), 16), ((4, 7), 28), ((7, 9), 13), ((1, 10), 22), ((7, 10), 22), ((9, 2), 16), ((8, 9), 23), ((4, 3), 19), ((6, 4), 25), ((8, 3), 16), ((10, 7), 28), ((1, 7), 20), ((8, 6), 21), ((2, 10), 25), ((5, 2), 22), ((7, 2), 30), ((7, 5), 23), ((5, 5), 20), ((6, 1), 24), ((10, 4), 20), ((5, 10), 30), ((5, 7), 23), ((1, 5), 24)])

# %%
actual_results = sorted(src_dest_cnts.items(), key=lambda x:x[1], reverse=True)

# %%
actual_results
# Out:
# [((5, 4), 35),
#  ((7, 4), 34),
#  ((2, 8), 33),
#  ((10, 2), 32),
#  ((2, 3), 31),
#  ((4, 5), 30),
#  ((6, 2), 30),
#  ((7, 2), 30),
#  ((5, 10), 30),
#  ((7, 7), 29),
#  ((4, 1), 28),
#  ((8, 4), 28),
#  ((4, 10), 28),
#  ((3, 10), 28),
#  ((8, 7), 28),
#  ((4, 7), 28),
#  ((10, 7), 28),
#  ((10, 5), 27),
#  ((8, 8), 27),
#  ((1, 6), 27),
#  ((2, 4), 27),
#  ((10, 6), 26),
#  ((2, 1), 26),
#  ((2, 2), 26),
#  ((3, 2), 25),
#  ((6, 4), 25),
#  ((2, 10), 25),
#  ((9, 8), 24),
#  ((1, 2), 24),
#  ((4, 2), 24),
#  ((6, 8), 24),
#  ((10, 3), 24),
#  ((4, 8), 24),
#  ((9, 10), 24),
#  ((6, 1), 24),
#  ((1, 5), 24),
#  ((2, 9), 23),
#  ((1, 9), 23),
#  ((9, 5), 23),
#  ((5, 6), 23),
#  ((7, 6), 23),
#  ((8, 5), 23),
#  ((8, 9), 23),
#  ((7, 5), 23),
#  ((5, 7), 23),
#  ((3, 7), 22),
#  ((8, 1), 22),
#  ((10, 8), 22),
#  ((4, 6), 22),
#  ((6, 6), 22),
#  ((6, 7), 22),
#  ((5, 8), 22),
#  ((7, 1), 22),
#  ((9, 9), 22),
#  ((9, 6), 22),
#  ((10, 10), 22),
#  ((1, 10), 22),
#  ((7, 10), 22),
#  ((5, 2), 22),
#  ((4, 4), 21),
#  ((7, 3), 21),
#  ((3, 8), 21),
#  ((8, 6), 21),
#  ((6, 10), 20),
#  ((10, 9), 20),
#  ((3, 1), 20),
#  ((1, 4), 20),
#  ((2, 6), 20),
#  ((2, 7), 20),
#  ((9, 1), 20),
#  ((1, 1), 20),
#  ((1, 7), 20),
#  ((5, 5), 20),
#  ((10, 4), 20),
#  ((5, 3), 19),
#  ((6, 9), 19),
#  ((6, 3), 19),
#  ((8, 2), 19),
#  ((4, 3), 19),
#  ((8, 10), 18),
#  ((10, 1), 18),
#  ((3, 3), 18),
#  ((3, 5), 18),
#  ((1, 3), 18),
#  ((4, 9), 18),
#  ((3, 9), 18),
#  ((6, 5), 17),
#  ((5, 9), 17),
#  ((2, 5), 17),
#  ((7, 8), 16),
#  ((9, 3), 16),
#  ((9, 4), 16),
#  ((3, 6), 16),
#  ((3, 4), 16),
#  ((9, 2), 16),
#  ((8, 3), 16),
#  ((9, 7), 13),
#  ((1, 8), 13),
#  ((7, 9), 13),
#  ((5, 1), 11)]
